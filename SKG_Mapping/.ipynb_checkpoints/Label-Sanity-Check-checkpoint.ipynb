# %% [markdown]
# # Label Sanity Check
#
# Before running any graphing notebooks, verify that the label columns in each partner's map files match
# the canonical label from the authoritative source (MONDO via OLS4, UniProt, PubChem).
#
# **Run order (per partner, in order Radboud → Biovista → Demokritos):**
# 1. Genes ← can run any time
# 2. Drugs ← can run any time
# 3. Diseases ← run ONLY after the disease map has been regenerated/patched with canonical MONDO labels
#
# A `✓` means the map label and the API canonical label match (case-insensitive).
# A `✗` means they differ — both values are printed so you can judge whether the difference matters.

# %%
require 'csv'
require 'net/http'
require 'json'
require 'uri'

SAMPLE_SIZE = 10
srand(42)  # reproducible random sample

# ── MONDO label via EBI OLS4 ────────────────────────────────────────────────
def get_mondo_label(mondo_uri)
  local = mondo_uri.match(/MONDO_\d+/)&.to_s
  return "no MONDO ID in: #{mondo_uri}" unless local
  iri     = "http://purl.obolibrary.org/obo/#{local}"
  encoded = URI.encode_uri_component(URI.encode_uri_component(iri))
  resp    = Net::HTTP.get_response(URI("https://www.ebi.ac.uk/ols4/api/ontologies/mondo/terms/#{encoded}"))
  return "OLS4 #{resp.code}" unless resp.is_a?(Net::HTTPSuccess)
  JSON.parse(resp.body)['label'] || '(no label in OLS4 response)'
rescue => e
  "error: #{e.message}"
end

# ── UniProt recommended full name ───────────────────────────────────────────
def get_uniprot_label(protein_uri)
  acc = protein_uri.to_s.match(/uniprot\/([A-Z0-9]+)/)&.[](1)
  return "no accession in: #{protein_uri}" unless acc
  resp = Net::HTTP.get_response(URI("https://rest.uniprot.org/uniprotkb/#{acc}?format=json"))
  return "UniProt #{resp.code}" unless resp.is_a?(Net::HTTPSuccess)
  data = JSON.parse(resp.body)
  data.dig('proteinDescription', 'recommendedName', 'fullName', 'value') ||
    data.dig('proteinDescription', 'submissionNames', 0, 'fullName', 'value') ||
    '(no recommended name in UniProt response)'
rescue => e
  "error: #{e.message}"
end

# ── PubChem IUPAC name ───────────────────────────────────────────────────────
def get_pubchem_iupac(cid_value)
  num = cid_value.to_s.match(/(\d+)/)&.[](1)
  return "no CID in: #{cid_value}" unless num
  resp = Net::HTTP.get_response(URI("https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/#{num}/property/IUPACName/JSON"))
  return "PubChem #{resp.code}" unless resp.is_a?(Net::HTTPSuccess)
  JSON.parse(resp.body).dig('PropertyTable', 'Properties', 0, 'IUPACName') || '(no IUPAC name in PubChem response)'
rescue => e
  "error: #{e.message}"
end

# ── Generic sampler + reporter ───────────────────────────────────────────────
def check_labels(rows, label_col:, id_col:, &lookup)
  usable = rows.reject { |r| r[id_col].to_s.strip.empty? || r[label_col].to_s.strip.empty? }
  if usable.empty?
    puts "  (no usable rows — map may be empty or not yet generated)"
    return
  end
  sample = usable.sample([SAMPLE_SIZE, usable.size].min)
  matches = 0
  sample.each do |row|
    map_label = row[label_col].to_s.strip
    canonical = lookup.call(row[id_col].to_s.strip)
    ok = map_label.downcase == canonical.downcase
    matches += 1 if ok
    if ok
      puts "  ✓  #{map_label}"
    else
      puts "  ✗  MAP: #{map_label}"
      puts "     CAN: #{canonical}"
    end
    sleep 0.3  # be polite to public APIs
  end
  puts "  → #{matches}/#{sample.size} exact matches (case-insensitive)"
end

puts "Setup complete. SAMPLE_SIZE=#{SAMPLE_SIZE}"

# %% [markdown]
# ---
# ## Radboud

# %%
# Radboud genes — label column should equal recommended_full (UniProt)
# Map columns: sourceid, label, geneid, protein, recommended_full, taxon
# Graphing notebook uses: gene['label'] for NCBI gene URI label
rows = CSV.read('./radboud/maps/genes.map', headers: true).to_a.map(&:to_h)
puts "Radboud genes — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'label', id_col: 'protein') { |uri| get_uniprot_label(uri) }

# %%
# Radboud drugs — IUPACname column should match PubChem canonical IUPAC
# Map columns: chembl, label, CID, IUPACname
# Graphing notebook uses: drug['IUPACname']
rows = CSV.read('./radboud/maps/drugs.map', headers: true).to_a.map(&:to_h)
puts "Radboud drugs — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'IUPACname', id_col: 'CID') { |cid| get_pubchem_iupac(cid) }

# %%
# Radboud diseases — prefname column should match MONDO canonical prefLabel
# Map columns: source, mondo, prefname
# Graphing notebook uses: disease['prefname']
# *** RUN ONLY AFTER map_diseases-mondo.ipynb finishes regenerating diseases.map ***
rows = CSV.read('./radboud/maps/diseases.map', headers: true).to_a.map(&:to_h)
puts "Radboud diseases — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'prefname', id_col: 'mondo') { |uri| get_mondo_label(uri) }

# %% [markdown]
# ---
# ## Biovista

# %%
# Biovista genes — recommended_full column should match UniProt
# Map columns: bv_geneid, bv_label, geneid, protein, recommended_full, taxon
# Graphing notebooks use: gene['recommended_full']
rows = CSV.read('./biovista/maps/2025-biovista-genes.map', headers: true).to_a.map(&:to_h)
puts "Biovista genes — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'recommended_full', id_col: 'protein') { |uri| get_uniprot_label(uri) }

# %%
# Biovista drugs — IUPACname column should match PubChem
# Map columns: biovista_meshid, biovista_label, CID, IUPACname
# Graphing notebooks use: drug['IUPACname']
rows = CSV.read('./biovista/maps/2025-biovista-drugs.map', headers: true).to_a.map(&:to_h)
puts "Biovista drugs — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'IUPACname', id_col: 'CID') { |cid| get_pubchem_iupac(cid) }

# %%
# Biovista diseases — name column should match MONDO canonical prefLabel
# Map columns: biovista_umls, orphanet, snomed, name, mondo
# Graphing notebooks use: disease['name'] (or disease_line['name'])
# *** RUN ONLY AFTER biovista-diseases-2026-Mondo.ipynb patch cell has been run ***
rows = CSV.read('./biovista/maps/2026-biovista-disease-mondo.map', headers: true).to_a.map(&:to_h)
puts "Biovista diseases — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'name', id_col: 'mondo') { |uri| get_mondo_label(uri) }

# %% [markdown]
# ---
# ## Demokritos

# %%
# Demokritos genes — recommended_full column should match UniProt
# Map columns: source, label, geneid, protein, recommended_full, taxon
# Graphing notebooks use: gene['recommended_full']
rows = CSV.read('./demokritos/maps/2026-gene-mappings.map', headers: true).to_a.map(&:to_h)
puts "Demokritos genes — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'recommended_full', id_col: 'protein') { |uri| get_uniprot_label(uri) }

# %%
# Demokritos drugs — IUPACname column should match PubChem
# Map columns: demokritosid, xref, pubchem_cid, IUPACname
# Note: pubchem_cid is a full URI, e.g. https://pubchem.ncbi.nlm.nih.gov/compound/547
# Graphing notebooks use: drug['IUPACname']
rows = CSV.read('./demokritos/maps/2026-drug-mappings.map', headers: true).to_a.map(&:to_h)
puts "Demokritos drugs — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'IUPACname', id_col: 'pubchem_cid') { |cid| get_pubchem_iupac(cid) }

# %%
# Demokritos diseases — prefname column should match MONDO canonical prefLabel
# Map columns: demokritos_umls, prefname, mondo
# Graphing notebooks use: disease['prefname']
# *** RUN ONLY AFTER 2026-Disease Mapping.ipynb patch cell has been run ***
rows = CSV.read('./demokritos/maps/2026-demokritos-disease-mondo.map', headers: true).to_a.map(&:to_h)
puts "Demokritos diseases — #{rows.size} rows, sampling #{[SAMPLE_SIZE, rows.size].min}"
check_labels(rows, label_col: 'prefname', id_col: 'mondo') { |uri| get_mondo_label(uri) }
