# %% [markdown]
# # Map Diseases Radboud -> MONDO
#
# # Strategy
#
# Diseases have been extracted from the three files that contain disease references.
#
# This is disease.list.uniq
#
# There's all kinds of namespaces in there... a bit of a mess!
#
# Here we will try to map into MONDO.  In some cases, the disease reference is already MONDO, so that's good!  Other namespaces that I think we can mange are:  EFO (sometimes), DOID, and Orphanet

# %%
# puts `head -20 disease.list.uniq`
# puts `grep MONDO disease.list.uniq | head -20`
puts ENV["OBOAPIKEY"]
# Out:
# 74027bd8-6be0-4329-be22-aa3717f97243

# %%
require 'rest-client'
require 'json'

def map_id_to_disease(name)
    name.strip!
    # warn "mapping #{name}"
  return false unless (name =~ /EFO_/ || name =~ /DOID_(.*)/ || name =~ /MONDO_(.*)/ || name =~ /Orphanet_(.*)/)
  identifier = $1  #W dfrom the match above
  api_key = ENV["OBOAPIKEY"] # Replace with BioPortal API key
  begin
    if name =~ /DOID/
      url =  "https://data.bioontology.org/search?q=DOID:#{identifier}&ontologies=DOID&require_exact_match=true&apikey=#{api_key}"
    elsif name =~ /MONDO/
      url =  "https://data.bioontology.org/search?q=MONDO:#{identifier}&ontologies=MONDO&require_exact_match=true&apikey=#{api_key}"      
    else
      url =  "https://data.bioontology.org/search?q=Orphanet:#{identifier}&ontologies=ORDO&require_exact_match=true&apikey=#{api_key}"
    end
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    # warn "No data found for #{name} #{e.inspect}\n"
    return false
  end
  mappings = []
  data = JSON.parse(response)

#  if hit = data.dig('collection', 0)
  if hit = data.dig('collection')
    hit.each do |h|
      disease_name = h&.dig('prefLabel')
      uri = h&.dig('@id')
      linksurl = h&.dig('links', 'mappings')
      mappings << { id: name, uri: uri, disease_name: disease_name, linksurl: linksurl}
    end
    return mappings
  else
    # warn "No data found for #{name}\n"
    return false
  end

rescue StandardError => e
  # warn "No data found for #{name} Error: #{e.inspect}\n"
  return false
end

# test
["DOID_7551", "MONDO_0000070", "Orphanet_10", "Orphanet_22"].each do |name|
  warn map_id_to_disease(name)  # returns array
end
# Out:
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings"}
# {:id=>"MONDO_0000070", :uri=>"http://purl.obolibrary.org/obo/MONDO_0000070", :disease_name=>"Mycobacterium tuberculosis, susceptibility", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0000070/mappings"}
# {:id=>"Orphanet_10", :uri=>"http://www.orpha.net/ORDO/Orphanet_10", :disease_name=>"48,XXYY syndrome", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_10/mappings"}
# {:id=>"Orphanet_22", :uri=>"http://www.orpha.net/ORDO/Orphanet_22", :disease_name=>"Succinic semialdehyde dehydrogenase deficiency", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_22/mappings"}
# ["DOID_7551", "MONDO_0000070", "Orphanet_10", "Orphanet_22"]

# %%
def get_mondo_from_mapping(mapping)
  api_key = ENV["OBOAPIKEY"] # Replace with BioPortal API key
    
  begin
    url = mapping+"?apikey=#{api_key}"
     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    # warn "No data found for mapping #{e.inspect}\n"
    return false
  end
    mappings = []
    data = JSON.parse(response)

    data.each do |mapp|
      mapp["classes"].each do |thisclass|
        next unless thisclass["@id"] =~ /MONDO/
        return {"mondo": thisclass["@id"]}
      end
    end
    # warn "no MONDO found for DOID/ORDO/MONDO #{mapping}"
    return false

rescue StandardError => e
  # warn  "parsing or other error in #{mapping} Error: #{e.inspect}\n"
  return false
end

# test
[
     "DOID_7551", 
    # "MONDO_0000070", 
    #"Orphanet_22",
].each do |name|
  results = map_id_to_disease(name)  # this returns a hash
    warn results
  if results
    results = results.first # (can only be one)
    nextres = get_mondo_from_mapping(results[:linksurl])
    warn nextres
    if nextres
      results.merge! nextres
    end
    puts results
  else
    warn "found no results for #{name}"
  end
end
# Out:
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings"}
# https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# {:mondo=>"http://purl.obolibrary.org/obo/MONDO_0004277"}
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0004277"}
# ["DOID_7551"]

# %% [markdown]
# ## Special Case EFO
# sometimes can find efo -> MONDO

# %%
require 'rest-client'
require 'json'

def special_case_efo_to_mondo(efo)
        efo.strip!
    # warn "**#{efo}**"

    api_key = ENV["OBOAPIKEY"]
    url = "https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2F#{efo}?apikey=#{api_key}"
    # warn url
    headers = {
    "Accept"     => "application/json",
    "User-Agent" => "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
    }

    begin
        response = RestClient.get(url, headers: headers)
#         warn response
    rescue
        warn "step 1 EFO Lookup failed"
        return false
    end
    
    data = JSON.parse(response.body)
    mondo = ""

    if prefname = data.dig('prefLabel')
        # warn "MATCHING #{prefname}"
        url2 = "https://data.bioontology.org/search?q=#{prefname}&ontologies=MONDO&apikey=#{api_key}"
#         warn "getting #{url2}"
        begin
            response = RestClient.get(url2, headers: headers)
        rescue
            warn "step 2 failed - search for MONDO by prefname HTTP call failed"
            return false
        end
        data = JSON.parse(response)
#         warn data
        records = data.dig('collection')
        records.each do |r|
#             warn r['prefLabel']
            next unless r['prefLabel'].downcase == prefname.downcase
            mondo = r['@id']
            break
        end
    else
        warn "Step 2 failed - can't find preflabel for #{efo}...???"
    end
    if mondo
        return {id: efo, mondo: mondo, disease_name: prefname}
    else
        warn "general failure - can't find mondo for #{efo} #{prefname} ...???"
        return false
    end
end
# test
puts special_case_efo_to_mondo("EFO_0000713")
# Out:
# {:id=>"EFO_0000713", :mondo=>"", :disease_name=>"obsolete_subarachnoid hemorrhage"}

# %% [markdown]
# ## special case Orphanet
# BioOntologies has a mapping from MONDO to Orphanet, but not vice versa
#
# SO... if we have an Orphanet code, we need to get the prefLabel (disease name according to orphanet), then search MONDO by that disease name, and match it against the discovered MONDO recofrds.  UNFORTUNATELY, it often appears as a synonym, rather than the prefLabel for the record, so... that sucks!
#
# Note - it is not the first or even the only match!  Need to parse through all matching MONDO records until we hit the exact match in the synonyms.

# %%
require 'rest-client'
require 'json'

def special_case_orpha_to_mondo(orphacode)
    orphacode.strip!
#     warn "special case orphacode #{orphacode}"
    mapping = map_id_to_disease(orphacode).first  # returns array
    warn mapping.class
    unless mapping
        # warn "no mapping found for #{orphacode} (this is very strange!)"
        return false
    end
    
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings"}
    search_term = mapping[:disease_name]
#     warn search_term
    unless search_term
        # warn "no disease name found for #{orphacode} (this is very strange!)"
        return false
    end
    
    monarch_orphacode = orphacode.gsub(/_/, ":")
    entity_ids = "entity_id=#{monarch_orphacode}&"
# warn "calling monarch https://api-v3.monarchinitiative.org/v3/api/mappings?#{entity_ids}format=json&limit=500&offset=0"
    response = RestClient.get(
    "https://api-v3.monarchinitiative.org/v3/api/mappings?#{entity_ids}format=json&limit=500&offset=0"
    )
# warn "called monarch"
#     warn "Request URL: #{response.request.url}"

    data = JSON.parse(response.body)
# warn data
    data['items'].each do |item|
        if item['object_id'] =~ /#{monarch_orphacode}/
          mondo_id = item['subject_id']  # e.g. "MONDO:0018940"
          mondo_term = item['subject_label']  # e.g. "Leigh Syndrome"
          mondo_id.gsub!("MONDO:", "http://purl.obolibrary.org/obo/MONDO_")
          return mapping.merge({mondo: mondo_id, term: mondo_term})
        end
    end
    warn "general failure - can't find mondo for orphanet #{orphacode} #{search_term} ...???"
    return false
end

# test
[
    # "Orphanet_3315",
    # "Orphanet_101010",
    "Orphanet_22"
].each do |orphacode|
  puts  special_case_orpha_to_mondo(orphacode)
#     {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0004277"}
end
# Out:
# Hash
# {:id=>"Orphanet_22", :uri=>"http://www.orpha.net/ORDO/Orphanet_22", :disease_name=>"Succinic semialdehyde dehydrogenase deficiency", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_22/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0010083", :term=>"succinic semialdehyde dehydrogenase deficiency"}
# ["Orphanet_22"]

# %%
def get_mondo_label(mondo_uri)
  return nil unless mondo_uri && !mondo_uri.empty?
  local = mondo_uri.match(/MONDO_\d+/)&.[](0)
  return "" unless local
  iri = "http://purl.obolibrary.org/obo/#{local}"
  encoded = URI.encode_uri_component(URI.encode_uri_component(iri))
  response = Net::HTTP.get_response(URI("https://www.ebi.ac.uk/ols4/api/ontologies/mondo/terms/#{encoded}"))
  return "" unless response.is_a?(Net::HTTPSuccess)
  JSON.parse(response.body)['label']
rescue => e
  warn "MONDO label lookup failed for #{mondo_uri}: #{e}"
  ""
end

# test

mondo_uri = "http://purl.obolibrary.org/obo/MONDO_0100176"
warn get_mondo_label(mondo_uri)
# Out:
# AP-4 deficiency syndrome

# %%
require 'csv'

file = "disease.list.uniq"

diseaselist = File.readlines(file)

puts diseaselist.length  
puts diseaselist.first
# Out:
# 9341
# "DOID_10718"

# %%
puts `grep -i 'orphanet_' disease.list.uniq | wc -l`
# Out:
# 4412

# %%
puts `grep -i EFO disease.list.uniq | wc -l`
# Out:
# 2829

# %%
puts `grep -i _22 disease.list.uniq | wc -l`
# Out:
# 113

# %%
require 'net/http'
require 'uri'

$stdout.sync = true   # Disables buffering for STDOUT
$stderr.sync = true   # Disables buffering for STDERR (warn, etc.)

# write the mapping file
f = File.open('./maps/diseases.map', 'w')
e = File.open('./maps/diseases-errors.txt', 'w')
f.write CSV.generate_line(%w[source mondo prefname])

# FOR RESTART ONLY!!!!
# f = File.open("./maps/diseases.map", "a")
# e = File.open("./maps/diseases-errors.txt", "a")

diseaselist = File.readlines(file)


# deal with MONDO first, because it needs no mapping
diseaselist.each do |name|
    name.strip!
  cleanname = name.gsub(/"/, '')
  next unless cleanname =~ /MONDO_/
  warn cleanname
  res = "http://purl.obolibrary.org/obo/#{cleanname}"  
  mondolabel = get_mondo_label(res)
    unless mondolabel
        warn "found no mondo label for #{cleanname}"
        e.write "found no mondo label for #{cleanname}\n"
        e.flush # This forces the write to disk immediately
        next
    end
  warn "found mondo #{mondolabel}"
  f.write CSV.generate_line([cleanname, res, mondolabel])
  f.flush
end


# spoeial case for EFO
diseaselist = File.readlines(file)
diseaselist.each do |name|
    name.strip!
  cleanname = name.gsub(/"/, '')
  next unless cleanname =~ /EFO_/

  warn cleanname
  res = special_case_efo_to_mondo(cleanname) # {:id=>"EFO_0000713", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0005099", :disease_name=>"subarachnoid hemorrhage"}
  if !res || res[:mondo].empty?
    warn "found no mondo for #{cleanname}"
    e.write "found no mondo for #{cleanname}\n"
    e.flush # This forces the write to disk immediately
    next
  end
  f.write CSV.generate_line([cleanname, res[:mondo], get_mondo_label(res[:mondo]) || res[:disease_name]])
  f.flush
end

# Special case for ORPHA
diseaselist = File.readlines(file)
diseaselist.each do |name|
    name.strip!
  cleanname = name.gsub(/"/, '')
  next unless cleanname =~ /Orphanet_/

  warn cleanname
  res = special_case_orpha_to_mondo(cleanname) # {:id=>"Orphanet:101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0012476"}
  if !res || res[:mondo].empty?
    warn "found no mondo for #{cleanname}"
    e.write "found no mondo for #{cleanname}\n"
    e.flush
    next
  end
  warn "found mondo #{res[:mondo]}"
  f.write CSV.generate_line([cleanname, res[:mondo], get_mondo_label(res[:mondo]) || res[:disease_name]])
  f.flush
end

diseaselist = File.readlines(file)
diseaselist.each do |name|
    name.strip!
  cleanname = name.gsub(/"/, '')
  next if cleanname =~ /HP_/ # not HPO terms
  next if cleanname =~ /EFO_/ # not EFO terms
  next if cleanname =~ /OTAR_/ # not OTAR terms
  next if cleanname =~ /Orphanet_/ # not ORPHA terms
  next if cleanname =~ /MONDO_/  # MONDO is done already
  warn cleanname

  results = map_id_to_disease(cleanname)
  if results
    results = results.first # (can only be one)
    nextres = get_mondo_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    else
      warn "found no mondo for #{cleanname}"
      e.write "found no mondo for #{cleanname}\n"
      e.flush
    end

    f.write CSV.generate_line([cleanname, results[:mondo], get_mondo_label(results[:mondo]) || results[:disease_name]])
    f.flush
    # {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/763377006"}
  else
    warn "found no results for #{cleanname}"
    e.write "found no results for #{cleanname}\n"
    e.flush
  end
end
f.close
e.close
# Out:
# MONDO_0000030
# found mondo familial sleep-related hypermotor epilepsy
# MONDO_0000070
# found mondo Mycobacterium tuberculosis, susceptibility
# MONDO_0000108
# found mondo bacteremia, susceptibility
# MONDO_0000169
# found mondo obsolete microphthalmia, isolated, with cataract
# MONDO_0000170
# found mondo microphthalmia, isolated, with coloboma
# MONDO_0000468
# found mondo third-degree atrioventricular block
# MONDO_0000489
# found mondo diabetic encephalopathy
# MONDO_0000532
# found mondo lung combined type small cell adenocarcinoma
# MONDO_0000573
# found mondo recombinase activating gene 2 deficiency
# MONDO_0000595
# found mondo sexual disorder
# MONDO_0000643
# found mondo vulvar benign neoplasm
# MONDO_0000701
# found mondo ischemic colitis
# MONDO_0000816
# found mondo abdominal obesity-metabolic syndrome
# MONDO_0000883
# found mondo obsolete myeloid neoplasms associated with PDGFRB rearrangement
# MONDO_0000890
# found mondo Zika virus congenital syndrome
# MONDO_0000892
# found mondo colon medullary carcinoma
# MONDO_0000894
# found mondo mucinous bronchioloalveolar adenocarcinoma
# MONDO_0000923
# found mondo interstitial emphysema
# MONDO_0000924
# found mondo compensatory emphysema
# MONDO_0000944
# found mondo cerebral artery occlusion
# MONDO_0000962
# found mondo spindle cell lipoma
# MONDO_0000988
# found mondo discharging ear
# MONDO_0001020
# found mondo amblyopia
# MONDO_0001078
# found mondo tropical sprue
# MONDO_0001087
# found mondo schizotypal personality disorder
# MONDO_0001160
# found mondo dissociative disorder
# MONDO_0001161
# found mondo schizoid personality disorder
# MONDO_0001163
# found mondo paranoid personality disorder
# MONDO_0001197
# found mondo qualitative platelet defect
# MONDO_0001285
# found mondo endometriosis of pelvic peritoneum
# MONDO_0001288
# found mondo endometriosis of rectovaginal septum and vagina
# MONDO_0001291
# found mondo brain compression
# MONDO_0001296
# found mondo acquired night blindness
# MONDO_0001299
# found mondo diabetic autonomic neuropathy
# MONDO_0001302
# found mondo hypertensive heart disease
# MONDO_0001330
# found mondo presbyopia
# MONDO_0001369
# found mondo chronic laryngitis
# MONDO_0001374
# found mondo bladder sarcoma
# MONDO_0001410
# found mondo postmenopausal atrophic vaginitis
# MONDO_0001434
# found mondo inflammatory spondylopathy
# MONDO_0001438
# found mondo postinflammatory pulmonary fibrosis
# MONDO_0001444
# found mondo Chagas disease
# MONDO_0001539
# found mondo retinal perforation
# MONDO_0001543
# found mondo lesion of sciatic nerve
# MONDO_0001551
# found mondo ulceration of vulva
# MONDO_0001557
# found mondo olecranon bursitis
# MONDO_0001558
# found mondo Potter sequence
# MONDO_0001578
# found mondo obsolete hernia of ovary and fallopian tube
# MONDO_0001580
# found mondo lacrimal duct cancer
# MONDO_0001583
# found mondo diabetic polyneuropathy
# MONDO_0001618
# found mondo balanoposthitis
# MONDO_0001658
# found mondo nontoxic goiter
# MONDO_0001680
# found mondo vaginal mullerian papilloma
# MONDO_0001721
# found mondo urethral intrinsic sphincter deficiency
# MONDO_0001730
# found mondo urethral syndrome
# MONDO_0001750
# found mondo non-renal secondary hyperparathyroidism
# MONDO_0001784
# found mondo malignant renovascular hypertension
# MONDO_0001798
# found mondo hypermobility syndrome
# MONDO_0001815
# found mondo extrapyramidal and movement disease
# MONDO_0001828
# found mondo acquired color blindness
# MONDO_0001841
# found mondo uterine corpus epithelioid leiomyoma
# MONDO_0001847
# found mondo nuclear senile cataract
# MONDO_0001858
# found mondo Tietze syndrome
# MONDO_0001859
# found mondo obsolete algoneurodystrophy
# MONDO_0001878
# found mondo acquired hypertrophic pyloric stenosis
# MONDO_0001903
# found mondo calcific tendinitis
# MONDO_0002000
# found mondo anaerobic meningitis
# MONDO_0002009
# found mondo major depressive disorder
# MONDO_0002046
# found mondo alcohol abuse
# MONDO_0002083
# found mondo Richter transformation
# MONDO_0002172
# found mondo otosalpingitis
# MONDO_0002203
# found mondo constipation disorder
# MONDO_0002246
# found mondo perichondritis of auricle
# MONDO_0002278
# found mondo benign colon neoplasm
# MONDO_0002317
# found mondo central nervous system origin vertigo
# MONDO_0002336
# found mondo obsolete inflammatory and toxic neuropathy
# MONDO_0002354
# found mondo benign laryngeal neoplasm
# MONDO_0002355
# found mondo glottis carcinoma
# MONDO_0002359
# found mondo periosteal chondroma
# MONDO_0002368
# found mondo papillary serous cystadenocarcinoma
# MONDO_0002375
# found mondo sebaceous adenoma
# MONDO_0002376
# found mondo spleen angiosarcoma
# MONDO_0002398
# found mondo mucinous adenofibroma
# MONDO_0002416
# found mondo ethmoid sinus squamous cell carcinoma
# MONDO_0002423
# found mondo rectosigmoid junction neoplasm
# MONDO_0002426
# found mondo lung sarcoma
# MONDO_0002450
# found mondo prostatic adenoma
# MONDO_0002548
# found mondo cellular schwannoma
# MONDO_0002558
# found mondo melanotic neurilemmoma
# MONDO_0002579
# found mondo orbit embryonal rhabdomyosarcoma
# MONDO_0002588
# found mondo thymoma type A
# MONDO_0002605
# found mondo hepatic angiomyolipoma
# MONDO_0002606
# found mondo epithelioid type angiomyolipoma
# MONDO_0002618
# found mondo undifferentiated high grade pleomorphic sarcoma of bone
# MONDO_0002619
# found mondo bone fibrosarcoma
# MONDO_0002621
# found mondo extraosseous osteosarcoma
# MONDO_0002627
# found mondo chondroblastic osteosarcoma
# MONDO_0002630
# found mondo small cell osteogenic sarcoma
# MONDO_0002652
# found mondo anus adenocarcinoma
# MONDO_0002674
# found mondo stricture or kinking of ureter
# MONDO_0002764
# found mondo urethra squamous cell carcinoma
# MONDO_0002775
# found mondo anovulation
# MONDO_0002812
# found mondo infectious otitis interna
# MONDO_0002836
# found mondo urethra transitional cell carcinoma
# MONDO_0002839
# found mondo obsolete leather-bottle stomach
# MONDO_0002855
# found mondo ectomesenchymoma
# MONDO_0002863
# found mondo rhabdomyosarcoma with mixed embryonal and alveolar features
# MONDO_0002876
# found mondo cervical adenosarcoma
# MONDO_0002877
# found mondo cervical carcinosarcoma
# MONDO_0002878
# found mondo uterine corpus adenosarcoma
# MONDO_0002959
# found mondo radiculopathy
# MONDO_0002996
# found mondo cavernous sinus meningioma
# MONDO_0003035
# found mondo ovarian angiosarcoma
# MONDO_0003049
# found mondo ovarian large-cell neuroendocrine carcinoma
# MONDO_0003125
# found mondo testicular sex cord-stromal neoplasm
# MONDO_0003143
# found mondo angiokeratoma
# MONDO_0003158
# found mondo malignant myoepithelioma
# MONDO_0003168
# found mondo cerebellar pilocytic astrocytoma
# MONDO_0003173
# found mondo brain stem astrocytic neoplasm
# MONDO_0003180
# found mondo cutaneous adenocystic carcinoma
# MONDO_0003181
# found mondo lung adenoid cystic carcinoma
# MONDO_0003200
# found mondo urethra adenocarcinoma
# MONDO_0003206
# found mondo acquired hemangioma
# MONDO_0003214
# found mondo apocrine adenocarcinoma
# MONDO_0003219
# found mondo gastroesophageal junction adenocarcinoma
# MONDO_0003223
# found mondo meninges hemangiopericytoma
# MONDO_0003243
# found mondo hepatocellular clear cell carcinoma
# MONDO_0003263
# found mondo childhood cerebellar neoplasm
# MONDO_0003265
# found mondo adjustment disorder
# MONDO_0003350
# found mondo granular cell leiomyosarcoma
# MONDO_0003353
# found mondo heart leiomyosarcoma
# MONDO_0003366
# found mondo hydrarthrosis
# MONDO_0003376
# found mondo mediastinum leiomyosarcoma
# MONDO_0003446
# found mondo papillary hidradenoma
# MONDO_0003448
# found mondo benign spiradenoma
# MONDO_0003453
# found mondo conjunctival intraepithelial neoplasm
# MONDO_0003455
# found mondo bile duct papillary neoplasm
# MONDO_0003468
# found mondo biphasic synovial sarcoma
# MONDO_0003472
# found mondo lice infestation
# MONDO_0003473
# found mondo spinal cord ependymoma
# MONDO_0003519
# found mondo malignant syringoma
# MONDO_0003523
# found mondo gastrin-producing neuroendocrine tumor
# MONDO_0003531
# found mondo papillary eccrine carcinoma
# MONDO_0003561
# found mondo malignant giant cell tumor of soft parts
# MONDO_0003594
# found mondo mixed liposarcoma
# MONDO_0003619
# found mondo salpingitis
# MONDO_0003624
# found mondo acinic cell breast carcinoma
# MONDO_0003632
# found mondo endocervicitis
# MONDO_0003668
# found mondo extragonadal seminoma
# MONDO_0003680
# found mondo periosteal chondrosarcoma
# MONDO_0003681
# found mondo myxoid chondrosarcoma
# MONDO_0003684
# found mondo clear cell chondrosarcoma
# MONDO_0003710
# found mondo ovarian mixed germ cell neoplasm
# MONDO_0003714
# found mondo bladder urachal squamous cell carcinoma
# MONDO_0003735
# found mondo central nervous system immature teratoma
# MONDO_0003744
# found mondo spindle cell intraocular melanoma
# MONDO_0003761
# Interrupt:
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1792:in `initialize'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1792:in `open'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1792:in `block in timeouted_connect'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/timeout-0.4.3/lib/timeout.rb:185:in `block in timeout'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/timeout-0.4.3/lib/timeout.rb:192:in `timeout'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1791:in `timeouted_connect'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1677:in `connect'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1655:in `do_start'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1629:in `start'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:1064:in `start'
# /home/osboxes/.rvm/gems/ruby-3.2.4/gems/net-http-0.9.1/lib/net/http.rb:824:in `get_response'
# (irb):6:in `get_mondo_label'
# (irb):24:in `block in <top (required)>'
# (irb):19:in `each'
# (irb):19:in `<top (required)>'

# %%
puts `pwd`
# Out:
# /home/osboxes/CODE/SIMPATHIC2/SKG_Mapping/radboud

# %% [markdown]
# ## Patch: update existing diseases.map with MONDO canonical labels
#
# Run the cell below to update `prefname` in the existing `diseases.map` to use the MONDO canonical label from OLS4, without needing to redo the expensive BioPortal/Monarch lookups from scratch.
#
# It deduplicates MONDO URIs first (~6,600 unique values vs ~9,300 rows), then writes `diseases.map.updated`. Review, then rename to `diseases.map`.
#
# Expected runtime: ~15 minutes.

# %%
def patch_mondo_label(mondo_id)
  return "" unless mondo_id && !mondo_id.empty?
  local = mondo_id.match(/MONDO_\d+/)&.[](0)
  return "" unless local
  iri = "http://purl.obolibrary.org/obo/#{local}"
  encoded = URI.encode_uri_component(URI.encode_uri_component(iri))
  response = Net::HTTP.get_response(URI("https://www.ebi.ac.uk/ols4/api/ontologies/mondo/terms/#{encoded}"))
  return "" unless response.is_a?(Net::HTTPSuccess)
  JSON.parse(response.body)['label']
rescue => e
  warn "MONDO label lookup failed for #{mondo_uri}: #{e}"
  ""
end

# test
warn patch_mondo_label('"MONDO_0003304"')
# Out:
# plexiform neurofibroma

# %%
require 'net/http'
require 'uri'
require 'json'
require 'csv'



$stdout.sync = true
$stderr.sync = true

rows = CSV.read('./maps/diseases.map', headers: true)
#unique_mondos = rows.map { |r| r['mondo'] }.compact.uniq
#warn "Fetching MONDO canonical labels for #{unique_mondos.size} unique URIs..."

CSV.open('./maps/diseases.map.updated', 'w') do |out|
    out << ['source', 'mondo', 'prefname']

    rows.each do |row|
      label = nil
      source = row["source"]
      if source =~ /MONDO/
          3.times do
            label = patch_mondo_label(source)
            break if label
            sleep 1
          end
          warn "no label found for #{uri}" unless label
          out << [row['source'], "http://purl.obolibrary.org/obo/#{source}", label]
      else
        out << [row['source'], row['mondo'], row['prefname']]
      end
    end

end

warn "Written to ./maps/diseases.map.updated"
warn "Review, then: mv ./maps/diseases.map.updated ./maps/diseases.map"
# Out:
# Written to ./maps/diseases.map.updated
# Review, then: mv ./maps/diseases.map.updated ./maps/diseases.map
