# %% [markdown]
# # Map Diseases Radboud -> MONDO
#
# # Strategy
#
# Diseases have been extracted from the three files that contain disease references.
#
# This is disease.list.uniq
#
# There's all kinds of namespaces in there... a bit of a mess!
#
# Here we will try to map into MONDO.  In some cases, the disease reference is already MONDO, so that's good!  Other namespaces that I think we can mange are:  EFO (sometimes), DOID, and Orphanet

# %%
# puts `head -20 disease.list.uniq`
# puts `grep MONDO disease.list.uniq | head -20`
puts ENV["APIKEY"]
# Out:
# 74027bd8-6be0-4329-be22-aa3717f97243

# %%
require 'rest-client'
require 'json'

def map_id_to_disease(name)
    name.strip!
    warn "mapping #{name}"
  return false unless (name =~ /EFO_/ || name =~ /DOID_(.*)/ || name =~ /MONDO_(.*)/ || name =~ /Orphanet_(.*)/)
  identifier = $1  #W dfrom the match above
  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    if name =~ /DOID/
      url =  "https://data.bioontology.org/search?q=DOID:#{identifier}&ontologies=DOID&require_exact_match=true&apikey=#{api_key}"
    elsif name =~ /MONDO/
      url =  "https://data.bioontology.org/search?q=MONDO:#{identifier}&ontologies=MONDO&require_exact_match=true&apikey=#{api_key}"      
    else
      url =  "https://data.bioontology.org/search?q=Orphanet:#{identifier}&ontologies=ORDO&require_exact_match=true&apikey=#{api_key}"
    end
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for #{name} #{e.inspect}\n"
    return false
  end
  mappings = []
  data = JSON.parse(response)

#  if hit = data.dig('collection', 0)
  if hit = data.dig('collection')
    hit.each do |h|
      disease_name = h&.dig('prefLabel')
      uri = h&.dig('@id')
      linksurl = h&.dig('links', 'mappings')
      mappings << { id: name, uri: uri, disease_name: disease_name, linksurl: linksurl}
    end
    return mappings
  else
    warn "No data found for #{name}\n"
    return false
  end

rescue StandardError => e
  warn "No data found for #{name} Error: #{e.inspect}\n"
  return false
end

# test
["DOID_7551", "MONDO_0000070", "Orphanet_10", "Orphanet_22"].each do |name|
  warn map_id_to_disease(name)  # returns array
end
# Out:
# mapping DOID_7551
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings"}
# mapping MONDO_0000070
# {:id=>"MONDO_0000070", :uri=>"http://purl.obolibrary.org/obo/MONDO_0000070", :disease_name=>"Mycobacterium tuberculosis, susceptibility", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0000070/mappings"}
# mapping Orphanet_10
# {:id=>"Orphanet_10", :uri=>"http://www.orpha.net/ORDO/Orphanet_10", :disease_name=>"48,XXYY syndrome", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_10/mappings"}
# mapping Orphanet_22
# {:id=>"Orphanet_22", :uri=>"http://www.orpha.net/ORDO/Orphanet_22", :disease_name=>"Succinic semialdehyde dehydrogenase deficiency", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_22/mappings"}
# ["DOID_7551", "MONDO_0000070", "Orphanet_10", "Orphanet_22"]

# %%
def get_mondo_from_mapping(mapping)
  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    url = mapping+"?apikey=#{api_key}"
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for mapping #{e.inspect}\n"
    return false
  end
    mappings = []
    data = JSON.parse(response)

    data.each do |mapp|
      mapp["classes"].each do |thisclass|
        next unless thisclass["@id"] =~ /MONDO/
        return {"mondo": thisclass["@id"]}
      end
    end
    warn "no MONDO found for DOID/ORDO/MONDO #{mapping}"
    return false

rescue StandardError => e
  warn  "parsing or other error in #{mapping} Error: #{e.inspect}\n"
  return false
end

# test
[
    # "DOID_7551", 
    # "MONDO_0000070", 
    "Orphanet_22",
].each do |name|
  results = map_id_to_disease(name)  # this returns a hash
  if results
    results = results.first # (can only be one)
    nextres = get_mondo_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    end
    puts results
  else
    warn "found no results for #{name}"
  end
end
# Out:
# mapping Orphanet_22
# {:id=>"Orphanet_22", :uri=>"http://www.orpha.net/ORDO/Orphanet_22", :disease_name=>"Succinic semialdehyde dehydrogenase deficiency", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_22/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0010083"}
# ["Orphanet_22"]

# %% [markdown]
# ## Special Case EFO
# sometimes can find efo -> MONDO

# %%
require 'rest-client'
require 'json'

def special_case_efo_to_mondo(efo)
        efo.strip!
    warn "**#{efo}**"

    api_key = ENV["APIKEY"]
    url = "https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2F#{efo}?apikey=#{api_key}"
    warn url
    headers = {
    "Accept"     => "application/json",
    "User-Agent" => "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
    }

    begin
        response = RestClient.get(url, headers: headers)
#         warn response
    rescue
        warn "step 1 EFO Lookup failed"
        return false
    end
    
    data = JSON.parse(response.body)
    mondo = ""

    if prefname = data.dig('prefLabel')
        warn "MATCHING #{prefname}"
        url2 = "https://data.bioontology.org/search?q=#{prefname}&ontologies=MONDO&apikey=#{api_key}"
#         warn "getting #{url2}"
        begin
            response = RestClient.get(url2, headers: headers)
        rescue
            warn "step 2 failed - search for MONDO by prefname HTTP call failed"
            return false
        end
        data = JSON.parse(response)
#         warn data
        records = data.dig('collection')
        records.each do |r|
#             warn r['prefLabel']
            next unless r['prefLabel'].downcase == prefname.downcase
            mondo = r['@id']
            break
        end
    else
        warn "Step 2 failed - can't find preflabel for #{efo}...???"
    end
    if mondo
        return {id: efo, mondo: mondo, disease_name: prefname}
    else
        warn "general failure - can't find mondo for #{efo} #{prefname} ...???"
        return false
    end
end
# test
puts special_case_efo_to_mondo("EFO_0000713")
# Out:
# **EFO_0000713**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000713?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING subarachnoid hemorrhage
# {:id=>"EFO_0000713", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0005099", :disease_name=>"subarachnoid hemorrhage"}

# %% [markdown]
# ## special case Orphanet
# BioOntologies has a mapping from MONDO to Orphanet, but not vice versa
#
# SO... if we have an Orphanet code, we need to get the prefLabel (disease name according to orphanet), then search MONDO by that disease name, and match it against the discovered MONDO recofrds.  UNFORTUNATELY, it often appears as a synonym, rather than the prefLabel for the record, so... that sucks!
#
# Note - it is not the first or even the only match!  Need to parse through all matching MONDO records until we hit the exact match in the synonyms.

# %%
require 'rest-client'
require 'json'

def special_case_orpha_to_mondo(orphacode)
    orphacode.strip!
#     warn "special case orphacode #{orphacode}"
    mapping = map_id_to_disease(orphacode).first  # returns array
    warn mapping.class
    unless mapping
        warn "no mapping found for #{orphacode} (this is very strange!)"
        return false
    end
    
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings"}
    search_term = mapping[:disease_name]
#     warn search_term
    unless search_term
        warn "no disease name found for #{orphacode} (this is very strange!)"
        return false
    end
    
    monarch_orphacode = orphacode.gsub(/_/, ":")
    entity_ids = "entity_id=#{monarch_orphacode}&"

    response = RestClient.get(
    "https://api-v3.monarchinitiative.org/v3/api/mappings?#{entity_ids}format=json&limit=500&offset=0"
    )

#     warn "Request URL: #{response.request.url}"

    data = JSON.parse(response.body)
# warn data
    data['items'].each do |item|
        if item['object_id'] =~ /#{monarch_orphacode}/
          mondo_id = item['subject_id']  # e.g. "MONDO:0018940"
          mondo_term = item['subject_label']  # e.g. "Leigh Syndrome"
          mondo_id.gsub!("MONDO:", "http://purl.obolibrary.org/obo/MONDO_")
          return mapping.merge({mondo: mondo_id, term: mondo_term})
        end
    end
    warn "general failure - can't find mondo for orphanet #{orphacode} #{search_term} ...???"
    return false
end

# test
[
    # "Orphanet_3315",
    # "Orphanet_101010",
    "Orphanet_22"
].each do |orphacode|
  puts  special_case_orpha_to_mondo(orphacode)
#     {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0004277"}
end
# Out:
# mapping Orphanet_22
# Hash
# {:id=>"Orphanet_22", :uri=>"http://www.orpha.net/ORDO/Orphanet_22", :disease_name=>"Succinic semialdehyde dehydrogenase deficiency", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_22/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0010083", :term=>"succinic semialdehyde dehydrogenase deficiency"}
# ["Orphanet_22"]

# %%
require 'csv'

file = "disease.list.uniq"

diseaselist = File.readlines(file)

puts diseaselist.length  
puts diseaselist.first
# Out:
# 9341
# "DOID_10718"

# %%
puts `grep -i 'orphanet_' disease.list.uniq | wc -l`
# Out:
# 0

# %%
puts `grep -i EFO disease.list.uniq | wc -l`
# Out:
# 2829

# %%
puts `grep -i _22 disease.list.uniq | wc -l`
# Out:
# 113

# %%
$stdout.sync = true   # Disables buffering for STDOUT
$stderr.sync = true   # Disables buffering for STDERR (warn, etc.)

# write the mapping file
f = File.open('./maps/diseases.map', 'w')
e = File.open('./maps/diseases-errors.txt', 'w')
f.write CSV.generate_line(%w[source mondo prefname])

# FOR RESTART ONLY!!!!
# f = File.open("./maps/diseases.map", "a")
# e = File.open("./maps/diseases-errors.txt", "a")

diseaselist = File.readlines(file)

# spoeial case for EFO
diseaselist.each do |name|
  cleanname = name.gsub(/"/, '')
  next unless cleanname =~ /EFO_/

  warn cleanname
  res = special_case_efo_to_mondo(cleanname) # {:id=>"EFO_0000713", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0005099", :disease_name=>"subarachnoid hemorrhage"}
  if !res || res[:mondo].empty?
    warn "found no mondo for #{cleanname}"
    e.write "found no mondo for #{cleanname}\n"
    e.flush # This forces the write to disk immediately
    next
  end
  f.write CSV.generate_line([cleanname, res[:mondo], res[:disease_name]])
  f.flush
end

# I HAVE NO IDEA WHY THIS RESET IS NECESSARY, but orphanet codes are changed to ":" instead of "_"... somewhere
diseaselist = File.readlines(file)
# spoeial case for ORPHA
diseaselist.each do |name|
  cleanname = name.gsub(/"/, '')
  next unless cleanname =~ /Orphanet_/

  warn cleanname
  res = special_case_orpha_to_mondo(cleanname) # {:id=>"Orphanet:101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0012476"}
  if !res || res[:mondo].empty?
    warn "found no mondo for #{cleanname}"
    e.write "found no mondo for #{cleanname}\n"
    e.flush
    next
  end
  warn "found mondo #{res[:mondo]}"
  f.write CSV.generate_line([cleanname, res[:mondo], res[:disease_name]])
  f.flush
end

diseaselist = File.readlines(file)
diseaselist.each do |name|
  cleanname = name.gsub(/"/, '')
  next if cleanname =~ /HP_/ # not HPO terms
  next if cleanname =~ /EFO_/ # not EFO terms
  next if cleanname =~ /OTAR_/ # not OTAR terms
  next if cleanname =~ /Orphanet_/ # not ORPHA terms

  warn cleanname

  results = map_id_to_disease(cleanname)
  if results
    results = results.first # (can only be one)
    nextres = get_mondo_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    else
      warn "found no mondo for #{cleanname}"
      e.write "found no mondo for #{cleanname}\n"
      e.flush
    end

    f.write CSV.generate_line([cleanname, results[:mondo], results[:disease_name]])
    f.flush
    # {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/763377006"}
  else
    warn "found no results for #{cleanname}"
    e.write "found no results for #{cleanname}\n"
    e.flush
  end
end
f.close
e.close
# Out:
# EFO_0000174
# **EFO_0000174**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000174?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Ewing sarcoma
# EFO_0000180
# **EFO_0000180**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000180?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING HIV-1 infection
# found no mondo for EFO_0000180
# EFO_0000195
# **EFO_0000195**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000195?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING metabolic syndrome
# found no mondo for EFO_0000195
# EFO_0000196
# **EFO_0000196**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000196?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING metastatic prostate cancer
# found no mondo for EFO_0000196
# EFO_0000205
# **EFO_0000205**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000205?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING stage I endometrioid carcinoma
# EFO_0000206
# **EFO_0000206**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000206?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING stage II endometrioid carcinoma
# EFO_0000211
# **EFO_0000211**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000211?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING unspecified peripheral T-cell lymphoma
# found no mondo for EFO_0000211
# EFO_0000223
# **EFO_0000223**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000223?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acute myelomonocytic leukemia
# found no mondo for EFO_0000223
# EFO_0000224
# **EFO_0000224**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000224?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acute promyelocytic leukemia
# EFO_0000225
# **EFO_0000225**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000225?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acute quadriplegic myopathy
# EFO_0000233
# **EFO_0000233**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000233?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING adenosquamous lung carcinoma
# EFO_0000248
# **EFO_0000248**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000248?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING alveolar rhabdomyosarcoma
# EFO_0000255
# **EFO_0000255**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000255?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING angioimmunoblastic T-cell lymphoma
# EFO_0000280
# **EFO_0000280**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000280?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Barrett's esophagus
# found no mondo for EFO_0000280
# EFO_0000281
# **EFO_0000281**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000281?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING basal-like breast carcinoma
# EFO_0000284
# **EFO_0000284**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000284?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING benign prostatic hyperplasia
# EFO_0000330
# **EFO_0000330**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000330?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING childhood acute myeloid leukemia
# EFO_0000331
# **EFO_0000331**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000331?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING chondroblastoma
# EFO_0000332
# **EFO_0000332**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000332?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING chondromyxoid fibroma
# EFO_0000335
# **EFO_0000335**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000335?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING chromophobe renal cell carcinoma
# EFO_0000350
# **EFO_0000350**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000350?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING clear cell sarcoma of the kidney
# found no mondo for EFO_0000350
# EFO_0000394
# **EFO_0000394**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000394?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING dedifferentiated chondrosarcoma
# EFO_0000397
# **EFO_0000397**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000397?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING dermal neurofibroma
# found no mondo for EFO_0000397
# EFO_0000404
# **EFO_0000404**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000404?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING diffuse scleroderma
# EFO_0000432
# **EFO_0000432**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000432?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING breast ductal carcinoma in situ
# found no mondo for EFO_0000432
# EFO_0000483
# **EFO_0000483**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000483?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING exercise
# found no mondo for EFO_0000483
# EFO_0000495
# **EFO_0000495**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000495?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING fetal growth restriction
# EFO_0000500
# **EFO_0000500**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000500?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING ganglioneuroma
# EFO_0000502
# **EFO_0000502**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000502?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING ganglioneuroblastoma
# EFO_0000504
# **EFO_0000504**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000504?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING gastric intestinal type adenocarcinoma
# EFO_0000552
# **EFO_0000552**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000552?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING invasive breast ductal and lobular carcinoma
# found no mondo for EFO_0000552
# EFO_0000553
# **EFO_0000553**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000553?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING invasive lobular carcinoma
# found no mondo for EFO_0000553
# EFO_0000555
# **EFO_0000555**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000555?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING irritable bowel syndrome
# EFO_0000557
# **EFO_0000557**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000557?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING juvenile dermatomyositis
# EFO_0000559
# **EFO_0000559**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000559?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING keratinizing squamous cell carcinoma
# EFO_0000580
# **EFO_0000580**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000580?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING medullary breast carcinoma
# EFO_0000595
# **EFO_0000595**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000595?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING monophasic synovial sarcoma
# EFO_0000613
# **EFO_0000613**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000613?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING myxoid liposarcoma
# EFO_0000614
# **EFO_0000614**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000614?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING obsolete_narcolepsy with cataplexy
# found no mondo for EFO_0000614
# EFO_0000650
# **EFO_0000650**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000650?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING whooping cough
# found no mondo for EFO_0000650
# EFO_0000658
# **EFO_0000658**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000658?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING plexiform neurofibroma
# EFO_0000660
# **EFO_0000660**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000660?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING polycystic ovary syndrome
# EFO_0000666
# **EFO_0000666**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000666?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING portal hypertension
# EFO_0000678
# **EFO_0000678**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000678?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING pterygium
# EFO_0000694
# **EFO_0000694**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000694?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING severe acute respiratory syndrome
# EFO_0000699
# **EFO_0000699**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000699?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Sjogren syndrome
# EFO_0000713
# **EFO_0000713**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000713?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING subarachnoid hemorrhage
# EFO_0000730
# **EFO_0000730**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000730?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING undifferentiated sarcoma
# found no mondo for EFO_0000730
# EFO_0000736
# **EFO_0000736**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000736?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING well-differentiated liposarcoma
# EFO_0000737
# **EFO_0000737**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000737?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING well-differentiated sarcoma
# found no mondo for EFO_0000737
# EFO_0000762
# **EFO_0000762**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000762?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING hepatocellular adenoma
# EFO_0000765
# **EFO_0000765**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000765?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING AIDS
# EFO_0000767
# **EFO_0000767**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000767?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING idiopathic cardiomyopathy
# EFO_0000775
# **EFO_0000775**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000775?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Whipple's disease
# found no mondo for EFO_0000775
# EFO_0000776
# **EFO_0000776**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000776?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Aeromonas hydrophila infection
# found no mondo for EFO_0000776
# EFO_0000777
# **EFO_0000777**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000777?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING human granulocytic anaplasmosis
# EFO_0000778
# **EFO_0000778**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000778?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING anthrax infection
# EFO_0000779
# **EFO_0000779**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000779?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Drosophila C virus infection
# EFO_0000780
# **EFO_0000780**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000780?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Enterococcus faecalis infection
# EFO_0000781
# **EFO_0000781**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000781?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Pectobacterium carotovorum infection
# EFO_0000782
# **EFO_0000782**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000782?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Hibiscus chlorotic ringspot virus infection
# found no mondo for EFO_0000782
# EFO_0001055
# **EFO_0001055**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001055?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING borderline leprosy
# EFO_0001056
# **EFO_0001056**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001056?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING tuberculoid leprosy
# EFO_0001057
# **EFO_0001057**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001057?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING lepromatous leprosy
# EFO_0001060
# **EFO_0001060**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001060?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING celiac disease
# EFO_0001064
# **EFO_0001064**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001064?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Down syndrome
# EFO_0001066
# **EFO_0001066**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001066?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING experimental autoimmune encephalomyelitis
# EFO_0001070
# **EFO_0001070**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001070?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING folate deficiency
# found no mondo for EFO_0001070
# EFO_0001072
# **EFO_0001072**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001072?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING memory impairment
# found no mondo for EFO_0001072
# EFO_0001074
# **EFO_0001074**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001074?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING morbid obesity
# EFO_0001077
# **EFO_0001077**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001077?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Pseudomonas aeruginosa CF5 infection
# EFO_0001078
# **EFO_0001078**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001078?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Pseudomonas aeruginosa PA14 infection
# EFO_0001357
# **EFO_0001357**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001357?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING sporadic amyotrophic lateral sclerosis
# EFO_0001358
# **EFO_0001358**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001358?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING post-traumatic stress disorder
# EFO_0001382
# **EFO_0001382**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001382?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING puberty
# found no mondo for EFO_0001382
# EFO_0001425
# **EFO_0001425**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001425?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING ischemic cardiomyopathy
# found no mondo for EFO_0001425
# EFO_0001675
# **EFO_0001675**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0001675?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING simian immunodeficiency virus infection
# EFO_0002423
# **EFO_0002423**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002423?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING osteoma
# EFO_0002429
# **EFO_0002429**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002429?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING polycythemia vera
# found no mondo for EFO_0002429
# EFO_0002430
# **EFO_0002430**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002430?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING primary myelofibrosis
# EFO_0002496
# **EFO_0002496**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002496?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING actinic keratosis
# EFO_0002497
# **EFO_0002497**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002497?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acute hypotension
# EFO_0002498
# **EFO_0002498**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002498?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING aggressive insulitis
# EFO_0002499
# **EFO_0002499**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002499?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING anaplastic astrocytoma
# EFO_0002500
# **EFO_0002500**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002500?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING anaplastic oligoastrocytoma
# EFO_0002501
# **EFO_0002501**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002501?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING anaplastic oligodendroglioma
# EFO_0002502
# **EFO_0002502**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002502?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING benign insulitis
# EFO_0002504
# **EFO_0002504**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002504?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING serous cystadenoma
# EFO_0002507
# **EFO_0002507**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002507?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING ovarian adenoma benign
# EFO_0002510
# **EFO_0002510**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002510?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING serous cystadenofibroma
# EFO_0002511
# **EFO_0002511**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002511?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING simple cystadenoma
# found no mondo for EFO_0002511
# EFO_0002546
# **EFO_0002546**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002546?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING abnormal glucose tolerance
# found no mondo for EFO_0002546
# EFO_0002608
# **EFO_0002608**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002608?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING AIDS dementia
# found no mondo for EFO_0002608
# EFO_0002610
# **EFO_0002610**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002610?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING cocaine dependence
# EFO_0002613
# **EFO_0002613**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002613?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING iatrogenic Kaposi's sarcoma
# EFO_0002614
# **EFO_0002614**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002614?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING obsolete_insulin resistance
# found no mondo for EFO_0002614
# EFO_0002615
# **EFO_0002615**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002615?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING internal carotid artery stenosis
# EFO_0002616
# **EFO_0002616**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002616?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING macroglobulinemia
# found no mondo for EFO_0002616
# EFO_0002617
# **EFO_0002617**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002617?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING metastatic melanoma
# EFO_0002622
# **EFO_0002622**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002622?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING rotavirus infection
# EFO_0002623
# **EFO_0002623**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002623?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING septic peritonitis
# EFO_0002628
# **EFO_0002628**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002628?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING peripartum cardiomyopathy
# EFO_0002629
# **EFO_0002629**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002629?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING viral cardiomyopathy
# found no mondo for EFO_0002629
# EFO_0002686
# **EFO_0002686**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002686?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING atopy
# found no mondo for EFO_0002686
# EFO_0002687
# **EFO_0002687**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002687?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING ischemia reperfusion injury
# EFO_0002689
# **EFO_0002689**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002689?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING antiphospholipid syndrome
# EFO_0002756
# **EFO_0002756**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002756?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING fasting
# found no mondo for EFO_0002756
# EFO_0002894
# **EFO_0002894**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0002894?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING amelanotic skin melanoma
# EFO_0003015
# **EFO_0003015**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003015?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING aggressive behavior
# found no mondo for EFO_0003015
# EFO_0003016
# **EFO_0003016**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003016?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING collecting duct carcinoma
# EFO_0003017
# **EFO_0003017**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003017?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING transitional cell carcinoma of kidney
# found no mondo for EFO_0003017
# EFO_0003026
# **EFO_0003026**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003026?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING minimally differentiated acute myeloblastic leukemia
# found no mondo for EFO_0003026
# EFO_0003027
# **EFO_0003027**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003027?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acute myeloblastic leukemia without maturation
# EFO_0003029
# **EFO_0003029**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003029?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acute basophilic leukemia
# EFO_0003046
# **EFO_0003046**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003046?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING heart transplant rejection
# found no mondo for EFO_0003046
# EFO_0003073
# **EFO_0003073**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003073?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING asymptomatic myeloma
# found no mondo for EFO_0003073
# EFO_0003075
# **EFO_0003075**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003075?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING xanthoma
# EFO_0003083
# **EFO_0003083**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003083?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING pleomorphic liposarcoma
# EFO_0003084
# **EFO_0003084**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003084?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING round cell liposarcoma
# EFO_0003085
# **EFO_0003085**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003085?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING dedifferentiated liposarcoma
# EFO_0003094
# **EFO_0003094**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003094?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING ganglioglioma
# EFO_0003096
# **EFO_0003096**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003096?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Pick disease
# EFO_0003110
# **EFO_0003110**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003110?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING villitis
# found no mondo for EFO_0003110
# EFO_0003145
# **EFO_0003145**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003145?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING high output heart failure
# EFO_0003147
# **EFO_0003147**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003147?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING mild heart failure
# EFO_0003148
# **EFO_0003148**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003148?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING moderate heart failure
# EFO_0003149
# **EFO_0003149**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003149?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING advanced heart failure
# EFO_0003757
# **EFO_0003757**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003757?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Asperger syndrome
# found no mondo for EFO_0003757
# EFO_0003758
# **EFO_0003758**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003758?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING autism
# EFO_0003759
# **EFO_0003759**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003759?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING pervasive developmental disorder - not otherwise specified
# found no mondo for EFO_0003759
# EFO_0003760
# **EFO_0003760**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003760?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING central nervous system cyst
# EFO_0003762
# **EFO_0003762**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003762?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING vitamin D deficiency
# EFO_0003764
# **EFO_0003764**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003764?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING transient ischemic attack
# EFO_0003766
# **EFO_0003766**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003766?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING obsolete_pain in abdomen
# found no mondo for EFO_0003766
# EFO_0003768
# **EFO_0003768**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003768?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING nicotine dependence
# EFO_0003779
# **EFO_0003779**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003779?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Hashimoto's thyroiditis
# found no mondo for EFO_0003779
# EFO_0003780
# **EFO_0003780**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003780?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Behcet's syndrome
# found no mondo for EFO_0003780
# EFO_0003783
# **EFO_0003783**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003783?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING progressive bulbar palsy
# EFO_0003802
# **EFO_0003802**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003802?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING refractory anemia
# found no mondo for EFO_0003802
# EFO_0003811
# **EFO_0003811**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003811?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING refractory anemia with excess blasts
# found no mondo for EFO_0003811
# EFO_0003812
# **EFO_0003812**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003812?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING refractory anemia with ringed sideroblasts
# found no mondo for EFO_0003812
# EFO_0003822
# **EFO_0003822**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003822?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING hyperemia
# found no mondo for EFO_0003822
# EFO_0003830
# **EFO_0003830**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003830?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING prostatitis
# EFO_0003837
# **EFO_0003837**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003837?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING calcification
# found no mondo for EFO_0003837
# EFO_0003849
# **EFO_0003849**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003849?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING palatal neoplasm
# EFO_0003854
# **EFO_0003854**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003854?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING postmenopausal osteoporosis
# EFO_0003855
# **EFO_0003855**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003855?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING intestinal polyp
# EFO_0003874
# **EFO_0003874**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003874?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING flatfoot
# EFO_0003876
# **EFO_0003876**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003876?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING intermittent vascular claudication
# EFO_0003888
# **EFO_0003888**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003888?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING attention deficit hyperactivity disorder
# found no mondo for EFO_0003888
# EFO_0003894
# **EFO_0003894**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003894?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acne
# EFO_0003895
# **EFO_0003895**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003895?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING epistaxis
# found no mondo for EFO_0003895
# EFO_0003896
# **EFO_0003896**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003896?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING left ventricular hypertrophy
# found no mondo for EFO_0003896
# EFO_0003898
# **EFO_0003898**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003898?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING ankylosing spondylitis
# EFO_0003901
# **EFO_0003901**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003901?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING dysuria
# found no mondo for EFO_0003901
# EFO_0003902
# **EFO_0003902**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003902?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING spinal fracture
# EFO_0003907
# **EFO_0003907**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003907?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING deep vein thrombosis
# found no mondo for EFO_0003907
# EFO_0003911
# **EFO_0003911**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003911?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING atrial flutter
# EFO_0003913
# **EFO_0003913**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003913?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING angina pectoris
# found no mondo for EFO_0003913
# EFO_0003921
# **EFO_0003921**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003921?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING pouchitis
# EFO_0003922
# **EFO_0003922**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003922?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING obsolete_menopause
# found no mondo for EFO_0003922
# EFO_0003924
# **EFO_0003924**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003924?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING hair color
# found no mondo for EFO_0003924
# EFO_0003928
# **EFO_0003928**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003928?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING necrotizing enterocolitis
# EFO_0003929
# **EFO_0003929**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003929?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING relapsing-remitting multiple sclerosis
# EFO_0003930
# **EFO_0003930**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003930?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING menarche
# found no mondo for EFO_0003930
# EFO_0003932
# **EFO_0003932**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003932?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING bacterial vaginosis
# EFO_0003939
# **EFO_0003939**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003939?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING energy intake
# found no mondo for EFO_0003939
# EFO_0003943
# **EFO_0003943**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003943?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING humerus fracture
# EFO_0003944
# **EFO_0003944**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003944?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING tibia fracture
# EFO_0003949
# **EFO_0003949**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003949?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING eye color
# found no mondo for EFO_0003949
# EFO_0003952
# **EFO_0003952**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003952?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING fever of unknown origin
# found no mondo for EFO_0003952
# EFO_0003956
# **EFO_0003956**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003956?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING seasonal allergic rhinitis
# EFO_0003957
# **EFO_0003957**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003957?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING radius fracture
# EFO_0003958
# **EFO_0003958**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003958?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING sunburn
# EFO_0003964
# **EFO_0003964**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0003964?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING hip fracture
# EFO_0004125
# **EFO_0004125**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004125?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING growth hormone-secreting pituitary adenoma
# found no mondo for EFO_0004125
# EFO_0004126
# **EFO_0004126**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004126?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Adie syndrome
# found no mondo for EFO_0004126
# EFO_0004127
# **EFO_0004127**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004127?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING hyperthyroxinemia
# EFO_0004138
# **EFO_0004138**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004138?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING bundle branch block
# found no mondo for EFO_0004138
# EFO_0004143
# **EFO_0004143**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004143?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING carpal tunnel syndrome
# EFO_0004144
# **EFO_0004144**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004144?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING acatalasia
# EFO_0004191
# **EFO_0004191**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004191?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING androgenetic alopecia
# EFO_0004192
# **EFO_0004192**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004192?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING alopecia areata
# EFO_0004194
# **EFO_0004194**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004194?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING IGA glomerulonephritis
# EFO_0004207
# **EFO_0004207**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004207?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING pathological myopia
# found no mondo for EFO_0004207
# EFO_0004208
# **EFO_0004208**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004208?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Vitiligo
# EFO_0004209
# **EFO_0004209**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004209?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING hypospadias
# EFO_0004212
# **EFO_0004212**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004212?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Keloid
# EFO_0004213
# **EFO_0004213**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004213?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING otosclerosis
# EFO_0004215
# **EFO_0004215**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004215?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING obsolete_anorexia nervosa
# found no mondo for EFO_0004215
# EFO_0004216
# **EFO_0004216**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004216?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING conduct disorder
# EFO_0004220
# **EFO_0004220**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004220?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING chronic hepatitis C virus infection
# EFO_0004224
# **EFO_0004224**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004224?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Coronary Restenosis
# EFO_0004227
# **EFO_0004227**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004227?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Dengue Hemorrhagic Fever
# EFO_0004228
# **EFO_0004228**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004228?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING drug-induced liver injury
# EFO_0004229
# **EFO_0004229**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004229?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Dupuytren Contracture
# found no mondo for EFO_0004229
# EFO_0004233
# **EFO_0004233**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004233?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING obsolete_leukopenia
# found no mondo for EFO_0004233
# EFO_0004235
# **EFO_0004235**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004235?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING exfoliation syndrome
# EFO_0004239
# **EFO_0004239**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004239?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING chronic hepatitis B virus infection
# EFO_0004240
# **EFO_0004240**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004240?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING heroin dependence
# EFO_0004242
# **EFO_0004242**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004242?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING obsessive-compulsive disorder
# EFO_0004246
# **EFO_0004246**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004246?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING mucocutaneous lymph node syndrome
# EFO_0004249
# **EFO_0004249**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004249?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING meningococcal infection
# EFO_0004251
# **EFO_0004251**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004251?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING myeloproliferative disorder
# found no mondo for EFO_0004251
# EFO_0004252
# **EFO_0004252**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004252?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING nasopharyngeal neoplasm
# EFO_0004253
# **EFO_0004253**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004253?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING nephrolithiasis
# EFO_0004265
# **EFO_0004265**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004265?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING peripheral arterial disease
# EFO_0004268
# **EFO_0004268**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004268?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING sclerosing cholangitis
# EFO_0004270
# **EFO_0004270**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004270?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING restless legs syndrome
# EFO_0004274
# **EFO_0004274**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004274?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING gout
# EFO_0004276
# **EFO_0004276**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004276?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING Stevens-Johnson syndrome
# EFO_0004278
# **EFO_0004278**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004278?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING sudden cardiac arrest
# EFO_0004279
# **EFO_0004279**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004279?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING suntan
# found no mondo for EFO_0004279
# EFO_0004284
# **EFO_0004284**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004284?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING upper aerodigestive tract neoplasm
# EFO_0004286
# **EFO_0004286**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004286?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING venous thromboembolism
# EFO_0004316
# **EFO_0004316**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004316?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING exploratory behavior
# found no mondo for EFO_0004316
# EFO_0004317
# **EFO_0004317**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004317?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING extraversion
# found no mondo for EFO_0004317
# EFO_0004318
# **EFO_0004318**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004318?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING smoking behavior
# found no mondo for EFO_0004318
# EFO_0004319
# **EFO_0004319**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004319?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING smoking cessation
# found no mondo for EFO_0004319
# EFO_0004320
# **EFO_0004320**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004320?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING suicidal ideation
# found no mondo for EFO_0004320
# EFO_0004321
# **EFO_0004321**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004321?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING attempted suicide
# found no mondo for EFO_0004321
# EFO_0004329
# **EFO_0004329**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004329?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING alcohol drinking
# found no mondo for EFO_0004329
# EFO_0004330
# **EFO_0004330**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004330?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING coffee consumption
# found no mondo for EFO_0004330
# EFO_0004333
# **EFO_0004333**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0004333?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING episodic memory
# found no mondo for EFO_0004333
# EFO_0004334
# **EFO_0004334**
# ...
# MONDO_0021470
# mapping MONDO_0021470
# MONDO_0021474
# mapping MONDO_0021474
# MONDO_0021476
# mapping MONDO_0021476
# MONDO_0021487
# mapping MONDO_0021487
# MONDO_0021496
# mapping MONDO_0021496
# MONDO_0021506
# mapping MONDO_0021506
# MONDO_0021553
# mapping MONDO_0021553
# MONDO_0021633
# mapping MONDO_0021633
# MONDO_0021663
# mapping MONDO_0021663
# MONDO_0021677
# mapping MONDO_0021677
# MONDO_0021718
# mapping MONDO_0021718
# MONDO_0021739
# mapping MONDO_0021739
# MONDO_0021765
# mapping MONDO_0021765
# MONDO_0021804
# mapping MONDO_0021804
# MONDO_0021812
# mapping MONDO_0021812
# MONDO_0021953
# mapping MONDO_0021953
# MONDO_0022057
# mapping MONDO_0022057
# MONDO_0022096
# mapping MONDO_0022096
# MONDO_0022113
# mapping MONDO_0022113
# MONDO_0022293
# mapping MONDO_0022293
# MONDO_0022394
# mapping MONDO_0022394
# MONDO_0022749
# mapping MONDO_0022749
# MONDO_0022963
# mapping MONDO_0022963
# MONDO_0022965
# mapping MONDO_0022965
# MONDO_0023069
# mapping MONDO_0023069
# MONDO_0023297
# mapping MONDO_0023297
# MONDO_0023619
# mapping MONDO_0023619
# MONDO_0023691
# mapping MONDO_0023691
# MONDO_0023692
# mapping MONDO_0023692
# MONDO_0023726
# mapping MONDO_0023726
# MONDO_0023757
# mapping MONDO_0023757
# MONDO_0023868
# mapping MONDO_0023868
# MONDO_0024275
# mapping MONDO_0024275
# MONDO_0024280
# mapping MONDO_0024280
# MONDO_0024290
# mapping MONDO_0024290
# MONDO_0024301
# mapping MONDO_0024301
# MONDO_0024305
# mapping MONDO_0024305
# MONDO_0024306
# mapping MONDO_0024306
# MONDO_0024351
# mapping MONDO_0024351
# MONDO_0024358
# mapping MONDO_0024358
# MONDO_0024392
# mapping MONDO_0024392
# MONDO_0024414
# mapping MONDO_0024414
# MONDO_0024419
# mapping MONDO_0024419
# MONDO_0024464
# mapping MONDO_0024464
# MONDO_0024519
# mapping MONDO_0024519
# MONDO_0024525
# mapping MONDO_0024525
# MONDO_0024546
# mapping MONDO_0024546
# MONDO_0024620
# mapping MONDO_0024620
# MONDO_0024649
# mapping MONDO_0024649
# MONDO_0024677
# mapping MONDO_0024677
# MONDO_0024892
# mapping MONDO_0024892
# MONDO_0025484
# mapping MONDO_0025484
# MONDO_0026045
# mapping MONDO_0026045
# MONDO_0026722
# mapping MONDO_0026722
# MONDO_0026730
# mapping MONDO_0026730
# MONDO_0026733
# mapping MONDO_0026733
# MONDO_0026767
# mapping MONDO_0026767
# MONDO_0026768
# mapping MONDO_0026768
# MONDO_0027751
# mapping MONDO_0027751
# MONDO_0029130
# mapping MONDO_0029130
# MONDO_0029131
# mapping MONDO_0029131
# MONDO_0029133
# mapping MONDO_0029133
# MONDO_0029134
# mapping MONDO_0029134
# MONDO_0029135
# mapping MONDO_0029135
# MONDO_0029136
# mapping MONDO_0029136
# MONDO_0029137
# mapping MONDO_0029137
# MONDO_0029140
# mapping MONDO_0029140
# MONDO_0029143
# mapping MONDO_0029143
# MONDO_0029144
# mapping MONDO_0029144
# MONDO_0030006
# mapping MONDO_0030006
# MONDO_0030007
# mapping MONDO_0030007
# MONDO_0030008
# mapping MONDO_0030008
# MONDO_0030013
# mapping MONDO_0030013
# MONDO_0030015
# mapping MONDO_0030015
# MONDO_0030017
# mapping MONDO_0030017
# MONDO_0030019
# mapping MONDO_0030019
# MONDO_0030020
# mapping MONDO_0030020
# MONDO_0030024
# mapping MONDO_0030024
# MONDO_0030025
# mapping MONDO_0030025
# MONDO_0030027
# mapping MONDO_0030027
# MONDO_0030028
# mapping MONDO_0030028
# MONDO_0030029
# mapping MONDO_0030029
# MONDO_0030030
# mapping MONDO_0030030
# MONDO_0030031
# mapping MONDO_0030031
# MONDO_0030033
# mapping MONDO_0030033
# MONDO_0030034
# mapping MONDO_0030034
# MONDO_0030035
# mapping MONDO_0030035
# MONDO_0030036
# mapping MONDO_0030036
# MONDO_0030037
# mapping MONDO_0030037
# MONDO_0030038
# mapping MONDO_0030038
# MONDO_0030042
# mapping MONDO_0030042
# MONDO_0030043
# mapping MONDO_0030043
# MONDO_0030044
# mapping MONDO_0030044
# MONDO_0030045
# mapping MONDO_0030045
# MONDO_0030046
# mapping MONDO_0030046
# MONDO_0030047
# mapping MONDO_0030047
# MONDO_0030048
# mapping MONDO_0030048
# MONDO_0030049
# mapping MONDO_0030049
# MONDO_0030051
# mapping MONDO_0030051
# MONDO_0030054
# mapping MONDO_0030054
# MONDO_0030055
# mapping MONDO_0030055
# MONDO_0030057
# mapping MONDO_0030057
# MONDO_0030058
# mapping MONDO_0030058
# MONDO_0030059
# mapping MONDO_0030059
# MONDO_0030060
# mapping MONDO_0030060
# MONDO_0030061
# mapping MONDO_0030061
# MONDO_0030062
# mapping MONDO_0030062
# MONDO_0030063
# mapping MONDO_0030063
# MONDO_0030064
# mapping MONDO_0030064
# MONDO_0030065
# mapping MONDO_0030065
# MONDO_0030066
# mapping MONDO_0030066
# MONDO_0030067
# mapping MONDO_0030067
# MONDO_0030069
# mapping MONDO_0030069
# MONDO_0030070
# mapping MONDO_0030070
# MONDO_0030071
# mapping MONDO_0030071
# MONDO_0030072
# mapping MONDO_0030072
# MONDO_0030073
# mapping MONDO_0030073
# MONDO_0030074
# mapping MONDO_0030074
# MONDO_0030087
# mapping MONDO_0030087
# MONDO_0030088
# mapping MONDO_0030088
# MONDO_0030089
# mapping MONDO_0030089
# MONDO_0030105
# mapping MONDO_0030105
# MONDO_0030118
# mapping MONDO_0030118
# MONDO_0030134
# mapping MONDO_0030134
# MONDO_0030907
# mapping MONDO_0030907
# MONDO_0030910
# mapping MONDO_0030910
# MONDO_0030912
# mapping MONDO_0030912
# MONDO_0030914
# mapping MONDO_0030914
# MONDO_0030916
# mapping MONDO_0030916
# MONDO_0030917
# mapping MONDO_0030917
# MONDO_0030918
# mapping MONDO_0030918
# MONDO_0030919
# mapping MONDO_0030919
# MONDO_0030922
# mapping MONDO_0030922
# MONDO_0032485
# mapping MONDO_0032485
# MONDO_0032591
# mapping MONDO_0032591
# MONDO_0032594
# mapping MONDO_0032594
# MONDO_0032610
# mapping MONDO_0032610
# MONDO_0032677
# mapping MONDO_0032677
# MONDO_0032681
# mapping MONDO_0032681
# MONDO_0032687
# mapping MONDO_0032687
# MONDO_0032688
# mapping MONDO_0032688
# MONDO_0032697
# mapping MONDO_0032697
# MONDO_0032737
# mapping MONDO_0032737
# MONDO_0032745
# mapping MONDO_0032745
# MONDO_0032751
# mapping MONDO_0032751
# MONDO_0032755
# mapping MONDO_0032755
# MONDO_0032760
# mapping MONDO_0032760
# MONDO_0032763
# mapping MONDO_0032763
# MONDO_0032781
# mapping MONDO_0032781
# MONDO_0032843
# mapping MONDO_0032843
# MONDO_0032882
# mapping MONDO_0032882
# MONDO_0032884
# mapping MONDO_0032884
# MONDO_0032885
# mapping MONDO_0032885
# MONDO_0032886
# mapping MONDO_0032886
# MONDO_0032887
# mapping MONDO_0032887
# MONDO_0032888
# mapping MONDO_0032888
# MONDO_0032889
# mapping MONDO_0032889
# MONDO_0032890
# mapping MONDO_0032890
# MONDO_0032891
# mapping MONDO_0032891
# MONDO_0032892
# mapping MONDO_0032892
# MONDO_0032893
# mapping MONDO_0032893
# MONDO_0032894
# mapping MONDO_0032894
# MONDO_0032895
# mapping MONDO_0032895
# MONDO_0032896
# mapping MONDO_0032896
# MONDO_0032897
# mapping MONDO_0032897
# MONDO_0032898
# mapping MONDO_0032898
# MONDO_0032899
# mapping MONDO_0032899
# MONDO_0032900
# mapping MONDO_0032900
# MONDO_0032901
# mapping MONDO_0032901
# MONDO_0032902
# mapping MONDO_0032902
# MONDO_0032903
# mapping MONDO_0032903
# MONDO_0032904
# mapping MONDO_0032904
# MONDO_0032905
# mapping MONDO_0032905
# MONDO_0032906
# mapping MONDO_0032906
# MONDO_0032907
# mapping MONDO_0032907
# MONDO_0032908
# mapping MONDO_0032908
# MONDO_0032909
# mapping MONDO_0032909
# MONDO_0032910
# mapping MONDO_0032910
# MONDO_0032911
# mapping MONDO_0032911
# MONDO_0032912
# mapping MONDO_0032912
# MONDO_0032913
# mapping MONDO_0032913
# MONDO_0032914
# mapping MONDO_0032914
# MONDO_0032915
# mapping MONDO_0032915
# MONDO_0032916
# mapping MONDO_0032916
# MONDO_0032917
# mapping MONDO_0032917
# MONDO_0032918
# mapping MONDO_0032918
# MONDO_0032919
# mapping MONDO_0032919
# MONDO_0032920
# mapping MONDO_0032920
# MONDO_0032921
# mapping MONDO_0032921
# MONDO_0032922
# mapping MONDO_0032922
# MONDO_0032923
# mapping MONDO_0032923
# MONDO_0032924
# mapping MONDO_0032924
# MONDO_0032925
# mapping MONDO_0032925
# MONDO_0032926
# mapping MONDO_0032926
# MONDO_0032927
# mapping MONDO_0032927
# MONDO_0032928
# mapping MONDO_0032928
# MONDO_0032930
# mapping MONDO_0032930
# MONDO_0032931
# mapping MONDO_0032931
# MONDO_0032932
# mapping MONDO_0032932
# MONDO_0032934
# mapping MONDO_0032934
# MONDO_0032935
# mapping MONDO_0032935
# MONDO_0032936
# mapping MONDO_0032936
# MONDO_0032937
# mapping MONDO_0032937
# MONDO_0032938
# mapping MONDO_0032938
# MONDO_0032939
# mapping MONDO_0032939
# MONDO_0032940
# mapping MONDO_0032940
# MONDO_0032941
# mapping MONDO_0032941
# MONDO_0032942
# mapping MONDO_0032942
# MONDO_0032943
# mapping MONDO_0032943
# MONDO_0033006
# mapping MONDO_0033006
# MONDO_0033014
# mapping MONDO_0033014
# MONDO_0033043
# mapping MONDO_0033043
# MONDO_0033201
# mapping MONDO_0033201
# MONDO_0033374
# mapping MONDO_0033374
# MONDO_0033482
# mapping MONDO_0033482
# MONDO_0033532
# mapping MONDO_0033532
# MONDO_0033533
# mapping MONDO_0033533
# MONDO_0033534
# mapping MONDO_0033534
# MONDO_0033537
# mapping MONDO_0033537
# MONDO_0033541
# mapping MONDO_0033541
# MONDO_0033542
# mapping MONDO_0033542
# MONDO_0033543
# mapping MONDO_0033543
# MONDO_0033544
# mapping MONDO_0033544
# MONDO_0033545
# mapping MONDO_0033545
# MONDO_0033546
# mapping MONDO_0033546
# MONDO_0033547
# mapping MONDO_0033547
# MONDO_0033548
# mapping MONDO_0033548
# MONDO_0033549
# mapping MONDO_0033549
# MONDO_0033551
# mapping MONDO_0033551
# MONDO_0033554
# mapping MONDO_0033554
# MONDO_0033555
# mapping MONDO_0033555
# MONDO_0033556
# mapping MONDO_0033556
# MONDO_0033557
# mapping MONDO_0033557
# MONDO_0033558
# mapping MONDO_0033558
# MONDO_0033559
# mapping MONDO_0033559
# MONDO_0033560
# mapping MONDO_0033560
# MONDO_0033561
# mapping MONDO_0033561
# MONDO_0033562
# mapping MONDO_0033562
# MONDO_0033563
# mapping MONDO_0033563
# MONDO_0033564
# mapping MONDO_0033564
# MONDO_0033565
# mapping MONDO_0033565
# MONDO_0033566
# mapping MONDO_0033566
# MONDO_0033569
# mapping MONDO_0033569
# MONDO_0033570
# mapping MONDO_0033570
# MONDO_0033572
# mapping MONDO_0033572
# MONDO_0033613
# mapping MONDO_0033613
# MONDO_0033614
# mapping MONDO_0033614
# MONDO_0033615
# mapping MONDO_0033615
# MONDO_0033618
# mapping MONDO_0033618
# MONDO_0033619
# mapping MONDO_0033619
# MONDO_0033620
# mapping MONDO_0033620
# MONDO_0033621
# mapping MONDO_0033621
# MONDO_0033622
# mapping MONDO_0033622
# MONDO_0033635
# mapping MONDO_0033635
# MONDO_0033636
# mapping MONDO_0033636
# MONDO_0033637
# mapping MONDO_0033637
# MONDO_0033638
# mapping MONDO_0033638
# MONDO_0033639
# mapping MONDO_0033639
# MONDO_0033645
# mapping MONDO_0033645
# MONDO_0033646
# mapping MONDO_0033646
# MONDO_0033649
# mapping MONDO_0033649
# MONDO_0033650
# mapping MONDO_0033650
# MONDO_0033651
# mapping MONDO_0033651
# MONDO_0033652
# mapping MONDO_0033652
# MONDO_0033653
# mapping MONDO_0033653
# MONDO_0033654
# mapping MONDO_0033654
# MONDO_0033655
# mapping MONDO_0033655
# MONDO_0033656
# mapping MONDO_0033656
# MONDO_0033683
# mapping MONDO_0033683
# MONDO_0033948
# mapping MONDO_0033948
# MONDO_0033967
# mapping MONDO_0033967
# MONDO_0034103
# mapping MONDO_0034103
# MONDO_0034204
# mapping MONDO_0034204
# MONDO_0036484
# mapping MONDO_0036484
# MONDO_0037737
# mapping MONDO_0037737
# MONDO_0040500
# mapping MONDO_0040500
# MONDO_0041086
# mapping MONDO_0041086
# MONDO_0041447
# mapping MONDO_0041447
# MONDO_0041825
# mapping MONDO_0041825
# MONDO_0042233
# mapping MONDO_0042233
# MONDO_0042484
# mapping MONDO_0042484
# MONDO_0042487
# mapping MONDO_0042487
# MONDO_0043224
# mapping MONDO_0043224
# MONDO_0043237
# mapping MONDO_0043237
# MONDO_0043364
# mapping MONDO_0043364
# MONDO_0043765
# mapping MONDO_0043765
# MONDO_0044001
# mapping MONDO_0044001
# MONDO_0044206
# mapping MONDO_0044206
# MONDO_0044302
# mapping MONDO_0044302
# MONDO_0044303
# mapping MONDO_0044303
# MONDO_0044304
# mapping MONDO_0044304
# MONDO_0044306
# mapping MONDO_0044306
# MONDO_0044312
# mapping MONDO_0044312
# MONDO_0044316
# mapping MONDO_0044316
# MONDO_0044318
# mapping MONDO_0044318
# MONDO_0044319
# mapping MONDO_0044319
# MONDO_0044322
# mapping MONDO_0044322
# MONDO_0044324
# mapping MONDO_0044324
# MONDO_0044325
# mapping MONDO_0044325
# MONDO_0044326
# mapping MONDO_0044326
# MONDO_0044327
# mapping MONDO_0044327
# MONDO_0044635
# mapping MONDO_0044635
# MONDO_0044660
# mapping MONDO_0044660
# MONDO_0044714
# mapping MONDO_0044714
# MONDO_0044724
# mapping MONDO_0044724
# MONDO_0044725
# mapping MONDO_0044725
# MONDO_0044727
# mapping MONDO_0044727
# MONDO_0044738
# mapping MONDO_0044738
# MONDO_0044784
# mapping MONDO_0044784
# MONDO_0044785
# mapping MONDO_0044785
# MONDO_0044787
# mapping MONDO_0044787
# MONDO_0044791
# mapping MONDO_0044791
# MONDO_0044792
# mapping MONDO_0044792
# MONDO_0044793
# mapping MONDO_0044793
# MONDO_0044877
# mapping MONDO_0044877
# MONDO_0044889
# mapping MONDO_0044889
# MONDO_0044903
# mapping MONDO_0044903
# MONDO_0044915
# mapping MONDO_0044915
# MONDO_0044916
# mapping MONDO_0044916
# MONDO_0044917
# mapping MONDO_0044917
# MONDO_0045023
# mapping MONDO_0045023
# MONDO_0045031
# mapping MONDO_0045031
# no MONDO found for DOID/ORDO/MONDO https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0045031/mappings
# found no mondo for MONDO_0045031
# MONDO_0045056
# mapping MONDO_0045056
# MONDO_0045068
# mapping MONDO_0045068
# MONDO_0049221
# mapping MONDO_0049221
# MONDO_0054559
# mapping MONDO_0054559
# MONDO_0054565
# mapping MONDO_0054565
# MONDO_0054591
# mapping MONDO_0054591
# MONDO_0054636
# mapping MONDO_0054636
# MONDO_0054691
# mapping MONDO_0054691
# MONDO_0054695
# mapping MONDO_0054695
# MONDO_0054699
# mapping MONDO_0054699
# MONDO_0054700
# mapping MONDO_0054700
# MONDO_0054732
# mapping MONDO_0054732
# MONDO_0054733
# mapping MONDO_0054733
# MONDO_0054741
# mapping MONDO_0054741
# MONDO_0054742
# mapping MONDO_0054742
# MONDO_0054743
# mapping MONDO_0054743
# MONDO_0054748
# mapping MONDO_0054748
# MONDO_0054750
# mapping MONDO_0054750
# MONDO_0054764
# mapping MONDO_0054764
# MONDO_0054781
# mapping MONDO_0054781
# MONDO_0054782
# mapping MONDO_0054782
# MONDO_0054785
# mapping MONDO_0054785
# MONDO_0054794
# mapping MONDO_0054794
# MONDO_0054801
# mapping MONDO_0054801
# MONDO_0054813
# mapping MONDO_0054813
# MONDO_0054817
# mapping MONDO_0054817
# MONDO_0054833
# mapping MONDO_0054833
# MONDO_0054837
# mapping MONDO_0054837
# MONDO_0054842
# mapping MONDO_0054842
# MONDO_0054845
# mapping MONDO_0054845
# MONDO_0054852
# mapping MONDO_0054852
# MONDO_0054860
# mapping MONDO_0054860
# MONDO_0056797
# mapping MONDO_0056797
# MONDO_0060457
# mapping MONDO_0060457
# MONDO_0060490
# mapping MONDO_0060490
# MONDO_0060491
# mapping MONDO_0060491
# MONDO_0060502
# mapping MONDO_0060502
# MONDO_0060507
# mapping MONDO_0060507
# MONDO_0060510
# mapping MONDO_0060510
# MONDO_0060527
# mapping MONDO_0060527
# MONDO_0060532
# mapping MONDO_0060532
# MONDO_0060533
# mapping MONDO_0060533
# MONDO_0060549
# mapping MONDO_0060549
# MONDO_0060551
# mapping MONDO_0060551
# MONDO_0060554
# mapping MONDO_0060554
# MONDO_0060555
# mapping MONDO_0060555
# MONDO_0060556
# mapping MONDO_0060556
# MONDO_0060577
# mapping MONDO_0060577
# MONDO_0060578
# mapping MONDO_0060578
# MONDO_0060582
# mapping MONDO_0060582
# MONDO_0060583
# mapping MONDO_0060583
# MONDO_0060589
# mapping MONDO_0060589
# MONDO_0060591
# mapping MONDO_0060591
# MONDO_0060593
# mapping MONDO_0060593
# MONDO_0060596
# mapping MONDO_0060596
# MONDO_0060611
# mapping MONDO_0060611
# MONDO_0060622
# mapping MONDO_0060622
# MONDO_0060624
# mapping MONDO_0060624
# MONDO_0060627
# mapping MONDO_0060627
# MONDO_0060631
# mapping MONDO_0060631
# MONDO_0060640
# mapping MONDO_0060640
# MONDO_0060641
# mapping MONDO_0060641
# MONDO_0060642
# mapping MONDO_0060642
# MONDO_0060650
# mapping MONDO_0060650
# MONDO_0060663
# mapping MONDO_0060663
# MONDO_0060664
# mapping MONDO_0060664
# MONDO_0060666
# mapping MONDO_0060666
# MONDO_0060702
# mapping MONDO_0060702
# MONDO_0060704
# mapping MONDO_0060704
# MONDO_0060707
# mapping MONDO_0060707
# MONDO_0060711
# mapping MONDO_0060711
# MONDO_0060712
# mapping MONDO_0060712
# MONDO_0060713
# mapping MONDO_0060713
# MONDO_0060720
# mapping MONDO_0060720
# MONDO_0060724
# mapping MONDO_0060724
# MONDO_0060729
# mapping MONDO_0060729
# MONDO_0060733
# mapping MONDO_0060733
# MONDO_0060745
# mapping MONDO_0060745
# MONDO_0060752
# mapping MONDO_0060752
# MONDO_0060758
# mapping MONDO_0060758
# MONDO_0060759
# mapping MONDO_0060759
# MONDO_0060760
# mapping MONDO_0060760
# MONDO_0060761
# mapping MONDO_0060761
# MONDO_0060763
# mapping MONDO_0060763
# MONDO_0060779
# mapping MONDO_0060779
# MONDO_0100035
# mapping MONDO_0100035
# MONDO_0100039
# mapping MONDO_0100039
# MONDO_0100040
# mapping MONDO_0100040
# MONDO_0100058
# mapping MONDO_0100058
# MONDO_0100061
# mapping MONDO_0100061
# MONDO_0100069
# mapping MONDO_0100069
# MONDO_0100095
# mapping MONDO_0100095
# MONDO_0100096
# mapping MONDO_0100096
# MONDO_0100114
# mapping MONDO_0100114
# MONDO_0100116
# mapping MONDO_0100116
# MONDO_0100130
# mapping MONDO_0100130
# MONDO_0100147
# mapping MONDO_0100147
# MONDO_0100157
# mapping MONDO_0100157
# MONDO_0100176
# mapping MONDO_0100176
# MONDO_0100186
# mapping MONDO_0100186
# MONDO_0100194
# mapping MONDO_0100194
# MONDO_0100195
# mapping MONDO_0100195
# MONDO_0100218
# mapping MONDO_0100218
# MONDO_0100219
# mapping MONDO_0100219
# MONDO_0100220
# mapping MONDO_0100220
# MONDO_0100221
# mapping MONDO_0100221
# MONDO_0100320
# mapping MONDO_0100320
# NCIT_C117245
# mapping NCIT_C117245
# found no results for NCIT_C117245
# NCIT_C74532
# mapping NCIT_C74532
# found no results for NCIT_C74532
# NCIT_C95746
# mapping NCIT_C95746
# found no results for NCIT_C95746
# OBI_1110021
# mapping OBI_1110021
# found no results for OBI_1110021
# source
# mapping source
# found no results for source
# target
# mapping target
# found no results for target

# %%
puts `pwd`
# Out:
# /home/osboxes/CODE/SIMPATHIC2/SKG_Mapping/radboud
