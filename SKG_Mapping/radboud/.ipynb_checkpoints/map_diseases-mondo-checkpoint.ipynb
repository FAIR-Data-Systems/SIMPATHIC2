# %% [markdown]
# # Map Diseases Radboud -> MONDO
#
# # Strategy
#
# Diseases have been extracted from the three files that contain disease references.
#
# This is disease.list.uniq
#
# There's all kinds of namespaces in there... a bit of a mess!
#
# Here we will try to map into MONDO.  In some cases, the disease reference is already MONDO, so that's good!  Other namespaces that I think we can mange are:  EFO (sometimes), DOID, and Orphanet

# %%
# puts `head -20 disease.list.uniq`
# puts `grep MONDO disease.list.uniq | head -20`
puts ENV["APIKEY"]
# Out:
# 74027bd8-6be0-4329-be22-aa3717f97243

# %%
require 'rest-client'
require 'json'

def map_id_to_disease(name)
    name.strip!
    warn "mapping #{name}"
  return false unless (name =~ /EFO_/ || name =~ /DOID_(.*)/ || name =~ /MONDO_(.*)/ || name =~ /Orphanet_(.*)/)
  identifier = $1  #W dfrom the match above
  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    if name =~ /DOID/
      url =  "https://data.bioontology.org/search?q=DOID:#{identifier}&ontologies=DOID&require_exact_match=true&apikey=#{api_key}"
    elsif name =~ /MONDO/
      url =  "https://data.bioontology.org/search?q=MONDO:#{identifier}&ontologies=MONDO&require_exact_match=true&apikey=#{api_key}"      
    else
      url =  "https://data.bioontology.org/search?q=Orphanet:#{identifier}&ontologies=ORDO&require_exact_match=true&apikey=#{api_key}"
    end
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for #{name} #{e.inspect}\n"
    return false
  end
  mappings = []
  data = JSON.parse(response)

#  if hit = data.dig('collection', 0)
  if hit = data.dig('collection')
    hit.each do |h|
      disease_name = h&.dig('prefLabel')
      uri = h&.dig('@id')
      linksurl = h&.dig('links', 'mappings')
      mappings << { id: name, uri: uri, disease_name: disease_name, linksurl: linksurl}
    end
    return mappings
  else
    warn "No data found for #{name}\n"
    return false
  end

rescue StandardError => e
  warn "No data found for #{name} Error: #{e.inspect}\n"
  return false
end

# test
["DOID_7551", "MONDO_0000070", "Orphanet_10"].each do |name|
  warn map_id_to_disease(name)  # returns array
end
# Out:
# mapping DOID_7551
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings"}
# mapping MONDO_0000070
# {:id=>"MONDO_0000070", :uri=>"http://purl.obolibrary.org/obo/MONDO_0000070", :disease_name=>"Mycobacterium tuberculosis, susceptibility", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0000070/mappings"}
# mapping Orphanet_10
# {:id=>"Orphanet_10", :uri=>"http://www.orpha.net/ORDO/Orphanet_10", :disease_name=>"48,XXYY syndrome", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_10/mappings"}
# ["DOID_7551", "MONDO_0000070", "Orphanet_10"]

# %%
def get_mondo_from_mapping(mapping)
  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    url = mapping+"?apikey=#{api_key}"
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for mapping #{e.inspect}\n"
    return false
  end
    mappings = []
    data = JSON.parse(response)

    data.each do |mapp|
      mapp["classes"].each do |thisclass|
        next unless thisclass["@id"] =~ /MONDO/
        return {"mondo": thisclass["@id"]}
      end
    end
    warn "no MONDO found for DOID/ORDO/MONDO #{mapping}"
    return false

rescue StandardError => e
  warn  "parsing or other error in #{mapping} Error: #{e.inspect}\n"
  return false
end

# test
["DOID_7551", "MONDO_0000070", "Orphanet_10"].each do |name|
  results = map_id_to_disease(name)  # this returns a hash
  if results
    results = results.first # (can only be one)
    nextres = get_mondo_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    end
    puts results
  else
    warn "found no results for #{name}"
  end
end
# Out:
# mapping DOID_7551
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0004277"}
# mapping MONDO_0000070
# {:id=>"MONDO_0000070", :uri=>"http://purl.obolibrary.org/obo/MONDO_0000070", :disease_name=>"Mycobacterium tuberculosis, susceptibility", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0000070/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0000070"}
# mapping Orphanet_10
# {:id=>"Orphanet_10", :uri=>"http://www.orpha.net/ORDO/Orphanet_10", :disease_name=>"48,XXYY syndrome", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_10/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0015028"}
# ["DOID_7551", "MONDO_0000070", "Orphanet_10"]

# %% [markdown]
# ## Special Case EFO
# sometimes can find efo -> MONDO

# %%
require 'rest-client'
require 'json'

def special_case_efo_to_mondo(efo)
        efo.strip!
    warn "**#{efo}**"

    api_key = ENV["APIKEY"]
    url = "https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2F#{efo}?apikey=#{api_key}"
    warn url
    headers = {
    "Accept"     => "application/json",
    "User-Agent" => "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
    }

    begin
        response = RestClient.get(url, headers: headers)
#         warn response
    rescue
        warn "step 1 EFO Lookup failed"
        return false
    end
    
    data = JSON.parse(response.body)
    mondo = ""

    if prefname = data.dig('prefLabel')
        warn "MATCHING #{prefname}"
        url2 = "https://data.bioontology.org/search?q=#{prefname}&ontologies=MONDO&apikey=#{api_key}"
#         warn "getting #{url2}"
        begin
            response = RestClient.get(url2, headers: headers)
        rescue
            warn "step 2 failed - search for MONDO by prefname HTTP call failed"
            return false
        end
        data = JSON.parse(response)
#         warn data
        records = data.dig('collection')
        records.each do |r|
#             warn r['prefLabel']
            next unless r['prefLabel'].downcase == prefname.downcase
            mondo = r['@id']
            break
        end
    else
        warn "Step 2 failed - can't find preflabel for #{efo}...???"
    end
    if mondo
        return {id: efo, mondo: mondo, disease_name: prefname}
    else
        warn "general failure - can't find mondo for #{efo} #{prefname} ...???"
        return false
    end
end
# test
puts special_case_efo_to_mondo("EFO_0000713")
# Out:
# **EFO_0000713**
# https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2FEFO_0000713?apikey=74027bd8-6be0-4329-be22-aa3717f97243
# MATCHING subarachnoid hemorrhage
# {:id=>"EFO_0000713", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0005099", :disease_name=>"subarachnoid hemorrhage"}

# %% [markdown]
# ## special case Orphanet
# BioOntologies has a mapping from MONDO to Orphanet, but not vice versa
#
# SO... if we have an Orphanet code, we need to get the prefLabel (disease name according to orphanet), then search MONDO by that disease name, and match it against the discovered MONDO recofrds.  UNFORTUNATELY, it often appears as a synonym, rather than the prefLabel for the record, so... that sucks!
#
# Note - it is not the first or even the only match!  Need to parse through all matching MONDO records until we hit the exact match in the synonyms.

# %%
# require 'rest-client'
# require 'json'

# def special_case_orpha_to_mondo(orphacode)
#         orphacode.strip!

#     api_key = ENV["APIKEY"]
#     mapping = map_id_to_disease(orphacode).first  # returns array
# #     warn mapping.class
# # {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings"}
#     search_term = mapping[:disease_name]
# #     warn search_term
#     unless search_term
#         warn "no disease name found for #{orphacode} (this is very strange!)"
#         return false
#     end
#     searchurl = "https://data.bioontology.org/search?q=#{search_term}&ontologies=MONDO&apikey=#{api_key}"
#     headers = {
#     "Accept"     => "application/json",
#     "User-Agent" => "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
#     }

#     begin
#         response = RestClient.get(searchurl, headers: headers)
# #         warn response
#     rescue
#         return false
#     end
#     warn "matching #{search_term}"
#     mondo = ""
#     data = JSON.parse(response)
#     records = data.dig('collection')
#     records.each do |r|
# # prefLabel": "hereditary spastic paraplegia 30",
# # -"synonym": [
# # "KIF1A hereditary spastic paraplegia",
# # "hereditary spastic paraplegia type 30",
# # "autosomal spastic paraplegia type 30",
# # "hereditary spastic paraplegia caused by mutation in KIF1A",
# # "spastic paraplegia 30, autosomal dominant",
# # "SPG30"
# # ],
#         next unless r['synonym']
#         r['synonym'].each do |synonym|
# #             warn "match against #{synonym}"
#             next unless synonym.downcase == search_term.downcase
#             mondo = r['@id']
#         end
#     end
#     if mondo
#         return mapping.merge!({mondo: mondo})  #W preserve the existing hash
#     else
#         warn "general failure - can't find mondo for orphanet #{orphacode} #{search_term} ...???"

#         return false
#     end

# end

# # test
# ["Orphanet_101010"].each do |orphacode|
#   puts  special_case_orpha_to_mondo(orphacode)
# #     {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0004277"}
# end

# %%
require 'rest-client'
require 'json'

def special_case_orpha_to_mondo(orphacode)
    orphacode.strip!
#     warn "special case orphacode #{orphacode}"
    mapping = map_id_to_disease(orphacode).first  # returns array
    warn mapping.class
    unless mapping
        warn "no mapping found for #{orphacode} (this is very strange!)"
        return false
    end
    
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings"}
    search_term = mapping[:disease_name]
#     warn search_term
    unless search_term
        warn "no disease name found for #{orphacode} (this is very strange!)"
        return false
    end
    
    monarch_orphacode = orphacode.gsub(/_/, ":")
    entity_ids = "entity_id=#{monarch_orphacode}&"

    response = RestClient.get(
    "https://api-v3.monarchinitiative.org/v3/api/mappings?#{entity_ids}format=json&limit=500&offset=0"
    )

#     warn "Request URL: #{response.request.url}"

    data = JSON.parse(response.body)
# warn data
    data['items'].each do |item|
        if item['object_id'] =~ /#{monarch_orphacode}/
          mondo_id = item['subject_id']  # e.g. "MONDO:0018940"
          mondo_term = item['subject_label']  # e.g. "Leigh Syndrome"
          mondo_id.gsub!("MONDO:", "http://purl.obolibrary.org/obo/MONDO_")
          return mapping.merge({mondo: mondo_id, term: mondo_term})
        end
    end
    warn "general failure - can't find mondo for orphanet #{orphacode} #{search_term} ...???"
    return false
end

# test
["Orphanet_3315","Orphanet_101010"].each do |orphacode|
  puts  special_case_orpha_to_mondo(orphacode)
#     {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0004277"}
end
# Out:
# mapping Orphanet_3315
# NilClass
# no mapping found for Orphanet_3315 (this is very strange!)
# false
# mapping Orphanet_101010
# Hash
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0012476", :term=>"hereditary spastic paraplegia 30"}
# ["Orphanet_3315", "Orphanet_101010"]

# %%
require 'csv'

file = "disease.list.uniq"

diseaselist = File.readlines(file)

puts diseaselist.length  
puts diseaselist.first
# Out:
# 9341
# "DOID_10718"

# %%
puts `grep -i 'orphanet_' disease.list.uniq | wc -l`
# Out:
# 0

# %%
puts `grep -i EFO disease.list.uniq | wc -l`
# Out:
# 2829

# %%
$stdout.sync = true   # Disables buffering for STDOUT
$stderr.sync = true   # Disables buffering for STDERR (warn, etc.)

# write the mapping file
# f = File.open("./maps/diseases.map", "w")
# e = File.open("./maps/diseases-errors.txt", "w")
# f.write CSV.generate_line(["source","mondo","prefname"])

# FOR RESTART ONLY!!!!
f = File.open("./maps/diseases.map", "a")
e = File.open("./maps/diseases-errors.txt", "a")



diseaselist = File.readlines(file)

# spoeial case for EFO
# diseaselist.each do |name|
#     cleanname = name.gsub(/"/, "")
#     next unless cleanname =~ /EFO_/
#     warn cleanname
#     res = special_case_efo_to_mondo(cleanname) # {:id=>"EFO_0000713", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0005099", :disease_name=>"subarachnoid hemorrhage"}
#     if !res || res[:mondo].empty?
#         warn "found no mondo for #{cleanname}"
#         e.write "found no mondo for #{cleanname}\n"
#         e.flush  # This forces the write to disk immediately
#         next
#     end
#     f.write CSV.generate_line([cleanname,res[:mondo],res[:disease_name]])
#     f.flush
# end

# I HAVE NO IDEA WHY THIS RESET IS NECESSARY, but orphanet codes are changed to ":" instead of "_"... somewhere
diseaselist = File.readlines(file)
# spoeial case for ORPHA
diseaselist.each do |name|
    cleanname = name.gsub(/"/, "")
    next unless cleanname =~ /Orphanet_/
    warn cleanname
    res = special_case_orpha_to_mondo(cleanname) # {:id=>"Orphanet:101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :mondo=>"http://purl.obolibrary.org/obo/MONDO_0012476"}
    if !res || res[:mondo].empty?
        warn "found no mondo for #{cleanname}"
        e.write "found no mondo for #{cleanname}\n"
        e.flush
        next
    end
    warn "found mondo #{res[:mondo]}"
    f.write CSV.generate_line([cleanname,res[:mondo],res[:disease_name]])
    f.flush
end

diseaselist = File.readlines(file)
# diseaselist.each do |name|
#     cleanname = name.gsub(/"/, "")
#     next if cleanname =~ /HP_/  # not HPO terms
#     next if cleanname =~ /EFO_/  # not EFO terms
#     next if cleanname =~ /OTAR_/  # not OTAR terms
#     next if cleanname =~ /Orphanet_/  # not ORPHA terms
#     warn cleanname

#   results = map_id_to_disease(cleanname)
#   if results
#     results = results.first # (can only be one)
#     nextres = get_mondo_from_mapping(results[:linksurl])
#     if nextres
#       results.merge! nextres
#     else
#       warn "found no mondo for #{cleanname}"
#       e.write "found no mondo for #{cleanname}\n"
#       e.flush
#     end

#     f.write CSV.generate_line(cleanname,results[:mondo],results[:disease_name]])
#     f.flush
#     # {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/763377006"}
#   else
#     warn "found no results for #{cleanname}"
#     e.write "found no results for #{cleanname}\n"
#     e.flush
#   end
# end
f.close
e.close
# Out:
# Orphanet_10
# mapping Orphanet_10
# Hash
# found mondo MONDO:0015028
# Orphanet_100
# mapping Orphanet_100
# Hash
# found mondo MONDO:0008840
# Orphanet_1000
# mapping Orphanet_1000
# Hash
# found mondo MONDO:0010390
# Orphanet_100006
# mapping Orphanet_100006
# Hash
# found mondo MONDO:0015033
# Orphanet_100008
# mapping Orphanet_100008
# Hash
# found mondo MONDO:0007098
# Orphanet_100011
# mapping Orphanet_100011
# Hash
# found mondo MONDO:0015034
# Orphanet_100012
# mapping Orphanet_100012
# Hash
# found mondo MONDO:0015035
# Orphanet_100013
# mapping Orphanet_100013
# Hash
# found mondo MONDO:0015036
# Orphanet_100014
# mapping Orphanet_100014
# Hash
# found mondo MONDO:0015037
# Orphanet_100015
# mapping Orphanet_100015
# Hash
# found mondo MONDO:0015038
# Orphanet_100016
# mapping Orphanet_100016
# Hash
# found mondo MONDO:0015039
# Orphanet_100032
# mapping Orphanet_100032
# Hash
# found mondo MONDO:0968955
# Orphanet_100034
# mapping Orphanet_100034
# Hash
# found mondo MONDO:0007093
# Orphanet_100043
# mapping Orphanet_100043
# Hash
# found mondo MONDO:0011675
# Orphanet_100045
# mapping Orphanet_100045
# Hash
# found mondo MONDO:0012012
# Orphanet_100047
# mapping Orphanet_100047
# Hash
# found mondo MONDO:0015050
# Orphanet_100048
# mapping Orphanet_100048
# Hash
# found mondo MONDO:0015051
# Orphanet_100050
# mapping Orphanet_100050
# Hash
# found mondo MONDO:0015053
# Orphanet_100051
# mapping Orphanet_100051
# Hash
# found mondo MONDO:0015054
# Orphanet_100054
# mapping Orphanet_100054
# Hash
# found mondo MONDO:0012526
# Orphanet_100071
# mapping Orphanet_100071
# Hash
# found mondo MONDO:0015060
# Orphanet_1001
# mapping Orphanet_1001
# Hash
# found mondo MONDO:0010886
# Orphanet_1003
# mapping Orphanet_1003
# Hash
# found mondo MONDO:0008403
# Orphanet_1005
# mapping Orphanet_1005
# Hash
# found mondo MONDO:0008754
# Orphanet_1006
# mapping Orphanet_1006
# Hash
# found mondo MONDO:0015082
# Orphanet_1008
# mapping Orphanet_1008
# Hash
# found mondo MONDO:0007085
# Orphanet_100924
# mapping Orphanet_100924
# Hash
# found mondo MONDO:0013000
# Orphanet_100973
# mapping Orphanet_100973
# Hash
# found mondo MONDO:0010659
# Orphanet_100974
# mapping Orphanet_100974
# Hash
# found mondo MONDO:0015084
# Orphanet_100976
# mapping Orphanet_100976
# Hash
# found mondo MONDO:0015085
# Orphanet_100978
# mapping Orphanet_100978
# Hash
# found mondo MONDO:0015086
# Orphanet_100984
# mapping Orphanet_100984
# Hash
# found mondo MONDO:0008437
# Orphanet_100985
# mapping Orphanet_100985
# Hash
# found mondo MONDO:0008438
# Orphanet_100986
# mapping Orphanet_100986
# Hash
# found mondo MONDO:0010047
# Orphanet_100988
# mapping Orphanet_100988
# Hash
# found mondo MONDO:0010878
# Orphanet_100989
# mapping Orphanet_100989
# Hash
# found mondo MONDO:0011339
# Orphanet_100990
# mapping Orphanet_100990
# Hash
# general failure - can't find mondo for orphanet Orphanet:100990 OBSOLETE: Autosomal dominant spastic paraplegia type 9 ...???
# found no mondo for Orphanet:100990
# Orphanet_100991
# mapping Orphanet_100991
# Hash
# found mondo MONDO:0011408
# Orphanet_100993
# mapping Orphanet_100993
# Hash
# found mondo MONDO:0011489
# Orphanet_100994
# mapping Orphanet_100994
# Hash
# found mondo MONDO:0011532
# Orphanet_100995
# mapping Orphanet_100995
# Hash
# found mondo MONDO:0011522
# Orphanet_100996
# mapping Orphanet_100996
# Hash
# found mondo MONDO:0010044
# Orphanet_100997
# mapping Orphanet_100997
# Hash
# found mondo MONDO:0010287
# Orphanet_100998
# mapping Orphanet_100998
# Hash
# found mondo MONDO:0010043
# Orphanet_100999
# mapping Orphanet_100999
# Hash
# found mondo MONDO:0011785
# Orphanet_101
# mapping Orphanet_101
# Hash
# found mondo MONDO:0007435
# Orphanet_1010
# mapping Orphanet_1010
# Hash
# found mondo MONDO:0007083
# Orphanet_101000
# mapping Orphanet_101000
# Hash
# found mondo MONDO:0010156
# Orphanet_101001
# mapping Orphanet_101001
# Hash
# found mondo MONDO:0009568
# Orphanet_101003
# mapping Orphanet_101003
# Hash
# found mondo MONDO:0010046
# Orphanet_101004
# mapping Orphanet_101004
# Hash
# found mondo MONDO:0011862
# Orphanet_101005
# mapping Orphanet_101005
# Hash
# found mondo MONDO:0011992
# Orphanet_101006
# mapping Orphanet_101006
# Hash
# found mondo MONDO:0012213
# Orphanet_101007
# mapping Orphanet_101007
# Hash
# found mondo MONDO:0012181
# Orphanet_101008
# mapping Orphanet_101008
# Hash
# found mondo MONDO:0012256
# Orphanet_101009
# mapping Orphanet_101009
# Hash
# found mondo MONDO:0012334
# Orphanet_101010
# mapping Orphanet_101010
# Hash
# found mondo MONDO:0012476
# Orphanet_101011
# mapping Orphanet_101011
# Hash
# found mondo MONDO:0012453
# Orphanet_101016
# mapping Orphanet_101016
# Hash
# found mondo MONDO:0019171
# Orphanet_101022
# mapping Orphanet_101022
# Hash
# general failure - can't find mondo for orphanet Orphanet:101022 Mediterranean macrothrombocytopenia ...???
# found no mondo for Orphanet:101022
# Orphanet_101028
# mapping Orphanet_101028
# Hash
# found mondo MONDO:0011624
# Orphanet_101029
# mapping Orphanet_101029
# Hash
# found mondo MONDO:0015093
# Orphanet_101030
# mapping Orphanet_101030
# Hash
# found mondo MONDO:0015094
# Orphanet_101033
# mapping Orphanet_101033
# Hash
# general failure - can't find mondo for orphanet Orphanet:101033 OBSOLETE: Peters anomaly-cataract syndrome ...???
# found no mondo for Orphanet:101033
# Orphanet_101039
# mapping Orphanet_101039
# Hash
# found mondo MONDO:0010246
# Orphanet_101041
# mapping Orphanet_101041
# Hash
# found mondo MONDO:0015096
# Orphanet_101042
# mapping Orphanet_101042
# Hash
# general failure - can't find mondo for orphanet Orphanet:101042 OBSOLETE: Taussig-Bing syndrome ...???
# found no mondo for Orphanet:101042
# Orphanet_101046
# mapping Orphanet_101046
# Hash
# found mondo MONDO:0010898
# Orphanet_101049
# mapping Orphanet_101049
# Hash
# found mondo MONDO:0007792
# Orphanet_101050
# mapping Orphanet_101050
# Hash
# found mondo MONDO:0010926
# Orphanet_101052
# mapping Orphanet_101052
# Hash
# general failure - can't find mondo for orphanet Orphanet:101052 OBSOLETE: Microlissencephaly type B ...???
# found no mondo for Orphanet:101052
# Orphanet_101063
# mapping Orphanet_101063
# Hash
# found mondo MONDO:0010029
# Orphanet_101068
# mapping Orphanet_101068
# Hash
# found mondo MONDO:0012401
# Orphanet_101070
# mapping Orphanet_101070
# Hash
# found mondo MONDO:0011738
# Orphanet_101071
# mapping Orphanet_101071
# Hash
# found mondo MONDO:0015099
# Orphanet_101075
# mapping Orphanet_101075
# Hash
# found mondo MONDO:0010549
# Orphanet_101076
# mapping Orphanet_101076
# Hash
# found mondo MONDO:0010550
# Orphanet_101077
# mapping Orphanet_101077
# Hash
# found mondo MONDO:0010551
# Orphanet_101078
# mapping Orphanet_101078
# Hash
# found mondo MONDO:0010689
# Orphanet_101081
# mapping Orphanet_101081
# Hash
# found mondo MONDO:0007309
# Orphanet_101082
# mapping Orphanet_101082
# Hash
# found mondo MONDO:0007307
# Orphanet_101083
# mapping Orphanet_101083
# Hash
# found mondo MONDO:0010995
# Orphanet_101084
# mapping Orphanet_101084
# Hash
# found mondo MONDO:0011890
# Orphanet_101085
# mapping Orphanet_101085
# Hash
# found mondo MONDO:0011902
# Orphanet_101088
# mapping Orphanet_101088
# Hash
# found mondo MONDO:0010626
# Orphanet_101089
# mapping Orphanet_101089
# Hash
# found mondo MONDO:0011528
# Orphanet_101090
# mapping Orphanet_101090
# Hash
# found mondo MONDO:0011735
# Orphanet_101091
# mapping Orphanet_101091
# Hash
# found mondo MONDO:0011985
# Orphanet_101092
# mapping Orphanet_101092
# Hash
# found mondo MONDO:0011971
# Orphanet_101097
# mapping Orphanet_101097
# Hash
# found mondo MONDO:0011916
# Orphanet_101101
# mapping Orphanet_101101
# Hash
# found mondo MONDO:0011570
# Orphanet_101102
# mapping Orphanet_101102
# Hash
# found mondo MONDO:0011901
# Orphanet_101104
# mapping Orphanet_101104
# Hash
# found mondo MONDO:0015101
# Orphanet_101108
# mapping Orphanet_101108
# Hash
# found mondo MONDO:0012449
# Orphanet_101109
# mapping Orphanet_101109
# Hash
# found mondo MONDO:0012450
# Orphanet_101110
# mapping Orphanet_101110
# Hash
# found mondo MONDO:0012098
# Orphanet_101111
# mapping Orphanet_101111
# Hash
# found mondo MONDO:0012103
# Orphanet_101112
# mapping Orphanet_101112
# Hash
# found mondo MONDO:0012246
# Orphanet_101150
# mapping Orphanet_101150
# Hash
# found mondo MONDO:0011551
# Orphanet_101351
# mapping Orphanet_101351
# Hash
# found mondo MONDO:0010066
# Orphanet_1014
# mapping Orphanet_1014
# Hash
# found mondo MONDO:0011019
# Orphanet_1018
# mapping Orphanet_1018
# Hash
# found mondo MONDO:0010641
# Orphanet_1020
# mapping Orphanet_1020
# Hash
# found mondo MONDO:0015140
# Orphanet_1021
# mapping Orphanet_1021
# Hash
# found mondo MONDO:0008766
# Orphanet_1023
# mapping Orphanet_1023
# Hash
# found mondo MONDO:0007787
# Orphanet_1027
# mapping Orphanet_1027
# Hash
# general failure - can't find mondo for orphanet Orphanet:1027 Autosomal recessive amelia ...???
# found no mondo for Orphanet:1027
# Orphanet_1028
# mapping Orphanet_1028
# Hash
# found mondo MONDO:0007095
# Orphanet_1031
# mapping Orphanet_1031
# Hash
# found mondo MONDO:0008771
# Orphanet_1032
# mapping Orphanet_1032
# Hash
# general failure - can't find mondo for orphanet Orphanet:1032 OBSOLETE: Hyperdibasic aminoaciduria type 1 ...???
# found no mondo for Orphanet:1032
# Orphanet_1035
# mapping Orphanet_1035
# Hash
# found mondo MONDO:0009585
# Orphanet_103907
# mapping Orphanet_103907
# Hash
# found mondo MONDO:0015169
# Orphanet_103909
# mapping Orphanet_103909
# Hash
# found mondo MONDO:0012803
# Orphanet_103910
# mapping Orphanet_103910
# Hash
# found mondo MONDO:0015171
# Orphanet_103912
# mapping Orphanet_103912
# Hash
# found mondo MONDO:0015172
# Orphanet_104
# mapping Orphanet_104
# Hash
# found mondo MONDO:0010788
# Orphanet_1040
# mapping Orphanet_1040
# Hash
# found mondo MONDO:0015177
# Orphanet_104077
# mapping Orphanet_104077
# Hash
# found mondo MONDO:0015191
# Orphanet_104078
# mapping Orphanet_104078
# Hash
# found mondo MONDO:0015192
# Orphanet_1044
# mapping Orphanet_1044
# Hash
# general failure - can't find mondo for orphanet Orphanet:1044 OBSOLETE: Anemia due to adenosine triphosphatase deficiency ...???
# found no mondo for Orphanet:1044
# Orphanet_1046
# mapping Orphanet_1046
# Hash
# found mondo MONDO:0010891
# Orphanet_1048
# mapping Orphanet_1048
# Hash
# found mondo MONDO:0008791
# Orphanet_105
# mapping Orphanet_105
# Hash
# found mondo MONDO:0015195
# Orphanet_1051
# mapping Orphanet_1051
# Hash
# found mondo MONDO:0007382
# Orphanet_1052
# mapping Orphanet_1052
# Hash
# found mondo MONDO:0000141
# Orphanet_1059
# mapping Orphanet_1059
# Hash
# found mondo MONDO:0007203
# Orphanet_1062
# mapping Orphanet_1062
# Hash
# found mondo MONDO:0007116
# Orphanet_1063
# mapping Orphanet_1063
# Hash
# found mondo MONDO:0011927
# Orphanet_1064
# mapping Orphanet_1064
# Hash
# found mondo MONDO:0008796
# Orphanet_1065
# mapping Orphanet_1065
# Hash
# found mondo MONDO:0008795
# Orphanet_1067
# mapping Orphanet_1067
# Hash
# found mondo MONDO:0015198
# Orphanet_1068
# mapping Orphanet_1068
# Hash
# found mondo MONDO:0015199
# Orphanet_1069
# mapping Orphanet_1069
# Hash
# found mondo MONDO:0007120
# Orphanet_107
# mapping Orphanet_107
# Hash
# found mondo MONDO:0007029
# Orphanet_1072
# mapping Orphanet_1072
# Hash
# found mondo MONDO:0007123
# Orphanet_1074
# mapping Orphanet_1074
# Hash
# found mondo MONDO:0015201
# Orphanet_1077
# mapping Orphanet_1077
# Hash
# found mondo MONDO:0008007
# Orphanet_1078
# mapping Orphanet_1078
# Hash
# found mondo MONDO:0008563
# Orphanet_1084
# mapping Orphanet_1084
# Hash
# found mondo MONDO:0015205
# Orphanet_1088
# mapping Orphanet_1088
# Hash
# general failure - can't find mondo for orphanet Orphanet:1088 OBSOLETE: Short stature-heart defect-craniofacial anomalies syndrome ...???
# found no mondo for Orphanet:1088
# Orphanet_109
# mapping Orphanet_109
# Hash
# found mondo MONDO:0007924
# Orphanet_1092
# mapping Orphanet_1092
# Hash
# general failure - can't find mondo for orphanet Orphanet:1092 Renal-genital-middle ear anomalies ...???
# found no mondo for Orphanet:1092
# Orphanet_1094
# mapping Orphanet_1094
# Hash
# found mondo MONDO:0011795
# Orphanet_11
# mapping Orphanet_11
# Hash
# found mondo MONDO:0015228
# Orphanet_1101
# mapping Orphanet_1101
# Hash
# found mondo MONDO:0015230
# Orphanet_1104
# mapping Orphanet_1104
# Hash
# found mondo MONDO:0010930
# Orphanet_1106
# mapping Orphanet_1106
# Hash
# found mondo MONDO:0008800
# Orphanet_111
# mapping Orphanet_111
# Hash
# found mondo MONDO:0010543
# Orphanet_1110
# mapping Orphanet_1110
# Hash
# found mondo MONDO:0007143
# Orphanet_1112
# mapping Orphanet_1112
# Hash
# found mondo MONDO:0008806
# Orphanet_1113
# mapping Orphanet_1113
# Hash
# found mondo MONDO:0010882
# Orphanet_1114
# mapping Orphanet_1114
# Hash
# found mondo MONDO:0007145
# Orphanet_1115
# mapping Orphanet_1115
# Hash
# general failure - can't find mondo for orphanet Orphanet:1115 OBSOLETE: Recessive aplasia cutis congenita of limbs ...???
# found no mondo for Orphanet:1115
# Orphanet_1116
# mapping Orphanet_1116
# Hash
# found mondo MONDO:0008808
# Orphanet_1117
# mapping Orphanet_1117
# Hash
# found mondo MONDO:0010988
# Orphanet_1118
# mapping Orphanet_1118
# Hash
# found mondo MONDO:0007225
# Orphanet_1120
# mapping Orphanet_1120
# Hash
# found mondo MONDO:0011116
# Orphanet_1121
# mapping Orphanet_1121
# Hash
# found mondo MONDO:0015232
# Orphanet_1122
# mapping Orphanet_1122
# Hash
# found mondo MONDO:0010750
# Orphanet_1123
# mapping Orphanet_1123
# Hash
# found mondo MONDO:0015233
# Orphanet_1125
# mapping Orphanet_1125
# Hash
# found mondo MONDO:0009764
# Orphanet_1126
# mapping Orphanet_1126
# Hash
# found mondo MONDO:0011062
# Orphanet_1129
# mapping Orphanet_1129
# Hash
# found mondo MONDO:0015234
# Orphanet_1130
# mapping Orphanet_1130
# Hash
# found mondo MONDO:0015235
# Orphanet_1131
# mapping Orphanet_1131
# Hash
# found mondo MONDO:0010539
# Orphanet_1133
# mapping Orphanet_1133
# Hash
# found mondo MONDO:0008812
# Orphanet_1135
# mapping Orphanet_1135
# Hash
# general failure - can't find mondo for orphanet Orphanet:1135 Arrhinia-choanal atresia-microphthalmia syndrome ...???
# found no mondo for Orphanet:1135
# Orphanet_1136
# mapping Orphanet_1136
# Hash
# general failure - can't find mondo for orphanet Orphanet:1136 OBSOLETE: Arnold-Chiari malformation type II ...???
# found no mondo for Orphanet:1136
# Orphanet_114
# mapping Orphanet_114
# Hash
# found mondo MONDO:0007177
# Orphanet_1144
# mapping Orphanet_1144
# Hash
# found mondo MONDO:0007159
# Orphanet_1145
# mapping Orphanet_1145
# Hash
# found mondo MONDO:0010532
# Orphanet_1146
# mapping Orphanet_1146
# Hash
# found mondo MONDO:0015240
# Orphanet_1149
# mapping Orphanet_1149
# Hash
# found mondo MONDO:0015241
# Orphanet_115
# mapping Orphanet_115
# Hash
# found mondo MONDO:0007363
# Orphanet_1150
# mapping Orphanet_1150
# Hash
# found mondo MONDO:0008825
# Orphanet_1154
# mapping Orphanet_1154
# Hash
# found mondo MONDO:0007158
# Orphanet_1155
# mapping Orphanet_1155
# Hash
# general failure - can't find mondo for orphanet Orphanet:1155 OBSOLETE: Arthrogryposis due to muscular dystrophy ...???
# found no mondo for Orphanet:1155
# Orphanet_1159
# mapping Orphanet_1159
# Hash
# found mondo MONDO:0008827
# Orphanet_1166
# mapping Orphanet_1166
# Hash
# found mondo MONDO:0007443
# Orphanet_1168
# mapping Orphanet_1168
# Hash
# found mondo MONDO:0008842
# Orphanet_1170
# mapping Orphanet_1170
# Hash
# found mondo MONDO:0008943
# Orphanet_1171
# mapping Orphanet_1171
# Hash
# found mondo MONDO:0011038
# Orphanet_1173
# mapping Orphanet_1173
# Hash
# found mondo MONDO:0008935
# Orphanet_1174
# mapping Orphanet_1174
# Hash
# found mondo MONDO:0008934
# Orphanet_1175
# mapping Orphanet_1175
# Hash
# found mondo MONDO:0010547
# Orphanet_1177
# mapping Orphanet_1177
# Hash
# found mondo MONDO:0008938
# Orphanet_1178
# mapping Orphanet_1178
# Hash
# found mondo MONDO:0010095
# Orphanet_1179
# mapping Orphanet_1179
# Hash
# found mondo MONDO:0008206
# Orphanet_118
# mapping Orphanet_118
# Hash
# found mondo MONDO:0009562
# Orphanet_1180
# mapping Orphanet_1180
# Hash
# found mondo MONDO:0008980
# Orphanet_1182
# mapping Orphanet_1182
# Hash
# found mondo MONDO:0007165
# Orphanet_1185
# mapping Orphanet_1185
# Hash
# found mondo MONDO:0010062
# Orphanet_1186
# mapping Orphanet_1186
# Hash
# found mondo MONDO:0010060
# Orphanet_1187
# mapping Orphanet_1187
# Hash
# found mondo MONDO:0010533
# Orphanet_1188
# mapping Orphanet_1188
# Hash
# found mondo MONDO:0008838
# Orphanet_119
# mapping Orphanet_119
# Hash
# found mondo MONDO:0011423
# Orphanet_1190
# mapping Orphanet_1190
# Hash
# found mondo MONDO:0007167
# Orphanet_1192
# mapping Orphanet_1192
# Hash
# found mondo MONDO:0008843
# Orphanet_1193
# mapping Orphanet_1193
# Hash
# found mondo MONDO:0010323
# Orphanet_1194
# mapping Orphanet_1194
# Hash
# found mondo MONDO:0013546
# Orphanet_1195
# mapping Orphanet_1195
# Hash
# found mondo MONDO:0008846
# Orphanet_1198
# mapping Orphanet_1198
# Hash
# found mondo MONDO:0010562
# Orphanet_1200
# mapping Orphanet_1200
# Hash
# found mondo MONDO:0012064
# Orphanet_1201
# mapping Orphanet_1201
# Hash
# found mondo MONDO:0009476
# Orphanet_1202
# mapping Orphanet_1202
# Hash
# found mondo MONDO:0007879
# Orphanet_1203
# mapping Orphanet_1203
# Hash
# found mondo MONDO:0009126
# Orphanet_1216
# mapping Orphanet_1216
# Hash
# found mondo MONDO:0010839
# Orphanet_1217
# mapping Orphanet_1217
# Hash
# found mondo MONDO:0015250
# Orphanet_122
# mapping Orphanet_122
# Hash
# found mondo MONDO:0800445
# Orphanet_1225
# mapping Orphanet_1225
# Hash
# found mondo MONDO:0009039
# Orphanet_1226
# mapping Orphanet_1226
# Hash
# found mondo MONDO:0009437
# Orphanet_1227
# mapping Orphanet_1227
# Hash
# found mondo MONDO:0008874
# Orphanet_1228
# mapping Orphanet_1228
# Hash
# found mondo MONDO:0007185
# Orphanet_123
# mapping Orphanet_123
# Hash
# found mondo MONDO:0009872
# Orphanet_1231
# mapping Orphanet_1231
# Hash
# found mondo MONDO:0008853
# Orphanet_1234
# mapping Orphanet_1234
# Hash
# found mondo MONDO:0009901
# Orphanet_1237
# mapping Orphanet_1237
# Hash
# found mondo MONDO:0008857
# Orphanet_1239
# mapping Orphanet_1239
# Hash
# found mondo MONDO:0008858
# Orphanet_124
# mapping Orphanet_124
# Hash
# found mondo MONDO:0015253
# Orphanet_1240
# mapping Orphanet_1240
# Hash
# general failure - can't find mondo for orphanet Orphanet:1240 Metaphyseal acroscyphodysplasia ...???
# found no mondo for Orphanet:1240
# Orphanet_1241
# mapping Orphanet_1241
# Hash
# found mondo MONDO:0007711
# Orphanet_1243
# mapping Orphanet_1243
# Hash
# found mondo MONDO:0007931
# Orphanet_1246
# mapping Orphanet_1246
# Hash
# found mondo MONDO:0007226
# Orphanet_1248
# mapping Orphanet_1248
# Hash
# found mondo MONDO:0007953
# Orphanet_125
# mapping Orphanet_125
# Hash
# found mondo MONDO:0008876
# Orphanet_1252
# mapping Orphanet_1252
# Hash
# found mondo MONDO:0007200
# Orphanet_1253
# mapping Orphanet_1253
# Hash
# found mondo MONDO:0007198
# Orphanet_1256
# mapping Orphanet_1256
# Hash
# found mondo MONDO:0015255
# Orphanet_1258
# mapping Orphanet_1258
# Hash
# general failure - can't find mondo for orphanet Orphanet:1258 OBSOLETE: Blepharoptosis-cleft palate-ectrodactyly-dental anomalies syndrome ...???
# found no mondo for Orphanet:1258
# Orphanet_1259
# mapping Orphanet_1259
# Hash
# found mondo MONDO:0007202
# Orphanet_1260
# mapping Orphanet_1260
# Hash
# general failure - can't find mondo for orphanet Orphanet:1260 OBSOLETE: Sino-auricular heart block ...???
# found no mondo for Orphanet:1260
# Orphanet_1261
# mapping Orphanet_1261
# Hash
# found mondo MONDO:0009167
# Orphanet_1262
# mapping Orphanet_1262
# Hash
# found mondo MONDO:0007207
# Orphanet_1263
# mapping Orphanet_1263
# Hash
# found mondo MONDO:0007208
# Orphanet_1264
# mapping Orphanet_1264
# Hash
# found mondo MONDO:0008622
# Orphanet_1266
# mapping Orphanet_1266
# Hash
# general failure - can't find mondo for orphanet Orphanet:1266 Dermato-cardio-skeletal syndrome, Borrone type ...???
# found no mondo for Orphanet:1266
# Orphanet_127
# mapping Orphanet_127
# Hash
# found mondo MONDO:0010537
# Orphanet_1270
# mapping Orphanet_1270
# Hash
# found mondo MONDO:0008879
# Orphanet_1272
# mapping Orphanet_1272
# Hash
# found mondo MONDO:0011049
# Orphanet_1275
# mapping Orphanet_1275
# Hash
# found mondo MONDO:0008520
# Orphanet_1276
# mapping Orphanet_1276
# Hash
# found mondo MONDO:0007211
# Orphanet_1277
# mapping Orphanet_1277
# Hash
# found mondo MONDO:0015259
# Orphanet_1278
# mapping Orphanet_1278
# Hash
# found mondo MONDO:0007214
# Orphanet_1292
# mapping Orphanet_1292
# Hash
# found mondo MONDO:0007230
# Orphanet_1295
# mapping Orphanet_1295
# Hash
# found mondo MONDO:0007231
# Orphanet_1296
# mapping Orphanet_1296
# Hash
# found mondo MONDO:0009507
# Orphanet_1297
# mapping Orphanet_1297
# Hash
# found mondo MONDO:0007235
# Orphanet_1299
# mapping Orphanet_1299
# Hash
# found mondo MONDO:0008885
# Orphanet_13
# mapping Orphanet_13
# Hash
# found mondo MONDO:0009863
# Orphanet_130
# mapping Orphanet_130
# Hash
# found mondo MONDO:0015263
# Orphanet_1300
# mapping Orphanet_1300
# Hash
# found mondo MONDO:0007334
# Orphanet_1307
# mapping Orphanet_1307
# Hash
# found mondo MONDO:0009525
# Orphanet_1308
# mapping Orphanet_1308
# Hash
# found mondo MONDO:0008893
# Orphanet_1309
# mapping Orphanet_1309
# Hash
# found mondo MONDO:0015268
# Orphanet_1310
# mapping Orphanet_1310
# Hash
# found mondo MONDO:0007244
# Orphanet_1318
# mapping Orphanet_1318
# Hash
# found mondo MONDO:0008896
# Orphanet_1319
# mapping Orphanet_1319
# Hash
# found mondo MONDO:0007249
# Orphanet_132
# mapping Orphanet_132
# Hash
# found mondo MONDO:0015270
# Orphanet_1325
# mapping Orphanet_1325
# Hash
# found mondo MONDO:0015272
# Orphanet_1326
# mapping Orphanet_1326
# Hash
# found mondo MONDO:0008899
# Orphanet_1327
# mapping Orphanet_1327
# Hash
# found mondo MONDO:0008898
# Orphanet_1328
# mapping Orphanet_1328
# Hash
# found mondo MONDO:0007542
# Orphanet_1331
# mapping Orphanet_1331
# Hash
# found mondo MONDO:0700275
# Orphanet_1333
# mapping Orphanet_1333
# Hash
# found mondo MONDO:0015278
# Orphanet_1335
# mapping Orphanet_1335
# Hash
# found mondo MONDO:0010742
# Orphanet_1336
# mapping Orphanet_1336
# Hash
# found mondo MONDO:0007757
# Orphanet_1338
# mapping Orphanet_1338
# Hash
# found mondo MONDO:0009008
# Orphanet_134
# mapping Orphanet_134
# Hash
# found mondo MONDO:0008760
# Orphanet_1340
# mapping Orphanet_1340
# Hash
# found mondo MONDO:0015280
# Orphanet_1342
# mapping Orphanet_1342
# Hash
# found mondo MONDO:0007702
# Orphanet_1344
# mapping Orphanet_1344
# Hash
# found mondo MONDO:0015281
# Orphanet_1345
# mapping Orphanet_1345
# Hash
# found mondo MONDO:0015282
# Orphanet_1349
# mapping Orphanet_1349
# Hash
# found mondo MONDO:0015283
# Orphanet_1350
# mapping Orphanet_1350
# Hash
# found mondo MONDO:0015284
# Orphanet_1352
# mapping Orphanet_1352
# Hash
# found mondo MONDO:0010825
# Orphanet_1354
# mapping Orphanet_1354
# Hash
# found mondo MONDO:0008917
# Orphanet_1355
# mapping Orphanet_1355
# Hash
# found mondo MONDO:0010039
# Orphanet_1358
# mapping Orphanet_1358
# Hash
# found mondo MONDO:0031415
# Orphanet_1361
# mapping Orphanet_1361
# Hash
# found mondo MONDO:0008921
# Orphanet_1366
# mapping Orphanet_1366
# Hash
# found mondo MONDO:0008923
# Orphanet_1368
# mapping Orphanet_1368
# Hash
# found mondo MONDO:0008928
# Orphanet_1369
# mapping Orphanet_1369
# Hash
# found mondo MONDO:0008922
# Orphanet_1373
# mapping Orphanet_1373
# Hash
# found mondo MONDO:0007277
# Orphanet_1375
# mapping Orphanet_1375
# Hash
# found mondo MONDO:0008894
# Orphanet_1376
# mapping Orphanet_1376
# Hash
# general failure - can't find mondo for orphanet Orphanet:1376 OBSOLETE: Congenital cataract-ichthyosis syndrome ...???
# found no mondo for Orphanet:1376
# Orphanet_137605
# mapping Orphanet_137605
# Hash
# found mondo MONDO:0012669
# Orphanet_137608
# mapping Orphanet_137608
# Hash
# found mondo MONDO:0015293
# Orphanet_137622
# mapping Orphanet_137622
# Hash
# found mondo MONDO:0015295
# Orphanet_137625
# mapping Orphanet_137625
# Hash
# found mondo MONDO:0012693
# Orphanet_137628
# mapping Orphanet_137628
# Hash
# found mondo MONDO:0015296
# Orphanet_137631
# mapping Orphanet_137631
# Hash
# found mondo MONDO:0012757
# Orphanet_137634
# mapping Orphanet_137634
# Hash
# found mondo MONDO:0013357
# Orphanet_137639
# mapping Orphanet_137639
# Hash
# found mondo MONDO:0100600
# Orphanet_137653
# mapping Orphanet_137653
# Hash
# found mondo MONDO:0015297
# Orphanet_137658
# mapping Orphanet_137658
# Hash
# general failure - can't find mondo for orphanet Orphanet:137658 Microcephaly-intellectual disability-phalangeal and neurological anomalies syndrome ...???
# found no mondo for Orphanet:137658
# Orphanet_137667
# mapping Orphanet_137667
# Hash
# found mondo MONDO:0012016
# Orphanet_137675
# mapping Orphanet_137675
# Hash
# found mondo MONDO:0010771
# Orphanet_137678
# mapping Orphanet_137678
# Hash
# found mondo MONDO:0012206
# Orphanet_137681
# mapping Orphanet_137681
# Hash
# found mondo MONDO:0012191
# Orphanet_1377
# mapping Orphanet_1377
# Hash
# found mondo MONDO:0015300
# Orphanet_137754
# mapping Orphanet_137754
# Hash
# found mondo MONDO:0012368
# Orphanet_137776
# mapping Orphanet_137776
# Hash
# found mondo MONDO:0011868
# Orphanet_137783
# mapping Orphanet_137783
# Hash
# found mondo MONDO:0012656
# Orphanet_137831
# mapping Orphanet_137831
# Hash
# found mondo MONDO:0010337
# Orphanet_137834
# mapping Orphanet_137834
# Hash
# found mondo MONDO:0009579
# Orphanet_137867
# mapping Orphanet_137867
# Hash
# found mondo MONDO:0015307
# Orphanet_137871
# mapping Orphanet_137871
# Hash
# general failure - can't find mondo for orphanet Orphanet:137871 OBSOLETE: Laminopathy type Decaudain-Vigouroux ...???
# found no mondo for Orphanet:137871
# Orphanet_137888
# mapping Orphanet_137888
# Hash
# found mondo MONDO:0000107
# Orphanet_137893
# mapping Orphanet_137893
# Hash
# found mondo MONDO:0009461
# Orphanet_137898
# mapping Orphanet_137898
# Hash
# found mondo MONDO:0012622
# Orphanet_137902
# mapping Orphanet_137902
# Hash
# general failure - can't find mondo for orphanet Orphanet:137902 OBSOLETE: Isolated optic nerve hypoplasia/aplasia ...???
# found no mondo for Orphanet:137902
# Orphanet_137908
# mapping Orphanet_137908
# Hash
# found mondo MONDO:0012718
# Orphanet_137911
# mapping Orphanet_137911
# Hash
# general failure - can't find mondo for orphanet Orphanet:137911 Autism-facial port-wine stain syndrome ...???
# found no mondo for Orphanet:137911
# Orphanet_138
# mapping Orphanet_138
# Hash
# found mondo MONDO:0008965
# Orphanet_1380
# mapping Orphanet_1380
# Hash
# found mondo MONDO:0009045
# Orphanet_138066
# mapping Orphanet_138066
# Hash
# general failure - can't find mondo for orphanet Orphanet:138066 OBSOLETE: Pierre Robin syndrome associated with miscellaneous anomalies ...???
# found no mondo for Orphanet:138066
# Orphanet_1381
# mapping Orphanet_1381
# Hash
# found mondo MONDO:0015324
# Orphanet_1383
# mapping Orphanet_1383
# Hash
# found mondo MONDO:0015325
# Orphanet_1387
# mapping Orphanet_1387
# Hash
# found mondo MONDO:8000008
# Orphanet_1388
# mapping Orphanet_1388
# Hash
# found mondo MONDO:0014507
# Orphanet_1389
# mapping Orphanet_1389
# Hash
# found mondo MONDO:0009024
# Orphanet_139
# mapping Orphanet_139
# Hash
# found mondo MONDO:0010621
# Orphanet_1390
# mapping Orphanet_1390
# Hash
# found mondo MONDO:0015326
# Orphanet_1393
# mapping Orphanet_1393
# Hash
# found mondo MONDO:0007301
# Orphanet_139373
# mapping Orphanet_139373
# Hash
# general failure - can't find mondo for orphanet Orphanet:139373 OBSOLETE: Recessive hereditary methemoglobinemia type 1 ...???
# found no mondo for Orphanet:139373
# Orphanet_139380
# mapping Orphanet_139380
# Hash
# general failure - can't find mondo for orphanet Orphanet:139380 OBSOLETE: Recessive hereditary methemoglobinemia type 2 ...???
# found no mondo for Orphanet:139380
# Orphanet_139399
# mapping Orphanet_139399
# Hash
# found mondo MONDO:0015339
# Orphanet_1394
# mapping Orphanet_1394
# Hash
# found mondo MONDO:0800436
# Orphanet_139406
# mapping Orphanet_139406
# Hash
# found mondo MONDO:0012719
# Orphanet_139411
# mapping Orphanet_139411
# Hash
# found mondo MONDO:0011424
# Orphanet_139441
# mapping Orphanet_139441
# Hash
# found mondo MONDO:0012905
# Orphanet_139444
# mapping Orphanet_139444
# Hash
# found mondo MONDO:0015348
# Orphanet_139447
# mapping Orphanet_139447
# Hash
# found mondo MONDO:0015349
# Orphanet_139450
# mapping Orphanet_139450
# Hash
# found mondo MONDO:0012739
# Orphanet_139455
# mapping Orphanet_139455
# Hash
# found mondo MONDO:0012733
# Orphanet_139466
# mapping Orphanet_139466
# Hash
# found mondo MONDO:0012734
# Orphanet_139471
# mapping Orphanet_139471
# Hash
# found mondo MONDO:0011936
# Orphanet_139474
# mapping Orphanet_139474
# Hash
# found mondo MONDO:0015350
# Orphanet_139480
# mapping Orphanet_139480
# Hash
# found mondo MONDO:0012787
# Orphanet_139491
# mapping Orphanet_139491
# Hash
# general failure - can't find mondo for orphanet Orphanet:139491 OBSOLETE: Hemochromatosis type 4 ...???
# found no mondo for Orphanet:139491
# Orphanet_139507
# mapping Orphanet_139507
# Hash
# found mondo MONDO:0011012
# Orphanet_139512
# mapping Orphanet_139512
# Hash
# found mondo MONDO:0015351
# Orphanet_139515
# mapping Orphanet_139515
# Hash
# found mondo MONDO:0012640
# Orphanet_139518
# mapping Orphanet_139518
# Hash
# found mondo MONDO:0008451
# Orphanet_139525
# mapping Orphanet_139525
# Hash
# found mondo MONDO:0015352
# Orphanet_139536
# mapping Orphanet_139536
# Hash
# found mondo MONDO:0100350
# Orphanet_139547
# mapping Orphanet_139547
# Hash
# found mondo MONDO:0011771
# Orphanet_139552
# mapping Orphanet_139552
# Hash
# found mondo MONDO:0011585
# Orphanet_139557
# mapping Orphanet_139557
# Hash
# found mondo MONDO:0010338
# Orphanet_139564
# mapping Orphanet_139564
# Hash
# found mondo MONDO:0011961
# Orphanet_139573
# mapping Orphanet_139573
# Hash
# found mondo MONDO:0015354
# Orphanet_139578
# mapping Orphanet_139578
# Hash
# found mondo MONDO:0009748
# Orphanet_139583
# mapping Orphanet_139583
# Hash
# found mondo MONDO:0010378
# Orphanet_139589
# mapping Orphanet_139589
# Hash
# found mondo MONDO:0015355
# Orphanet_1396
# mapping Orphanet_1396
# Hash
# general failure - can't find mondo for orphanet Orphanet:1396 OBSOLETE: Cerebrorenodigital syndrome ...???
# found no mondo for Orphanet:1396
# Orphanet_1397
# mapping Orphanet_1397
# Hash
# found mondo MONDO:0010612
# Orphanet_1399
# mapping Orphanet_1399
# Hash
# found mondo MONDO:0009493
# Orphanet_14
# mapping Orphanet_14
# Hash
# found mondo MONDO:0008692
# Orphanet_140
# mapping Orphanet_140
# Hash
# found mondo MONDO:0007251
# Orphanet_140436
# mapping Orphanet_140436
# Hash
# found mondo MONDO:0011744
# Orphanet_140481
# mapping Orphanet_140481
# Hash
# found mondo MONDO:0011998
# Orphanet_1406
# mapping Orphanet_1406
# Hash
# found mondo MONDO:0015367
# Orphanet_1408
# mapping Orphanet_1408
# Hash
# general failure - can't find mondo for orphanet Orphanet:1408 Hair defect-photosensitivity-intellectual disability syndrome ...???
# found no mondo for Orphanet:1408
# Orphanet_1409
# mapping Orphanet_1409
# Hash
# general failure - can't find mondo for orphanet Orphanet:1409 Woolly hair-hypotrichosis-everted lower lip-outstanding ears syndrome ...???
# found no mondo for Orphanet:1409
# Orphanet_140905
# mapping Orphanet_140905
# Hash
# found mondo MONDO:0013533
# Orphanet_140908
# mapping Orphanet_140908
# Hash
# found mondo MONDO:0012658
# Orphanet_140917
# mapping Orphanet_140917
# Hash
# found mondo MONDO:0008484
# Orphanet_140922
# mapping Orphanet_140922
# Hash
# found mondo MONDO:0012127
# Orphanet_140927
# mapping Orphanet_140927
# Hash
# found mondo MONDO:0011904
# Orphanet_140933
# mapping Orphanet_140933
# Hash
# found mondo MONDO:0015371
# Orphanet_140936
# mapping Orphanet_140936
# Hash
# found mondo MONDO:0012008
# Orphanet_140941
# mapping Orphanet_140941
# Hash
# found mondo MONDO:0014420
# Orphanet_140944
# mapping Orphanet_140944
# Hash
# found mondo MONDO:0013038
# Orphanet_140952
# mapping Orphanet_140952
# Hash
# found mondo MONDO:0010408
# Orphanet_140963
# mapping Orphanet_140963
# Hash
# found mondo MONDO:0012854
# Orphanet_140966
# mapping Orphanet_140966
# Hash
# found mondo MONDO:0014272
# Orphanet_140969
# mapping Orphanet_140969
# Hash
# found mondo MONDO:0009964
# Orphanet_140976
# mapping Orphanet_140976
# Hash
# found mondo MONDO:0011202
# Orphanet_140989
# mapping Orphanet_140989
# Hash
# found mondo MONDO:0015374
# Orphanet_1410
# mapping Orphanet_1410
# Hash
# found mondo MONDO:0008621
# Orphanet_141000
# mapping Orphanet_141000
# Hash
# found mondo MONDO:0013035
# Orphanet_141007
# mapping Orphanet_141007
# Hash
# found mondo MONDO:0009795
# Orphanet_141118
# mapping Orphanet_141118
# Hash
# found mondo MONDO:0015394
# Orphanet_141127
# mapping Orphanet_141127
# Hash
# found mondo MONDO:0011340
# Orphanet_141136
# mapping Orphanet_141136
# Hash
# general failure - can't find mondo for orphanet Orphanet:141136 Otomandibular syndrome ...???
# found no mondo for Orphanet:141136
# Orphanet_141145
# mapping Orphanet_141145
# Hash
# found mondo MONDO:0007590
# Orphanet_141152
# mapping Orphanet_141152
# Hash
# found mondo MONDO:0013003
# Orphanet_141163
# mapping Orphanet_141163
# Hash
# found mondo MONDO:0015399
# Orphanet_1412
# mapping Orphanet_1412
# Hash
# found mondo MONDO:0008521
# Orphanet_141258
# mapping Orphanet_141258
# Hash
# found mondo MONDO:0010850
# Orphanet_141261
# mapping Orphanet_141261
# Hash
# found mondo MONDO:0015416
# Orphanet_141265
# mapping Orphanet_141265
# Hash
# found mondo MONDO:0015417
# Orphanet_141276
# mapping Orphanet_141276
# Hash
# found mondo MONDO:0013300
# Orphanet_141327
# mapping Orphanet_141327
# Hash
# general failure - can't find mondo for orphanet Orphanet:141327 OBSOLETE: Orofaciodigital syndrome type 12 ...???
# found no mondo for Orphanet:141327
# Orphanet_141330
# mapping Orphanet_141330
# Hash
# found mondo MONDO:0015422
# Orphanet_141333
# mapping Orphanet_141333
# Hash
# found mondo MONDO:0008864
# Orphanet_1414
# mapping Orphanet_1414
# Hash
# found mondo MONDO:0008966
# Orphanet_1420
# mapping Orphanet_1420
# Hash
# found mondo MONDO:0015424
# Orphanet_1421
# mapping Orphanet_1421
# Hash
# general failure - can't find mondo for orphanet Orphanet:1421 OBSOLETE: Lethal chondrodysplasia, Seller type ...???
# found no mondo for Orphanet:1421
# Orphanet_1422
# mapping Orphanet_1422
# Hash
# found mondo MONDO:0010814
# Orphanet_1423
# mapping Orphanet_1423
# Hash
# found mondo MONDO:0015425
# Orphanet_1425
# mapping Orphanet_1425
# Hash
# found mondo MONDO:0015426
# Orphanet_1426
# mapping Orphanet_1426
# Hash
# found mondo MONDO:0008974
# Orphanet_1428
# mapping Orphanet_1428
# Hash
# general failure - can't find mondo for orphanet Orphanet:1428 OBSOLETE: Familial chondromalacia patellae ...???
# found no mondo for Orphanet:1428
# Orphanet_1429
# mapping Orphanet_1429
# Hash
# found mondo MONDO:0001595
# Orphanet_1433
# mapping Orphanet_1433
# Hash
# found mondo MONDO:0015428
# Orphanet_1434
# mapping Orphanet_1434
# Hash
# general failure - can't find mondo for orphanet Orphanet:1434 OBSOLETE: Choroideremia-hypopituitarism syndrome ...???
# found no mondo for Orphanet:1434
# Orphanet_1435
# mapping Orphanet_1435
# Hash
# found mondo MONDO:0010558
# Orphanet_1436
# mapping Orphanet_1436
# Hash
# found mondo MONDO:0010668
# Orphanet_1437
# mapping Orphanet_1437
# Hash
# found mondo MONDO:0015430
# Orphanet_1438
# mapping Orphanet_1438
# Hash
# found mondo MONDO:0015431
# Orphanet_1439
# mapping Orphanet_1439
# Hash
# found mondo MONDO:0015432
# Orphanet_1440
# mapping Orphanet_1440
# Hash
# found mondo MONDO:0014708
# Orphanet_1441
# mapping Orphanet_1441
# Hash
# found mondo MONDO:0015433
# Orphanet_1442
# mapping Orphanet_1442
# Hash
# found mondo MONDO:0015434
# Orphanet_1443
# mapping Orphanet_1443
# Hash
# found mondo MONDO:0015435
# Orphanet_1444
# mapping Orphanet_1444
# Hash
# found mondo MONDO:0015436
# Orphanet_1445
# mapping Orphanet_1445
# Hash
# found mondo MONDO:0015437
# Orphanet_1446
# mapping Orphanet_1446
# Hash
# found mondo MONDO:0015438
# Orphanet_1447
# mapping Orphanet_1447
# Hash
# found mondo MONDO:0015439
# Orphanet_1448
# mapping Orphanet_1448
# Hash
# found mondo MONDO:0015440
# Orphanet_1449
# mapping Orphanet_1449
# Hash
# found mondo MONDO:0015441
# Orphanet_1450
# mapping Orphanet_1450
# Hash
# found mondo MONDO:0015443
# Orphanet_1452
# mapping Orphanet_1452
# Hash
# found mondo MONDO:0007340
# Orphanet_1453
# mapping Orphanet_1453
# Hash
# found mondo MONDO:0007341
# Orphanet_1454
# mapping Orphanet_1454
# Hash
# found mondo MONDO:0100349
# Orphanet_1458
# mapping Orphanet_1458
# Hash
# found mondo MONDO:0010879
# Orphanet_147
# mapping Orphanet_147
# Hash
# found mondo MONDO:0009376
# Orphanet_1471
# mapping Orphanet_1471
# Hash
# found mondo MONDO:0007353
# Orphanet_1473
# mapping Orphanet_1473
# Hash
# found mondo MONDO:0007355
# Orphanet_1475
# mapping Orphanet_1475
# Hash
# found mondo MONDO:0007352
# Orphanet_1479
# mapping Orphanet_1479
# Hash
# found mondo MONDO:0007173
# Orphanet_1484
# mapping Orphanet_1484
# Hash
# found mondo MONDO:0010531
# Orphanet_1485
# mapping Orphanet_1485
# Hash
# found mondo MONDO:0008826
# Orphanet_1486
# mapping Orphanet_1486
# Hash
# found mondo MONDO:0009670
# Orphanet_1487
# mapping Orphanet_1487
# Hash
# found mondo MONDO:0007134
# Orphanet_1488
# mapping Orphanet_1488
# Hash
# found mondo MONDO:0008850
# Orphanet_1490
# mapping Orphanet_1490
# Hash
# found mondo MONDO:0009015
# Orphanet_1493
# mapping Orphanet_1493
# Hash
# found mondo MONDO:0009452
# Orphanet_1495
# mapping Orphanet_1495
# Hash
# found mondo MONDO:0015458
# Orphanet_1496
# mapping Orphanet_1496
# Hash
# found mondo MONDO:0000902
# Orphanet_1497
# mapping Orphanet_1497
# Hash
# found mondo MONDO:0010569
# Orphanet_15
# mapping Orphanet_15
# Hash
# found mondo MONDO:0007037
# Orphanet_1506
# mapping Orphanet_1506
# Hash
# found mondo MONDO:0015462
# Orphanet_1507
# mapping Orphanet_1507
# Hash
# found mondo MONDO:0009999
# Orphanet_1508
# mapping Orphanet_1508
# Hash
# found mondo MONDO:0007392
# Orphanet_1509
# mapping Orphanet_1509
# Hash
# found mondo MONDO:0007841
# Orphanet_1512
# mapping Orphanet_1512
# Hash
# found mondo MONDO:0009028
# Orphanet_1513
# mapping Orphanet_1513
# Hash
# found mondo MONDO:0009031
# Orphanet_1514
# mapping Orphanet_1514
# Hash
# found mondo MONDO:0015463
# Orphanet_1515
# mapping Orphanet_1515
# Hash
# found mondo MONDO:0009032
# Orphanet_1516
# mapping Orphanet_1516
# Hash
# found mondo MONDO:0009034
# Orphanet_1517
# mapping Orphanet_1517
# Hash
# found mondo MONDO:0009406
# Orphanet_1519
# mapping Orphanet_1519
# Hash
# found mondo MONDO:0800025
# Orphanet_1520
# mapping Orphanet_1520
# Hash
# found mondo MONDO:0010570
# Orphanet_1521
# mapping Orphanet_1521
# Hash
# found mondo MONDO:0015464
# Orphanet_1524
# mapping Orphanet_1524
# Hash
# found mondo MONDO:0011253
# Orphanet_1525
# mapping Orphanet_1525
# Hash
# found mondo MONDO:0015466
# Orphanet_1527
# mapping Orphanet_1527
# Hash
# found mondo MONDO:0015467
# Orphanet_1528
# mapping Orphanet_1528
# Hash
# found mondo MONDO:0009042
# Orphanet_1529
# mapping Orphanet_1529
# Hash
# found mondo MONDO:0007395
# Orphanet_1530
# mapping Orphanet_1530
# Hash
# general failure - can't find mondo for orphanet Orphanet:1530 OBSOLETE: Craniosynostosis-cataract syndrome ...???
# found no mondo for Orphanet:1530
# Orphanet_1532
# mapping Orphanet_1532
# Hash
# found mondo MONDO:0011157
# Orphanet_1533
# mapping Orphanet_1533
# Hash
# general failure - can't find mondo for orphanet Orphanet:1533 OBSOLETE: Craniosynostosis-fibular aplasia syndrome ...???
# found no mondo for Orphanet:1533
# Orphanet_1535
# mapping Orphanet_1535
# Hash
# general failure - can't find mondo for orphanet Orphanet:1535 Craniosynostosis-dysmorphism-brachydactyly syndrome ...???
# found no mondo for Orphanet:1535
# Orphanet_1538
# mapping Orphanet_1538
# Hash
# found mondo MONDO:0007401
# Orphanet_1540
# mapping Orphanet_1540
# Hash
# found mondo MONDO:0007400
# Orphanet_1541
# mapping Orphanet_1541
# Hash
# found mondo MONDO:0011481
# Orphanet_1545
# mapping Orphanet_1545
# Hash
# found mondo MONDO:0010091
# Orphanet_1547
# mapping Orphanet_1547
# Hash
# found mondo MONDO:0007409
# Orphanet_1548
# mapping Orphanet_1548
# Hash
# found mondo MONDO:0015473
# Orphanet_1551
# mapping Orphanet_1551
# Hash
# found mondo MONDO:0007368
# Orphanet_1552
# mapping Orphanet_1552
# Hash
# found mondo MONDO:0008305
# Orphanet_1553
# mapping Orphanet_1553
# Hash
# found mondo MONDO:0011134
# Orphanet_1555
# mapping Orphanet_1555
# Hash
# found mondo MONDO:0007412
# Orphanet_155884
# mapping Orphanet_155884
# Hash
# found mondo MONDO:0015480
# Orphanet_155889
# mapping Orphanet_155889
# Hash
# found mondo MONDO:0015481
# Orphanet_156
# mapping Orphanet_156
# Hash
# found mondo MONDO:0009705
# Orphanet_1561
# mapping Orphanet_1561
# Hash
# found mondo MONDO:0015487
# Orphanet_156156
# mapping Orphanet_156156
# Hash
# general failure - can't find mondo for orphanet Orphanet:156156 Lipoatrophy with diabetes, leukomelanodermic papules, liver steatosis, and hypertrophic cardiomyopathy ...???
# found no mondo for Orphanet:156156
# Orphanet_1562
# mapping Orphanet_1562
# Hash
# general failure - can't find mondo for orphanet Orphanet:1562 OBSOLETE: Dacryocystitis-osteopoikilosis syndrome ...???
# found no mondo for Orphanet:1562
# Orphanet_1563
# mapping Orphanet_1563
# Hash
# found mondo MONDO:0009533
# Orphanet_1566
# mapping Orphanet_1566
# Hash
# found mondo MONDO:0009075
# Orphanet_156728
# mapping Orphanet_156728
# Hash
# found mondo MONDO:0012108
# Orphanet_156731
# mapping Orphanet_156731
# Hash
# found mondo MONDO:0009139
# Orphanet_1568
# mapping Orphanet_1568
# Hash
# found mondo MONDO:0010574
# Orphanet_1571
# mapping Orphanet_1571
# Hash
# found mondo MONDO:0800167
# Orphanet_157215
# mapping Orphanet_157215
# Hash
# found mondo MONDO:0009431
# Orphanet_1573
# mapping Orphanet_1573
# Hash
# found mondo MONDO:0011107
# Orphanet_1574
# mapping Orphanet_1574
# Hash
# found mondo MONDO:0009978
# Orphanet_157713
# mapping Orphanet_157713
# Hash
# found mondo MONDO:0015519
# Orphanet_157716
# mapping Orphanet_157716
# Hash
# found mondo MONDO:0015520
# Orphanet_157719
# mapping Orphanet_157719
# Hash
# found mondo MONDO:0015521
# Orphanet_157769
# mapping Orphanet_157769
# Hash
# found mondo MONDO:0018677
# Orphanet_157788
# mapping Orphanet_157788
# Hash
# general failure - can't find mondo for orphanet Orphanet:157788 Hypospadias-hypertelorism-coloboma and deafness syndrome ...???
# found no mondo for Orphanet:157788
# Orphanet_157794
# mapping Orphanet_157794
# Hash
# found mondo MONDO:0011023
# Orphanet_1578
# mapping Orphanet_1578
# Hash
# found mondo MONDO:0009908
# Orphanet_157801
# mapping Orphanet_157801
# Hash
# found mondo MONDO:0012271
# Orphanet_157846
# mapping Orphanet_157846
# Hash
# found mondo MONDO:0011638
# Orphanet_157941
# mapping Orphanet_157941
# Hash
# found mondo MONDO:0011299
# Orphanet_157946
# mapping Orphanet_157946
# Hash
# found mondo MONDO:0011487
# Orphanet_157949
# mapping Orphanet_157949
# Hash
# found mondo MONDO:0009306
# Orphanet_157954
# mapping Orphanet_157954
# Hash
# found mondo MONDO:0012794
# Orphanet_157962
# mapping Orphanet_157962
# Hash
# found mondo MONDO:0012802
# Orphanet_157965
# mapping Orphanet_157965
# Hash
# found mondo MONDO:0012873
# Orphanet_157973
# mapping Orphanet_157973
# Hash
# found mondo MONDO:0013178
# Orphanet_158
# mapping Orphanet_158
# Hash
# found mondo MONDO:0008919
# Orphanet_1580
# mapping Orphanet_1580
# Hash
# found mondo MONDO:0011055
# Orphanet_158029
# mapping Orphanet_158029
# Hash
# general failure - can't find mondo for orphanet Orphanet:158029 OBSOLETE: Sea-blue histiocytosis ...???
# found no mondo for Orphanet:158029
# Orphanet_1581
# mapping Orphanet_1581
# Hash
# found mondo MONDO:0015546
# Orphanet_158668
# mapping Orphanet_158668
# Hash
# found mondo MONDO:0011472
# Orphanet_158673
# mapping Orphanet_158673
# Hash
# found mondo MONDO:0015552
# Orphanet_158676
# mapping Orphanet_158676
# Hash
# found mondo MONDO:0015553
# Orphanet_158681
# mapping Orphanet_158681
# Hash
# found mondo MONDO:0012258
# Orphanet_158684
# mapping Orphanet_158684
# Hash
# found mondo MONDO:0012807
# Orphanet_158687
# mapping Orphanet_158687
# Hash
# found mondo MONDO:0012323
# Orphanet_1587
# mapping Orphanet_1587
# Hash
# found mondo MONDO:0013481
# Orphanet_159
# mapping Orphanet_159
# Hash
# found mondo MONDO:0008918
# Orphanet_1590
# mapping Orphanet_1590
# Hash
# found mondo MONDO:0011248
# Orphanet_1596
# mapping Orphanet_1596
# Hash
# found mondo MONDO:0012964
# Orphanet_1597
# mapping Orphanet_1597
# Hash
# found mondo MONDO:0015562
# Orphanet_1598
# mapping Orphanet_1598
# Hash
# found mondo MONDO:0007800
# Orphanet_16
# mapping Orphanet_16
# Hash
# found mondo MONDO:0010563
# Orphanet_1600
# mapping Orphanet_1600
# Hash
# found mondo MONDO:0011147
# Orphanet_1606
# mapping Orphanet_1606
# Hash
# found mondo MONDO:0011929
# Orphanet_1617
# mapping Orphanet_1617
# Hash
# found mondo MONDO:0015566
# Orphanet_162
# mapping Orphanet_162
# Hash
# found mondo MONDO:0015567
# Orphanet_1620
# mapping Orphanet_1620
# Hash
# found mondo MONDO:0013424
# Orphanet_1621
# mapping Orphanet_1621
# Hash
# found mondo MONDO:0014185
# Orphanet_1627
# mapping Orphanet_1627
# Hash
# found mondo MONDO:0015571
# Orphanet_163
# mapping Orphanet_163
# Hash
# found mondo MONDO:0010952
# Orphanet_163596
# mapping Orphanet_163596
# Hash
# found mondo MONDO:0015579
# Orphanet_1636
# mapping Orphanet_1636
# Hash
# found mondo MONDO:0015580
# Orphanet_163634
# mapping Orphanet_163634
# Hash
# found mondo MONDO:0013808
# Orphanet_163649
# mapping Orphanet_163649
# Hash
# found mondo MONDO:0011261
# Orphanet_163654
# mapping Orphanet_163654
# Hash
# found mondo MONDO:0012716
# Orphanet_163662
# mapping Orphanet_163662
# Hash
# found mondo MONDO:0010902
# Orphanet_163665
# mapping Orphanet_163665
# Hash
# found mondo MONDO:0010073
# Orphanet_163668
# mapping Orphanet_163668
# Hash
# found mondo MONDO:0008472
# Orphanet_163681
# mapping Orphanet_163681
# Hash
# found mondo MONDO:0012400
# Orphanet_163684
# mapping Orphanet_163684
# Hash
# found mondo MONDO:0013391
# Orphanet_163693
# mapping Orphanet_163693
# Hash
# found mondo MONDO:0015583
# Orphanet_163696
# mapping Orphanet_163696
# Hash
# found mondo MONDO:0009699
# Orphanet_163708
# mapping Orphanet_163708
# Hash
# found mondo MONDO:0015585
# Orphanet_163717
# mapping Orphanet_163717
# Hash
# found mondo MONDO:0015586
# Orphanet_163721
# mapping Orphanet_163721
# Hash
# found mondo MONDO:0015587
# Orphanet_163727
# mapping Orphanet_163727
# Hash
# found mondo MONDO:0011970
# Orphanet_163746
# mapping Orphanet_163746
# Hash
# found mondo MONDO:0012198
# Orphanet_163927
# mapping Orphanet_163927
# Hash
# found mondo MONDO:0015597
# Orphanet_163931
# mapping Orphanet_163931
# Hash
# found mondo MONDO:0013626
# Orphanet_163937
# mapping Orphanet_163937
# Hash
# found mondo MONDO:0010417
# Orphanet_163956
# mapping Orphanet_163956
# Hash
# found mondo MONDO:0010461
# Orphanet_163961
# mapping Orphanet_163961
# Hash
# found mondo MONDO:0010464
# Orphanet_163966
# mapping Orphanet_163966
# Hash
# found mondo MONDO:0010463
# Orphanet_163971
# mapping Orphanet_163971
# Hash
# found mondo MONDO:0015600
# Orphanet_163976
# mapping Orphanet_163976
# Hash
# found mondo MONDO:0015601
# Orphanet_163979
# mapping Orphanet_163979
# Hash
# found mondo MONDO:0010412
# Orphanet_163982
# mapping Orphanet_163982
# Hash
# general failure - can't find mondo for orphanet Orphanet:163982 X-linked intellectual disability-spastic quadriparesis syndrome ...???
# found no mondo for Orphanet:163982
# Orphanet_163985
# mapping Orphanet_163985
# Hash
# found mondo MONDO:0010375
# Orphanet_163988
# mapping Orphanet_163988
# Hash
# found mondo MONDO:0015602
# Orphanet_1642
# mapping Orphanet_1642
# Hash
# found mondo MONDO:0015605
# Orphanet_1643
# mapping Orphanet_1643
# Hash
# found mondo MONDO:0015606
# Orphanet_1646
# mapping Orphanet_1646
# Hash
# found mondo MONDO:0015607
# Orphanet_1647
# mapping Orphanet_1647
# Hash
# found mondo MONDO:0008108
# Orphanet_164736
# mapping Orphanet_164736
# Hash
# found mondo MONDO:0015609
# Orphanet_1654
# mapping Orphanet_1654
# Hash
# general failure - can't find mondo for orphanet Orphanet:1654 OBSOLETE: Natal teeth-intestinal pseudoobstruction-patent ductus syndrome ...???
# found no mondo for Orphanet:1654
# Orphanet_1655
# mapping Orphanet_1655
# Hash
# found mondo MONDO:0009333
# Orphanet_1657
# mapping Orphanet_1657
# Hash
# found mondo MONDO:0009095
# Orphanet_1658
# mapping Orphanet_1658
# Hash
# found mondo MONDO:0007507
# Orphanet_165805
# mapping Orphanet_165805
# Hash
# found mondo MONDO:0013742
# Orphanet_165991
# mapping Orphanet_165991
# Hash
# found mondo MONDO:0012396
# Orphanet_165994
# mapping Orphanet_165994
# Hash
# general failure - can't find mondo for orphanet Orphanet:165994 Pituitary resistance to thyroid hormone ...???
# found no mondo for Orphanet:165994
# Orphanet_1660
# mapping Orphanet_1660
# Hash
# found mondo MONDO:0007449
# Orphanet_166002
# mapping Orphanet_166002
# Hash
# found mondo MONDO:0015627
# Orphanet_166011
# mapping Orphanet_166011
# Hash
# general failure - can't find mondo for orphanet Orphanet:166011 Multiple epiphyseal dysplasia, Beighton type ...???
# found no mondo for Orphanet:166011
# Orphanet_166016
# mapping Orphanet_166016
# Hash
# found mondo MONDO:0011109
# Orphanet_166024
# mapping Orphanet_166024
# Hash
# found mondo MONDO:0011778
# Orphanet_166029
# mapping Orphanet_166029
# Hash
# found mondo MONDO:0012253
# Orphanet_166032
# mapping Orphanet_166032
# Hash
# found mondo MONDO:0012254
# Orphanet_166035
# mapping Orphanet_166035
# Hash
# found mondo MONDO:0009598
# Orphanet_166038
# mapping Orphanet_166038
# Hash
# found mondo MONDO:0009594
# Orphanet_166063
# mapping Orphanet_166063
# Hash
# found mondo MONDO:0009166
# Orphanet_166068
# mapping Orphanet_166068
# Hash
# general failure - can't find mondo for orphanet Orphanet:166068 Pontocerebellar hypoplasia type 5 ...???
# found no mondo for Orphanet:166068
# Orphanet_166073
# mapping Orphanet_166073
# Hash
# found mondo MONDO:0012683
# Orphanet_166078
# mapping Orphanet_166078
# Hash
# found mondo MONDO:0008668
# Orphanet_166084
# mapping Orphanet_166084
# Hash
# found mondo MONDO:0015628
# Orphanet_166087
# mapping Orphanet_166087
# Hash
# found mondo MONDO:0015629
# Orphanet_166090
# mapping Orphanet_166090
# Hash
# found mondo MONDO:0015630
# Orphanet_166093
# mapping Orphanet_166093
# Hash
# found mondo MONDO:0015631
# Orphanet_166096
# mapping Orphanet_166096
# Hash
# found mondo MONDO:0010191
# Orphanet_1661
# mapping Orphanet_1661
# Hash
# found mondo MONDO:0010579
# Orphanet_166100
# mapping Orphanet_166100
# Hash
# found mondo MONDO:0008490
# Orphanet_166105
# mapping Orphanet_166105
# Hash
# found mondo MONDO:0015632
# Orphanet_166108
# mapping Orphanet_166108
# Hash
# found mondo MONDO:0012856
# Orphanet_166113
# mapping Orphanet_166113
# Hash
# found mondo MONDO:0010535
# Orphanet_166119
# mapping Orphanet_166119
# Hash
# found mondo MONDO:0015634
# Orphanet_1662
# mapping Orphanet_1662
# Hash
# found mondo MONDO:0031213
# Orphanet_166265
# mapping Orphanet_166265
# Hash
# found mondo MONDO:0007442
# Orphanet_166272
# mapping Orphanet_166272
# Hash
# found mondo MONDO:0100325
# Orphanet_166277
# mapping Orphanet_166277
# Hash
# found mondo MONDO:0011501
# Orphanet_166282
# mapping Orphanet_166282
# Hash
# found mondo MONDO:0012061
# Orphanet_166286
# mapping Orphanet_166286
# Hash
# found mondo MONDO:0015635
# Orphanet_166299
# mapping Orphanet_166299
# Hash
# general failure - can't find mondo for orphanet Orphanet:166299 Benign partial epilepsy of infancy with complex partial seizures ...???
# found no mondo for Orphanet:166299
# Orphanet_166302
# mapping Orphanet_166302
# Hash
# general failure - can't find mondo for orphanet Orphanet:166302 Benign partial epilepsy with secondarily generalized seizures in infancy ...???
# found no mondo for Orphanet:166302
# Orphanet_166305
# mapping Orphanet_166305
# Hash
# general failure - can't find mondo for orphanet Orphanet:166305 OBSOLETE: Benign infantile seizures associated with mild gastroenteritis ...???
# found no mondo for Orphanet:166305
# Orphanet_166308
# mapping Orphanet_166308
# Hash
# ...
# Orphanet_98868
# mapping Orphanet_98868
# Hash
# found mondo MONDO:0008165
# Orphanet_98869
# mapping Orphanet_98869
# Hash
# found mondo MONDO:0020337
# Orphanet_98870
# mapping Orphanet_98870
# Hash
# found mondo MONDO:0007109
# Orphanet_98873
# mapping Orphanet_98873
# Hash
# found mondo MONDO:0009134
# Orphanet_98885
# mapping Orphanet_98885
# Hash
# found mondo MONDO:0013623
# Orphanet_98886
# mapping Orphanet_98886
# Hash
# found mondo MONDO:0013622
# Orphanet_98889
# mapping Orphanet_98889
# Hash
# found mondo MONDO:0020340
# Orphanet_98890
# mapping Orphanet_98890
# Hash
# found mondo MONDO:0010698
# Orphanet_98893
# mapping Orphanet_98893
# Hash
# found mondo MONDO:0011486
# Orphanet_98895
# mapping Orphanet_98895
# Hash
# found mondo MONDO:0010311
# Orphanet_98896
# mapping Orphanet_98896
# Hash
# found mondo MONDO:0010679
# Orphanet_98897
# mapping Orphanet_98897
# Hash
# found mondo MONDO:0025193
# Orphanet_989
# mapping Orphanet_989
# Hash
# found mondo MONDO:0007073
# Orphanet_98902
# mapping Orphanet_98902
# Hash
# found mondo MONDO:0011539
# Orphanet_98904
# mapping Orphanet_98904
# Hash
# found mondo MONDO:0008070
# Orphanet_98905
# mapping Orphanet_98905
# Hash
# found mondo MONDO:0009712
# Orphanet_98907
# mapping Orphanet_98907
# Hash
# found mondo MONDO:0010155
# Orphanet_98908
# mapping Orphanet_98908
# Hash
# found mondo MONDO:0012545
# Orphanet_98909
# mapping Orphanet_98909
# Hash
# found mondo MONDO:0011076
# Orphanet_98912
# mapping Orphanet_98912
# Hash
# found mondo MONDO:0012277
# Orphanet_98913
# mapping Orphanet_98913
# Hash
# found mondo MONDO:0020344
# Orphanet_98914
# mapping Orphanet_98914
# Hash
# found mondo MONDO:0020345
# Orphanet_98915
# mapping Orphanet_98915
# Hash
# found mondo MONDO:0020346
# Orphanet_98920
# mapping Orphanet_98920
# Hash
# found mondo MONDO:0011436
# Orphanet_98934
# mapping Orphanet_98934
# Hash
# found mondo MONDO:0011671
# Orphanet_98938
# mapping Orphanet_98938
# Hash
# found mondo MONDO:0000170
# Orphanet_98941
# mapping Orphanet_98941
# Hash
# general failure - can't find mondo for orphanet Orphanet:98941 OBSOLETE: Von Hippel anomaly ...???
# found no mondo for Orphanet:98941
# Orphanet_98942
# mapping Orphanet_98942
# Hash
# found mondo MONDO:0020354
# Orphanet_98943
# mapping Orphanet_98943
# Hash
# found mondo MONDO:0020355
# Orphanet_98944
# mapping Orphanet_98944
# Hash
# found mondo MONDO:0020356
# Orphanet_98945
# mapping Orphanet_98945
# Hash
# found mondo MONDO:0007351
# Orphanet_98946
# mapping Orphanet_98946
# Hash
# found mondo MONDO:0020357
# Orphanet_98947
# mapping Orphanet_98947
# Hash
# found mondo MONDO:0007354
# Orphanet_98948
# mapping Orphanet_98948
# Hash
# found mondo MONDO:0020359
# Orphanet_98949
# mapping Orphanet_98949
# Hash
# found mondo MONDO:0020360
# Orphanet_98950
# mapping Orphanet_98950
# Hash
# found mondo MONDO:0020361
# Orphanet_98951
# mapping Orphanet_98951
# Hash
# found mondo MONDO:0020362
# Orphanet_98955
# mapping Orphanet_98955
# Hash
# found mondo MONDO:0010425
# Orphanet_98956
# mapping Orphanet_98956
# Hash
# found mondo MONDO:0007375
# Orphanet_98957
# mapping Orphanet_98957
# Hash
# found mondo MONDO:0008777
# Orphanet_98958
# mapping Orphanet_98958
# Hash
# found mondo MONDO:0020363
# Orphanet_98959
# mapping Orphanet_98959
# Hash
# found mondo MONDO:0013026
# Orphanet_98960
# mapping Orphanet_98960
# Hash
# found mondo MONDO:0011185
# Orphanet_98961
# mapping Orphanet_98961
# Hash
# found mondo MONDO:0012043
# Orphanet_98962
# mapping Orphanet_98962
# Hash
# found mondo MONDO:0007377
# Orphanet_98963
# mapping Orphanet_98963
# Hash
# found mondo MONDO:0011855
# Orphanet_98964
# mapping Orphanet_98964
# Hash
# found mondo MONDO:0007380
# Orphanet_98967
# mapping Orphanet_98967
# Hash
# found mondo MONDO:0007374
# Orphanet_98969
# mapping Orphanet_98969
# Hash
# found mondo MONDO:0009020
# Orphanet_98970
# mapping Orphanet_98970
# Hash
# found mondo MONDO:0007376
# Orphanet_98971
# mapping Orphanet_98971
# Hash
# found mondo MONDO:0013027
# Orphanet_98972
# mapping Orphanet_98972
# Hash
# found mondo MONDO:0009018
# Orphanet_98973
# mapping Orphanet_98973
# Hash
# found mondo MONDO:0020364
# Orphanet_98974
# mapping Orphanet_98974
# Hash
# found mondo MONDO:0005321
# Orphanet_98975
# mapping Orphanet_98975
# Hash
# general failure - can't find mondo for orphanet Orphanet:98975 Congenital hereditary endothelial dystrophy type I ...???
# found no mondo for Orphanet:98975
# Orphanet_98978
# mapping Orphanet_98978
# Hash
# found mondo MONDO:0020368
# Orphanet_98979
# mapping Orphanet_98979
# Hash
# found mondo MONDO:0020369
# Orphanet_98980
# mapping Orphanet_98980
# Hash
# found mondo MONDO:0020370
# Orphanet_98981
# mapping Orphanet_98981
# Hash
# found mondo MONDO:0020371
# Orphanet_98983
# mapping Orphanet_98983
# Hash
# general failure - can't find mondo for orphanet Orphanet:98983 OBSOLETE: Congenital cataract, Volkmann type ...???
# found no mondo for Orphanet:98983
# Orphanet_98984
# mapping Orphanet_98984
# Hash
# found mondo MONDO:0011430
# Orphanet_98985
# mapping Orphanet_98985
# Hash
# found mondo MONDO:0020372
# Orphanet_98986
# mapping Orphanet_98986
# Hash
# general failure - can't find mondo for orphanet Orphanet:98986 OBSOLETE: Coppock-like cataract ...???
# found no mondo for Orphanet:98986
# Orphanet_98987
# mapping Orphanet_98987
# Hash
# general failure - can't find mondo for orphanet Orphanet:98987 OBSOLETE: Cataract, Hutterite type ...???
# found no mondo for Orphanet:98987
# Orphanet_98988
# mapping Orphanet_98988
# Hash
# found mondo MONDO:0020373
# Orphanet_98989
# mapping Orphanet_98989
# Hash
# found mondo MONDO:0020374
# Orphanet_98990
# mapping Orphanet_98990
# Hash
# found mondo MONDO:0020375
# Orphanet_98991
# mapping Orphanet_98991
# Hash
# found mondo MONDO:0020376
# Orphanet_98993
# mapping Orphanet_98993
# Hash
# found mondo MONDO:0020378
# Orphanet_98994
# mapping Orphanet_98994
# Hash
# found mondo MONDO:0021548
# Orphanet_98995
# mapping Orphanet_98995
# Hash
# found mondo MONDO:0020379
# Orphanet_990
# mapping Orphanet_990
# Hash
# found mondo MONDO:0008740
# Orphanet_99000
# mapping Orphanet_99000
# Hash
# found mondo MONDO:0011979
# Orphanet_99002
# mapping Orphanet_99002
# Hash
# found mondo MONDO:0009979
# Orphanet_99003
# mapping Orphanet_99003
# Hash
# found mondo MONDO:0020382
# Orphanet_99004
# mapping Orphanet_99004
# Hash
# found mondo MONDO:0020383
# Orphanet_99012
# mapping Orphanet_99012
# Hash
# general failure - can't find mondo for orphanet Orphanet:99012 OBSOLETE: Autosomal recessive optic atrophy, OPA6 type ...???
# found no mondo for Orphanet:99012
# Orphanet_99013
# mapping Orphanet_99013
# Hash
# found mondo MONDO:0011803
# Orphanet_99014
# mapping Orphanet_99014
# Hash
# found mondo MONDO:0010699
# Orphanet_99015
# mapping Orphanet_99015
# Hash
# found mondo MONDO:0010733
# Orphanet_99022
# mapping Orphanet_99022
# Hash
# general failure - can't find mondo for orphanet Orphanet:99022 OBSOLETE: Niemann-Pick disease type E ...???
# found no mondo for Orphanet:99022
# Orphanet_99027
# mapping Orphanet_99027
# Hash
# found mondo MONDO:0008215
# Orphanet_99042
# mapping Orphanet_99042
# Hash
# found mondo MONDO:0020385
# Orphanet_99043
# mapping Orphanet_99043
# Hash
# found mondo MONDO:0020386
# Orphanet_99044
# mapping Orphanet_99044
# Hash
# general failure - can't find mondo for orphanet Orphanet:99044 Double outlet right ventricle with subaortic ventricular septal defect ...???
# found no mondo for Orphanet:99044
# Orphanet_99045
# mapping Orphanet_99045
# Hash
# found mondo MONDO:0020387
# Orphanet_99046
# mapping Orphanet_99046
# Hash
# found mondo MONDO:0020388
# Orphanet_99047
# mapping Orphanet_99047
# Hash
# general failure - can't find mondo for orphanet Orphanet:99047 Double outlet right ventricle with doubly committed ventricular septal defect ...???
# found no mondo for Orphanet:99047
# Orphanet_99092
# mapping Orphanet_99092
# Hash
# found mondo MONDO:0007112
# Orphanet_99094
# mapping Orphanet_99094
# Hash
# found mondo MONDO:0020427
# Orphanet_99095
# mapping Orphanet_99095
# Hash
# found mondo MONDO:0020428
# Orphanet_99096
# mapping Orphanet_99096
# Hash
# general failure - can't find mondo for orphanet Orphanet:99096 OBSOLETE: Multiple ventricular septal defects ...???
# found no mondo for Orphanet:99096
# Orphanet_99097
# mapping Orphanet_99097
# Hash
# general failure - can't find mondo for orphanet Orphanet:99097 OBSOLETE: Single ventricular septal defect ...???
# found no mondo for Orphanet:99097
# Orphanet_991
# mapping Orphanet_991
# Hash
# found mondo MONDO:0008741
# Orphanet_99103
# mapping Orphanet_99103
# Hash
# found mondo MONDO:0020434
# Orphanet_99104
# mapping Orphanet_99104
# Hash
# found mondo MONDO:0020435
# Orphanet_99105
# mapping Orphanet_99105
# Hash
# found mondo MONDO:0020436
# Orphanet_99106
# mapping Orphanet_99106
# Hash
# found mondo MONDO:0020437
# Orphanet_99135
# mapping Orphanet_99135
# Hash
# found mondo MONDO:0020457
# Orphanet_99138
# mapping Orphanet_99138
# Hash
# found mondo MONDO:0020458
# Orphanet_99169
# mapping Orphanet_99169
# Hash
# found mondo MONDO:0020461
# Orphanet_99170
# mapping Orphanet_99170
# Hash
# found mondo MONDO:0020462
# Orphanet_99171
# mapping Orphanet_99171
# Hash
# found mondo MONDO:0020463
# Orphanet_99172
# mapping Orphanet_99172
# Hash
# found mondo MONDO:0020464
# Orphanet_99176
# mapping Orphanet_99176
# Hash
# found mondo MONDO:0020465
# Orphanet_99177
# mapping Orphanet_99177
# Hash
# found mondo MONDO:0007464
# Orphanet_99179
# mapping Orphanet_99179
# Hash
# found mondo MONDO:0009236
# Orphanet_99226
# mapping Orphanet_99226
# Hash
# found mondo MONDO:0020466
# Orphanet_99228
# mapping Orphanet_99228
# Hash
# found mondo MONDO:0020467
# Orphanet_99324
# mapping Orphanet_99324
# Hash
# found mondo MONDO:0020468
# Orphanet_99329
# mapping Orphanet_99329
# Hash
# found mondo MONDO:0020469
# Orphanet_99330
# mapping Orphanet_99330
# Hash
# found mondo MONDO:0020470
# Orphanet_99361
# mapping Orphanet_99361
# Hash
# found mondo MONDO:0007958
# Orphanet_994
# mapping Orphanet_994
# Hash
# found mondo MONDO:0100101
# Orphanet_99413
# mapping Orphanet_99413
# Hash
# found mondo MONDO:0020472
# Orphanet_99429
# mapping Orphanet_99429
# Hash
# found mondo MONDO:0021023
# Orphanet_99642
# mapping Orphanet_99642
# Hash
# found mondo MONDO:0013233
# Orphanet_99645
# mapping Orphanet_99645
# Hash
# general failure - can't find mondo for orphanet Orphanet:99645 Dappled diaphyseal dysplasia ...???
# found no mondo for Orphanet:99645
# Orphanet_99646
# mapping Orphanet_99646
# Hash
# found mondo MONDO:0013941
# Orphanet_99647
# mapping Orphanet_99647
# Hash
# found mondo MONDO:0020474
# Orphanet_99657
# mapping Orphanet_99657
# Hash
# found mondo MONDO:0009141
# Orphanet_99672
# mapping Orphanet_99672
# Hash
# found mondo MONDO:0011219
# Orphanet_99688
# mapping Orphanet_99688
# Hash
# found mondo MONDO:0020475
# Orphanet_99701
# mapping Orphanet_99701
# Hash
# found mondo MONDO:0020476
# Orphanet_99706
# mapping Orphanet_99706
# Hash
# general failure - can't find mondo for orphanet Orphanet:99706 OBSOLETE: Progeria-associated arthropathy ...???
# found no mondo for Orphanet:99706
# Orphanet_99718
# mapping Orphanet_99718
# Hash
# found mondo MONDO:0020478
# Orphanet_99723
# mapping Orphanet_99723
# Hash
# general failure - can't find mondo for orphanet Orphanet:99723 OBSOLETE: Familial esophageal achalasia ...???
# found no mondo for Orphanet:99723
# Orphanet_99731
# mapping Orphanet_99731
# Hash
# found mondo MONDO:0010089
# Orphanet_99734
# mapping Orphanet_99734
# Hash
# found mondo MONDO:0020481
# Orphanet_99735
# mapping Orphanet_99735
# Hash
# found mondo MONDO:0020482
# Orphanet_99736
# mapping Orphanet_99736
# Hash
# found mondo MONDO:0020483
# Orphanet_99741
# mapping Orphanet_99741
# Hash
# found mondo MONDO:0020485
# Orphanet_99742
# mapping Orphanet_99742
# Hash
# found mondo MONDO:0011790
# Orphanet_99749
# mapping Orphanet_99749
# Hash
# found mondo MONDO:0012548
# Orphanet_99764
# mapping Orphanet_99764
# Hash
# general failure - can't find mondo for orphanet Orphanet:99764 OBSOLETE: Familial hyperreninemic hypoaldosteronism type 2 ...???
# found no mondo for Orphanet:99764
# Orphanet_99776
# mapping Orphanet_99776
# Hash
# found mondo MONDO:0020490
# Orphanet_99791
# mapping Orphanet_99791
# Hash
# found mondo MONDO:0007437
# Orphanet_99792
# mapping Orphanet_99792
# Hash
# found mondo MONDO:0007438
# Orphanet_99797
# mapping Orphanet_99797
# Hash
# found mondo MONDO:0008797
# Orphanet_99798
# mapping Orphanet_99798
# Hash
# found mondo MONDO:0005486
# Orphanet_998
# mapping Orphanet_998
# Hash
# found mondo MONDO:0010403
# Orphanet_99802
# mapping Orphanet_99802
# Hash
# found mondo MONDO:0020492
# Orphanet_99803
# mapping Orphanet_99803
# Hash
# found mondo MONDO:0020493
# Orphanet_99806
# mapping Orphanet_99806
# Hash
# found mondo MONDO:0020494
# Orphanet_99807
# mapping Orphanet_99807
# Hash
# found mondo MONDO:0020495
# Orphanet_99811
# mapping Orphanet_99811
# Hash
# found mondo MONDO:8000011
# Orphanet_99812
# mapping Orphanet_99812
# Hash
# found mondo MONDO:0011686
# Orphanet_99817
# mapping Orphanet_99817
# Hash
# general failure - can't find mondo for orphanet Orphanet:99817 Non-polyposis Turcot syndrome ...???
# found no mondo for Orphanet:99817
# Orphanet_99818
# mapping Orphanet_99818
# Hash
# general failure - can't find mondo for orphanet Orphanet:99818 Turcot syndrome with polyposis ...???
# found no mondo for Orphanet:99818
# Orphanet_99819
# mapping Orphanet_99819
# Hash
# found mondo MONDO:0011309
# Orphanet_99832
# mapping Orphanet_99832
# Hash
# found mondo MONDO:0032819
# Orphanet_99842
# mapping Orphanet_99842
# Hash
# found mondo MONDO:0007293
# Orphanet_99843
# mapping Orphanet_99843
# Hash
# found mondo MONDO:0009953
# Orphanet_99844
# mapping Orphanet_99844
# Hash
# found mondo MONDO:0013016
# Orphanet_99845
# mapping Orphanet_99845
# Hash
# found mondo MONDO:0020504
# Orphanet_99846
# mapping Orphanet_99846
# Hash
# found mondo MONDO:0008046
# Orphanet_99849
# mapping Orphanet_99849
# Hash
# found mondo MONDO:0013046
# Orphanet_99852
# mapping Orphanet_99852
# Hash
# found mondo MONDO:0020505
# Orphanet_99853
# mapping Orphanet_99853
# Hash
# found mondo MONDO:0020506
# Orphanet_99854
# mapping Orphanet_99854
# Hash
# found mondo MONDO:0020507
# Orphanet_99858
# mapping Orphanet_99858
# Hash
# found mondo MONDO:0020510
# Orphanet_99875
# mapping Orphanet_99875
# Hash
# general failure - can't find mondo for orphanet Orphanet:99875 OBSOLETE: Ehlers-Danlos syndrome type 7A ...???
# found no mondo for Orphanet:99875
# Orphanet_99876
# mapping Orphanet_99876
# Hash
# general failure - can't find mondo for orphanet Orphanet:99876 OBSOLETE: Ehlers-Danlos syndrome type 7B ...???
# found no mondo for Orphanet:99876
# Orphanet_99877
# mapping Orphanet_99877
# Hash
# general failure - can't find mondo for orphanet Orphanet:99877 OBSOLETE: Familial parathyroid adenoma ...???
# found no mondo for Orphanet:99877
# Orphanet_99878
# mapping Orphanet_99878
# Hash
# found mondo MONDO:0020524
# Orphanet_99879
# mapping Orphanet_99879
# Hash
# found mondo MONDO:0015027
# Orphanet_99880
# mapping Orphanet_99880
# Hash
# found mondo MONDO:0007768
# Orphanet_99885
# mapping Orphanet_99885
# Hash
# found mondo MONDO:0100164
# Orphanet_99886
# mapping Orphanet_99886
# Hash
# found mondo MONDO:0011073
# Orphanet_99898
# mapping Orphanet_99898
# Hash
# found mondo MONDO:0020530
# Orphanet_999
# mapping Orphanet_999
# Hash
# found mondo MONDO:0009196
# Orphanet_99901
# mapping Orphanet_99901
# Hash
# found mondo MONDO:0012624
# Orphanet_99936
# mapping Orphanet_99936
# Hash
# found mondo MONDO:0010949
# Orphanet_99937
# mapping Orphanet_99937
# Hash
# found mondo MONDO:0011633
# Orphanet_99938
# mapping Orphanet_99938
# Hash
# found mondo MONDO:0011091
# Orphanet_99939
# mapping Orphanet_99939
# Hash
# found mondo MONDO:0011894
# Orphanet_99940
# mapping Orphanet_99940
# Hash
# found mondo MONDO:0011687
# Orphanet_99941
# mapping Orphanet_99941
# Hash
# general failure - can't find mondo for orphanet Orphanet:99941 Autosomal dominant Charcot-Marie-Tooth disease type 2G ...???
# found no mondo for Orphanet:99941
# Orphanet_99942
# mapping Orphanet_99942
# Hash
# found mondo MONDO:0011889
# Orphanet_99943
# mapping Orphanet_99943
# Hash
# found mondo MONDO:0011903
# Orphanet_99944
# mapping Orphanet_99944
# Hash
# found mondo MONDO:0020558
# Orphanet_99945
# mapping Orphanet_99945
# Hash
# found mondo MONDO:0012096
# Orphanet_99946
# mapping Orphanet_99946
# Hash
# found mondo MONDO:0007308
# Orphanet_99947
# mapping Orphanet_99947
# Hash
# found mondo MONDO:0012231
# Orphanet_99948
# mapping Orphanet_99948
# Hash
# found mondo MONDO:0008961
# Orphanet_99949
# mapping Orphanet_99949
# Hash
# found mondo MONDO:0011113
# Orphanet_99950
# mapping Orphanet_99950
# Hash
# found mondo MONDO:0011085
# Orphanet_99951
# mapping Orphanet_99951
# Hash
# found mondo MONDO:0011527
# Orphanet_99952
# mapping Orphanet_99952
# Hash
# found mondo MONDO:0013959
# Orphanet_99953
# mapping Orphanet_99953
# Hash
# found mondo MONDO:0011534
# Orphanet_99954
# mapping Orphanet_99954
# Hash
# found mondo MONDO:0012250
# Orphanet_99955
# mapping Orphanet_99955
# Hash
# found mondo MONDO:0011066
# Orphanet_99956
# mapping Orphanet_99956
# Hash
# found mondo MONDO:0011475
# Orphanet_99960
# mapping Orphanet_99960
# Hash
# found mondo MONDO:0009469
# Orphanet_99989
# mapping Orphanet_99989
# Hash
# found mondo MONDO:0020569

# %%
puts `pwd`
# Out:
# /home/osboxes/CODE/SIMPATHIC2/SKG_Mapping/radboud
