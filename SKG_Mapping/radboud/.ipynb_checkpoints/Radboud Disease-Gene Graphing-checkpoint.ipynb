# %%
puts `head -2 ./mappings/genes.map`
# Out:
# sourceid,label,geneid,protein,recommended_full,taxon
# ENSG00000012779,ENSG00000012779,http://purl.uniprot.org/geneid/240,http://purl.uniprot.org/uniprot/P09917,Polyunsaturated fatty acid 5-lipoxygenase,http://purl.uniprot.org/taxonomy/9606

# %%
puts `head -2 ./mappings/diseases.map`
# Out:
# source,mondo,prefname
# EFO_0000174,http://purl.obolibrary.org/obo/MONDO_0012817,Ewing sarcoma

# %%
puts `head -2 ./rawdata/disease-gene.csv`
# Out:
# "source","source_type","target","target_type"
# "DOID_7551","disease","ENSG00000058085","gene"

# %%
require 'linkeddata'
require 'rdf/nquads'
require 'csv'

e = File.open('./graph/disease-gene-errors.txt', 'w') 

# Define namespaces
SIMPATHIC = RDF::Vocabulary.new('urn:simpathic:')
RDFS = RDF::Vocabulary.new('http://www.w3.org/2000/01/rdf-schema#')
# Read input files
disease_mappings = CSV.read('./maps/diseases.map', headers: true)
gene_mappings = CSV.read('./maps/genes.map', headers: true)
failures = {}


# refresh
f = File.open('./graph/disease-gene.nq.large', 'w')
f.close

recordcount = 0
CSV.foreach('./rawdata/disease-gene.csv', col_sep: ",", quote_char: '"', 
  liberal_parsing: true, headers: true) do |row|
# "source","source_type","target","target_type"
# "DOID_7551","disease","ENSG00000058085","gene"
  disease_id = row['source']
  gene_id = row['target']
  score = 1
  #evidence = ""

#   warn "searching for #{disease_id}"
  disease = disease_mappings.find { |d| d['source'] == disease_id }
  gene = gene_mappings.find { |d| d['sourceid'] == gene_id }
  
  unless disease
    next if failures[disease_id]
    failures[disease_id] = 1
    warn "disease lookup failed #{disease_id}"
    e.write "disease lookup failed #{disease_id}\n"
    next
  end
  unless gene
    next if failures[gene_id]
    failures[gene_id] = 1
    warn "gene lookup failed #{gene_id}"
    e.write "gene lookup failed #{gene_id}\n"
    next
  end
  
  # Extract relevant IDs and labels
# source,mondo,prefname
# Orphanet:100032,MONDO:0968955,Hypocalcified amelogenesis imperfecta
  mondo_uri = RDF::URI.new(disease['mondo'])
  mondo_type = RDF::URI.new("https://bioportal.bioontology.org/ontologies/MONDO")
  mondo_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Disease")
  mondo_label =  RDF::Literal.new("MONDO Term")
#   orphanet = RDF::URI.new(disease['orpha'])
  disease_label = RDF::Literal.new(disease['prefname'])
  original_disease = RDF::Literal.new(disease['source'])
  

#   sourceid,label,geneid,protein,recommended_full,taxon
#   ENSG00000091831,ENSG00000091831,http://purl.uniprot.org/geneid/2099,http://purl.uniprot.org/uniprot/P03372,Estrogen receptor,http://purl.uniprot.org/taxonomy/9606
  gene_uri = RDF::URI.new(gene['geneid'])
  gene_type = RDF::URI.new("http://edamontology.org/data_1027")
  gene_label =  RDF::Literal.new("NCBI/UniProt Gene Identifier")
  gene_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Gene")
  gene_label = RDF::Literal.new(gene['label'])

  
  protein_uri = RDF::URI.new(gene['protein'])
  protein_type = RDF::URI.new("http://edamontology.org/data_2291")
  protein_label =  RDF::Literal.new("UniProt Identifier")
  protein_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Protein")
  human_protein_label = RDF::Literal.new(gene['recommended_full'])
    
  taxon = RDF::URI.new(gene['taxon'])
  
  # Create context URI
  context_uri = RDF::URI.new("urn:simpathic:context:#{disease_id}_#{gene_id}")
  general_context = RDF::URI.new("urn:simpathic:context:all_metadata")
  
  # Create RDF repository (need to do this each time, since there are hundreds of thousands of lines, and the graph gets too big for memory)
  graph = RDF::Repository.new


  # Add quads to graph using RDF::Statement
  graph << RDF::Statement.new(mondo_uri, SIMPATHIC['associated-with'], protein_uri, graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri, SIMPATHIC['associated-with'], mondo_uri, graph_name: context_uri)

    
  graph << RDF::Statement.new(mondo_uri, RDFS.label, disease_label, graph_name: context_uri)
  graph << RDF::Statement.new(mondo_uri, RDF.type, mondo_type, graph_name: context_uri)
  graph << RDF::Statement.new(mondo_uri, RDF.type, mondo_core_type, graph_name: context_uri)
  graph << RDF::Statement.new(mondo_type, RDFS.label, mondo_label, graph_name: context_uri)
#   graph << RDF::Statement.new(mondo_uri, SIMPATHIC['orphanet'], orphanet, graph_name: context_uri)
  graph << RDF::Statement.new(mondo_uri, SIMPATHIC['original-id'], original_disease, graph_name: context_uri)
  
  graph << RDF::Statement.new(gene_uri,  RDFS.label,       gene_label , graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  RDF.type,         gene_type, graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  RDF.type,         gene_core_type, graph_name: context_uri)
  graph << RDF::Statement.new(gene_type, RDFS.label,       RDF::Literal.new("NCBI Gene"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_core_type, RDFS.label,  RDF::Literal.new("Gene"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{gene_id}"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  SIMPATHIC['in-taxon'], taxon, graph_name: context_uri)
    
  graph << RDF::Statement.new(mondo_uri, SIMPATHIC['associated-with'], gene_uri, graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri, SIMPATHIC['associated-with'], mondo_uri, graph_name: context_uri)

  
  graph << RDF::Statement.new(protein_uri,  RDFS.label,       human_protein_label , graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  RDF.type,         protein_type, graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  RDF.type,         protein_core_type, graph_name: context_uri)
  graph << RDF::Statement.new(protein_type, RDFS.label,       RDF::Literal.new("UniProt"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_core_type, RDFS.label,  RDF::Literal.new("Protein"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{gene_id}"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  SIMPATHIC['in-taxon'], taxon, graph_name: context_uri)

  
  graph << RDF::Statement.new(context_uri, SIMPATHIC['skg-source'], RDF::Literal.new("Radboud"), graph_name: general_context)
#   graph << RDF::Statement.new(context_uri, SIMPATHIC['evidence'], RDF::URI.new(evidence))
#   graph << RDF::Statement.new(context_uri, SIMPATHIC['score'], RDF::Literal.new(score))


#   warn "graph #{context_uri} built"
  # Write RDF to file in N-Quads format
  File.open('./graph/disease-gene.nq.large', 'a') do |f|
    RDF::Writer.for(:nquads).new(f) do |writer|
#         warn "writing quads"
      writer << graph
    end
  end
#   warn "end graph writing"

end
warn "completed graph building"
e.close

puts "RDF quads written"
# Out:
# (irb):7: warning: already initialized constant Object::SIMPATHIC
# (irb):7: warning: previous definition of SIMPATHIC was here
# (irb):8: warning: already initialized constant Object::RDFS
# (irb):8: warning: previous definition of RDFS was here
# disease lookup failed DOID_7551
# disease lookup failed HP_0000857
# disease lookup failed HP_0012076
# disease lookup failed MONDO_0030006
# disease lookup failed HP_0000520
# disease lookup failed HP_0000802
# disease lookup failed MONDO_0021116
# disease lookup failed HP_0001591
# disease lookup failed HP_0002035
# disease lookup failed HP_0008909
# disease lookup failed MONDO_0002203
# disease lookup failed MONDO_0004392
# disease lookup failed MONDO_0012806
# disease lookup failed MONDO_0032911
# disease lookup failed EFO_0000713
# disease lookup failed HP_0009816
# disease lookup failed HP_0010865
# disease lookup failed HP_0012042
# disease lookup failed MONDO_0008597
# disease lookup failed MONDO_0044784
# disease lookup failed MONDO_0054781
# disease lookup failed HP_0002571
# disease lookup failed HP_0004308
# disease lookup failed HP_0012390
# disease lookup failed HP_0012410
# disease lookup failed HP_0100727
# disease lookup failed MONDO_0009619
# disease lookup failed MONDO_0011377
# disease lookup failed MONDO_0015003
# disease lookup failed MONDO_0032889
# disease lookup failed MONDO_0000030
# disease lookup failed MONDO_0030060
# disease lookup failed EFO_0001675
# disease lookup failed HP_0000327
# disease lookup failed HP_0006789
# disease lookup failed HP_0030834
# disease lookup failed MONDO_0001410
# disease lookup failed MONDO_0014725
# disease lookup failed MONDO_0054695
# disease lookup failed EFO_0000174
# disease lookup failed EFO_0003073
# disease lookup failed HP_0000200
# disease lookup failed MONDO_0012670
# disease lookup failed MONDO_0014608
# disease lookup failed MONDO_0019471
# disease lookup failed MONDO_0044325
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0002904
# disease lookup failed EFO_0000595
# disease lookup failed HP_0002153
# disease lookup failed MONDO_0009559
# disease lookup failed MONDO_0015643
# disease lookup failed MONDO_0017386
# disease lookup failed MONDO_0030019
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000876
# disease lookup failed HP_0003076
# disease lookup failed HP_0025428
# disease lookup failed MONDO_0002368
# disease lookup failed MONDO_0004331
# disease lookup failed MONDO_0007845
# disease lookup failed MONDO_0008630
# disease lookup failed MONDO_0032940
# disease lookup failed EFO_0000233
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000720
# disease lookup failed HP_0030833
# disease lookup failed HP_0004448
# disease lookup failed HP_0005639
# disease lookup failed HP_0040185
# disease lookup failed MONDO_0014919
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0001642
# disease lookup failed HP_0002221
# disease lookup failed HP_0002307
# disease lookup failed MONDO_0010888
# disease lookup failed MONDO_0021804
# disease lookup failed HP_0011923
# disease lookup failed MONDO_0001330
# disease lookup failed MONDO_0009374
# disease lookup failed MONDO_0009816
# disease lookup failed MONDO_0010635
# disease lookup failed MONDO_0018715
# disease lookup failed MONDO_0020854
# writing quads
# disease lookup failed EFO_0003046
# disease lookup failed HP_0001605
# disease lookup failed HP_0004763
# disease lookup failed MONDO_0044793
# disease lookup failed HP_0000954
# disease lookup failed HP_0030160
# disease lookup failed MONDO_0020845
# disease lookup failed MONDO_0010589
# disease lookup failed MONDO_0030910
# disease lookup failed MONDO_0032917
# disease lookup failed EFO_0000332
# disease lookup failed HP_0002036
# disease lookup failed HP_0002251
# disease lookup failed HP_0003040
# disease lookup failed MONDO_0009703
# disease lookup failed MONDO_0013680
# disease lookup failed HP_0002857
# disease lookup failed MONDO_0018794
# disease lookup failed MONDO_0060589
# disease lookup failed HP_0002110
# disease lookup failed HP_0002119
# disease lookup failed HP_0011344
# disease lookup failed HP_0011499
# disease lookup failed HP_0100633
# disease lookup failed MONDO_0021469
# disease lookup failed MONDO_0060582
# disease lookup failed HP_0000131
# disease lookup failed MONDO_0016690
# disease lookup failed MONDO_0054699
# disease lookup failed HP_0000023
# disease lookup failed HP_0000540
# disease lookup failed HP_0000978
# disease lookup failed HP_0002140
# disease lookup failed MONDO_0004379
# disease lookup failed MONDO_0030917
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0002900
# disease lookup failed HP_0002936
# disease lookup failed HP_0004872
# disease lookup failed HP_0006571
# disease lookup failed MONDO_0014940
# disease lookup failed MONDO_0054852
# disease lookup failed HP_0001776
# disease lookup failed HP_0012235
# disease lookup failed MONDO_0010504
# disease lookup failed MONDO_0020593
# disease lookup failed MONDO_0100186
# disease lookup failed HP_0012199
# disease lookup failed MONDO_0010318
# disease lookup failed MONDO_0014850
# disease lookup failed MONDO_0018653
# disease lookup failed EFO_0000502
# disease lookup failed MONDO_0002278
# disease lookup failed MONDO_0044312
# disease lookup failed MONDO_0054860
# disease lookup failed EFO_0001357
# disease lookup failed HP_0001082
# disease lookup failed MONDO_0004359
# disease lookup failed MONDO_0007268
# disease lookup failed MONDO_0007336
# disease lookup failed MONDO_0029143
# disease lookup failed HP_0000307
# disease lookup failed HP_0001520
# disease lookup failed HP_0003073
# disease lookup failed HP_0004691
# disease lookup failed MONDO_0001903
# disease lookup failed MONDO_0002863
# disease lookup failed MONDO_0009866
# disease lookup failed MONDO_0014369
# disease lookup failed MONDO_0020638
# disease lookup failed MONDO_0054565
# disease lookup failed MONDO_0060758
# disease lookup failed EFO_0002616
# disease lookup failed HP_0000678
# disease lookup failed HP_0001880
# disease lookup failed HP_0008967
# disease lookup failed HP_0011736
# disease lookup failed MONDO_0012586
# disease lookup failed MONDO_0013618
# disease lookup failed MONDO_0014603
# disease lookup failed HP_0002342
# disease lookup failed MONDO_0008939
# disease lookup failed MONDO_0009948
# disease lookup failed MONDO_0011571
# disease lookup failed MONDO_0011973
# disease lookup failed MONDO_0013928
# disease lookup failed HP_0001094
# disease lookup failed HP_0004419
# disease lookup failed HP_0005181
# disease lookup failed HP_0008419
# disease lookup failed HP_0012388
# disease lookup failed HP_0400007
# disease lookup failed MONDO_0020853
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed EFO_0003779
# disease lookup failed HP_0020174
# disease lookup failed HP_0031273
# disease lookup failed MONDO_0014252
# disease lookup failed MONDO_0014701
# disease lookup failed MONDO_0019457
# disease lookup failed MONDO_0032928
# disease lookup failed EFO_0000195
# disease lookup failed HP_0000823
# disease lookup failed HP_0002171
# disease lookup failed HP_0100504
# disease lookup failed MONDO_0014801
# disease lookup failed MONDO_0019474
# disease lookup failed EFO_0003812
# disease lookup failed HP_0000011
# disease lookup failed HP_0000121
# disease lookup failed MONDO_0000816
# disease lookup failed MONDO_0019469
# disease lookup failed MONDO_0020513
# disease lookup failed MONDO_0032688
# disease lookup failed MONDO_0032887
# disease lookup failed MONDO_0032909
# disease lookup failed MONDO_0044327
# disease lookup failed MONDO_0060729
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# gene lookup failed ENSG00000106123
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000044
# disease lookup failed HP_0001987
# disease lookup failed HP_0003419
# disease lookup failed HP_0025267
# disease lookup failed MONDO_0001285
# disease lookup failed MONDO_0060583
# disease lookup failed EFO_0000331
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000803
# disease lookup failed HP_0005855
# disease lookup failed MONDO_0004933
# disease lookup failed MONDO_0044725
# disease lookup failed HP_0000767
# disease lookup failed MONDO_0004784
# disease lookup failed MONDO_0013017
# disease lookup failed MONDO_0018072
# disease lookup failed OBI_1110021
# disease lookup failed HP_0002024
# disease lookup failed HP_0012595
# disease lookup failed MONDO_0003531
# disease lookup failed MONDO_0008672
# disease lookup failed MONDO_0011431
# disease lookup failed MONDO_0013334
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0002148
# disease lookup failed MONDO_0003158
# disease lookup failed MONDO_0003865
# disease lookup failed MONDO_0013549
# disease lookup failed MONDO_0014464
# disease lookup failed MONDO_0024677
# disease lookup failed MONDO_0029130
# disease lookup failed MONDO_0060663
# disease lookup failed EFO_0002496
# disease lookup failed HP_0000265
# disease lookup failed HP_0002144
# disease lookup failed HP_0002757
# disease lookup failed HP_0003756
# disease lookup failed HP_0005280
# disease lookup failed HP_0011411
# disease lookup failed MONDO_0003619
# disease lookup failed MONDO_0004557
# disease lookup failed MONDO_0007586
# disease lookup failed MONDO_0012274
# disease lookup failed MONDO_0013543
# disease lookup failed MONDO_0013656
# disease lookup failed MONDO_0014813
# disease lookup failed MONDO_0030027
# disease lookup failed MONDO_0042487
# disease lookup failed EFO_0001358
# disease lookup failed HP_0000341
# disease lookup failed HP_0000616
# disease lookup failed MONDO_0008295
# disease lookup failed HP_0001279
# disease lookup failed MONDO_0054743
# disease lookup failed HP_0006882
# disease lookup failed HP_0012167
# disease lookup failed MONDO_0030062
# disease lookup failed HP_0000473
# disease lookup failed MONDO_0030034
# disease lookup failed MONDO_0032882
# disease lookup failed EFO_0000613
# disease lookup failed MONDO_0001302
# disease lookup failed MONDO_0012909
# disease lookup failed MONDO_0015564
# disease lookup failed MONDO_0032903
# disease lookup failed EFO_0000775
# disease lookup failed MONDO_0002558
# disease lookup failed MONDO_0007648
# disease lookup failed MONDO_0011283
# disease lookup failed MONDO_0014671
# disease lookup failed MONDO_0014957
# disease lookup failed MONDO_0019088
# disease lookup failed MONDO_0032932
# disease lookup failed EFO_0000394
# disease lookup failed HP_0002901
# disease lookup failed MONDO_0010292
# disease lookup failed MONDO_0015813
# disease lookup failed MONDO_0032936
# writing quads
# writing quads
# disease lookup failed HP_0000132
# disease lookup failed HP_0000768
# disease lookup failed HP_0031217
# disease lookup failed HP_0031456
# disease lookup failed MONDO_0019465
# disease lookup failed EFO_0003759
# disease lookup failed HP_0002751
# disease lookup failed MONDO_0009709
# disease lookup failed MONDO_0010920
# disease lookup failed MONDO_0016700
# disease lookup failed EFO_0000255
# disease lookup failed HP_0011974
# disease lookup failed MONDO_0008409
# disease lookup failed MONDO_0036484
# disease lookup failed EFO_0000736
# disease lookup failed MONDO_0011853
# disease lookup failed MONDO_0020852
# disease lookup failed MONDO_0032908
# disease lookup failed MONDO_0054794
# disease lookup failed HP_0002136
# disease lookup failed HP_0009020
# disease lookup failed HP_0025116
# disease lookup failed MONDO_0014834
# disease lookup failed EFO_0002756
# disease lookup failed MONDO_0001369
# disease lookup failed MONDO_0008452
# disease lookup failed MONDO_0008560
# disease lookup failed HP_0001336
# disease lookup failed HP_0002243
# disease lookup failed MONDO_0020723
# disease lookup failed HP_0001010
# disease lookup failed MONDO_0020850
# disease lookup failed HP_0000175
# disease lookup failed HP_0000771
# disease lookup failed HP_0012603
# disease lookup failed MONDO_0003219
# disease lookup failed MONDO_0023297
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0012098
# disease lookup failed HP_0030151
# disease lookup failed HP_0040187
# disease lookup failed MONDO_0010817
# disease lookup failed MONDO_0032843
# disease lookup failed MONDO_0060611
# disease lookup failed MONDO_0002959
# disease lookup failed MONDO_0012183
# disease lookup failed MONDO_0014278
# disease lookup failed MONDO_0014948
# disease lookup failed EFO_0000614
# disease lookup failed EFO_0001070
# disease lookup failed MONDO_0010967
# disease lookup failed MONDO_0012561
# disease lookup failed MONDO_0012991
# disease lookup failed MONDO_0014528
# disease lookup failed MONDO_0100095
# disease lookup failed EFO_0000330
# disease lookup failed HP_0000054
# disease lookup failed HP_0000975
# disease lookup failed HP_0007141
# disease lookup failed MONDO_0002172
# disease lookup failed MONDO_0009815
# disease lookup failed MONDO_0044206
# disease lookup failed HP_0000112
# disease lookup failed HP_0001176
# disease lookup failed HP_0005484
# disease lookup failed HP_0010313
# disease lookup failed MONDO_0003200
# disease lookup failed MONDO_0011688
# disease lookup failed MONDO_0014994
# disease lookup failed MONDO_0016611
# disease lookup failed MONDO_0032737
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000577
# disease lookup failed HP_0009720
# disease lookup failed MONDO_0015006
# disease lookup failed MONDO_0021280
# disease lookup failed MONDO_0032594
# disease lookup failed MONDO_0060641
# disease lookup failed EFO_0000762
# disease lookup failed EFO_0001057
# disease lookup failed MONDO_0002621
# disease lookup failed MONDO_0012431
# disease lookup failed MONDO_0014956
# disease lookup failed MONDO_0024519
# disease lookup failed MONDO_0008343
# disease lookup failed MONDO_0010560
# disease lookup failed MONDO_0012868
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0030016
# disease lookup failed MONDO_0002009
# disease lookup failed MONDO_0016030
# disease lookup failed MONDO_0016683
# disease lookup failed DOID_10718
# disease lookup failed MONDO_0002588
# disease lookup failed MONDO_0009410
# disease lookup failed MONDO_0011450
# disease lookup failed MONDO_0033656
# writing quads
# writing quads
# disease lookup failed HP_0001256
# disease lookup failed MONDO_0012676
# disease lookup failed MONDO_0020460
# disease lookup failed EFO_0001064
# disease lookup failed MONDO_0004222
# disease lookup failed MONDO_0021553
# disease lookup failed MONDO_0003448
# disease lookup failed MONDO_0014455
# disease lookup failed MONDO_0024525
# disease lookup failed EFO_0000504
# disease lookup failed HP_0002066
# disease lookup failed HP_0004804
# disease lookup failed MONDO_0030038
# disease lookup failed EFO_0000650
# disease lookup failed HP_0000337
# disease lookup failed HP_0006610
# disease lookup failed HP_0012227
# disease lookup failed MONDO_0026722
# disease lookup failed MONDO_0044319
# disease lookup failed MONDO_0044917
# disease lookup failed EFO_0000552
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000618
# disease lookup failed HP_0001643
# disease lookup failed HP_0012228
# disease lookup failed MONDO_0011837
# disease lookup failed MONDO_0017043
# disease lookup failed MONDO_0030008
# disease lookup failed MONDO_0044660
# disease lookup failed MONDO_0044714
# disease lookup failed HP_0004605
# disease lookup failed MONDO_0004187
# disease lookup failed MONDO_0007509
# disease lookup failed MONDO_0032920
# disease lookup failed MONDO_0032938
# disease lookup failed MONDO_0054833
# disease lookup failed HP_0200026
# disease lookup failed MONDO_0011959
# disease lookup failed MONDO_0026045
# disease lookup failed MONDO_0032943
# disease lookup failed MONDO_0060533
# disease lookup failed HP_0002080
# disease lookup failed HP_0012205
# disease lookup failed MONDO_0007728
# disease lookup failed MONDO_0014993
# disease lookup failed MONDO_0019740
# disease lookup failed MONDO_0054733
# disease lookup failed EFO_0000248
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000316
# disease lookup failed HP_0001385
# disease lookup failed MONDO_0010432
# disease lookup failed MONDO_0020657
# disease lookup failed MONDO_0030045
# disease lookup failed EFO_0001072
# disease lookup failed MONDO_0014714
# disease lookup failed MONDO_0030922
# disease lookup failed EFO_0000658
# disease lookup failed HP_0000286
# disease lookup failed HP_0000325
# disease lookup failed HP_0011705
# disease lookup failed MONDO_0014968
# disease lookup failed MONDO_0032591
# disease lookup failed HP_0000360
# disease lookup failed MONDO_0013500
# disease lookup failed MONDO_0032892
# disease lookup failed HP_0003274
# disease lookup failed HP_0007754
# disease lookup failed HP_0012424
# disease lookup failed HP_0012735
# disease lookup failed MONDO_0014853
# disease lookup failed MONDO_0019479
# disease lookup failed HP_0002045
# disease lookup failed HP_0002196
# disease lookup failed MONDO_0009930
# disease lookup failed MONDO_0016222
# disease lookup failed MONDO_0023619
# disease lookup failed EFO_0003757
# disease lookup failed MONDO_0009436
# disease lookup failed MONDO_0030064
# disease lookup failed MONDO_0032914
# disease lookup failed MONDO_0054700
# disease lookup failed MONDO_0054764
# disease lookup failed MONDO_0060622
# disease lookup failed HP_0001182
# disease lookup failed HP_0001742
# disease lookup failed MONDO_0008210
# disease lookup failed MONDO_0009063
# disease lookup failed MONDO_0011024
# disease lookup failed MONDO_0013081
# disease lookup failed MONDO_0013536
# disease lookup failed EFO_0002546
# disease lookup failed HP_0001075
# disease lookup failed MONDO_0014953
# disease lookup failed MONDO_0032923
# disease lookup failed MONDO_0060713
# disease lookup failed HP_0001558
# disease lookup failed MONDO_0013809
# disease lookup failed MONDO_0029137
# disease lookup failed HP_0001651
# disease lookup failed MONDO_0000489
# disease lookup failed MONDO_0014806
# disease lookup failed MONDO_0060627
# disease lookup failed EFO_0000500
# disease lookup failed HP_0001822
# disease lookup failed MONDO_0003789
# disease lookup failed MONDO_0009578
# disease lookup failed MONDO_0060711
# disease lookup failed MONDO_0060724
# disease lookup failed EFO_0003780
# disease lookup failed HP_0000494
# disease lookup failed MONDO_0013474
# disease lookup failed MONDO_0022113
# disease lookup failed HP_0000138
# disease lookup failed HP_0002907
# disease lookup failed HP_0003146
# disease lookup failed MONDO_0004483
# disease lookup failed MONDO_0009776
# disease lookup failed MONDO_0030029
# disease lookup failed MONDO_0030051
# disease lookup failed MONDO_0032927
# disease lookup failed MONDO_0033558
# disease lookup failed HP_0000343
# disease lookup failed MONDO_0014689
# disease lookup failed MONDO_0032687
# disease lookup failed HP_0001290
# disease lookup failed HP_0001548
# disease lookup failed HP_0003127
# disease lookup failed HP_0003710
# disease lookup failed MONDO_0003214
# disease lookup failed EFO_0003017
# disease lookup failed HP_0000272
# disease lookup failed HP_0001344
# disease lookup failed HP_0001405
# disease lookup failed HP_0008981
# disease lookup failed MONDO_0026767
# disease lookup failed MONDO_0030007
# disease lookup failed MONDO_0043364
# disease lookup failed MONDO_0060733
# disease lookup failed NCIT_C74532
# disease lookup failed HP_0000248
# disease lookup failed HP_0012450
# disease lookup failed MONDO_0003681
# disease lookup failed MONDO_0009305
# disease lookup failed MONDO_0014700
# disease lookup failed MONDO_0018661
# disease lookup failed HP_0003401
# disease lookup failed MONDO_0044915
# disease lookup failed HP_0001518
# disease lookup failed HP_0001976
# disease lookup failed HP_0002172
# disease lookup failed HP_0002376
# disease lookup failed MONDO_0024419
# disease lookup failed MONDO_0030035
# disease lookup failed MONDO_0030055
# disease lookup failed HP_0003323
# disease lookup failed HP_0030838
# disease lookup failed MONDO_0016693
# disease lookup failed MONDO_0030087
# disease lookup failed MONDO_0044303
# disease lookup failed HP_0003547
# disease lookup failed HP_0011096
# disease lookup failed MONDO_0011581
# disease lookup failed MONDO_0018696
# disease lookup failed EFO_0000350
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0010307
# disease lookup failed MONDO_0010953
# disease lookup failed MONDO_0032899
# disease lookup failed HP_0000863
# disease lookup failed EFO_0000335
# disease lookup failed HP_0001007
# disease lookup failed HP_0009908
# disease lookup failed HP_0011451
# disease lookup failed MONDO_0000701
# disease lookup failed MONDO_0009505
# disease lookup failed MONDO_0018327
# disease lookup failed MONDO_0054801
# disease lookup failed EFO_0000224
# disease lookup failed HP_0002313
# disease lookup failed HP_0002616
# disease lookup failed MONDO_0014809
# disease lookup failed HP_0002575
# disease lookup failed HP_0003489
# disease lookup failed HP_0010750
# disease lookup failed HP_0012317
# disease lookup failed MONDO_0015474
# disease lookup failed MONDO_0030044
# disease lookup failed EFO_0000432
# disease lookup failed HP_0000155
# disease lookup failed HP_0000414
# disease lookup failed HP_0002474
# disease lookup failed HP_0002999
# disease lookup failed HP_0005387
# disease lookup failed HP_0030757
# disease lookup failed MONDO_0008387
# disease lookup failed MONDO_0020312
# disease lookup failed MONDO_0032900
# disease lookup failed MONDO_0032905
# disease lookup failed MONDO_0060720
# disease lookup failed EFO_0002614
# disease lookup failed HP_0002194
# disease lookup failed HP_0002280
# disease lookup failed HP_0100257
# disease lookup failed MONDO_0008734
# disease lookup failed MONDO_0032924
# disease lookup failed MONDO_0044903
# disease lookup failed HP_0003074
# disease lookup failed HP_0011342
# disease lookup failed HP_0040216
# disease lookup failed MONDO_0030031
# disease lookup failed MONDO_0032898
# disease lookup failed HP_0001601
# disease lookup failed HP_0002043
# disease lookup failed HP_0011904
# disease lookup failed HP_0100607
# disease lookup failed MONDO_0008278
# disease lookup failed MONDO_0010986
# disease lookup failed MONDO_0022965
# disease lookup failed HP_0002905
# disease lookup failed HP_0009800
# disease lookup failed HP_0012594
# disease lookup failed MONDO_0014704
# disease lookup failed MONDO_0014805
# disease lookup failed MONDO_0015014
# disease lookup failed MONDO_0019202
# disease lookup failed EFO_0002608
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# gene lookup failed ENSG00000123201
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0001561
# disease lookup failed HP_0011950
# disease lookup failed MONDO_0014518
# disease lookup failed MONDO_0014548
# disease lookup failed MONDO_0014807
# disease lookup failed MONDO_0021739
# disease lookup failed MONDO_0030042
# disease lookup failed MONDO_0054842
# disease lookup failed EFO_0000196
# disease lookup failed HP_0000512
# disease lookup failed HP_0005184
# disease lookup failed HP_0011106
# disease lookup failed HP_0031844
# disease lookup failed MONDO_0011242
# disease lookup failed MONDO_0020647
# disease lookup failed MONDO_0030089
# disease lookup failed EFO_0000765
# disease lookup failed HP_0000465
# disease lookup failed MONDO_0011213
# disease lookup failed MONDO_0013279
# disease lookup failed MONDO_0044877
# disease lookup failed EFO_0000223
# writing quads
# writing quads
# disease lookup failed MONDO_0012944
# disease lookup failed MONDO_0014527
# disease lookup failed MONDO_0060507
# disease lookup failed EFO_0003822
# disease lookup failed HP_0002590
# disease lookup failed MONDO_0014665
# disease lookup failed MONDO_0020587
# disease lookup failed MONDO_0060549
# disease lookup failed HP_0000016
# disease lookup failed HP_0010864
# disease lookup failed HP_0012762
# disease lookup failed MONDO_0001583
# disease lookup failed MONDO_0008913
# disease lookup failed MONDO_0010178
# disease lookup failed HP_0002253
# disease lookup failed HP_0003236
# disease lookup failed HP_0011110
# disease lookup failed MONDO_0020761
# disease lookup failed MONDO_0030907
# disease lookup failed MONDO_0060702
# disease lookup failed HP_0001386
# disease lookup failed HP_0030402
# disease lookup failed MONDO_0007817
# disease lookup failed MONDO_0008289
# disease lookup failed HP_0000103
# disease lookup failed MONDO_0002046
# disease lookup failed MONDO_0002775
# disease lookup failed MONDO_0007608
# disease lookup failed MONDO_0012511
# disease lookup failed EFO_0000555
# disease lookup failed HP_0000485
# disease lookup failed HP_0002013
# disease lookup failed HP_0006834
# disease lookup failed MONDO_0012880
# disease lookup failed MONDO_0030105
# disease lookup failed MONDO_0032913
# disease lookup failed MONDO_0032916
# disease lookup failed EFO_0000666
# disease lookup failed EFO_0000730
# disease lookup failed MONDO_0003761
# disease lookup failed MONDO_0012804
# disease lookup failed MONDO_0014506
# disease lookup failed MONDO_0030037
# disease lookup failed MONDO_0032939
# disease lookup failed MONDO_0054813
# disease lookup failed MONDO_0060491
# disease lookup failed MONDO_0060664
# disease lookup failed EFO_0000211
# disease lookup failed HP_0000470
# disease lookup failed HP_0003124
# disease lookup failed HP_0005692
# disease lookup failed MONDO_0024290
# disease lookup failed EFO_0000553
# disease lookup failed MONDO_0002877
# disease lookup failed MONDO_0007849
# disease lookup failed MONDO_0008771
# disease lookup failed MONDO_0060761
# disease lookup failed EFO_0001066
# disease lookup failed HP_0004798
# disease lookup failed MONDO_0012112
# disease lookup failed MONDO_0030918
# disease lookup failed HP_0001260
# disease lookup failed HP_0001407
# disease lookup failed HP_0002180
# disease lookup failed HP_0008209
# disease lookup failed HP_0025425
# disease lookup failed MONDO_0003181
# disease lookup failed MONDO_0011163
# disease lookup failed MONDO_0014572
# disease lookup failed HP_0002555
# disease lookup failed MONDO_0007290
# disease lookup failed MONDO_0014137
# disease lookup failed MONDO_0020847
# disease lookup failed MONDO_0022096
# disease lookup failed MONDO_0032926
# disease lookup failed EFO_0000678
# disease lookup failed MONDO_0008593
# disease lookup failed EFO_0001060
# disease lookup failed HP_0001030
# disease lookup failed HP_0002105
# disease lookup failed HP_0040083
# disease lookup failed MONDO_0011173
# disease lookup failed MONDO_0014746
# disease lookup failed MONDO_0019139
# disease lookup failed MONDO_0060551
# disease lookup failed MONDO_0100096
# disease lookup failed EFO_0003766
# disease lookup failed HP_0009926
# disease lookup failed HP_0011840
# disease lookup failed MONDO_0021765
# disease lookup failed MONDO_0004651
# disease lookup failed MONDO_0014842
# disease lookup failed MONDO_0021812
# disease lookup failed MONDO_0025484
# disease lookup failed MONDO_0060640
# disease lookup failed HP_0000974
# disease lookup failed MONDO_0015023
# disease lookup failed MONDO_0017349
# disease lookup failed HP_0001662
# disease lookup failed HP_0002069
# disease lookup failed HP_0006000
# disease lookup failed MONDO_0020634
# disease lookup failed MONDO_0021115
# disease lookup failed MONDO_0032610
# disease lookup failed MONDO_0033006
# disease lookup failed MONDO_0019472
# disease lookup failed EFO_0002429
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0000474
# disease lookup failed HP_0003546
# disease lookup failed HP_0030839
# disease lookup failed MONDO_0009064
# disease lookup failed MONDO_0060556
# disease lookup failed HP_0005180
# disease lookup failed MONDO_0013196
# disease lookup failed MONDO_0013483
# disease lookup failed MONDO_0019558
# disease lookup failed MONDO_0054741
# disease lookup failed MONDO_0054742
# disease lookup failed HP_0000726
# disease lookup failed HP_0000738
# disease lookup failed MONDO_0007751
# disease lookup failed MONDO_0020740
# disease lookup failed EFO_0000778
# disease lookup failed HP_0002018
# disease lookup failed HP_0002448
# disease lookup failed MONDO_0054732
# disease lookup failed HP_0000400
# disease lookup failed MONDO_0013187
# disease lookup failed MONDO_0013419
# disease lookup failed HP_0001907
# disease lookup failed HP_0011079
# disease lookup failed MONDO_0001444
# disease lookup failed HP_0000260
# disease lookup failed HP_0002714
# disease lookup failed MONDO_0012738
# disease lookup failed MONDO_0013421
# disease lookup failed MONDO_0043224
# disease lookup failed MONDO_0100157
# disease lookup failed HP_0006536
# disease lookup failed HP_0100704
# disease lookup failed MONDO_0009867
# disease lookup failed MONDO_0016236
# disease lookup failed HP_0011713
# disease lookup failed MONDO_0021340
# disease lookup failed HP_0001919
# disease lookup failed HP_0002141
# disease lookup failed HP_0002355
# disease lookup failed MONDO_0033043
# disease lookup failed MONDO_0060577
# disease lookup failed HP_0006986
# disease lookup failed MONDO_0012737
# disease lookup failed MONDO_0013083
# disease lookup failed MONDO_0014791
# disease lookup failed MONDO_0030912
# disease lookup failed MONDO_0054559
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# writing quads
# disease lookup failed HP_0002829
# disease lookup failed EFO_0000699
# disease lookup failed HP_0002510
# disease lookup failed HP_0006699
# disease lookup failed MONDO_0017387
# disease lookup failed MONDO_0032893
# disease lookup failed HP_0002653
# disease lookup failed HP_0005521
# disease lookup failed HP_0008935
# disease lookup failed HP_0012664
# disease lookup failed HP_0000219
# disease lookup failed HP_0000331
# disease lookup failed MONDO_0014080
# disease lookup failed MONDO_0016735
# disease lookup failed MONDO_0024280
# disease lookup failed HP_0005241
# disease lookup failed MONDO_0007788
# disease lookup failed MONDO_0030058
# disease lookup failed MONDO_0060457
# disease lookup failed HP_0000989
# disease lookup failed HP_0010783
# disease lookup failed MONDO_0012657
# disease lookup failed EFO_0002430
# disease lookup failed HP_0000368
# disease lookup failed HP_0000408
# disease lookup failed HP_0030242
# disease lookup failed MONDO_0007962
# disease lookup failed MONDO_0012933
# disease lookup failed HP_0002032
# disease lookup failed HP_0003010
# disease lookup failed HP_0011868
# disease lookup failed MONDO_0003523
# disease lookup failed MONDO_0004169
# disease lookup failed MONDO_0018648
# disease lookup failed HP_0000603
# disease lookup failed HP_0001623
# disease lookup failed MONDO_0001087
# disease lookup failed MONDO_0011369
# disease lookup failed MONDO_0030015
# disease lookup failed MONDO_0030048
# disease lookup failed HP_0007716
# disease lookup failed HP_0009045
# disease lookup failed MONDO_0014497
# disease lookup failed MONDO_0030013
# disease lookup failed MONDO_0044326
# disease lookup failed EFO_0000660
# disease lookup failed MONDO_0010075
# disease lookup failed HP_0003270
# disease lookup failed MONDO_0001658
