# %% [markdown]
# Radboud uses CHEMBL.  Need to go to PubChem CIDs

# %%
require 'rest-client'
require 'json'

def map_chembl_to_cid(chembl_id)
  url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/#{URI.encode_www_form_component(chembl_id)}/cids/JSON"
  warn url
  response = RestClient.get(url)
  
  if response.code == 200
    data = JSON.parse(response.body)
    cid = data.dig('IdentifierList', 'CID', 0)
    { chembl_id: chembl_id, cid: cid || 'No CID found' }
  else
    { chembl_id: chembl_id, error: "No CID found (Status: #{response.code})" }
  end
rescue RestClient::ExceptionWithResponse => e
  { chembl_id: chembl_id, error: "Error: #{e.message}" }
end

def get_more_metadata(cid)
  url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/#{cid}/JSON"
  warn url
  response = RestClient.get(url)
  
  if response.code == 200
    data = JSON.parse(response.body)
    name = data.dig('Record', 'RecordTitle')
    { label: name, cid: cid || 'No CID found' }
  end
rescue RestClient::ExceptionWithResponse => e
  { cid: cid, error: "Error: #{e.message}" }
end
# Out:
# :get_more_metadata

# %%
# test
a = map_chembl_to_cid("CHEMBL1200656")
a.merge! get_more_metadata(a[:cid])
puts a
# Out:
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1200656/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/5284447/JSON
# {:chembl_id=>"CHEMBL1200656", :cid=>5284447, :label=>"Natamycin"}

# %%
require 'csv'

filelist = ["drug-disease.csv","drug-drugtype.csv","drug-gene.csv"]

druglist = {}
filelist.each do |csvfile|
  CSV.foreach("./rawdata/#{csvfile}", headers: true) do |row|
    next if row.size < 3

    source = row['source']
    abort unless source
    druglist[source] = 1
  end
end
puts druglist.length
# Out:
# 1966

# %%
require 'csv'
f = File.open("./mappings/drugs.map", "w")
f.write CSV.generate_line(["chembl","label","CID","IUPACname"])
e = File.open("./mappings/drugs-errors.txt", "w")

druglist.each_key do |chembl|
  a = map_chembl_to_cid(chembl)
  unless a[:cid]
    warn "FAILED CID lookup for #{chembl}\n"
    e.write "FAILED CID lookup for #{chembl}\n"
    next
  end
  a.merge! get_more_metadata(a[:cid])
  
  warn a
  if a[:label].is_a? Array
    label = a[:label][1]
  else
    label = a[:label]
  end
  f.write CSV.generate_line([chembl,chembl,a[:cid],a[:label]])
end
f.close
e.close
puts "done!"
# Out:
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1200656/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/5284447/JSON
# {:chembl_id=>"CHEMBL1200656", :cid=>5284447, :label=>"Natamycin"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1201746/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/148121/JSON
# {:chembl_id=>"CHEMBL1201746", :cid=>148121, :label=>"Pralatrexate"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1231/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/4634/JSON
# {:chembl_id=>"CHEMBL1231", :cid=>4634, :label=>"Oxybutynin"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2023898/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/25154714/JSON
# {:chembl_id=>"CHEMBL2023898", :cid=>25154714, :label=>"Daclatasvir"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL1091/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/5744/JSON
# {:chembl_id=>"CHEMBL1091", :cid=>5744, :label=>"Hydrocortisone Acetate"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL2308885/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/71716069/JSON
# {:chembl_id=>"CHEMBL2308885", :cid=>71716069, :label=>"[(8S,9S,10S,13S,14R,16R,17R)-17-(2-chloroacetyl)-9-fluoro-10,13,16-trimethyl-3,11-dioxo-7,8,12,14,15,16-hexahydro-6H-cyclopenta[a]phenanthren-17-yl] butanoate"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL24147/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/5054/JSON
# {:chembl_id=>"CHEMBL24147", :cid=>5054, :label=>"Resorcinol"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL364713/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/275196/JSON
# {:chembl_id=>"CHEMBL364713", :cid=>275196, :label=>"Noscapine"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL762/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/4636/JSON
# {:chembl_id=>"CHEMBL762", :cid=>4636, :label=>"Oxymetazoline"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL87493/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/3337/JSON
# {:chembl_id=>"CHEMBL87493", :cid=>3337, :label=>"Fenfluramine"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL112/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/1983/JSON
# {:chembl_id=>"CHEMBL112", :cid=>1983, :label=>"Acetaminophen"}
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/CHEMBL141/cids/JSON
# https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/3877/JSON

# %%
def map_chembl_to_name(chembl_id)
  url = "https://www.ebi.ac.uk/chembl/api/data/molecule/#{chembl_id}.json"
  response = RestClient.get(url)
  
  if response.code == 200
    data = JSON.parse(response.body)
    name = data.dig('molecule_properties', 'pref_name') || data.dig('molecule_synonyms')&.find { |s| s['syn_type'] == 'TRADE_NAME' }&.dig('molecule_synonym') || chembl_id
    { chembl_id: chembl_id, name: name }
  else
    { chembl_id: chembl_id, error: "No name found (Status: #{response.code})" }
  end
rescue RestClient::ExceptionWithResponse => e
  { chembl_id: chembl_id, error: "Error: #{e.message}" }
end

def map_name_to_sid(name)
  url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/substance/name/#{URI.encode_www_form_component(name)}/sids/JSON"
  response = RestClient.get(url)
  
  if response.code == 200
    data = JSON.parse(response.body)
    sid = data.dig('IdentifierList', 'SID', 0)
    { name: name, sid: sid || 'No SID found' }
  else
    { name: name, error: "No SID found (Status: #{response.code})" }
  end
rescue RestClient::ExceptionWithResponse => e
  { name: name, error: "Error: #{e.message}" }
end

# Don't bother - just stick to the substance id
# def map_sid_to_cid(sid)
#   url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/substance/sid/#{sid}/cids/JSON"
#   warn url
#   response = RestClient.get(url)
  
#   if response.code == 200
#     data = JSON.parse(response.body)
#     cid = data.dig('IdentifierList', 'CID', 0)
#     { sid: sid, cid: cid || 'No CID found' }
#   else
#     { sid: sid, error: "No CID found (Status: #{response.code})" }
#   end
# rescue RestClient::ExceptionWithResponse => e
#   { sid: sid, error: "Error: #{e.message}" }
# end
# Out:
# :map_name_to_sid

# %%
# test

puts map_chembl_to_name("CHEMBL1201460")
res = map_chembl_to_name("CHEMBL1201460")
puts map_name_to_sid(res[:name])
res.merge! map_name_to_sid(res[:name])

puts res
# Out:
# {:chembl_id=>"CHEMBL1201460", :name=>"Fragmin"}
# {:name=>"Fragmin", :sid=>49975203}
# {:chembl_id=>"CHEMBL1201460", :name=>"Fragmin", :sid=>49975203}

# %%
e.close
f.close

# Try to get biologics substance ids

f = File.open("./mappings/drugs.map", "a")
r = File.open("./mappings/drugs-errors.txt")
e = File.open("./mappings/drugs-biologics-errors.txt", "w")

r.each_line do |line|  # go over all errors
  chembl = line.match(/.*(CHEMBL\d+)/)[1]
  warn "runnign chembl #{chembl}"
  res = map_chembl_to_name(chembl)
  warn res
  res.merge! map_name_to_sid(res[:name])
  warn res
  unless res[:sid]
    warn "failed again for #{chembl}"
    e.write "failed again for #{chembl}\n"
    next
  end
  warn "write"
  f.write CSV.generate_line([chembl,chembl,res[:sid],a[:name]])
end
f.close
e.close
r.close
# Out:
# runnign chembl CHEMBL1201460
# {:chembl_id=>"CHEMBL1201460", :name=>"Fragmin"}
# {:chembl_id=>"CHEMBL1201460", :name=>"Fragmin", :sid=>49975203}
# write
# runnign chembl CHEMBL1201666
# {:chembl_id=>"CHEMBL1201666", :name=>"Refludan"}
# {:chembl_id=>"CHEMBL1201666", :name=>"Refludan", :sid=>85342099}
# write
# runnign chembl CHEMBL1742996
# {:chembl_id=>"CHEMBL1742996", :name=>"Kyntheum"}
# {:chembl_id=>"CHEMBL1742996", :name=>"Kyntheum", :sid=>187051841}
# write
# runnign chembl CHEMBL2108222
# {:chembl_id=>"CHEMBL2108222", :name=>"Palaprin fte"}
# {:chembl_id=>"CHEMBL2108222", :name=>"Palaprin fte", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108222
# runnign chembl CHEMBL1201476
# {:chembl_id=>"CHEMBL1201476", :name=>"Clexane"}
# {:chembl_id=>"CHEMBL1201476", :name=>"Clexane", :sid=>53787364}
# write
# runnign chembl CHEMBL2108147
# {:chembl_id=>"CHEMBL2108147", :name=>"Kabikinase"}
# {:chembl_id=>"CHEMBL2108147", :name=>"Kabikinase", :sid=>49988401}
# write
# runnign chembl CHEMBL1201833
# {:chembl_id=>"CHEMBL1201833", :name=>"Simponi"}
# {:chembl_id=>"CHEMBL1201833", :name=>"Simponi", :sid=>135329319}
# write
# runnign chembl CHEMBL832
# {:chembl_id=>"CHEMBL832", :name=>"Anturan"}
# {:chembl_id=>"CHEMBL832", :name=>"Anturan", :sid=>117338}
# write
# runnign chembl CHEMBL1200640
# {:chembl_id=>"CHEMBL1200640", :name=>"Fersaday"}
# {:chembl_id=>"CHEMBL1200640", :name=>"Fersaday", :sid=>53788915}
# write
# runnign chembl CHEMBL1201632
# {:chembl_id=>"CHEMBL1201632", :name=>"Cerezyme"}
# {:chembl_id=>"CHEMBL1201632", :name=>"Cerezyme", :sid=>50069655}
# write
# runnign chembl CHEMBL2108078
# {:chembl_id=>"CHEMBL2108078", :name=>"Natpar"}
# {:chembl_id=>"CHEMBL2108078", :name=>"Natpar", :sid=>135651867}
# write
# runnign chembl CHEMBL2364655
# {:chembl_id=>"CHEMBL2364655", :name=>"Repatha"}
# {:chembl_id=>"CHEMBL2364655", :name=>"Repatha", :sid=>178103915}
# write
# runnign chembl CHEMBL3989986
# {:chembl_id=>"CHEMBL3989986", :name=>"Ultomiris"}
# {:chembl_id=>"CHEMBL3989986", :name=>"Ultomiris", :sid=>381118878}
# write
# runnign chembl CHEMBL1201513
# {:chembl_id=>"CHEMBL1201513", :name=>"Calciparine"}
# {:chembl_id=>"CHEMBL1201513", :name=>"Calciparine", :sid=>134224540}
# write
# runnign chembl CHEMBL1201828
# {:chembl_id=>"CHEMBL1201828", :name=>"Soliris"}
# {:chembl_id=>"CHEMBL1201828", :name=>"Soliris", :sid=>50070199}
# write
# runnign chembl CHEMBL1201724
# {:chembl_id=>"CHEMBL1201724", :name=>"Betadine"}
# {:chembl_id=>"CHEMBL1201724", :name=>"Betadine", :sid=>542705}
# write
# runnign chembl CHEMBL1450
# {:chembl_id=>"CHEMBL1450", :name=>"Atovaquone"}
# {:chembl_id=>"CHEMBL1450", :name=>"Atovaquone", :sid=>9053}
# write
# runnign chembl CHEMBL1743041
# {:chembl_id=>"CHEMBL1743041", :name=>"Poteligeo"}
# {:chembl_id=>"CHEMBL1743041", :name=>"Poteligeo", :sid=>135317476}
# write
# runnign chembl CHEMBL3989751
# {:chembl_id=>"CHEMBL3989751", :name=>"CHEMBL3989751"}
# {:chembl_id=>"CHEMBL3989751", :name=>"CHEMBL3989751", :sid=>374364198}
# write
# runnign chembl CHEMBL1201583
# {:chembl_id=>"CHEMBL1201583", :name=>"Avastin"}
# {:chembl_id=>"CHEMBL1201583", :name=>"Avastin", :sid=>528618}
# write
# runnign chembl CHEMBL1742982
# {:chembl_id=>"CHEMBL1742982", :name=>"Eylea"}
# {:chembl_id=>"CHEMBL1742982", :name=>"Eylea", :sid=>135347926}
# write
# runnign chembl CHEMBL2362016
# {:chembl_id=>"CHEMBL2362016", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL2362016", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL2362016
# runnign chembl CHEMBL1201505
# {:chembl_id=>"CHEMBL1201505", :name=>"CHEMBL1201505"}
# {:chembl_id=>"CHEMBL1201505", :name=>"CHEMBL1201505", :sid=>103771354}
# write
# runnign chembl CHEMBL2108709
# {:chembl_id=>"CHEMBL2108709", :name=>"Santyl"}
# {:chembl_id=>"CHEMBL2108709", :name=>"Santyl", :sid=>135330780}
# write
# runnign chembl CHEMBL1201420
# {:chembl_id=>"CHEMBL1201420", :name=>"Abbokinase"}
# {:chembl_id=>"CHEMBL1201420", :name=>"Abbokinase", :sid=>49988403}
# write
# runnign chembl CHEMBL1201594
# {:chembl_id=>"CHEMBL1201594", :name=>"Elitek"}
# {:chembl_id=>"CHEMBL1201594", :name=>"Elitek", :sid=>7978475}
# write
# runnign chembl CHEMBL1743079
# {:chembl_id=>"CHEMBL1743079", :name=>"Tepezza"}
# {:chembl_id=>"CHEMBL1743079", :name=>"Tepezza", :sid=>160682616}
# write
# runnign chembl CHEMBL1743043
# {:chembl_id=>"CHEMBL1743043", :name=>"Lumoxiti"}
# {:chembl_id=>"CHEMBL1743043", :name=>"Lumoxiti", :sid=>135350821}
# write
# runnign chembl CHEMBL1743029
# {:chembl_id=>"CHEMBL1743029", :name=>"Trogarzo"}
# {:chembl_id=>"CHEMBL1743029", :name=>"Trogarzo", :sid=>135347929}
# write
# runnign chembl CHEMBL1201512
# {:chembl_id=>"CHEMBL1201512", :name=>"Vitravene"}
# {:chembl_id=>"CHEMBL1201512", :name=>"Vitravene", :sid=>76715614}
# write
# runnign chembl CHEMBL1237025
# {:chembl_id=>"CHEMBL1237025", :name=>"Krystexxa"}
# {:chembl_id=>"CHEMBL1237025", :name=>"Krystexxa", :sid=>104253156}
# write
# runnign chembl CHEMBL2109540
# {:chembl_id=>"CHEMBL2109540", :name=>"Praluent"}
# {:chembl_id=>"CHEMBL2109540", :name=>"Praluent", :sid=>178103355}
# write
# runnign chembl CHEMBL2108429
# {:chembl_id=>"CHEMBL2108429", :name=>"Bosatria"}
# {:chembl_id=>"CHEMBL2108429", :name=>"Bosatria", :sid=>135278932}
# write
# runnign chembl CHEMBL2108738
# {:chembl_id=>"CHEMBL2108738", :name=>"Opdivo"}
# {:chembl_id=>"CHEMBL2108738", :name=>"Opdivo", :sid=>135341610}
# write
# runnign chembl CHEMBL1201515
# {:chembl_id=>"CHEMBL1201515", :name=>"Somavert"}
# {:chembl_id=>"CHEMBL1201515", :name=>"Somavert", :sid=>50046579}
# write
# runnign chembl CHEMBL2108250
# {:chembl_id=>"CHEMBL2108250", :name=>"Eminase"}
# {:chembl_id=>"CHEMBL2108250", :name=>"Eminase", :sid=>49870196}
# write
# runnign chembl CHEMBL2108129
# {:chembl_id=>"CHEMBL2108129", :name=>"CHEMBL2108129"}
# {:chembl_id=>"CHEMBL2108129", :name=>"CHEMBL2108129", :sid=>160676919}
# write
# runnign chembl CHEMBL2108676
# {:chembl_id=>"CHEMBL2108676", :name=>"Bmn 110, rhgalns, n-acetylgalactosamine-6-sulfatase, chondroitinsulfatase, galactose-6-sulfate sulfatase, ec=3.1.6.4"}
# {:chembl_id=>"CHEMBL2108676", :name=>"Bmn 110, rhgalns, n-acetylgalactosamine-6-sulfatase, chondroitinsulfatase, galactose-6-sulfate sulfatase, ec=3.1.6.4", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108676
# runnign chembl CHEMBL4298062
# {:chembl_id=>"CHEMBL4298062", :name=>"Viltepso"}
# {:chembl_id=>"CHEMBL4298062", :name=>"Viltepso", :sid=>440816799}
# write
# runnign chembl CHEMBL1201572
# {:chembl_id=>"CHEMBL1201572", :name=>"Benepali"}
# {:chembl_id=>"CHEMBL1201572", :name=>"Benepali", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201572
# runnign chembl CHEMBL1440
# {:chembl_id=>"CHEMBL1440", :name=>"Achromycin"}
# {:chembl_id=>"CHEMBL1440", :name=>"Achromycin", :sid=>8144439}
# write
# runnign chembl CHEMBL1743070
# {:chembl_id=>"CHEMBL1743070", :name=>"Sylvant"}
# {:chembl_id=>"CHEMBL1743070", :name=>"Sylvant", :sid=>135263755}
# write
# runnign chembl CHEMBL2364648
# {:chembl_id=>"CHEMBL2364648", :name=>"Tremfya"}
# {:chembl_id=>"CHEMBL2364648", :name=>"Tremfya", :sid=>249565678}
# write
# runnign chembl CHEMBL2108396
# {:chembl_id=>"CHEMBL2108396", :name=>"CHEMBL2108396"}
# {:chembl_id=>"CHEMBL2108396", :name=>"CHEMBL2108396", :sid=>160693061}
# write
# runnign chembl CHEMBL2108675
# {:chembl_id=>"CHEMBL2108675", :name=>"Dupixent"}
# {:chembl_id=>"CHEMBL2108675", :name=>"Dupixent", :sid=>223365910}
# write
# runnign chembl CHEMBL2108041
# {:chembl_id=>"CHEMBL2108041", :name=>"Ocrevus"}
# {:chembl_id=>"CHEMBL2108041", :name=>"Ocrevus", :sid=>135357140}
# write
# runnign chembl CHEMBL2109065
# {:chembl_id=>"CHEMBL2109065", :name=>"Xigris"}
# {:chembl_id=>"CHEMBL2109065", :name=>"Xigris", :sid=>87225410}
# write
# runnign chembl CHEMBL4297229
# {:chembl_id=>"CHEMBL4297229", :name=>"Jeuveau"}
# {:chembl_id=>"CHEMBL4297229", :name=>"Jeuveau", :sid=>481101810}
# write
# runnign chembl CHEMBL4297536
# {:chembl_id=>"CHEMBL4297536", :name=>"Onpattro"}
# {:chembl_id=>"CHEMBL4297536", :name=>"Onpattro", :sid=>350082694}
# write
# runnign chembl CHEMBL4298110
# {:chembl_id=>"CHEMBL4298110", :name=>"Accrufer"}
# {:chembl_id=>"CHEMBL4298110", :name=>"Accrufer", :sid=>483929199}
# write
# runnign chembl CHEMBL1201584
# {:chembl_id=>"CHEMBL1201584", :name=>"Reopro"}
# {:chembl_id=>"CHEMBL1201584", :name=>"Reopro", :sid=>49982017}
# write
# runnign chembl CHEMBL2108597
# {:chembl_id=>"CHEMBL2108597", :name=>"Injectafer"}
# {:chembl_id=>"CHEMBL2108597", :name=>"Injectafer", :sid=>319417677}
# write
# runnign chembl CHEMBL1396
# {:chembl_id=>"CHEMBL1396", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL1396", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL1396
# runnign chembl CHEMBL1201662
# {:chembl_id=>"CHEMBL1201662", :name=>"Iprivask"}
# {:chembl_id=>"CHEMBL1201662", :name=>"Iprivask", :sid=>50064254}
# write
# runnign chembl CHEMBL1201825
# {:chembl_id=>"CHEMBL1201825", :name=>"Lucentis"}
# {:chembl_id=>"CHEMBL1201825", :name=>"Lucentis", :sid=>50070212}
# write
# runnign chembl CHEMBL1237026
# {:chembl_id=>"CHEMBL1237026", :name=>"CHEMBL1237026"}
# {:chembl_id=>"CHEMBL1237026", :name=>"CHEMBL1237026", :sid=>104253157}
# write
# runnign chembl CHEMBL1201561
# {:chembl_id=>"CHEMBL1201561", :name=>"Peg-Intron"}
# {:chembl_id=>"CHEMBL1201561", :name=>"Peg-Intron", :sid=>50069692}
# write
# runnign chembl CHEMBL1201593
# {:chembl_id=>"CHEMBL1201593", :name=>"Actilyse"}
# {:chembl_id=>"CHEMBL1201593", :name=>"Actilyse", :sid=>50018415}
# write
# runnign chembl CHEMBL33
# {:chembl_id=>"CHEMBL33", :name=>"Floxacin"}
# {:chembl_id=>"CHEMBL33", :name=>"Floxacin", :sid=>12014081}
# write
# runnign chembl CHEMBL3990048
# {:chembl_id=>"CHEMBL3990048", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL3990048", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL3990048
# runnign chembl CHEMBL3833373
# {:chembl_id=>"CHEMBL3833373", :name=>"Bavencio"}
# {:chembl_id=>"CHEMBL3833373", :name=>"Bavencio", :sid=>252827393}
# write
# runnign chembl CHEMBL2108278
# {:chembl_id=>"CHEMBL2108278", :name=>"Exondys 51"}
# {:chembl_id=>"CHEMBL2108278", :name=>"Exondys 51", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108278
# runnign chembl CHEMBL2110563
# {:chembl_id=>"CHEMBL2110563", :name=>"Behepan"}
# {:chembl_id=>"CHEMBL2110563", :name=>"Behepan", :sid=>164235444}
# write
# runnign chembl CHEMBL4297537
# {:chembl_id=>"CHEMBL4297537", :name=>"Tegsedi"}
# {:chembl_id=>"CHEMBL4297537", :name=>"Tegsedi", :sid=>316918496}
# write
# runnign chembl CHEMBL1201534
# {:chembl_id=>"CHEMBL1201534", :name=>"Orgaran"}
# {:chembl_id=>"CHEMBL1201534", :name=>"Orgaran", :sid=>50069725}
# write
# runnign chembl CHEMBL2103737
# {:chembl_id=>"CHEMBL2103737", :name=>"Alpharedisol"}
# {:chembl_id=>"CHEMBL2103737", :name=>"Alpharedisol", :sid=>134990072}
# write
# runnign chembl CHEMBL3544921
# {:chembl_id=>"CHEMBL3544921", :name=>"Brineura"}
# {:chembl_id=>"CHEMBL3544921", :name=>"Brineura", :sid=>252089514}
# write
# runnign chembl CHEMBL4298187
# {:chembl_id=>"CHEMBL4298187", :name=>"Diafertm"}
# {:chembl_id=>"CHEMBL4298187", :name=>"Diafertm", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL4298187
# runnign chembl CHEMBL1201560
# {:chembl_id=>"CHEMBL1201560", :name=>"Pegasys"}
# {:chembl_id=>"CHEMBL1201560", :name=>"Pegasys", :sid=>85286088}
# write
# runnign chembl CHEMBL1201688
# {:chembl_id=>"CHEMBL1201688", :name=>"Vitravene"}
# {:chembl_id=>"CHEMBL1201688", :name=>"Vitravene", :sid=>76715614}
# write
# runnign chembl CHEMBL1201414
# {:chembl_id=>"CHEMBL1201414", :name=>"Innohep"}
# {:chembl_id=>"CHEMBL1201414", :name=>"Innohep", :sid=>251963954}
# write
# runnign chembl CHEMBL1201564
# {:chembl_id=>"CHEMBL1201564", :name=>"Actimmune"}
# {:chembl_id=>"CHEMBL1201564", :name=>"Actimmune", :sid=>135032842}
# write
# runnign chembl CHEMBL1201830
# {:chembl_id=>"CHEMBL1201830", :name=>"Arcalyst"}
# {:chembl_id=>"CHEMBL1201830", :name=>"Arcalyst", :sid=>135350808}
# write
# runnign chembl CHEMBL1201580
# {:chembl_id=>"CHEMBL1201580", :name=>"Amgevita"}
# {:chembl_id=>"CHEMBL1201580", :name=>"Amgevita", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201580
# runnign chembl CHEMBL3039583
# {:chembl_id=>"CHEMBL3039583", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL3039583", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL3039583
# runnign chembl CHEMBL1201657
# {:chembl_id=>"CHEMBL1201657", :name=>"Heparin lock flush"}
# {:chembl_id=>"CHEMBL1201657", :name=>"Heparin lock flush", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201657
# runnign chembl CHEMBL2107886
# {:chembl_id=>"CHEMBL2107886", :name=>"Clivarine"}
# {:chembl_id=>"CHEMBL2107886", :name=>"Clivarine", :sid=>134224897}
# write
# runnign chembl CHEMBL4297762
# {:chembl_id=>"CHEMBL4297762", :name=>"Vyondys 53"}
# {:chembl_id=>"CHEMBL4297762", :name=>"Vyondys 53", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL4297762
# runnign chembl CHEMBL2108574
# {:chembl_id=>"CHEMBL2108574", :name=>"CHEMBL2108574"}
# {:chembl_id=>"CHEMBL2108574", :name=>"CHEMBL2108574", :sid=>160693080}
# write
# runnign chembl CHEMBL1201576
# {:chembl_id=>"CHEMBL1201576", :name=>"Mabthera"}
# {:chembl_id=>"CHEMBL1201576", :name=>"Mabthera", :sid=>50070184}
# write
# runnign chembl CHEMBL2105487
# {:chembl_id=>"CHEMBL2105487", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL2105487", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL2105487
# runnign chembl CHEMBL3544926
# {:chembl_id=>"CHEMBL3544926", :name=>"Anthim"}
# {:chembl_id=>"CHEMBL3544926", :name=>"Anthim", :sid=>377483932}
# write
# runnign chembl CHEMBL2103749
# {:chembl_id=>"CHEMBL2103749", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL2103749", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL2103749
# runnign chembl CHEMBL101
# {:chembl_id=>"CHEMBL101", :name=>"Antadol"}
# {:chembl_id=>"CHEMBL101", :name=>"Antadol", :sid=>86400}
# write
# runnign chembl CHEMBL3707326
# {:chembl_id=>"CHEMBL3707326", :name=>"Crysvita"}
# {:chembl_id=>"CHEMBL3707326", :name=>"Crysvita", :sid=>318164811}
# write
# runnign chembl CHEMBL1201558
# {:chembl_id=>"CHEMBL1201558", :name=>"Intron-A"}
# {:chembl_id=>"CHEMBL1201558", :name=>"Intron-A", :sid=>404772571}
# write
# runnign chembl CHEMBL2108494
# {:chembl_id=>"CHEMBL2108494", :name=>"CHEMBL2108494"}
# {:chembl_id=>"CHEMBL2108494", :name=>"CHEMBL2108494", :sid=>160693071}
# write
# runnign chembl CHEMBL1201661
# {:chembl_id=>"CHEMBL1201661", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL1201661", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL1201661
# runnign chembl CHEMBL604
# {:chembl_id=>"CHEMBL604", :name=>"Caustic Powder"}
# {:chembl_id=>"CHEMBL604", :name=>"Caustic Powder", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL604
# runnign chembl CHEMBL1201421
# {:chembl_id=>"CHEMBL1201421", :name=>"Macugen"}
# {:chembl_id=>"CHEMBL1201421", :name=>"Macugen", :sid=>50070203}
# write
# runnign chembl CHEMBL1201186
# {:chembl_id=>"CHEMBL1201186", :name=>"CHEMBL1201186"}
# {:chembl_id=>"CHEMBL1201186", :name=>"CHEMBL1201186", :sid=>103771169}
# write
# runnign chembl CHEMBL1201624
# {:chembl_id=>"CHEMBL1201624", :name=>"Survanta"}
# {:chembl_id=>"CHEMBL1201624", :name=>"Survanta", :sid=>50070149}
# write
# runnign chembl CHEMBL2108638
# {:chembl_id=>"CHEMBL2108638", :name=>"Abthrax"}
# {:chembl_id=>"CHEMBL2108638", :name=>"Abthrax", :sid=>135308664}
# write
# runnign chembl CHEMBL1201544
# {:chembl_id=>"CHEMBL1201544", :name=>"Armidexan"}
# {:chembl_id=>"CHEMBL1201544", :name=>"Armidexan", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201544
# runnign chembl CHEMBL1201832
# {:chembl_id=>"CHEMBL1201832", :name=>"Nplate"}
# {:chembl_id=>"CHEMBL1201832", :name=>"Nplate", :sid=>135347108}
# write
# runnign chembl CHEMBL2218885
# {:chembl_id=>"CHEMBL2218885", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL2218885", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL2218885
# runnign chembl CHEMBL1201447
# {:chembl_id=>"CHEMBL1201447", :name=>"Infasurf preservative free"}
# {:chembl_id=>"CHEMBL1201447", :name=>"Infasurf preservative free", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201447
# runnign chembl CHEMBL1201834
# {:chembl_id=>"CHEMBL1201834", :name=>"Ilaris"}
# {:chembl_id=>"CHEMBL1201834", :name=>"Ilaris", :sid=>135332926}
# write
# runnign chembl CHEMBL1201622
# {:chembl_id=>"CHEMBL1201622", :name=>"Curosurf"}
# {:chembl_id=>"CHEMBL1201622", :name=>"Curosurf", :sid=>11528958}
# write
# runnign chembl CHEMBL1742991
# {:chembl_id=>"CHEMBL1742991", :name=>"Fasenra"}
# {:chembl_id=>"CHEMBL1742991", :name=>"Fasenra", :sid=>135339902}
# write
# runnign chembl CHEMBL196
# {:chembl_id=>"CHEMBL196", :name=>"Ascor"}
# {:chembl_id=>"CHEMBL196", :name=>"Ascor", :sid=>134971787}
# write
# runnign chembl CHEMBL1201438
# {:chembl_id=>"CHEMBL1201438", :name=>"Proleukin"}
# {:chembl_id=>"CHEMBL1201438", :name=>"Proleukin", :sid=>49985142}
# write
# runnign chembl CHEMBL32
# {:chembl_id=>"CHEMBL32", :name=>"Avelox"}
# {:chembl_id=>"CHEMBL32", :name=>"Avelox", :sid=>11528782}
# write
# runnign chembl CHEMBL4594244
# {:chembl_id=>"CHEMBL4594244", :name=>"CHEMBL4594244"}
# {:chembl_id=>"CHEMBL4594244", :name=>"CHEMBL4594244", :sid=>440234800}
# write
# runnign chembl CHEMBL1200557
# {:chembl_id=>"CHEMBL1200557", :name=>"CHEMBL1200557"}
# {:chembl_id=>"CHEMBL1200557", :name=>"CHEMBL1200557", :sid=>103770540}
# write
# runnign chembl CHEMBL1201474
# {:chembl_id=>"CHEMBL1201474", :name=>"Colestid"}
# {:chembl_id=>"CHEMBL1201474", :name=>"Colestid", :sid=>49955761}
# write
# runnign chembl CHEMBL1201831
# {:chembl_id=>"CHEMBL1201831", :name=>"Cimzia"}
# {:chembl_id=>"CHEMBL1201831", :name=>"Cimzia", :sid=>135347437}
# write
# runnign chembl CHEMBL2108791
# {:chembl_id=>"CHEMBL2108791", :name=>"Metalyse"}
# {:chembl_id=>"CHEMBL2108791", :name=>"Metalyse", :sid=>134223915}
# write
# runnign chembl CHEMBL2109624
# {:chembl_id=>"CHEMBL2109624", :name=>"Cablivi"}
# {:chembl_id=>"CHEMBL2109624", :name=>"Cablivi", :sid=>315661208}
# write
# runnign chembl CHEMBL3137343
# {:chembl_id=>"CHEMBL3137343", :name=>"Keytruda"}
# {:chembl_id=>"CHEMBL3137343", :name=>"Keytruda", :sid=>187051801}
# write
# runnign chembl CHEMBL1201605
# {:chembl_id=>"CHEMBL1201605", :name=>"Zenapax"}
# {:chembl_id=>"CHEMBL1201605", :name=>"Zenapax", :sid=>538071}
# write
# runnign chembl CHEMBL1201621
# {:chembl_id=>"CHEMBL1201621", :name=>"Accretropin"}
# {:chembl_id=>"CHEMBL1201621", :name=>"Accretropin", :sid=>135274454}
# write
# runnign chembl CHEMBL1201649
# {:chembl_id=>"CHEMBL1201649", :name=>"Oestrogen"}
# {:chembl_id=>"CHEMBL1201649", :name=>"Oestrogen", :sid=>135309693}
# write
# runnign chembl CHEMBL2107884
# {:chembl_id=>"CHEMBL2107884", :name=>"Cinqaero"}
# {:chembl_id=>"CHEMBL2107884", :name=>"Cinqaero", :sid=>249565771}
# write
# runnign chembl CHEMBL1200823
# {:chembl_id=>"CHEMBL1200823", :name=>"Venofer"}
# {:chembl_id=>"CHEMBL1200823", :name=>"Venofer", :sid=>53789662}
# write
# runnign chembl CHEMBL1201431
# {:chembl_id=>"CHEMBL1201431", :name=>"Pulmozyme"}
# {:chembl_id=>"CHEMBL1201431", :name=>"Pulmozyme", :sid=>135289419}
# write
# runnign chembl CHEMBL2107885
# {:chembl_id=>"CHEMBL2107885", :name=>"Rapilysin"}
# {:chembl_id=>"CHEMBL2107885", :name=>"Rapilysin", :sid=>134222312}
# write
# runnign chembl CHEMBL3039537
# {:chembl_id=>"CHEMBL3039537", :name=>"Kanuma"}
# {:chembl_id=>"CHEMBL3039537", :name=>"Kanuma", :sid=>377483931}
# write
# runnign chembl CHEMBL2107874
# {:chembl_id=>"CHEMBL2107874", :name=>"Evenity"}
# {:chembl_id=>"CHEMBL2107874", :name=>"Evenity", :sid=>249565772}
# write
# runnign chembl CHEMBL1201589
# {:chembl_id=>"CHEMBL1201589", :name=>"Xolair"}
# {:chembl_id=>"CHEMBL1201589", :name=>"Xolair", :sid=>50067183}
# write
# runnign chembl CHEMBL1201581
# {:chembl_id=>"CHEMBL1201581", :name=>"Inflectra"}
# {:chembl_id=>"CHEMBL1201581", :name=>"Inflectra", :sid=>135305802}
# write
# runnign chembl CHEMBL1789844
# {:chembl_id=>"CHEMBL1789844", :name=>"Yervoy"}
# {:chembl_id=>"CHEMBL1789844", :name=>"Yervoy", :sid=>135287563}
# write
# runnign chembl CHEMBL1201827
# {:chembl_id=>"CHEMBL1201827", :name=>"Vectibix"}
# {:chembl_id=>"CHEMBL1201827", :name=>"Vectibix", :sid=>50070211}
# write
# runnign chembl CHEMBL1201486
# {:chembl_id=>"CHEMBL1201486", :name=>"Cardioquin"}
# {:chembl_id=>"CHEMBL1201486", :name=>"Cardioquin", :sid=>49972079}
# write
# runnign chembl CHEMBL2108350
# {:chembl_id=>"CHEMBL2108350", :name=>"Ruconest"}
# {:chembl_id=>"CHEMBL2108350", :name=>"Ruconest", :sid=>135346177}
# write
# runnign chembl CHEMBL2108938
# {:chembl_id=>"CHEMBL2108938", :name=>"Iodoflex"}
# {:chembl_id=>"CHEMBL2108938", :name=>"Iodoflex", :sid=>135298353}
# write
# runnign chembl CHEMBL2109005
# {:chembl_id=>"CHEMBL2109005", :name=>"CHEMBL2109005"}
# {:chembl_id=>"CHEMBL2109005", :name=>"CHEMBL2109005", :sid=>160687675}
# write
# runnign chembl CHEMBL3545131
# {:chembl_id=>"CHEMBL3545131", :name=>"Sarclisa"}
# {:chembl_id=>"CHEMBL3545131", :name=>"Sarclisa", :sid=>252827377}
# write
# runnign chembl CHEMBL3707352
# {:chembl_id=>"CHEMBL3707352", :name=>"CHEMBL3707352"}
# {:chembl_id=>"CHEMBL3707352", :name=>"CHEMBL3707352", :sid=>318464589}
# write
# runnign chembl CHEMBL1201479
# {:chembl_id=>"CHEMBL1201479", :name=>"Glycolax"}
# {:chembl_id=>"CHEMBL1201479", :name=>"Glycolax", :sid=>481110116}
# write
# runnign chembl CHEMBL3301587
# {:chembl_id=>"CHEMBL3301587", :name=>"Imfinzi"}
# {:chembl_id=>"CHEMBL3301587", :name=>"Imfinzi", :sid=>249565666}
# write
# runnign chembl CHEMBL1201647
# {:chembl_id=>"CHEMBL1201647", :name=>"CHEMBL1201647"}
# {:chembl_id=>"CHEMBL1201647", :name=>"CHEMBL1201647", :sid=>103771452}
# write
# runnign chembl CHEMBL3707227
# {:chembl_id=>"CHEMBL3707227", :name=>"Tecentriq"}
# {:chembl_id=>"CHEMBL3707227", :name=>"Tecentriq", :sid=>249565671}
# write
# runnign chembl CHEMBL1201497
# {:chembl_id=>"CHEMBL1201497", :name=>"Abasaglar"}
# {:chembl_id=>"CHEMBL1201497", :name=>"Abasaglar", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201497
# runnign chembl CHEMBL1201556
# {:chembl_id=>"CHEMBL1201556", :name=>"Regranex"}
# {:chembl_id=>"CHEMBL1201556", :name=>"Regranex", :sid=>135290697}
# write
# runnign chembl CHEMBL1201538
# {:chembl_id=>"CHEMBL1201538", :name=>"Admelog"}
# {:chembl_id=>"CHEMBL1201538", :name=>"Admelog", :sid=>135236610}
# write
# runnign chembl CHEMBL2108110
# {:chembl_id=>"CHEMBL2108110", :name=>"CHEMBL2108110"}
# {:chembl_id=>"CHEMBL2108110", :name=>"CHEMBL2108110", :sid=>160693017}
# write
# runnign chembl CHEMBL3301582
# {:chembl_id=>"CHEMBL3301582", :name=>"Polivy"}
# {:chembl_id=>"CHEMBL3301582", :name=>"Polivy", :sid=>223370409}
# write
# runnign chembl CHEMBL1201562
# {:chembl_id=>"CHEMBL1201562", :name=>"Avonex"}
# {:chembl_id=>"CHEMBL1201562", :name=>"Avonex", :sid=>252166551}
# write
# runnign chembl CHEMBL2109171
# {:chembl_id=>"CHEMBL2109171", :name=>"Inductos"}
# {:chembl_id=>"CHEMBL2109171", :name=>"Inductos", :sid=>135329802}
# write
# runnign chembl CHEMBL3991432
# {:chembl_id=>"CHEMBL3991432", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL3991432", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL3991432
# runnign chembl CHEMBL1743048
# {:chembl_id=>"CHEMBL1743048", :name=>"Gazyvaro"}
# {:chembl_id=>"CHEMBL1743048", :name=>"Gazyvaro", :sid=>135332744}
# write
# runnign chembl CHEMBL2108027
# {:chembl_id=>"CHEMBL2108027", :name=>"Trulicity"}
# {:chembl_id=>"CHEMBL2108027", :name=>"Trulicity", :sid=>135360107}
# write
# runnign chembl CHEMBL3707226
# {:chembl_id=>"CHEMBL3707226", :name=>"Defitelio"}
# {:chembl_id=>"CHEMBL3707226", :name=>"Defitelio", :sid=>134223505}
# write
# runnign chembl CHEMBL1201723
# {:chembl_id=>"CHEMBL1201723", :name=>"Veregen"}
# {:chembl_id=>"CHEMBL1201723", :name=>"Veregen", :sid=>135207091}
# write
# runnign chembl CHEMBL2108282
# {:chembl_id=>"CHEMBL2108282", :name=>"Novothirteen"}
# {:chembl_id=>"CHEMBL2108282", :name=>"Novothirteen", :sid=>160703794}
# write
# runnign chembl CHEMBL1428
# {:chembl_id=>"CHEMBL1428", :name=>"Nimodipine"}
# {:chembl_id=>"CHEMBL1428", :name=>"Nimodipine", :sid=>9476}
# write
# runnign chembl CHEMBL1201824
# {:chembl_id=>"CHEMBL1201824", :name=>"Lumizyme"}
# {:chembl_id=>"CHEMBL1201824", :name=>"Lumizyme", :sid=>103771522}
# write
# runnign chembl CHEMBL595
# {:chembl_id=>"CHEMBL595", :name=>"CHEMBL595"}
# {:chembl_id=>"CHEMBL595", :name=>"CHEMBL595", :sid=>103181943}
# write
# runnign chembl CHEMBL1201577
# {:chembl_id=>"CHEMBL1201577", :name=>"Erbitux"}
# {:chembl_id=>"CHEMBL1201577", :name=>"Erbitux", :sid=>317225970}
# write
# runnign chembl CHEMBL1742994
# {:chembl_id=>"CHEMBL1742994", :name=>"Adcetris"}
# {:chembl_id=>"CHEMBL1742994", :name=>"Adcetris", :sid=>135300399}
# write
# runnign chembl CHEMBL1201587
# {:chembl_id=>"CHEMBL1201587", :name=>"Campath"}
# {:chembl_id=>"CHEMBL1201587", :name=>"Campath", :sid=>50070197}
# write
# runnign chembl CHEMBL1743062
# {:chembl_id=>"CHEMBL1743062", :name=>"Cyramza"}
# {:chembl_id=>"CHEMBL1743062", :name=>"Cyramza", :sid=>135285364}
# write
# runnign chembl CHEMBL2108546
# {:chembl_id=>"CHEMBL2108546", :name=>"Oncaspar"}
# {:chembl_id=>"CHEMBL2108546", :name=>"Oncaspar", :sid=>50069759}
# write
# runnign chembl CHEMBL408
# {:chembl_id=>"CHEMBL408", :name=>"Prelay"}
# {:chembl_id=>"CHEMBL408", :name=>"Prelay", :sid=>12013560}
# write
# runnign chembl CHEMBL1368
# {:chembl_id=>"CHEMBL1368", :name=>"Ionosol B"}
# {:chembl_id=>"CHEMBL1368", :name=>"Ionosol B", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1368
# runnign chembl CHEMBL2097081
# {:chembl_id=>"CHEMBL2097081", :name=>"CHEMBL2097081"}
# {:chembl_id=>"CHEMBL2097081", :name=>"CHEMBL2097081", :sid=>194141199}
# write
# runnign chembl CHEMBL2108728
# {:chembl_id=>"CHEMBL2108728", :name=>"Asparlas"}
# {:chembl_id=>"CHEMBL2108728", :name=>"Asparlas", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108728
# runnign chembl CHEMBL1201464
# {:chembl_id=>"CHEMBL1201464", :name=>"Ovidrel"}
# {:chembl_id=>"CHEMBL1201464", :name=>"Ovidrel", :sid=>50070186}
# write
# runnign chembl CHEMBL2108681
# {:chembl_id=>"CHEMBL2108681", :name=>"Ilumetri"}
# {:chembl_id=>"CHEMBL2108681", :name=>"Ilumetri", :sid=>249565773}
# write
# runnign chembl CHEMBL2109027
# {:chembl_id=>"CHEMBL2109027", :name=>"Ananase"}
# {:chembl_id=>"CHEMBL2109027", :name=>"Ananase", :sid=>49895175}
# write
# runnign chembl CHEMBL414804
# {:chembl_id=>"CHEMBL414804", :name=>"Eloxatin"}
# {:chembl_id=>"CHEMBL414804", :name=>"Eloxatin", :sid=>53790063}
# write
# runnign chembl CHEMBL3833393
# {:chembl_id=>"CHEMBL3833393", :name=>"Hemlibra"}
# {:chembl_id=>"CHEMBL3833393", :name=>"Hemlibra", :sid=>354702217}
# write
# runnign chembl CHEMBL3833405
# {:chembl_id=>"CHEMBL3833405", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL3833405", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL3833405
# runnign chembl CHEMBL475534
# {:chembl_id=>"CHEMBL475534", :name=>"Baypress"}
# {:chembl_id=>"CHEMBL475534", :name=>"Baypress", :sid=>12013715}
# write
# runnign chembl CHEMBL1201441
# {:chembl_id=>"CHEMBL1201441", :name=>"Colistimethate sodium"}
# {:chembl_id=>"CHEMBL1201441", :name=>"Colistimethate sodium", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201441
# runnign chembl CHEMBL2007641
# {:chembl_id=>"CHEMBL2007641", :name=>"Omnitarg"}
# {:chembl_id=>"CHEMBL2007641", :name=>"Omnitarg", :sid=>50069677}
# write
# runnign chembl CHEMBL2107841
# {:chembl_id=>"CHEMBL2107841", :name=>"Eperzan"}
# {:chembl_id=>"CHEMBL2107841", :name=>"Eperzan", :sid=>135337445}
# write
# runnign chembl CHEMBL3707232
# {:chembl_id=>"CHEMBL3707232", :name=>"Ferromyn"}
# {:chembl_id=>"CHEMBL3707232", :name=>"Ferromyn", :sid=>198984150}
# write
# runnign chembl CHEMBL1863514
# {:chembl_id=>"CHEMBL1863514", :name=>"Erwinase[r] erwinaze[tm]"}
# {:chembl_id=>"CHEMBL1863514", :name=>"Erwinase[r] erwinaze[tm]", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1863514
# runnign chembl CHEMBL1237023
# {:chembl_id=>"CHEMBL1237023", :name=>"Prolia"}
# {:chembl_id=>"CHEMBL1237023", :name=>"Prolia", :sid=>135285955}
# write
# runnign chembl CHEMBL3707208
# {:chembl_id=>"CHEMBL3707208", :name=>"Fe-cap"}
# {:chembl_id=>"CHEMBL3707208", :name=>"Fe-cap", :sid=>505594874}
# write
# runnign chembl CHEMBL1201630
# {:chembl_id=>"CHEMBL1201630", :name=>"Iletin ii"}
# {:chembl_id=>"CHEMBL1201630", :name=>"Iletin ii", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201630
# runnign chembl CHEMBL3301581
# {:chembl_id=>"CHEMBL3301581", :name=>"Eladynos"}
# {:chembl_id=>"CHEMBL3301581", :name=>"Eladynos", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL3301581
# runnign chembl CHEMBL3707328
# {:chembl_id=>"CHEMBL3707328", :name=>"Emgality"}
# {:chembl_id=>"CHEMBL3707328", :name=>"Emgality", :sid=>310264747}
# write
# runnign chembl CHEMBL4298209
# {:chembl_id=>"CHEMBL4298209", :name=>"Blenrep"}
# {:chembl_id=>"CHEMBL4298209", :name=>"Blenrep", :sid=>434122177}
# write
# runnign chembl CHEMBL1237022
# {:chembl_id=>"CHEMBL1237022", :name=>"Actemra"}
# {:chembl_id=>"CHEMBL1237022", :name=>"Actemra", :sid=>104253153}
# write
# runnign chembl CHEMBL3990026
# {:chembl_id=>"CHEMBL3990026", :name=>"Revcovi"}
# {:chembl_id=>"CHEMBL3990026", :name=>"Revcovi", :sid=>316908554}
# write
# runnign chembl CHEMBL4297549
# {:chembl_id=>"CHEMBL4297549", :name=>"Cinryze"}
# {:chembl_id=>"CHEMBL4297549", :name=>"Cinryze", :sid=>333495402}
# write
# runnign chembl CHEMBL3707357
# {:chembl_id=>"CHEMBL3707357", :name=>"Beovu"}
# {:chembl_id=>"CHEMBL3707357", :name=>"Beovu", :sid=>252827371}
# write
# runnign chembl CHEMBL1201573
# {:chembl_id=>"CHEMBL1201573", :name=>"Neumega"}
# {:chembl_id=>"CHEMBL1201573", :name=>"Neumega", :sid=>50070167}
# write
# runnign chembl CHEMBL2108184
# {:chembl_id=>"CHEMBL2108184", :name=>"Fulyzaq"}
# {:chembl_id=>"CHEMBL2108184", :name=>"Fulyzaq", :sid=>475720826}
# write
# runnign chembl CHEMBL1201837
# {:chembl_id=>"CHEMBL1201837", :name=>"CHEMBL1201837"}
# {:chembl_id=>"CHEMBL1201837", :name=>"CHEMBL1201837", :sid=>103771535}
# write
# runnign chembl CHEMBL1909079
# {:chembl_id=>"CHEMBL1909079", :name=>"Omnigel"}
# {:chembl_id=>"CHEMBL1909079", :name=>"Omnigel", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1909079
# runnign chembl CHEMBL1201629
# {:chembl_id=>"CHEMBL1201629", :name=>"Regular iletin ii"}
# {:chembl_id=>"CHEMBL1201629", :name=>"Regular iletin ii", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201629
# runnign chembl CHEMBL1237024
# {:chembl_id=>"CHEMBL1237024", :name=>"CHEMBL1237024"}
# {:chembl_id=>"CHEMBL1237024", :name=>"CHEMBL1237024", :sid=>104253155}
# write
# runnign chembl CHEMBL1201531
# {:chembl_id=>"CHEMBL1201531", :name=>"Vertavis"}
# {:chembl_id=>"CHEMBL1201531", :name=>"Vertavis", :sid=>77704}
# write
# runnign chembl CHEMBL1201570
# {:chembl_id=>"CHEMBL1201570", :name=>"Kineret"}
# {:chembl_id=>"CHEMBL1201570", :name=>"Kineret", :sid=>50070165}
# write
# runnign chembl CHEMBL1201586
# {:chembl_id=>"CHEMBL1201586", :name=>"Synagis"}
# {:chembl_id=>"CHEMBL1201586", :name=>"Synagis", :sid=>50069681}
# write
# runnign chembl CHEMBL525610
# {:chembl_id=>"CHEMBL525610", :name=>"Bonsity"}
# {:chembl_id=>"CHEMBL525610", :name=>"Bonsity", :sid=>375084197}
# write
# runnign chembl CHEMBL1743047
# {:chembl_id=>"CHEMBL1743047", :name=>"Portrazza"}
# {:chembl_id=>"CHEMBL1743047", :name=>"Portrazza", :sid=>135263756}
# write
# runnign chembl CHEMBL2108581
# {:chembl_id=>"CHEMBL2108581", :name=>"Removab"}
# {:chembl_id=>"CHEMBL2108581", :name=>"Removab", :sid=>135311383}
# write
# runnign chembl CHEMBL413
# {:chembl_id=>"CHEMBL413", :name=>"Fyarro"}
# {:chembl_id=>"CHEMBL413", :name=>"Fyarro", :sid=>103164548}
# write
# runnign chembl CHEMBL1201631
# {:chembl_id=>"CHEMBL1201631", :name=>"Actrapid"}
# {:chembl_id=>"CHEMBL1201631", :name=>"Actrapid", :sid=>395818}
# write
# runnign chembl CHEMBL1201439
# {:chembl_id=>"CHEMBL1201439", :name=>"Simulect"}
# {:chembl_id=>"CHEMBL1201439", :name=>"Simulect", :sid=>50067184}
# write
# runnign chembl CHEMBL1201533
# {:chembl_id=>"CHEMBL1201533", :name=>"Thyrogen"}
# {:chembl_id=>"CHEMBL1201533", :name=>"Thyrogen", :sid=>317225999}
# write
# runnign chembl CHEMBL2107857
# {:chembl_id=>"CHEMBL2107857", :name=>"Myalepta"}
# {:chembl_id=>"CHEMBL2107857", :name=>"Myalepta", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2107857
# runnign chembl CHEMBL2107991
# {:chembl_id=>"CHEMBL2107991", :name=>"Spongostan"}
# {:chembl_id=>"CHEMBL2107991", :name=>"Spongostan", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2107991
# runnign chembl CHEMBL3989769
# {:chembl_id=>"CHEMBL3989769", :name=>"Biomydrin"}
# {:chembl_id=>"CHEMBL3989769", :name=>"Biomydrin", :sid=>49855593}
# write
# runnign chembl CHEMBL1201507
# {:chembl_id=>"CHEMBL1201507", :name=>"Copaxone"}
# {:chembl_id=>"CHEMBL1201507", :name=>"Copaxone", :sid=>49972930}
# write
# runnign chembl CHEMBL1201610
# {:chembl_id=>"CHEMBL1201610", :name=>"Acth"}
# {:chembl_id=>"CHEMBL1201610", :name=>"Acth", :sid=>53790127}
# write
# runnign chembl CHEMBL1743068
# {:chembl_id=>"CHEMBL1743068", :name=>"Cosentyx"}
# {:chembl_id=>"CHEMBL1743068", :name=>"Cosentyx", :sid=>135288104}
# write
# runnign chembl CHEMBL2108200
# {:chembl_id=>"CHEMBL2108200", :name=>"Conotrane"}
# {:chembl_id=>"CHEMBL2108200", :name=>"Conotrane", :sid=>49990836}
# write
# runnign chembl CHEMBL2108201
# {:chembl_id=>"CHEMBL2108201", :name=>"Debrisan"}
# {:chembl_id=>"CHEMBL2108201", :name=>"Debrisan", :sid=>49960595}
# write
# runnign chembl CHEMBL2108535
# {:chembl_id=>"CHEMBL2108535", :name=>"Anaflex"}
# {:chembl_id=>"CHEMBL2108535", :name=>"Anaflex", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108535
# runnign chembl CHEMBL2108730
# {:chembl_id=>"CHEMBL2108730", :name=>"Kevzara"}
# {:chembl_id=>"CHEMBL2108730", :name=>"Kevzara", :sid=>249565679}
# write
# runnign chembl CHEMBL1964120
# {:chembl_id=>"CHEMBL1964120", :name=>"Elelyso"}
# {:chembl_id=>"CHEMBL1964120", :name=>"Elelyso", :sid=>135318890}
# write
# runnign chembl CHEMBL2109092
# {:chembl_id=>"CHEMBL2109092", :name=>"Neorecormon"}
# {:chembl_id=>"CHEMBL2109092", :name=>"Neorecormon", :sid=>49965746}
# write
# runnign chembl CHEMBL1201608
# {:chembl_id=>"CHEMBL1201608", :name=>"Orthoclone okt3"}
# {:chembl_id=>"CHEMBL1201608", :name=>"Orthoclone okt3", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201608
# runnign chembl CHEMBL2109016
# {:chembl_id=>"CHEMBL2109016", :name=>"Hyperdrol"}
# {:chembl_id=>"CHEMBL2109016", :name=>"Hyperdrol", :sid=>175267407}
# write
# runnign chembl CHEMBL2109152
# {:chembl_id=>"CHEMBL2109152", :name=>"Alpha keri"}
# {:chembl_id=>"CHEMBL2109152", :name=>"Alpha keri", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2109152
# runnign chembl CHEMBL3545189
# {:chembl_id=>"CHEMBL3545189", :name=>"Takhzyro"}
# {:chembl_id=>"CHEMBL3545189", :name=>"Takhzyro", :sid=>315661179}
# write
# runnign chembl CHEMBL1201835
# {:chembl_id=>"CHEMBL1201835", :name=>"Stelara"}
# {:chembl_id=>"CHEMBL1201835", :name=>"Stelara", :sid=>135302166}
# write
# runnign chembl CHEMBL1201481
# {:chembl_id=>"CHEMBL1201481", :name=>"Photobarr"}
# {:chembl_id=>"CHEMBL1201481", :name=>"Photobarr", :sid=>103771429}
# write
# runnign chembl CHEMBL1201668
# {:chembl_id=>"CHEMBL1201668", :name=>"Natrecor"}
# {:chembl_id=>"CHEMBL1201668", :name=>"Natrecor", :sid=>135263544}
# write
# runnign chembl CHEMBL1201836
# {:chembl_id=>"CHEMBL1201836", :name=>"Arzerra"}
# {:chembl_id=>"CHEMBL1201836", :name=>"Arzerra", :sid=>135302238}
# write
# runnign chembl CHEMBL2146161
# {:chembl_id=>"CHEMBL2146161", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL2146161", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL2146161
# runnign chembl CHEMBL2359370
# {:chembl_id=>"CHEMBL2359370", :name=>"Asimil b-12"}
# {:chembl_id=>"CHEMBL2359370", :name=>"Asimil b-12", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2359370
# runnign chembl CHEMBL132530
# {:chembl_id=>"CHEMBL132530", :name=>"Lentaron"}
# {:chembl_id=>"CHEMBL132530", :name=>"Lentaron", :sid=>12013811}
# write
# runnign chembl CHEMBL1351
# {:chembl_id=>"CHEMBL1351", :name=>"Carboplatin"}
# {:chembl_id=>"CHEMBL1351", :name=>"Carboplatin", :sid=>565491}
# write
# runnign chembl CHEMBL1201516
# {:chembl_id=>"CHEMBL1201516", :name=>"Elmiron"}
# {:chembl_id=>"CHEMBL1201516", :name=>"Elmiron", :sid=>319423507}
# write
# runnign chembl CHEMBL1743034
# {:chembl_id=>"CHEMBL1743034", :name=>"Taltz"}
# {:chembl_id=>"CHEMBL1743034", :name=>"Taltz", :sid=>187051842}
# write
# runnign chembl CHEMBL1201823
# {:chembl_id=>"CHEMBL1201823", :name=>"Orencia"}
# {:chembl_id=>"CHEMBL1201823", :name=>"Orencia", :sid=>50070209}
# write
# runnign chembl CHEMBL1743049
# {:chembl_id=>"CHEMBL1743049", :name=>"Lartruvo"}
# {:chembl_id=>"CHEMBL1743049", :name=>"Lartruvo", :sid=>135279750}
# write
# runnign chembl CHEMBL3991035
# {:chembl_id=>"CHEMBL3991035", :name=>"CHEMBL3991035"}
# {:chembl_id=>"CHEMBL3991035", :name=>"CHEMBL3991035", :sid=>374363796}
# write
# runnign chembl CHEMBL2107869
# {:chembl_id=>"CHEMBL2107869", :name=>"Ins tresiba"}
# {:chembl_id=>"CHEMBL2107869", :name=>"Ins tresiba", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2107869
# runnign chembl CHEMBL4298047
# {:chembl_id=>"CHEMBL4298047", :name=>"Minjuvi"}
# {:chembl_id=>"CHEMBL4298047", :name=>"Minjuvi", :sid=>434122191}
# write
# runnign chembl CHEMBL414357
# {:chembl_id=>"CHEMBL414357", :name=>"Bydureon"}
# {:chembl_id=>"CHEMBL414357", :name=>"Bydureon", :sid=>92729736}
# write
# runnign chembl CHEMBL4297852
# {:chembl_id=>"CHEMBL4297852", :name=>"Oxervate"}
# {:chembl_id=>"CHEMBL4297852", :name=>"Oxervate", :sid=>178101723}
# write
# runnign chembl CHEMBL2108727
# {:chembl_id=>"CHEMBL2108727", :name=>"Imlygic"}
# {:chembl_id=>"CHEMBL2108727", :name=>"Imlygic", :sid=>135343059}
# write
# runnign chembl CHEMBL3989977
# {:chembl_id=>"CHEMBL3989977", :name=>"Gamifant"}
# {:chembl_id=>"CHEMBL3989977", :name=>"Gamifant", :sid=>318164814}
# write
# runnign chembl CHEMBL1200830
# {:chembl_id=>"CHEMBL1200830", :name=>"Feosol"}
# {:chembl_id=>"CHEMBL1200830", :name=>"Feosol", :sid=>49985305}
# write
# runnign chembl CHEMBL1201473
# {:chembl_id=>"CHEMBL1201473", :name=>"Cholestagel"}
# {:chembl_id=>"CHEMBL1201473", :name=>"Cholestagel", :sid=>135266932}
# write
# runnign chembl CHEMBL4297723
# {:chembl_id=>"CHEMBL4297723", :name=>"Libtayo"}
# {:chembl_id=>"CHEMBL4297723", :name=>"Libtayo", :sid=>381118800}
# write
# runnign chembl CHEMBL1201529
# {:chembl_id=>"CHEMBL1201529", :name=>"An-sulfur colloid"}
# {:chembl_id=>"CHEMBL1201529", :name=>"An-sulfur colloid", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1201529
# runnign chembl CHEMBL1201571
# {:chembl_id=>"CHEMBL1201571", :name=>"Amevive"}
# {:chembl_id=>"CHEMBL1201571", :name=>"Amevive", :sid=>50070202}
# write
# runnign chembl CHEMBL1201619
# {:chembl_id=>"CHEMBL1201619", :name=>"Trasylol"}
# {:chembl_id=>"CHEMBL1201619", :name=>"Trasylol", :sid=>617567}
# write
# runnign chembl CHEMBL1742990
# {:chembl_id=>"CHEMBL1742990", :name=>"Nujolix"}
# {:chembl_id=>"CHEMBL1742990", :name=>"Nujolix", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1742990
# runnign chembl CHEMBL1743007
# {:chembl_id=>"CHEMBL1743007", :name=>"Darzalex"}
# {:chembl_id=>"CHEMBL1743007", :name=>"Darzalex", :sid=>135304352}
# write
# runnign chembl CHEMBL1201568
# {:chembl_id=>"CHEMBL1201568", :name=>"Fulphila"}
# {:chembl_id=>"CHEMBL1201568", :name=>"Fulphila", :sid=>103771195}
# write
# runnign chembl CHEMBL2109334
# {:chembl_id=>"CHEMBL2109334", :name=>"Uplizna"}
# {:chembl_id=>"CHEMBL2109334", :name=>"Uplizna", :sid=>249565673}
# write
# runnign chembl CHEMBL2108304
# {:chembl_id=>"CHEMBL2108304", :name=>"Glybera"}
# {:chembl_id=>"CHEMBL2108304", :name=>"Glybera", :sid=>160687569}
# write
# runnign chembl CHEMBL2108265
# {:chembl_id=>"CHEMBL2108265", :name=>"Casc liq"}
# {:chembl_id=>"CHEMBL2108265", :name=>"Casc liq", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108265
# runnign chembl CHEMBL1201566
# {:chembl_id=>"CHEMBL1201566", :name=>"Aranesp"}
# {:chembl_id=>"CHEMBL1201566", :name=>"Aranesp", :sid=>49965748}
# write
# runnign chembl CHEMBL2108989
# {:chembl_id=>"CHEMBL2108989", :name=>"Spectrila"}
# {:chembl_id=>"CHEMBL2108989", :name=>"Spectrila", :sid=>481101518}
# write
# runnign chembl CHEMBL3707314
# {:chembl_id=>"CHEMBL3707314", :name=>"Mircera"}
# {:chembl_id=>"CHEMBL3707314", :name=>"Mircera", :sid=>381125304}
# write
# runnign chembl CHEMBL1705709
# {:chembl_id=>"CHEMBL1705709", :name=>"Sytron"}
# {:chembl_id=>"CHEMBL1705709", :name=>"Sytron", :sid=>49862088}
# write
# runnign chembl CHEMBL1742992
# {:chembl_id=>"CHEMBL1742992", :name=>"Blincyto"}
# {:chembl_id=>"CHEMBL1742992", :name=>"Blincyto", :sid=>135330301}
# write
# runnign chembl CHEMBL1201492
# {:chembl_id=>"CHEMBL1201492", :name=>"Renagel"}
# {:chembl_id=>"CHEMBL1201492", :name=>"Renagel", :sid=>11528901}
# write
# runnign chembl CHEMBL3833320
# {:chembl_id=>"CHEMBL3833320", :name=>"Vyepti"}
# {:chembl_id=>"CHEMBL3833320", :name=>"Vyepti", :sid=>381127856}
# write
# runnign chembl CHEMBL4297802
# {:chembl_id=>"CHEMBL4297802", :name=>"Palynziq"}
# {:chembl_id=>"CHEMBL4297802", :name=>"Palynziq", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL4297802
# runnign chembl CHEMBL1795072
# {:chembl_id=>"CHEMBL1795072", :name=>"Prialt"}
# {:chembl_id=>"CHEMBL1795072", :name=>"Prialt", :sid=>134224221}
# write
# runnign chembl CHEMBL3545262
# {:chembl_id=>"CHEMBL3545262", :name=>"Trodelvy"}
# {:chembl_id=>"CHEMBL3545262", :name=>"Trodelvy", :sid=>249565933}
# write
# runnign chembl CHEMBL1201865
# {:chembl_id=>"CHEMBL1201865", :name=>"Vpriv"}
# {:chembl_id=>"CHEMBL1201865", :name=>"Vpriv", :sid=>135352052}
# write
# runnign chembl CHEMBL3559672
# {:chembl_id=>"CHEMBL3559672", :name=>"Hiwolfia"}
# {:chembl_id=>"CHEMBL3559672", :name=>"Hiwolfia", :sid=>135302894}
# write
# runnign chembl CHEMBL4297166
# {:chembl_id=>"CHEMBL4297166", :name=>"Targocid"}
# {:chembl_id=>"CHEMBL4297166", :name=>"Targocid", :sid=>96099800}
# write
# runnign chembl CHEMBL2108677
# {:chembl_id=>"CHEMBL2108677", :name=>"Biib017"}
# {:chembl_id=>"CHEMBL2108677", :name=>"Biib017", :sid=>160687621}
# write
# runnign chembl CHEMBL4298126
# {:chembl_id=>"CHEMBL4298126", :name=>"CHEMBL4298126"}
# {:chembl_id=>"CHEMBL4298126", :name=>"CHEMBL4298126", :sid=>404720583}
# write
# runnign chembl CHEMBL1201496
# {:chembl_id=>"CHEMBL1201496", :name=>"Fiasp"}
# {:chembl_id=>"CHEMBL1201496", :name=>"Fiasp", :sid=>135235175}
# write
# runnign chembl CHEMBL1201826
# {:chembl_id=>"CHEMBL1201826", :name=>"Elaprase"}
# {:chembl_id=>"CHEMBL1201826", :name=>"Elaprase", :sid=>50070138}
# write
# runnign chembl CHEMBL4298180
# {:chembl_id=>"CHEMBL4298180", :name=>"Alofisel"}
# {:chembl_id=>"CHEMBL4298180", :name=>"Alofisel", :sid=>472420829}
# write
# runnign chembl CHEMBL1201477
# {:chembl_id=>"CHEMBL1201477", :name=>"Estradurin"}
# {:chembl_id=>"CHEMBL1201477", :name=>"Estradurin", :sid=>49965785}
# write
# runnign chembl CHEMBL1201607
# {:chembl_id=>"CHEMBL1201607", :name=>"Tysabri"}
# {:chembl_id=>"CHEMBL1201607", :name=>"Tysabri", :sid=>50069162}
# write
# runnign chembl CHEMBL1201563
# {:chembl_id=>"CHEMBL1201563", :name=>"Betaseron"}
# {:chembl_id=>"CHEMBL1201563", :name=>"Betaseron", :sid=>509364}
# write
# runnign chembl CHEMBL1743087
# {:chembl_id=>"CHEMBL1743087", :name=>"Entyvio"}
# {:chembl_id=>"CHEMBL1743087", :name=>"Entyvio", :sid=>135277804}
# write
# runnign chembl CHEMBL2108558
# {:chembl_id=>"CHEMBL2108558", :name=>"Califig"}
# {:chembl_id=>"CHEMBL2108558", :name=>"Califig", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108558
# runnign chembl CHEMBL4297535
# {:chembl_id=>"CHEMBL4297535", :name=>"Omegaven"}
# {:chembl_id=>"CHEMBL4297535", :name=>"Omegaven", :sid=>135310895}
# write
# runnign chembl CHEMBL1201567
# {:chembl_id=>"CHEMBL1201567", :name=>"Accofil"}
# {:chembl_id=>"CHEMBL1201567", :name=>"Accofil", :sid=>472422369}
# write
# runnign chembl CHEMBL1201798
# {:chembl_id=>"CHEMBL1201798", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL1201798", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL1201798
# runnign chembl CHEMBL2108336
# {:chembl_id=>"CHEMBL2108336", :name=>"Adlyxin"}
# {:chembl_id=>"CHEMBL2108336", :name=>"Adlyxin", :sid=>135267128}
# write
# runnign chembl CHEMBL2108446
# {:chembl_id=>"CHEMBL2108446", :name=>"Glucotard"}
# {:chembl_id=>"CHEMBL2108446", :name=>"Glucotard", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2108446
# runnign chembl CHEMBL3833329
# {:chembl_id=>"CHEMBL3833329", :name=>"Aimovig"}
# {:chembl_id=>"CHEMBL3833329", :name=>"Aimovig", :sid=>315661325}
# write
# runnign chembl CHEMBL2354773
# {:chembl_id=>"CHEMBL2354773", :name=>"Aureotan 100"}
# {:chembl_id=>"CHEMBL2354773", :name=>"Aureotan 100", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2354773
# runnign chembl CHEMBL1201613
# {:chembl_id=>"CHEMBL1201613", :name=>"Apidra"}
# {:chembl_id=>"CHEMBL1201613", :name=>"Apidra", :sid=>135332570}
# write
# runnign chembl CHEMBL3991443
# {:chembl_id=>"CHEMBL3991443", :name=>"CHEMBL3991443"}
# {:chembl_id=>"CHEMBL3991443", :name=>"CHEMBL3991443", :sid=>374364032}
# write
# runnign chembl CHEMBL1201645
# {:chembl_id=>"CHEMBL1201645", :name=>"CHEMBL1201645"}
# {:chembl_id=>"CHEMBL1201645", :name=>"CHEMBL1201645", :sid=>103771287}
# write
# runnign chembl CHEMBL3137342
# {:chembl_id=>"CHEMBL3137342", :name=>"Unituxin"}
# {:chembl_id=>"CHEMBL3137342", :name=>"Unituxin", :sid=>249565662}
# write
# runnign chembl CHEMBL4297756
# {:chembl_id=>"CHEMBL4297756", :name=>"Ajovy"}
# {:chembl_id=>"CHEMBL4297756", :name=>"Ajovy", :sid=>315661284}
# write
# runnign chembl CHEMBL1201575
# {:chembl_id=>"CHEMBL1201575", :name=>"Raptiva"}
# {:chembl_id=>"CHEMBL1201575", :name=>"Raptiva", :sid=>50069676}
# write
# runnign chembl CHEMBL1963684
# {:chembl_id=>"CHEMBL1963684", :name=>"Omontys"}
# {:chembl_id=>"CHEMBL1963684", :name=>"Omontys", :sid=>135312100}
# write
# runnign chembl CHEMBL3833307
# {:chembl_id=>"CHEMBL3833307", :name=>"Enspryng"}
# {:chembl_id=>"CHEMBL3833307", :name=>"Enspryng", :sid=>315661178}
# write
# runnign chembl CHEMBL1201550
# {:chembl_id=>"CHEMBL1201550", :name=>"Ontak"}
# {:chembl_id=>"CHEMBL1201550", :name=>"Ontak", :sid=>50070181}
# write
# runnign chembl CHEMBL1201670
# {:chembl_id=>"CHEMBL1201670", :name=>"Leukine"}
# {:chembl_id=>"CHEMBL1201670", :name=>"Leukine", :sid=>50070152}
# write
# runnign chembl CHEMBL973
# {:chembl_id=>"CHEMBL973", :name=>"Aubagio"}
# {:chembl_id=>"CHEMBL973", :name=>"Aubagio", :sid=>12014666}
# write
# runnign chembl CHEMBL1201585
# {:chembl_id=>"CHEMBL1201585", :name=>"Herceptin"}
# {:chembl_id=>"CHEMBL1201585", :name=>"Herceptin", :sid=>317225974}
# write
# runnign chembl CHEMBL1743082
# {:chembl_id=>"CHEMBL1743082", :name=>"Kadcyla"}
# {:chembl_id=>"CHEMBL1743082", :name=>"Kadcyla", :sid=>135353969}
# write
# runnign chembl CHEMBL1743010
# {:chembl_id=>"CHEMBL1743010", :name=>"Empliciti"}
# {:chembl_id=>"CHEMBL1743010", :name=>"Empliciti", :sid=>135312351}
# write
# runnign chembl CHEMBL2095222
# {:chembl_id=>"CHEMBL2095222", :name=>"Jetrea"}
# {:chembl_id=>"CHEMBL2095222", :name=>"Jetrea", :sid=>135332408}
# write
# runnign chembl CHEMBL4594265
# {:chembl_id=>"CHEMBL4594265", :name=>"Givlaari"}
# {:chembl_id=>"CHEMBL4594265", :name=>"Givlaari", :sid=>313371338}
# write
# runnign chembl CHEMBL502835
# {:chembl_id=>"CHEMBL502835", :name=>"Ofev"}
# {:chembl_id=>"CHEMBL502835", :name=>"Ofev", :sid=>135267499}
# write
# runnign chembl CHEMBL1789843
# {:chembl_id=>"CHEMBL1789843", :name=>"Benlysta"}
# {:chembl_id=>"CHEMBL1789843", :name=>"Benlysta", :sid=>135353783}
# write
# runnign chembl CHEMBL306043
# {:chembl_id=>"CHEMBL306043", :name=>"Myocrisin"}
# {:chembl_id=>"CHEMBL306043", :name=>"Myocrisin", :sid=>49974086}
# write
# runnign chembl CHEMBL2108594
# {:chembl_id=>"CHEMBL2108594", :name=>"Osigraft"}
# {:chembl_id=>"CHEMBL2108594", :name=>"Osigraft", :sid=>135333655}
# write
# runnign chembl CHEMBL1201506
# {:chembl_id=>"CHEMBL1201506", :name=>"Mylotarg"}
# {:chembl_id=>"CHEMBL1201506", :name=>"Mylotarg", :sid=>53787868}
# write
# runnign chembl CHEMBL2108724
# {:chembl_id=>"CHEMBL2108724", :name=>"Ozempic"}
# {:chembl_id=>"CHEMBL2108724", :name=>"Ozempic", :sid=>85366789}
# write
# runnign chembl CHEMBL3039545
# {:chembl_id=>"CHEMBL3039545", :name=>"Reblozyl"}
# {:chembl_id=>"CHEMBL3039545", :name=>"Reblozyl", :sid=>381127153}
# write
# runnign chembl CHEMBL3544996
# {:chembl_id=>"CHEMBL3544996", :name=>"Praxbind"}
# {:chembl_id=>"CHEMBL3544996", :name=>"Praxbind", :sid=>252166510}
# write
# runnign chembl CHEMBL121
# {:chembl_id=>"CHEMBL121", :name=>"Avandia"}
# {:chembl_id=>"CHEMBL121", :name=>"Avandia", :sid=>841984}
# write
# runnign chembl CHEMBL4594284
# {:chembl_id=>"CHEMBL4594284", :name=>"Tookad"}
# {:chembl_id=>"CHEMBL4594284", :name=>"Tookad", :sid=>198983722}
# write
# runnign chembl CHEMBL1060
# {:chembl_id=>"CHEMBL1060", :name=>"Neutral sod phos"}
# {:chembl_id=>"CHEMBL1060", :name=>"Neutral sod phos", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL1060
# runnign chembl CHEMBL2108311
# {:chembl_id=>"CHEMBL2108311", :name=>"Strensiq"}
# {:chembl_id=>"CHEMBL2108311", :name=>"Strensiq", :sid=>381126438}
# write
# runnign chembl CHEMBL2109198
# {:chembl_id=>"CHEMBL2109198", :name=>"Celevac"}
# {:chembl_id=>"CHEMBL2109198", :name=>"Celevac", :error=>"Error: 404 Not Found"}
# failed again for CHEMBL2109198
# runnign chembl CHEMBL4297573
# {:chembl_id=>"CHEMBL4297573", :name=>"Elzonris"}
# {:chembl_id=>"CHEMBL4297573", :name=>"Elzonris", :sid=>381128240}
# write
# runnign chembl CHEMBL441738
# {:chembl_id=>"CHEMBL441738", :name=>"Scenesse"}
# {:chembl_id=>"CHEMBL441738", :name=>"Scenesse", :sid=>363909708}
# write
# runnign chembl CHEMBL2068237
# {:chembl_id=>"CHEMBL2068237", :error=>"Error: 404 Not Found"}
# {:chembl_id=>"CHEMBL2068237", :error=>"Error: 404 Not Found", :name=>nil}
# failed again for CHEMBL2068237
# runnign chembl CHEMBL2108611
# {:chembl_id=>"CHEMBL2108611", :name=>"Besponsa"}
# {:chembl_id=>"CHEMBL2108611", :name=>"Besponsa", :sid=>135298753}
# write
# runnign chembl CHEMBL191
# {:chembl_id=>"CHEMBL191", :name=>"CHEMBL191"}
# {:chembl_id=>"CHEMBL191", :name=>"CHEMBL191", :sid=>103546496}
# write
# runnign chembl CHEMBL3990029
# {:chembl_id=>"CHEMBL3990029", :name=>"Skyrizi"}
# {:chembl_id=>"CHEMBL3990029", :name=>"Skyrizi", :sid=>310264703}
# write
