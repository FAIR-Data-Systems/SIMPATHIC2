# %% [markdown]
# Three files have disease info:
#
# disease-gene.csv
#
# disease-therapeuticarea.csv
#
# drug-disease.csv
#
# Uses ORPHA, HPO, and MONDO (or other) disease
#
# ORPHA we can keep
#
# HPO is not a disease, so make it a separate problem

# %% [markdown]
# # Radboud: map id to disease
#
# for DOID, the path is:
# DOID -> BIoPortal DOID Record (get label), follow mappings -> look for the SNOMEDCT mapping -> get ID

# %%
def efo_special_case(id)
    snomed = false
    url = "https://data.bioontology.org/ontologies/EFO/classes/http%3A%2F%2Fwww.ebi.ac.uk%2Fefo%2F#{id}?apikey=74027bd8-6be0-4329-be22-aa3717f97243"

    headers = {
    "Accept"     => "application/json",
    "User-Agent" => "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36"
    }

    begin
        response = RestClient.get(url, headers: headers)
    rescue
        return false
    end
    
    data = JSON.parse(response.body)

    if prefname = data.dig('prefLabel')
        step2 = "https://data.bioontology.org/search?q=#{prefname}&ontologies=SNOMEDCT&apikey=74027bd8-6be0-4329-be22-aa3717f97243"
#         warn "getting #{step2}"
        begin
            response = RestClient.get(step2, headers: headers)
        rescue
            return false
        end
        data = JSON.parse(response)
        records = data.dig('collection')
        records.each do |r|
#             warn r['prefLabel']
#             warn prefname
#             warn
            next unless r['prefLabel'].downcase == prefname.downcase
            snomed = r['@id']
            break
        end
    end
    if snomed
        return [id, snomed, prefname]
    else
        return false
    end
end
efo_special_case("EFO_0000713")
# Out:
# ["EFO_0000713", "http://purl.bioontology.org/ontology/SNOMEDCT/21454007", "subarachnoid hemorrhage"]

# %%
require "rest-client"
require 'json'


def map_id_to_disease(name)
  return false unless (name =~ /EFO_/ || name =~ /DOID_(.*)/ || name =~ /MONDO_(.*)/ || name =~ /Orphanet_(.*)/)
  identifier = $1
  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    if name =~ /DOID/
      url =  "https://data.bioontology.org/search?q=DOID:#{identifier}&ontologies=DOID&require_exact_match=true&apikey=#{api_key}"
    elsif name =~ /MONDO/
      url =  "https://data.bioontology.org/search?q=MONDO:#{identifier}&ontologies=MONDO&require_exact_match=true&apikey=#{api_key}"      
    else
      url =  "https://data.bioontology.org/search?q=Orphanet:#{identifier}&ontologies=ORDO&require_exact_match=true&apikey=74027bd8-6be0-4329-be22-aa3717f97243"
    end
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for #{name} #{e.inspect}\n"
    return false
  end
  mappings = []
  data = JSON.parse(response)

#  if hit = data.dig('collection', 0)
  if hit = data.dig('collection')
    hit.each do |h|
      disease_name = h&.dig('prefLabel')
      uri = h&.dig('@id')
      linksurl = h&.dig('links', 'mappings')
      mappings << { id: name, uri: uri, disease_name: disease_name, linksurl: linksurl}
    end
    return mappings
  else
    warn "No data found for #{name}\n"
    return false
  end

rescue StandardError => e
  warn "No data found for #{name} Error: #{e.inspect}\n"
  return false
end
# Out:
# :map_id_to_disease

# %%
# test
["DOID_7551", "MONDO_0003243", "Orphanet_101010"].each do |name|
  warn map_id_to_disease(name)
end
# Out:
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings"}
# {:id=>"MONDO_0003243", :uri=>"http://purl.obolibrary.org/obo/MONDO_0003243", :disease_name=>"hepatocellular clear cell carcinoma", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0003243/mappings"}
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings"}
# ["DOID_7551", "MONDO_0003243", "Orphanet_101010"]

# %%
def get_snomed_from_mapping(mapping)
  if mapping =~ /MONDO/ 
    type = "MONDO"
  else
    type = "DOID_ORDO"  # mapping =~ /Orphanet/
  end

  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    url = mapping+"?apikey=#{api_key}"
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for mapping #{e.inspect}\n"
    return false
  end
  mappings = []
  data = JSON.parse(response)

  if type == "DOID_ORDO"
    data.each do |mapp|
      mapp["classes"].each do |thisclass|
        next unless thisclass["@id"] =~ /SNOMEDCT/
        return {"snomed": thisclass["@id"]}
      end
    end
    warn "no SNOMED found for DOID/ORDO #{mapping}"
    return false
  else
    data.each do |mapp|
      mapp["classes"].each do |thisclass|
        next unless thisclass["@id"] =~ /(DOID_\d+)/  # if we start with MONDO, thre is no snomed,but there is a DOID
        doid = $1
        results = map_id_to_disease(doid) # go back to the beginning
        if results
          results = results.first # (can only be one doid)
          snomedres = get_snomed_from_mapping(results[:linksurl])  # recursive, but this time its a DOID
          if snomedres
            return snomedres  # {"snomed": thisclass["@id"]} from the routine above
          else
            warn "found no snomed for #{mapping}"
            return false
          end
        else
          warn "found no results for xreffed doid #{doid}"
          return false
        end
      end
    end
  end
    
  warn "No SNOMED found in #{mapping}\n"
  return false
rescue StandardError => e
  warn  "parsing or other error in #{mapping} Error: #{e.inspect}\n"
  return false
end
# Out:
# :get_snomed_from_mapping

# %%
# test
["DOID_7551", "MONDO_0003243", "Orphanet_101010"].each do |name|
  results = map_id_to_disease(name)
  if results
    results = results.first # (can only be one)
    nextres = get_snomed_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    end
    puts results
  else
    warn "found no results for #{name}"
  end
end
# Out:
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/15628003"}
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_5016/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0003243/mappings
# {:id=>"MONDO_0003243", :uri=>"http://purl.obolibrary.org/obo/MONDO_0003243", :disease_name=>"hepatocellular clear cell carcinoma", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0003243/mappings"}
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/763377006"}
# ["DOID_7551", "MONDO_0003243", "Orphanet_101010"]

# %%
require 'csv'

filelist = ["disease-gene.csv","disease-therapeuticarea.csv"]  # in these two it is called "source"

diseaselist = {}
filelist.each do |csvfile|
  CSV.foreach("./rawdata/#{csvfile}", headers: true) do |row|
    next if row.size < 3

    source = row['source'].strip
#     next if source =~ /HP_/
    abort unless source
    diseaselist[source] = 1
  end
end

filelist = ["drug-disease.csv"]  # in these two it is called "target"

filelist.each do |csvfile|
  CSV.foreach("./rawdata/#{csvfile}", headers: true) do |row|
    next if row.size < 3

    source = row['target'].strip
#     next if source =~ /HP_/
    abort unless source
    diseaselist[source] = 1
  end
end

puts diseaselist.length
# Out:
# 9339

# %%
# write the mapping file
f = File.open("./mappings/diseases.map", "w")
e = File.open("./mappings/diseases-errors.txt", "w")

f.write CSV.generate_line(["source","snomedct","orpha","prefname"])

# spoeial case for EFO
diseaselist.each_key do |name|
    next unless name =~ /EFO_/
    id, snomed, prefname = efo_special_case(name)
    unless id
        warn "found no snomed for links in #{name}"
        e.write "found no snomed for links in #{name}\n"
        next
    else
        orpha = "https://fake.orphanet/not-found"
        warn snomed
        f.write CSV.generate_line([id,snomed,orpha,prefname])
    end
end
        

diseaselist.each_key do |name|
  warn name
  next if name =~ /HP_/  # not HPO terms
  next if name =~ /EFO_/  # not EFO terms
  next if name =~ /OTAR_/  # not EFO terms
  
  results = map_id_to_disease(name)
  if results
    results = results.first # (can only be one)
    nextres = get_snomed_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    else
      warn "found no snomed for links in #{name}"
      e.write "found no snomed for links in #{name}\n"
    end
    snomed = results[:snomed]
    snomed = "https://fake.snomed/not-found" unless snomed
    if results[:uri] =~ /orpha/
      orpha = results[:uri]
    else
      orpha = "https://fake.orphanet/not-found"
    end
    f.write CSV.generate_line([results[:id],snomed,orpha,results[:disease_name]])
    # {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/763377006"}
  else
    warn "found no results for #{name}"
    e.write "found no results for #{name}\n"
  end
end
# Out:
# http://purl.bioontology.org/ontology/SNOMEDCT/21454007
# found no snomed for links in EFO_0001675
# found no snomed for links in EFO_0000174
# found no snomed for links in EFO_0003073
# found no snomed for links in EFO_0003075
# found no snomed for links in EFO_0000595
# http://purl.bioontology.org/ontology/SNOMEDCT/26843008
# found no snomed for links in EFO_0000233
# found no snomed for links in EFO_0003027
# http://purl.bioontology.org/ontology/SNOMEDCT/233964008
# http://purl.bioontology.org/ontology/SNOMEDCT/51608009
# found no snomed for links in EFO_0003046
# http://purl.bioontology.org/ontology/SNOMEDCT/39553005
# found no snomed for links in EFO_0003764
# http://purl.bioontology.org/ontology/SNOMEDCT/116381000119105
# found no snomed for links in EFO_0001357
# http://purl.bioontology.org/ontology/SNOMEDCT/190817009
# found no snomed for links in EFO_0002623
# found no snomed for links in EFO_0003779
# found no snomed for links in EFO_0000195
# found no snomed for links in EFO_0003812
# found no snomed for links in EFO_0002499
# http://purl.bioontology.org/ontology/SNOMEDCT/253072003
# http://purl.bioontology.org/ontology/SNOMEDCT/34713006
# http://purl.bioontology.org/ontology/SNOMEDCT/9001003
# found no snomed for links in EFO_0002628
# found no snomed for links in EFO_0003758
# http://purl.bioontology.org/ontology/SNOMEDCT/856006
# found no snomed for links in EFO_0001358
# http://purl.bioontology.org/ontology/SNOMEDCT/27849002
# http://purl.bioontology.org/ontology/SNOMEDCT/41545003
# http://purl.bioontology.org/ontology/SNOMEDCT/1290897001
# found no snomed for links in EFO_0002894
# found no snomed for links in EFO_0003759
# http://purl.bioontology.org/ontology/SNOMEDCT/413537009
# found no snomed for links in EFO_0000736
# http://purl.bioontology.org/ontology/SNOMEDCT/16985007
# http://purl.bioontology.org/ontology/SNOMEDCT/67280001
# found no snomed for links in EFO_0000614
# found no snomed for links in EFO_0001070
# found no snomed for links in EFO_0000330
# http://purl.bioontology.org/ontology/SNOMEDCT/128669006
# http://purl.bioontology.org/ontology/SNOMEDCT/1156419009
# http://purl.bioontology.org/ontology/SNOMEDCT/21560005
# http://purl.bioontology.org/ontology/SNOMEDCT/87191000119100
# found no snomed for links in EFO_0003760
# found no snomed for links in EFO_0001064
# found no snomed for links in EFO_0000504
# found no snomed for links in EFO_0000650
# found no snomed for links in EFO_0000552
# found no snomed for links in EFO_0003096
# http://purl.bioontology.org/ontology/SNOMEDCT/63449009
# found no snomed for links in EFO_0002617
# http://purl.bioontology.org/ontology/SNOMEDCT/386807006
# http://purl.bioontology.org/ontology/SNOMEDCT/403818001
# found no snomed for links in EFO_0003757
# found no snomed for links in EFO_0002546
# http://purl.bioontology.org/ontology/SNOMEDCT/116371000119107
# http://purl.bioontology.org/ontology/SNOMEDCT/310701003
# http://purl.bioontology.org/ontology/SNOMEDCT/408642003
# found no snomed for links in EFO_0000350
# http://purl.bioontology.org/ontology/SNOMEDCT/69077002
# http://purl.bioontology.org/ontology/SNOMEDCT/733471003
# found no snomed for links in EFO_0000224
# found no snomed for links in EFO_0000432
# found no snomed for links in EFO_0002614
# found no snomed for links in EFO_0002608
# found no snomed for links in EFO_0002687
# found no snomed for links in EFO_0000196
# http://purl.bioontology.org/ontology/SNOMEDCT/62479008
# http://purl.bioontology.org/ontology/SNOMEDCT/30962008
# found no snomed for links in EFO_0003149
# http://purl.bioontology.org/ontology/SNOMEDCT/30098003
# http://purl.bioontology.org/ontology/SNOMEDCT/10743008
# http://purl.bioontology.org/ontology/SNOMEDCT/34742003
# http://purl.bioontology.org/ontology/SNOMEDCT/128734000
# found no snomed for links in EFO_0000211
# found no snomed for links in EFO_0000553
# found no snomed for links in EFO_0001066
# http://purl.bioontology.org/ontology/SNOMEDCT/77489003
# http://purl.bioontology.org/ontology/SNOMEDCT/396331005
# found no snomed for links in EFO_0003766
# http://purl.bioontology.org/ontology/SNOMEDCT/128841001
# found no snomed for links in EFO_0002501
# found no snomed for links in EFO_0000778
# http://purl.bioontology.org/ontology/SNOMEDCT/56294008
# found no snomed for links in EFO_0000699
# http://purl.bioontology.org/ontology/SNOMEDCT/307651005
# http://purl.bioontology.org/ontology/SNOMEDCT/237055002
# found no snomed for links in EFO_0003084
# http://purl.bioontology.org/ontology/SNOMEDCT/22033007
# http://purl.bioontology.org/ontology/SNOMEDCT/31956009
# http://purl.bioontology.org/ontology/SNOMEDCT/61372001
# found no snomed for links in EFO_0003811
# found no snomed for links in EFO_0000225
# found no snomed for links in EFO_0000557
# found no snomed for links in EFO_0000180
# http://purl.bioontology.org/ontology/SNOMEDCT/112683004
# http://purl.bioontology.org/ontology/SNOMEDCT/238136002
# found no snomed for links in EFO_0002622
# http://purl.bioontology.org/ontology/SNOMEDCT/302914006
# http://purl.bioontology.org/ontology/SNOMEDCT/398447004
# found no snomed for links in EFO_0000404
# http://purl.bioontology.org/ontology/SNOMEDCT/266569009
# found no snomed for links in EFO_0001425
# found no snomed for links in EFO_0003802
# found no snomed for links in EFO_0009960
# found no snomed for links in EFO_0010977
# http://purl.bioontology.org/ontology/SNOMEDCT/188734009
# http://purl.bioontology.org/ontology/SNOMEDCT/4598005
# found no snomed for links in EFO_0005242
# found no snomed for links in EFO_0005556
# http://purl.bioontology.org/ontology/SNOMEDCT/36188001
# found no snomed for links in EFO_0006862
# http://purl.bioontology.org/ontology/SNOMEDCT/444717006
# http://purl.bioontology.org/ontology/SNOMEDCT/445105005
# http://purl.bioontology.org/ontology/SNOMEDCT/6381009
# found no snomed for links in EFO_1001410
# found no snomed for links in EFO_0003958
# http://purl.bioontology.org/ontology/SNOMEDCT/315345002
# found no snomed for links in EFO_0004795
# found no snomed for links in EFO_0009485
# http://purl.bioontology.org/ontology/SNOMEDCT/241975000
# found no snomed for links in EFO_0010267
# found no snomed for links in EFO_0010698
# http://purl.bioontology.org/ontology/SNOMEDCT/418930003
# found no snomed for links in EFO_1000244
# found no snomed for links in EFO_1000249
# http://purl.bioontology.org/ontology/SNOMEDCT/197315008
# found no snomed for links in EFO_1001829
# found no snomed for links in EFO_1001973
# http://purl.bioontology.org/ontology/SNOMEDCT/373717006
# http://purl.bioontology.org/ontology/SNOMEDCT/253084001
# http://purl.bioontology.org/ontology/SNOMEDCT/15244003
# found no snomed for links in EFO_0006347
# found no snomed for links in EFO_0006519
# http://purl.bioontology.org/ontology/SNOMEDCT/65457005
# found no snomed for links in EFO_0007332
# http://purl.bioontology.org/ontology/SNOMEDCT/44572005
# found no snomed for links in EFO_0010257
# found no snomed for links in EFO_1000937
# found no snomed for links in EFO_1001947
# found no snomed for links in EFO_0004191
# http://purl.bioontology.org/ontology/SNOMEDCT/276509008
# found no snomed for links in EFO_0010264
# found no snomed for links in EFO_1000991
# found no snomed for links in EFO_0003957
# http://purl.bioontology.org/ontology/SNOMEDCT/74578003
# found no snomed for links in EFO_0007312
# found no snomed for links in EFO_0008503
# found no snomed for links in EFO_0009513
# found no snomed for links in EFO_0009552
# found no snomed for links in EFO_1000118
# found no snomed for links in EFO_1000429
# http://purl.bioontology.org/ontology/SNOMEDCT/45004005
# found no snomed for links in EFO_1001985
# found no snomed for links in EFO_0005549
# http://purl.bioontology.org/ontology/SNOMEDCT/1208513005
# http://purl.bioontology.org/ontology/SNOMEDCT/404640003
# http://purl.bioontology.org/ontology/SNOMEDCT/186803007
# http://purl.bioontology.org/ontology/SNOMEDCT/416481006
# http://purl.bioontology.org/ontology/SNOMEDCT/1153570009
# found no snomed for links in EFO_0010634
# found no snomed for links in EFO_1000881
# http://purl.bioontology.org/ontology/SNOMEDCT/75570004
# http://purl.bioontology.org/ontology/SNOMEDCT/13791008
# found no snomed for links in EFO_0010279
# found no snomed for links in EFO_1000463
# found no snomed for links in EFO_1000527
# http://purl.bioontology.org/ontology/SNOMEDCT/1178986006
# found no snomed for links in EFO_1001497
# found no snomed for links in EFO_1001754
# http://purl.bioontology.org/ontology/SNOMEDCT/26158002
# found no snomed for links in EFO_0005301
# http://purl.bioontology.org/ontology/SNOMEDCT/76902006
# http://purl.bioontology.org/ontology/SNOMEDCT/33806008
# found no snomed for links in EFO_1000063
# found no snomed for links in EFO_1000587
# found no snomed for links in EFO_1000649
# found no snomed for links in EFO_1001177
# found no snomed for links in EFO_0005222
# found no snomed for links in EFO_1001441
# found no snomed for links in EFO_1001757
# found no snomed for links in EFO_1001770
# found no snomed for links in EFO_0004329
# found no snomed for links in EFO_0007311
# found no snomed for links in EFO_0007359
# http://purl.bioontology.org/ontology/SNOMEDCT/73918009
# http://purl.bioontology.org/ontology/SNOMEDCT/445227008
# found no snomed for links in EFO_1000508
# found no snomed for links in EFO_1001019
# http://purl.bioontology.org/ontology/SNOMEDCT/128351009
# found no snomed for links in EFO_0005325
# found no snomed for links in EFO_0005895
# found no snomed for links in EFO_0007208
# found no snomed for links in EFO_0007387
# found no snomed for links in EFO_0007669
# found no snomed for links in EFO_0009147
# found no snomed for links in EFO_1000140
# found no snomed for links in EFO_1000593
# http://purl.bioontology.org/ontology/SNOMEDCT/43153006
# http://purl.bioontology.org/ontology/SNOMEDCT/1332134000
# http://purl.bioontology.org/ontology/SNOMEDCT/371067004
# found no snomed for links in EFO_1001960
# http://purl.bioontology.org/ontology/SNOMEDCT/73442001
# found no snomed for links in EFO_0004350
# found no snomed for links in EFO_0004599
# http://purl.bioontology.org/ontology/SNOMEDCT/734022008
# http://purl.bioontology.org/ontology/SNOMEDCT/8260003
# http://purl.bioontology.org/ontology/SNOMEDCT/234526006
# found no snomed for links in EFO_1001422
# http://purl.bioontology.org/ontology/SNOMEDCT/6042001
# http://purl.bioontology.org/ontology/SNOMEDCT/430909002
# http://purl.bioontology.org/ontology/SNOMEDCT/15033003
# found no snomed for links in EFO_0009028
# found no snomed for links in EFO_0009615
# found no snomed for links in EFO_1000740
# http://purl.bioontology.org/ontology/SNOMEDCT/69254008
# found no snomed for links in EFO_1000911
# found no snomed for links in EFO_1001034
# http://purl.bioontology.org/ontology/SNOMEDCT/17263003
# found no snomed for links in EFO_1001302
# http://purl.bioontology.org/ontology/SNOMEDCT/22851009
# http://purl.bioontology.org/ontology/SNOMEDCT/201736002
# http://purl.bioontology.org/ontology/SNOMEDCT/734021001
# found no snomed for links in EFO_0010248
# found no snomed for links in EFO_1000032
# found no snomed for links in EFO_1001409
# http://purl.bioontology.org/ontology/SNOMEDCT/788878000
# found no snomed for links in EFO_0004233
# found no snomed for links in EFO_1001871
# found no snomed for links in EFO_0004252
# http://purl.bioontology.org/ontology/SNOMEDCT/9062008
# http://purl.bioontology.org/ontology/SNOMEDCT/372146004
# http://purl.bioontology.org/ontology/SNOMEDCT/71186008
# http://purl.bioontology.org/ontology/SNOMEDCT/367391008
# found no snomed for links in EFO_1000177
# found no snomed for links in EFO_1000272
# http://purl.bioontology.org/ontology/SNOMEDCT/414581006
# http://purl.bioontology.org/ontology/SNOMEDCT/1162933001
# http://purl.bioontology.org/ontology/SNOMEDCT/399357009
# found no snomed for links in EFO_0009472
# found no snomed for links in EFO_1000317
# found no snomed for links in EFO_1001309
# http://purl.bioontology.org/ontology/SNOMEDCT/55735004
# http://purl.bioontology.org/ontology/SNOMEDCT/237495005
# found no snomed for links in EFO_0004125
# found no snomed for links in EFO_0004278
# found no snomed for links in EFO_0007232
# found no snomed for links in EFO_0007300
# found no snomed for links in EFO_0007314
# found no snomed for links in EFO_0009706
# http://purl.bioontology.org/ontology/SNOMEDCT/65508009
# found no snomed for links in EFO_1001275
# found no snomed for links in EFO_1001371
# http://purl.bioontology.org/ontology/SNOMEDCT/277605001
# found no snomed for links in EFO_0004321
# found no snomed for links in EFO_0004686
# http://purl.bioontology.org/ontology/SNOMEDCT/128816008
# found no snomed for links in EFO_0007755
# found no snomed for links in EFO_1000206
# found no snomed for links in EFO_1000340
# found no snomed for links in EFO_1000597
# http://purl.bioontology.org/ontology/SNOMEDCT/31653004
# http://purl.bioontology.org/ontology/SNOMEDCT/123799005
# found no snomed for links in EFO_0007671
# found no snomed for links in EFO_0008618
# http://purl.bioontology.org/ontology/SNOMEDCT/1187120008
# found no snomed for links in EFO_0009842
# http://purl.bioontology.org/ontology/SNOMEDCT/32916005
# found no snomed for links in EFO_1002014
# found no snomed for links in EFO_0006792
# found no snomed for links in EFO_0007527
# http://purl.bioontology.org/ontology/SNOMEDCT/1237475006
# found no snomed for links in EFO_0009200
# found no snomed for links in EFO_1000417
# found no snomed for links in EFO_1000437
# found no snomed for links in EFO_1000807
# http://purl.bioontology.org/ontology/SNOMEDCT/1173036000
# found no snomed for links in EFO_0009158
# found no snomed for links in EFO_0010255
# found no snomed for links in EFO_0010656
# found no snomed for links in EFO_1000562
# found no snomed for links in EFO_1000633
# http://purl.bioontology.org/ontology/SNOMEDCT/65323003
# found no snomed for links in EFO_0009024
# found no snomed for links in EFO_0004562
# found no snomed for links in EFO_0008553
# found no snomed for links in EFO_0009170
# found no snomed for links in EFO_1000439
# found no snomed for links in EFO_1000511
# found no snomed for links in EFO_1000685
# found no snomed for links in EFO_1000947
# found no snomed for links in EFO_0004335
# found no snomed for links in EFO_0004714
# found no snomed for links in EFO_0010632
# http://purl.bioontology.org/ontology/SNOMEDCT/403986008
# found no snomed for links in EFO_1000584
# found no snomed for links in EFO_1000864
# http://purl.bioontology.org/ontology/SNOMEDCT/197660000
# http://purl.bioontology.org/ontology/SNOMEDCT/14756005
# found no snomed for links in EFO_0008532
# found no snomed for links in EFO_1001343
# found no snomed for links in EFO_0009301
# http://purl.bioontology.org/ontology/SNOMEDCT/277619001
# found no snomed for links in EFO_0009296
# found no snomed for links in EFO_0009780
# found no snomed for links in EFO_1000192
# found no snomed for links in EFO_1000907
# found no snomed for links in EFO_1001255
# found no snomed for links in EFO_1001983
# http://purl.bioontology.org/ontology/SNOMEDCT/8247009
# http://purl.bioontology.org/ontology/SNOMEDCT/22255007
# found no snomed for links in EFO_0009637
# found no snomed for links in EFO_0009909
# found no snomed for links in EFO_1000499
# found no snomed for links in EFO_1000509
# found no snomed for links in EFO_0005678
# found no snomed for links in EFO_0007395
# found no snomed for links in EFO_0007454
# found no snomed for links in EFO_1000131
# http://purl.bioontology.org/ontology/SNOMEDCT/35262004
# found no snomed for links in EFO_1001466
# found no snomed for links in EFO_0007262
# http://purl.bioontology.org/ontology/SNOMEDCT/77377001
# found no snomed for links in EFO_0010652
# http://purl.bioontology.org/ontology/SNOMEDCT/1156451005
# http://purl.bioontology.org/ontology/SNOMEDCT/235110008
# http://purl.bioontology.org/ontology/SNOMEDCT/420422005
# http://purl.bioontology.org/ontology/SNOMEDCT/52072009
# http://purl.bioontology.org/ontology/SNOMEDCT/3951002
# http://purl.bioontology.org/ontology/SNOMEDCT/237613005
# found no snomed for links in EFO_0010266
# found no snomed for links in EFO_0010269
# found no snomed for links in EFO_1000112
# found no snomed for links in EFO_1000319
# found no snomed for links in EFO_1000595
# found no snomed for links in EFO_1001905
# found no snomed for links in EFO_1001939
# http://purl.bioontology.org/ontology/SNOMEDCT/23502006
# http://purl.bioontology.org/ontology/SNOMEDCT/88092000
# found no snomed for links in EFO_1000100
# found no snomed for links in EFO_1000456
# found no snomed for links in EFO_1001169
# found no snomed for links in EFO_0005288
# found no snomed for links in EFO_0006994
# found no snomed for links in EFO_1000543
# found no snomed for links in EFO_1002040
# http://purl.bioontology.org/ontology/SNOMEDCT/30911005
# http://purl.bioontology.org/ontology/SNOMEDCT/384709000
# found no snomed for links in EFO_0010661
# found no snomed for links in EFO_0005526
# http://purl.bioontology.org/ontology/SNOMEDCT/55907008
# found no snomed for links in EFO_0006995
# found no snomed for links in EFO_1000129
# found no snomed for links in EFO_1000945
# found no snomed for links in EFO_0005529
# http://purl.bioontology.org/ontology/SNOMEDCT/128922003
# http://purl.bioontology.org/ontology/SNOMEDCT/128814006
# found no snomed for links in EFO_0009008
# http://purl.bioontology.org/ontology/SNOMEDCT/65399007
# found no snomed for links in EFO_1001351
# http://purl.bioontology.org/ontology/SNOMEDCT/5370000
# found no snomed for links in EFO_0006865
# found no snomed for links in EFO_0009573
# http://purl.bioontology.org/ontology/SNOMEDCT/83225003
# found no snomed for links in EFO_1000254
# http://purl.bioontology.org/ontology/SNOMEDCT/44730006
# found no snomed for links in EFO_1001826
# found no snomed for links in EFO_0004318
# found no snomed for links in EFO_0005555
# found no snomed for links in EFO_0005924
# found no snomed for links in EFO_1000322
# found no snomed for links in EFO_0004875
# found no snomed for links in EFO_0007135
# http://purl.bioontology.org/ontology/SNOMEDCT/237292005
# found no snomed for links in EFO_1000138
# found no snomed for links in EFO_1000506
# found no snomed for links in EFO_1001461
# found no snomed for links in EFO_1001495
# found no snomed for links in EFO_1001953
# found no snomed for links in EFO_0009907
# found no snomed for links in EFO_1000150
# http://purl.bioontology.org/ontology/SNOMEDCT/112681002
# found no snomed for links in EFO_1001999
# http://purl.bioontology.org/ontology/SNOMEDCT/271558008
# http://purl.bioontology.org/ontology/SNOMEDCT/415238003
# found no snomed for links in EFO_0010655
# http://purl.bioontology.org/ontology/SNOMEDCT/198324001
# found no snomed for links in EFO_1001305
# found no snomed for links in EFO_1001919
# http://purl.bioontology.org/ontology/SNOMEDCT/203082005
# http://purl.bioontology.org/ontology/SNOMEDCT/85005007
# http://purl.bioontology.org/ontology/SNOMEDCT/314757003
# found no snomed for links in EFO_0008623
# found no snomed for links in EFO_1000405
# found no snomed for links in EFO_1000524
# found no snomed for links in EFO_1000572
# found no snomed for links in EFO_1000575
# found no snomed for links in EFO_1001979
# found no snomed for links in EFO_0004708
# http://purl.bioontology.org/ontology/SNOMEDCT/26065007
# http://purl.bioontology.org/ontology/SNOMEDCT/76627001
# http://purl.bioontology.org/ontology/SNOMEDCT/237816004
# found no snomed for links in EFO_0009299
# found no snomed for links in EFO_0010166
# found no snomed for links in EFO_0010252
# http://purl.bioontology.org/ontology/SNOMEDCT/419327006
# found no snomed for links in EFO_1000515
# found no snomed for links in EFO_1000559
# found no snomed for links in EFO_1001331
# http://purl.bioontology.org/ontology/SNOMEDCT/56727007
# http://purl.bioontology.org/ontology/SNOMEDCT/59051007
# http://purl.bioontology.org/ontology/SNOMEDCT/76783007
# http://purl.bioontology.org/ontology/SNOMEDCT/36024000
# found no snomed for links in EFO_0008579
# found no snomed for links in EFO_0009867
# found no snomed for links in EFO_1001328
# http://purl.bioontology.org/ontology/SNOMEDCT/240413000
# http://purl.bioontology.org/ontology/SNOMEDCT/230248006
# found no snomed for links in EFO_1000029
# found no snomed for links in EFO_1000126
# found no snomed for links in EFO_1000137
# http://purl.bioontology.org/ontology/SNOMEDCT/127962001
# http://purl.bioontology.org/ontology/SNOMEDCT/1187071008
# http://purl.bioontology.org/ontology/SNOMEDCT/55827005
# found no snomed for links in EFO_0004593
# found no snomed for links in EFO_0006740
# found no snomed for links in EFO_1000287
# http://purl.bioontology.org/ontology/SNOMEDCT/55333008
# found no snomed for links in EFO_1000666
# http://purl.bioontology.org/ontology/SNOMEDCT/32620007
# found no snomed for links in EFO_1001865
# found no snomed for links in EFO_0003949
# found no snomed for links in EFO_0005296
# found no snomed for links in EFO_0006352
# http://purl.bioontology.org/ontology/SNOMEDCT/63479002
# found no snomed for links in EFO_0010258
# found no snomed for links in EFO_1000058
# found no snomed for links in EFO_1000135
# http://purl.bioontology.org/ontology/SNOMEDCT/206292002
# found no snomed for links in EFO_1001092
# found no snomed for links in EFO_1001110
# found no snomed for links in EFO_1001249
# http://purl.bioontology.org/ontology/SNOMEDCT/19311003
# http://purl.bioontology.org/ontology/SNOMEDCT/235917005
# found no snomed for links in EFO_0007501
# found no snomed for links in EFO_1000171
# found no snomed for links in EFO_1000612
# found no snomed for links in EFO_0006511
# http://purl.bioontology.org/ontology/SNOMEDCT/56364004
# found no snomed for links in EFO_0003895
# http://purl.bioontology.org/ontology/SNOMEDCT/84027009
# http://purl.bioontology.org/ontology/SNOMEDCT/128773000
# found no snomed for links in EFO_1000603
# found no snomed for links in EFO_1001221
# http://purl.bioontology.org/ontology/SNOMEDCT/233607000
# found no snomed for links in EFO_1001957
# found no snomed for links in EFO_0005039
# http://purl.bioontology.org/ontology/SNOMEDCT/128788005
# found no snomed for links in EFO_0005622
# http://purl.bioontology.org/ontology/SNOMEDCT/75702008
# http://purl.bioontology.org/ontology/SNOMEDCT/267038008
# http://purl.bioontology.org/ontology/SNOMEDCT/6574001
# found no snomed for links in EFO_1000982
# http://purl.bioontology.org/ontology/SNOMEDCT/129618003
# http://purl.bioontology.org/ontology/SNOMEDCT/13507004
# http://purl.bioontology.org/ontology/SNOMEDCT/233707008
# found no snomed for links in EFO_0007178
# found no snomed for links in EFO_0009162
# found no snomed for links in EFO_1000191
# found no snomed for links in EFO_1000264
# found no snomed for links in EFO_1000440
# found no snomed for links in EFO_1000496
# http://purl.bioontology.org/ontology/SNOMEDCT/128735004
# http://purl.bioontology.org/ontology/SNOMEDCT/235876009
# http://purl.bioontology.org/ontology/SNOMEDCT/400130008
# found no snomed for links in EFO_1001818
# http://purl.bioontology.org/ontology/SNOMEDCT/12962009
# found no snomed for links in EFO_0007425
# found no snomed for links in EFO_1000845
# http://purl.bioontology.org/ontology/SNOMEDCT/58381000
# http://purl.bioontology.org/ontology/SNOMEDCT/25239006
# http://purl.bioontology.org/ontology/SNOMEDCT/11381005
# http://purl.bioontology.org/ontology/SNOMEDCT/445338005
# found no snomed for links in EFO_0007148
# found no snomed for links in EFO_0007173
# http://purl.bioontology.org/ontology/SNOMEDCT/5217008
# found no snomed for links in EFO_0008502
# found no snomed for links in EFO_1000885
# found no snomed for links in EFO_1000954
# found no snomed for links in EFO_1001121
# http://purl.bioontology.org/ontology/SNOMEDCT/87764000
# found no snomed for links in EFO_1001451
# found no snomed for links in EFO_1001978
# found no snomed for links in EFO_0007343
# http://purl.bioontology.org/ontology/SNOMEDCT/6020002
# found no snomed for links in EFO_0009447
# found no snomed for links in EFO_0009845
# http://purl.bioontology.org/ontology/SNOMEDCT/13583002
# found no snomed for links in EFO_1000517
# found no snomed for links in EFO_1000565
# http://purl.bioontology.org/ontology/SNOMEDCT/25690000
# http://purl.bioontology.org/ontology/SNOMEDCT/50490005
# http://purl.bioontology.org/ontology/SNOMEDCT/95550001
# found no snomed for links in EFO_1002028
# found no snomed for links in EFO_0005557
# found no snomed for links in EFO_1000401
# found no snomed for links in EFO_1001471
# found no snomed for links in EFO_1001916
# found no snomed for links in EFO_1001942
# http://purl.bioontology.org/ontology/SNOMEDCT/57406009
# http://purl.bioontology.org/ontology/SNOMEDCT/32456001
# http://purl.bioontology.org/ontology/SNOMEDCT/444150000
# http://purl.bioontology.org/ontology/SNOMEDCT/4584002
# found no snomed for links in EFO_0009441
# http://purl.bioontology.org/ontology/SNOMEDCT/863954001
# found no snomed for links in EFO_1001989
# http://purl.bioontology.org/ontology/SNOMEDCT/57606003
# found no snomed for links in EFO_1000619
# http://purl.bioontology.org/ontology/SNOMEDCT/63166000
# http://purl.bioontology.org/ontology/SNOMEDCT/230350000
# found no snomed for links in EFO_0004723
# http://purl.bioontology.org/ontology/SNOMEDCT/370534002
# found no snomed for links in EFO_0007147
# http://purl.bioontology.org/ontology/SNOMEDCT/230456007
# found no snomed for links in EFO_0008533
# http://purl.bioontology.org/ontology/SNOMEDCT/300920004
# found no snomed for links in EFO_0010567
# found no snomed for links in EFO_1000583
# found no snomed for links in EFO_1000906
# found no snomed for links in EFO_1001120
# found no snomed for links in EFO_0005717
# found no snomed for links in EFO_0007919
# found no snomed for links in EFO_0008504
# found no snomed for links in EFO_1000505
# found no snomed for links in EFO_0006344
# found no snomed for links in EFO_0007290
# found no snomed for links in EFO_0008523
# found no snomed for links in EFO_1001515
# found no snomed for links in EFO_0003855
# found no snomed for links in EFO_0004683
# http://purl.bioontology.org/ontology/SNOMEDCT/127012008
# http://purl.bioontology.org/ontology/SNOMEDCT/80908008
# found no snomed for links in EFO_0009094
# found no snomed for links in EFO_0009432
# found no snomed for links in EFO_0009614
# found no snomed for links in EFO_0010658
# found no snomed for links in EFO_1001927
# http://purl.bioontology.org/ontology/SNOMEDCT/4834000
# http://purl.bioontology.org/ontology/SNOMEDCT/311000119101
# found no snomed for links in EFO_1000030
# found no snomed for links in EFO_0005752
# found no snomed for links in EFO_0008545
# found no snomed for links in EFO_0009021
# found no snomed for links in EFO_0010663
# http://purl.bioontology.org/ontology/SNOMEDCT/116063003
# found no snomed for links in EFO_1000314
# found no snomed for links in EFO_1000324
# found no snomed for links in EFO_1001359
# found no snomed for links in EFO_0007224
# http://purl.bioontology.org/ontology/SNOMEDCT/271425001
# http://purl.bioontology.org/ontology/SNOMEDCT/371596008
# found no snomed for links in EFO_0007244
# http://purl.bioontology.org/ontology/SNOMEDCT/71906005
# found no snomed for links in EFO_0007444
# found no snomed for links in EFO_1000043
# found no snomed for links in EFO_1000156
# http://purl.bioontology.org/ontology/SNOMEDCT/128685001
# http://purl.bioontology.org/ontology/SNOMEDCT/44524009
# found no snomed for links in EFO_1001364
# found no snomed for links in EFO_0007537
# found no snomed for links in EFO_0009888
# http://purl.bioontology.org/ontology/SNOMEDCT/128800006
# found no snomed for links in EFO_1001202
# found no snomed for links in EFO_1001228
# found no snomed for links in EFO_1001361
# found no snomed for links in EFO_1001516
# http://purl.bioontology.org/ontology/SNOMEDCT/445187004
# found no snomed for links in EFO_0004653
# found no snomed for links in EFO_0005624
# http://purl.bioontology.org/ontology/SNOMEDCT/86500004
# found no snomed for links in EFO_0007483
# http://purl.bioontology.org/ontology/SNOMEDCT/428700003
# found no snomed for links in EFO_0009135
# found no snomed for links in EFO_0009254
# found no snomed for links in EFO_1000250
# http://purl.bioontology.org/ontology/SNOMEDCT/722872000
# found no snomed for links in EFO_0005400
# http://purl.bioontology.org/ontology/SNOMEDCT/23412002
# found no snomed for links in EFO_0009144
# found no snomed for links in EFO_1000368
# http://purl.bioontology.org/ontology/SNOMEDCT/404078000
# found no snomed for links in EFO_1001017
# http://purl.bioontology.org/ontology/SNOMEDCT/28670008
# found no snomed for links in EFO_1000332
# http://purl.bioontology.org/ontology/SNOMEDCT/73893000
# found no snomed for links in EFO_0009478
# found no snomed for links in EFO_1000569
# found no snomed for links in EFO_1001486
# found no snomed for links in EFO_0007585
# found no snomed for links in EFO_0007887
# found no snomed for links in EFO_0009677
# found no snomed for links in EFO_0010738
# found no snomed for links in EFO_1000084
# http://purl.bioontology.org/ontology/SNOMEDCT/373639002
# found no snomed for links in EFO_0007243
# found no snomed for links in EFO_0010820
# http://purl.bioontology.org/ontology/SNOMEDCT/726531007
# http://purl.bioontology.org/ontology/SNOMEDCT/51169003
# found no snomed for links in EFO_0007386
# http://purl.bioontology.org/ontology/SNOMEDCT/22754005
# http://purl.bioontology.org/ontology/SNOMEDCT/53132006
# http://purl.bioontology.org/ontology/SNOMEDCT/25723000
# found no snomed for links in EFO_0008586
# found no snomed for links in EFO_0009846
# found no snomed for links in EFO_1000256
# found no snomed for links in EFO_1000259
# http://purl.bioontology.org/ontology/SNOMEDCT/1144922006
# http://purl.bioontology.org/ontology/SNOMEDCT/53597009
# found no snomed for links in EFO_1000789
# http://purl.bioontology.org/ontology/SNOMEDCT/40225001
# http://purl.bioontology.org/ontology/SNOMEDCT/89555002
# http://purl.bioontology.org/ontology/SNOMEDCT/236706006
# found no snomed for links in EFO_0009152
# found no snomed for links in EFO_0009658
# http://purl.bioontology.org/ontology/SNOMEDCT/241006
# found no snomed for links in EFO_1001307
# http://purl.bioontology.org/ontology/SNOMEDCT/9713002
# http://purl.bioontology.org/ontology/SNOMEDCT/53622003
# found no snomed for links in EFO_0010062
# http://purl.bioontology.org/ontology/SNOMEDCT/1237359009
# found no snomed for links in EFO_1001870
# found no snomed for links in EFO_0004906
# found no snomed for links in EFO_0007287
# found no snomed for links in EFO_0008490
# http://purl.bioontology.org/ontology/SNOMEDCT/445237003
# found no snomed for links in EFO_0009954
# found no snomed for links in EFO_0010164
# found no snomed for links in EFO_1000286
# found no snomed for links in EFO_1000594
# found no snomed for links in EFO_1000941
# found no snomed for links in EFO_1001257
# found no snomed for links in EFO_1001792
# http://purl.bioontology.org/ontology/SNOMEDCT/128763002
# found no snomed for links in EFO_0010168
# http://purl.bioontology.org/ontology/SNOMEDCT/399165002
# found no snomed for links in EFO_1001256
# found no snomed for links in EFO_0004645
# http://purl.bioontology.org/ontology/SNOMEDCT/231896005
# found no snomed for links in EFO_1000081
# found no snomed for links in EFO_1000985
# found no snomed for links in EFO_0004249
# http://purl.bioontology.org/ontology/SNOMEDCT/396285007
# found no snomed for links in EFO_0008572
# http://purl.bioontology.org/ontology/SNOMEDCT/70933002
# http://purl.bioontology.org/ontology/SNOMEDCT/186788009
# found no snomed for links in EFO_0008324
# found no snomed for links in EFO_0009140
# found no snomed for links in EFO_1000854
# found no snomed for links in EFO_1000965
# found no snomed for links in EFO_1001378
# http://purl.bioontology.org/ontology/SNOMEDCT/14527007
# found no snomed for links in EFO_0009141
# http://purl.bioontology.org/ontology/SNOMEDCT/398019008
# found no snomed for links in EFO_1000127
# found no snomed for links in EFO_1001893
# found no snomed for links in EFO_0003907
# found no snomed for links in EFO_0004194
# http://purl.bioontology.org/ontology/SNOMEDCT/416010008
# found no snomed for links in EFO_0005223
# found no snomed for links in EFO_0006912
# found no snomed for links in EFO_0008484
# http://purl.bioontology.org/ontology/SNOMEDCT/2142002
# found no snomed for links in EFO_0009166
# found no snomed for links in EFO_0009463
# found no snomed for links in EFO_1000090
# found no snomed for links in EFO_1001106
# found no snomed for links in EFO_1002008
# http://purl.bioontology.org/ontology/SNOMEDCT/22607003
# found no snomed for links in EFO_0007415
# found no snomed for links in EFO_0009276
# http://purl.bioontology.org/ontology/SNOMEDCT/47821001
# found no snomed for links in EFO_0010178
# found no snomed for links in EFO_1001093
# http://purl.bioontology.org/ontology/SNOMEDCT/719218000
# found no snomed for links in EFO_1002011
# found no snomed for links in EFO_0007285
# found no snomed for links in EFO_0007381
# found no snomed for links in EFO_0007406
# http://purl.bioontology.org/ontology/SNOMEDCT/27355003
# found no snomed for links in EFO_1000402
# found no snomed for links in EFO_1001365
# found no snomed for links in EFO_1001450
# http://purl.bioontology.org/ontology/SNOMEDCT/21897009
# found no snomed for links in EFO_0004596
# found no snomed for links in EFO_0006718
# found no snomed for links in EFO_0007383
# found no snomed for links in EFO_1000071
# found no snomed for links in EFO_1000357
# http://purl.bioontology.org/ontology/SNOMEDCT/402415001
# http://purl.bioontology.org/ontology/SNOMEDCT/68158006
# http://purl.bioontology.org/ontology/SNOMEDCT/74400008
# found no snomed for links in EFO_0007487
# found no snomed for links in EFO_0009836
# found no snomed for links in EFO_0009866
# found no snomed for links in EFO_1000494
# http://purl.bioontology.org/ontology/SNOMEDCT/57653000
# found no snomed for links in EFO_1001934
# found no snomed for links in EFO_0004616
# found no snomed for links in EFO_0004888
# http://purl.bioontology.org/ontology/SNOMEDCT/235049008
# http://purl.bioontology.org/ontology/SNOMEDCT/35154004
# found no snomed for links in EFO_1000270
# found no snomed for links in EFO_1000588
# http://purl.bioontology.org/ontology/SNOMEDCT/253006001
# http://purl.bioontology.org/ontology/SNOMEDCT/72000004
# http://purl.bioontology.org/ontology/SNOMEDCT/87730004
# found no snomed for links in EFO_0006719
# http://purl.bioontology.org/ontology/SNOMEDCT/19065005
# found no snomed for links in EFO_0008628
# found no snomed for links in EFO_0009071
# found no snomed for links in EFO_1000012
# found no snomed for links in EFO_1000080
# found no snomed for links in EFO_1000321
# found no snomed for links in EFO_1001132
# found no snomed for links in EFO_0005427
# found no snomed for links in EFO_0007503
# found no snomed for links in EFO_0009155
# found no snomed for links in EFO_1000066
# found no snomed for links in EFO_1001060
# found no snomed for links in EFO_0004330
# http://purl.bioontology.org/ontology/SNOMEDCT/128914005
# http://purl.bioontology.org/ontology/SNOMEDCT/511008
# found no snomed for links in EFO_1000275
# found no snomed for links in EFO_1000564
# http://purl.bioontology.org/ontology/SNOMEDCT/30265004
# found no snomed for links in EFO_1000961
# http://purl.bioontology.org/ontology/SNOMEDCT/238149007
# found no snomed for links in EFO_0003964
# http://purl.bioontology.org/ontology/SNOMEDCT/14232007
# found no snomed for links in EFO_0007634
# found no snomed for links in EFO_0009446
# found no snomed for links in EFO_0010970
# found no snomed for links in EFO_1000308
# http://purl.bioontology.org/ontology/SNOMEDCT/20813000
# http://purl.bioontology.org/ontology/SNOMEDCT/38739001
# found no snomed for links in EFO_1001068
# http://purl.bioontology.org/ontology/SNOMEDCT/432261003
# http://purl.bioontology.org/ontology/SNOMEDCT/717780007
# found no snomed for links in EFO_0007488
# found no snomed for links in EFO_0009322
# found no snomed for links in EFO_0010648
# http://purl.bioontology.org/ontology/SNOMEDCT/400031009
# http://purl.bioontology.org/ontology/SNOMEDCT/76060004
# http://purl.bioontology.org/ontology/SNOMEDCT/708248004
# found no snomed for links in EFO_1001366
# http://purl.bioontology.org/ontology/SNOMEDCT/19265001
# http://purl.bioontology.org/ontology/SNOMEDCT/280137006
# http://purl.bioontology.org/ontology/SNOMEDCT/276638004
# found no snomed for links in EFO_0003874
# found no snomed for links in EFO_0009049
# found no snomed for links in EFO_0009443
# found no snomed for links in EFO_0009692
# found no snomed for links in EFO_0009958
# http://purl.bioontology.org/ontology/SNOMEDCT/64967004
# http://purl.bioontology.org/ontology/SNOMEDCT/56478004
# found no snomed for links in EFO_1001952
# http://purl.bioontology.org/ontology/SNOMEDCT/247398009
# found no snomed for links in EFO_0007313
# http://purl.bioontology.org/ontology/SNOMEDCT/1172844009
# found no snomed for links in EFO_0009300
# http://purl.bioontology.org/ontology/SNOMEDCT/87715008
# http://purl.bioontology.org/ontology/SNOMEDCT/38727009
# http://purl.bioontology.org/ontology/SNOMEDCT/9631008
# found no snomed for links in EFO_0007426
# http://purl.bioontology.org/ontology/SNOMEDCT/397825006
# found no snomed for links in EFO_1000199
# found no snomed for links in EFO_1000579
# found no snomed for links in EFO_1001390
# http://purl.bioontology.org/ontology/SNOMEDCT/109333005
# http://purl.bioontology.org/ontology/SNOMEDCT/202882003
# http://purl.bioontology.org/ontology/SNOMEDCT/413758000
# http://purl.bioontology.org/ontology/SNOMEDCT/367498001
# found no snomed for links in EFO_0004895
# found no snomed for links in EFO_0007418
# found no snomed for links in EFO_0009881
# http://purl.bioontology.org/ontology/SNOMEDCT/48532005
# found no snomed for links in EFO_1000435
# found no snomed for links in EFO_1000466
# http://purl.bioontology.org/ontology/SNOMEDCT/12818004
# http://purl.bioontology.org/ontology/SNOMEDCT/73415002
# found no snomed for links in EFO_0005840
# http://purl.bioontology.org/ontology/SNOMEDCT/37981002
# http://purl.bioontology.org/ontology/SNOMEDCT/76107001
# found no snomed for links in EFO_0010665
# http://purl.bioontology.org/ontology/SNOMEDCT/238124008
# found no snomed for links in EFO_1000338
# found no snomed for links in EFO_1001945
# http://purl.bioontology.org/ontology/SNOMEDCT/58405006
# found no snomed for links in EFO_0009383
# found no snomed for links in EFO_1001489
# found no snomed for links in EFO_1001827
# found no snomed for links in EFO_1001917
# http://purl.bioontology.org/ontology/SNOMEDCT/441541008
# http://purl.bioontology.org/ontology/SNOMEDCT/723826007
# found no snomed for links in EFO_0009146
# found no snomed for links in EFO_0009298
# found no snomed for links in EFO_0010280
# found no snomed for links in EFO_1000037
# found no snomed for links in EFO_1000598
# http://purl.bioontology.org/ontology/SNOMEDCT/61599003
# found no snomed for links in EFO_1001974
# http://purl.bioontology.org/ontology/SNOMEDCT/90560007
# http://purl.bioontology.org/ontology/SNOMEDCT/250978003
# found no snomed for links in EFO_0007463
# http://purl.bioontology.org/ontology/SNOMEDCT/8229003
# found no snomed for links in EFO_0009363
# found no snomed for links in EFO_0010276
# found no snomed for links in EFO_1000386
# found no snomed for links in EFO_1000623
# found no snomed for links in EFO_1000935
# found no snomed for links in EFO_0005542
# http://purl.bioontology.org/ontology/SNOMEDCT/716864001
# found no snomed for links in EFO_1000766
# found no snomed for links in EFO_1000883
# found no snomed for links in EFO_1001324
# http://purl.bioontology.org/ontology/SNOMEDCT/11543004
# found no snomed for links in EFO_0007369
# found no snomed for links in EFO_0008516
# found no snomed for links in EFO_0008556
# found no snomed for links in EFO_0009687
# found no snomed for links in EFO_1000075
# found no snomed for links in EFO_1000486
# http://purl.bioontology.org/ontology/SNOMEDCT/9418005
# found no snomed for links in EFO_1001812
# found no snomed for links in EFO_0003924
# found no snomed for links in EFO_0004220
# found no snomed for links in EFO_0004997
# found no snomed for links in EFO_0005783
# found no snomed for links in EFO_1000461
# http://purl.bioontology.org/ontology/SNOMEDCT/232016005
# http://purl.bioontology.org/ontology/SNOMEDCT/1059007
# http://purl.bioontology.org/ontology/SNOMEDCT/89906000
# http://purl.bioontology.org/ontology/SNOMEDCT/787787004
# found no snomed for links in EFO_0007183
# http://purl.bioontology.org/ontology/SNOMEDCT/1187470001
# found no snomed for links in EFO_0009130
# http://purl.bioontology.org/ontology/SNOMEDCT/278401004
# http://purl.bioontology.org/ontology/SNOMEDCT/58961005
# http://purl.bioontology.org/ontology/SNOMEDCT/404083008
# found no snomed for links in EFO_1000303
# found no snomed for links in EFO_1000409
# found no snomed for links in EFO_1000786
# found no snomed for links in EFO_1001935
# http://purl.bioontology.org/ontology/SNOMEDCT/47604008
# found no snomed for links in EFO_0009016
# found no snomed for links in EFO_0009715
# found no snomed for links in EFO_1000550
# http://purl.bioontology.org/ontology/SNOMEDCT/128209004
# found no snomed for links in EFO_1001500
# found no snomed for links in EFO_0007272
# found no snomed for links in EFO_0009316
# found no snomed for links in EFO_0009459
# found no snomed for links in EFO_0009515
# http://purl.bioontology.org/ontology/SNOMEDCT/441698009
# http://purl.bioontology.org/ontology/SNOMEDCT/39471001
# found no snomed for links in EFO_1000252
# http://purl.bioontology.org/ontology/SNOMEDCT/1234750000
# http://purl.bioontology.org/ontology/SNOMEDCT/197834003
# http://purl.bioontology.org/ontology/SNOMEDCT/38617005
# http://purl.bioontology.org/ontology/SNOMEDCT/49650001
# found no snomed for links in EFO_0005225
# found no snomed for links in EFO_0007445
# found no snomed for links in EFO_0008585
# found no snomed for links in EFO_0009046
# http://purl.bioontology.org/ontology/SNOMEDCT/768470007
# http://purl.bioontology.org/ontology/SNOMEDCT/52299001
# found no snomed for links in EFO_1000708
# found no snomed for links in EFO_1000848
# http://purl.bioontology.org/ontology/SNOMEDCT/45688009
# found no snomed for links in EFO_1001235
# http://purl.bioontology.org/ontology/SNOMEDCT/52441000
# found no snomed for links in EFO_1001787
# found no snomed for links in EFO_0003876
# found no snomed for links in EFO_0005524
# found no snomed for links in EFO_0005756
# found no snomed for links in EFO_0009870
# found no snomed for links in EFO_1000120
# found no snomed for links in EFO_1000358
# http://purl.bioontology.org/ontology/SNOMEDCT/68225006
# http://purl.bioontology.org/ontology/SNOMEDCT/473460002
# http://purl.bioontology.org/ontology/SNOMEDCT/87642003
# found no snomed for links in EFO_0010561
# found no snomed for links in EFO_1000838
# found no snomed for links in EFO_0009040
# http://purl.bioontology.org/ontology/SNOMEDCT/277158007
# http://purl.bioontology.org/ontology/SNOMEDCT/68944005
# found no snomed for links in EFO_1001012
# http://purl.bioontology.org/ontology/SNOMEDCT/30753002
# found no snomed for links in EFO_0007379
# found no snomed for links in EFO_0007506
# found no snomed for links in EFO_1000183
# http://purl.bioontology.org/ontology/SNOMEDCT/24976005
# found no snomed for links in EFO_1002030
# found no snomed for links in EFO_0004826
# http://purl.bioontology.org/ontology/SNOMEDCT/17382005
# http://purl.bioontology.org/ontology/SNOMEDCT/1208516002
# http://purl.bioontology.org/ontology/SNOMEDCT/35885006
# found no snomed for links in EFO_0009625
# found no snomed for links in EFO_1000139
# http://purl.bioontology.org/ontology/SNOMEDCT/14094001
# http://purl.bioontology.org/ontology/SNOMEDCT/24327009
# found no snomed for links in EFO_1001382
# http://purl.bioontology.org/ontology/SNOMEDCT/394659003
# http://purl.bioontology.org/ontology/SNOMEDCT/63480004
# http://purl.bioontology.org/ontology/SNOMEDCT/192970008
# found no snomed for links in EFO_0009044
# found no snomed for links in EFO_0009138
# found no snomed for links in EFO_1000483
# http://purl.bioontology.org/ontology/SNOMEDCT/80138003
# found no snomed for links in EFO_1002029
# found no snomed for links in EFO_0003922
# found no snomed for links in EFO_0005560
# found no snomed for links in EFO_0007160
# http://purl.bioontology.org/ontology/SNOMEDCT/1187537008
# http://purl.bioontology.org/ontology/SNOMEDCT/1290969006
# found no snomed for links in EFO_1000827
# http://purl.bioontology.org/ontology/SNOMEDCT/79268002
# found no snomed for links in EFO_0004228
# found no snomed for links in EFO_0009026
# found no snomed for links in EFO_0009732
# found no snomed for links in EFO_0009759
# found no snomed for links in EFO_0010653
# http://purl.bioontology.org/ontology/SNOMEDCT/27194006
# http://purl.bioontology.org/ontology/SNOMEDCT/16726004
# http://purl.bioontology.org/ontology/SNOMEDCT/415297005
# http://purl.bioontology.org/ontology/SNOMEDCT/76571007
# found no snomed for links in EFO_0009093
# found no snomed for links in EFO_0009951
# http://purl.bioontology.org/ontology/SNOMEDCT/31671006
# http://purl.bioontology.org/ontology/SNOMEDCT/772791006
# found no snomed for links in EFO_1000946
# found no snomed for links in EFO_1000950
# found no snomed for links in EFO_1001797
# http://purl.bioontology.org/ontology/SNOMEDCT/263134008
# found no snomed for links in EFO_0005410
# http://purl.bioontology.org/ontology/SNOMEDCT/192685000
# found no snomed for links in EFO_0007543
# found no snomed for links in EFO_1000107
# found no snomed for links in EFO_1000323
# found no snomed for links in EFO_1001096
# found no snomed for links in EFO_1001492
# found no snomed for links in EFO_1001857
# found no snomed for links in EFO_0005801
# found no snomed for links in EFO_0009009
# http://purl.bioontology.org/ontology/SNOMEDCT/109843000
# found no snomed for links in EFO_1000433
# http://purl.bioontology.org/ontology/SNOMEDCT/76169001
# http://purl.bioontology.org/ontology/SNOMEDCT/232035005
# http://purl.bioontology.org/ontology/SNOMEDCT/28651003
# found no snomed for links in EFO_1000502
# http://purl.bioontology.org/ontology/SNOMEDCT/277567002
# found no snomed for links in EFO_0004127
# found no snomed for links in EFO_0007495
# found no snomed for links in EFO_0009462
# http://purl.bioontology.org/ontology/SNOMEDCT/9092004
# found no snomed for links in EFO_1000611
# http://purl.bioontology.org/ontology/SNOMEDCT/203646004
# found no snomed for links in EFO_0009169
# found no snomed for links in EFO_1000348
# found no snomed for links in EFO_1000534
# found no snomed for links in EFO_1001006
# http://purl.bioontology.org/ontology/SNOMEDCT/230769007
# http://purl.bioontology.org/ontology/SNOMEDCT/425333006
# http://purl.bioontology.org/ontology/SNOMEDCT/240849009
# found no snomed for links in EFO_0007925
# found no snomed for links in EFO_0009048
# found no snomed for links in EFO_0009878
# found no snomed for links in EFO_1000367
# found no snomed for links in EFO_1001830
# found no snomed for links in EFO_0004246
# http://purl.bioontology.org/ontology/SNOMEDCT/404056007
# found no snomed for links in EFO_0007207
# found no snomed for links in EFO_0007520
# http://purl.bioontology.org/ontology/SNOMEDCT/128790006
# found no snomed for links in EFO_0009277
# found no snomed for links in EFO_0009570
# found no snomed for links in EFO_1001223
# found no snomed for links in EFO_1001799
# http://purl.bioontology.org/ontology/SNOMEDCT/238516007
# http://purl.bioontology.org/ontology/SNOMEDCT/69996000
# found no snomed for links in EFO_0010130
# http://purl.bioontology.org/ontology/SNOMEDCT/386766007
# found no snomed for links in EFO_0004591
# found no snomed for links in EFO_0004799
# found no snomed for links in EFO_0007768
# found no snomed for links in EFO_0009523
# found no snomed for links in EFO_0009911
# found no snomed for links in EFO_1000196
# found no snomed for links in EFO_1000510
# found no snomed for links in EFO_1000662
# http://purl.bioontology.org/ontology/SNOMEDCT/50485007
# http://purl.bioontology.org/ontology/SNOMEDCT/111488004
# http://purl.bioontology.org/ontology/SNOMEDCT/425500002
# http://purl.bioontology.org/ontology/SNOMEDCT/404227002
# found no snomed for links in EFO_1000294
# http://purl.bioontology.org/ontology/SNOMEDCT/72275000
# http://purl.bioontology.org/ontology/SNOMEDCT/48167000
# found no snomed for links in EFO_0004144
# found no snomed for links in EFO_0004284
# found no snomed for links in EFO_0004286
# found no snomed for links in EFO_0009042
# found no snomed for links in EFO_0010675
# found no snomed for links in EFO_1000147
# found no snomed for links in EFO_1000365
# found no snomed for links in EFO_1000479
# found no snomed for links in EFO_1000547
# found no snomed for links in EFO_1000644
# found no snomed for links in EFO_1000805
# http://purl.bioontology.org/ontology/SNOMEDCT/54087003
# found no snomed for links in EFO_1001179
# http://purl.bioontology.org/ontology/SNOMEDCT/102447009
# http://purl.bioontology.org/ontology/SNOMEDCT/426873000
# http://purl.bioontology.org/ontology/SNOMEDCT/62151007
# found no snomed for links in EFO_0007540
# found no snomed for links in EFO_1000141
# found no snomed for links in EFO_1000213
# found no snomed for links in EFO_1000580
# http://purl.bioontology.org/ontology/SNOMEDCT/1290898006
# found no snomed for links in EFO_1002006
# found no snomed for links in EFO_0006891
# found no snomed for links in EFO_0009015
# found no snomed for links in EFO_0009163
# found no snomed for links in EFO_1000441
# ...
# found no snomed for links in Orphanet_295142
# Orphanet_309169
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_309169/mappings
# found no snomed for links in Orphanet_309169
# Orphanet_3331
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_3331/mappings
# found no snomed for links in Orphanet_3331
# Orphanet_158676
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_158676/mappings
# found no snomed for links in Orphanet_158676
# Orphanet_238269
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_238269/mappings
# found no snomed for links in Orphanet_238269
# Orphanet_268758
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_268758/mappings
# found no snomed for links in Orphanet_268758
# Orphanet_295097
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295097/mappings
# found no snomed for links in Orphanet_295097
# Orphanet_295110
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295110/mappings
# found no snomed for links in Orphanet_295110
# Orphanet_309282
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_309282/mappings
# found no snomed for links in Orphanet_309282
# Orphanet_363424
# Orphanet_398189
# Orphanet_1809
# Orphanet_263548
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_263548/mappings
# found no snomed for links in Orphanet_263548
# Orphanet_28378
# Orphanet_295075
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295075/mappings
# found no snomed for links in Orphanet_295075
# Orphanet_306446
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_306446/mappings
# found no snomed for links in Orphanet_306446
# Orphanet_363534
# Orphanet_163982
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_163982/mappings
# found no snomed for links in Orphanet_163982
# Orphanet_2271
# Orphanet_2587
# Orphanet_300576
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_300576/mappings
# found no snomed for links in Orphanet_300576
# Orphanet_370127
# Orphanet_404448
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_404448/mappings
# found no snomed for links in Orphanet_404448
# Orphanet_1723
# Orphanet_231568
# Orphanet_284414
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_284414/mappings
# found no snomed for links in Orphanet_284414
# Orphanet_308013
# Orphanet_77302
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_77302/mappings
# found no snomed for links in Orphanet_77302
# Orphanet_2062
# Orphanet_247573
# Orphanet_2716
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2716/mappings
# found no snomed for links in Orphanet_2716
# Orphanet_295150
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295150/mappings
# found no snomed for links in Orphanet_295150
# Orphanet_3164
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_3164/mappings
# found no snomed for links in Orphanet_3164
# Orphanet_137911
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_137911/mappings
# found no snomed for links in Orphanet_137911
# Orphanet_2186
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2186/mappings
# found no snomed for links in Orphanet_2186
# Orphanet_238654
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_238654/mappings
# found no snomed for links in Orphanet_238654
# Orphanet_293462
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_293462/mappings
# found no snomed for links in Orphanet_293462
# Orphanet_330029
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_330029/mappings
# found no snomed for links in Orphanet_330029
# Orphanet_404476
# Orphanet_254930
# Orphanet_280558
# Orphanet_295239
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295239/mappings
# found no snomed for links in Orphanet_295239
# Orphanet_261204
# Orphanet_295124
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295124/mappings
# found no snomed for links in Orphanet_295124
# Orphanet_2967
# Orphanet_308400
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_308400/mappings
# found no snomed for links in Orphanet_308400
# Orphanet_329967
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_329967/mappings
# found no snomed for links in Orphanet_329967
# Orphanet_51084
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_51084/mappings
# found no snomed for links in Orphanet_51084
# Orphanet_289527
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_289527/mappings
# found no snomed for links in Orphanet_289527
# Orphanet_217059
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_217059/mappings
# found no snomed for links in Orphanet_217059
# Orphanet_2479
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2479/mappings
# found no snomed for links in Orphanet_2479
# Orphanet_314051
# Orphanet_391366
# Orphanet_295024
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295024/mappings
# found no snomed for links in Orphanet_295024
# Orphanet_254851
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_254851/mappings
# found no snomed for links in Orphanet_254851
# Orphanet_295087
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295087/mappings
# found no snomed for links in Orphanet_295087
# Orphanet_2994
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2994/mappings
# found no snomed for links in Orphanet_2994
# Orphanet_404437
# Orphanet_2508
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2508/mappings
# found no snomed for links in Orphanet_2508
# Orphanet_295225
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295225/mappings
# found no snomed for links in Orphanet_295225
# Orphanet_3133
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_3133/mappings
# found no snomed for links in Orphanet_3133
# Orphanet_1617
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_1617/mappings
# found no snomed for links in Orphanet_1617
# Orphanet_231147
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_231147/mappings
# found no snomed for links in Orphanet_231147
# Orphanet_2482
# Orphanet_324585
# Orphanet_261584
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_261584/mappings
# found no snomed for links in Orphanet_261584
# Orphanet_79144
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_79144/mappings
# found no snomed for links in Orphanet_79144
# Orphanet_79282
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_79282/mappings
# found no snomed for links in Orphanet_79282
# Orphanet_1487
# Orphanet_1948
# Orphanet_261295
# Orphanet_261323
# Orphanet_295120
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295120/mappings
# found no snomed for links in Orphanet_295120
# Orphanet_137628
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_137628/mappings
# found no snomed for links in Orphanet_137628
# Orphanet_1524
# Orphanet_209973
# Orphanet_2713
# Orphanet_295063
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295063/mappings
# found no snomed for links in Orphanet_295063
# Orphanet_2971
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2971/mappings
# found no snomed for links in Orphanet_2971
# Orphanet_314652
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_314652/mappings
# found no snomed for links in Orphanet_314652
# Orphanet_363412
# Orphanet_488
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_488/mappings
# found no snomed for links in Orphanet_488
# Orphanet_1406
# Orphanet_199279
# Orphanet_230845
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_230845/mappings
# found no snomed for links in Orphanet_230845
# Orphanet_238642
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_238642/mappings
# found no snomed for links in Orphanet_238642
# Orphanet_2649
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2649/mappings
# found no snomed for links in Orphanet_2649
# Orphanet_289290
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_289290/mappings
# found no snomed for links in Orphanet_289290
# Orphanet_483
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_483/mappings
# found no snomed for links in Orphanet_483
# Orphanet_79269
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_79269/mappings
# found no snomed for links in Orphanet_79269
# Orphanet_231137
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_231137/mappings
# found no snomed for links in Orphanet_231137
# Orphanet_370019
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_370019/mappings
# found no snomed for links in Orphanet_370019
# Orphanet_261572
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_261572/mappings
# found no snomed for links in Orphanet_261572
# Orphanet_268392
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_268392/mappings
# found no snomed for links in Orphanet_268392
# Orphanet_276413
# Orphanet_314662
# Orphanet_155889
# Orphanet_162
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_162/mappings
# found no snomed for links in Orphanet_162
# Orphanet_216972
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_216972/mappings
# found no snomed for links in Orphanet_216972
# Orphanet_2809
# Orphanet_295065
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295065/mappings
# found no snomed for links in Orphanet_295065
# Orphanet_2101
# Orphanet_319480
# Orphanet_276249
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_276249/mappings
# found no snomed for links in Orphanet_276249
# Orphanet_319519
# Orphanet_319635
# Orphanet_3224
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_3224/mappings
# found no snomed for links in Orphanet_3224
# Orphanet_324422
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_324422/mappings
# found no snomed for links in Orphanet_324422
# Orphanet_522077
# Orphanet_2007
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2007/mappings
# found no snomed for links in Orphanet_2007
# Orphanet_306658
# Orphanet_352577
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_352577/mappings
# found no snomed for links in Orphanet_352577
# Orphanet_1442
# Orphanet_295227
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_295227/mappings
# found no snomed for links in Orphanet_295227
# Orphanet_3166
# Orphanet_1493
# Orphanet_226307
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_226307/mappings
# found no snomed for links in Orphanet_226307
# Orphanet_2535
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2535/mappings
# found no snomed for links in Orphanet_2535
# Orphanet_268752
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_268752/mappings
# found no snomed for links in Orphanet_268752
# Orphanet_2836
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_2836/mappings
# found no snomed for links in Orphanet_2836
# Orphanet_3038
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_3038/mappings
# found no snomed for links in Orphanet_3038
# Orphanet_3315
# NoMethodError: undefined method `[]' for nil:NilClass
# (irb):31:in `block in <top (required)>'
# (irb):22:in `each_key'
# (irb):22:in `<top (required)>'

# %%
puts `pwd`
# Out:
# /home/osboxes/CODE/SIMPATHIC2/SKG_Mapping/radboud
