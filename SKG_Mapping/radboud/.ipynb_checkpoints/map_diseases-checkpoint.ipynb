# %% [markdown]
# Three fukes have disease info:
#
# disease-gene.csv
#
# disease-therapeuticarea.csv
#
# drug-disease.csv
#
# Uses ORPHA, HPO, and MONDO (or other) disease
#
# ORPHA we can keep
#
# HPO is not a disease, so make it a separate problem

# %% [markdown]
# # map id to disease
#
# for DOID, the path is:
# DOID -> BIoPortal DOID Record (get label), follow mappings -> look for the SNOMEDCT mapping -> get ID

# %%
require "rest-client"
require 'json'


def map_id_to_disease(name)
  return false unless (name =~ /DOID_(.*)/ || name =~ /MONDO_(.*)/ || name =~ /Orphanet_(.*)/)
  identifier = $1
  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    if name =~ /DOID/
      url =  "https://data.bioontology.org/search?q=DOID:#{identifier}&ontologies=DOID&require_exact_match=true&apikey=#{api_key}"
    elsif name =~ /MONDO/
      url =  "https://data.bioontology.org/search?q=MONDO:#{identifier}&ontologies=MONDO&require_exact_match=true&apikey=#{api_key}"      
    else
      url =  "https://data.bioontology.org/search?q=Orphanet:#{identifier}&ontologies=ORDO&require_exact_match=true&apikey=74027bd8-6be0-4329-be22-aa3717f97243"
    end
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for #{name} #{e.inspect}\n"
    return false
  end
  mappings = []
  data = JSON.parse(response)

#  if hit = data.dig('collection', 0)
  if hit = data.dig('collection')
    hit.each do |h|
      disease_name = h&.dig('prefLabel')
      uri = h&.dig('@id')
      linksurl = h&.dig('links', 'mappings')
      mappings << { id: name, uri: uri, disease_name: disease_name, linksurl: linksurl}
    end
    return mappings
  else
    warn "No data found for #{name}\n"
    return false
  end

rescue StandardError => e
  warn "No data found for #{name} Error: #{e.inspect}\n"
  return false
end
# Out:
# :map_id_to_disease

# %%
# test
["DOID_7551", "MONDO_0003243", "Orphanet_101010"].each do |name|
  warn map_id_to_disease(name)
end
# Out:
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings"}
# {:id=>"MONDO_0003243", :uri=>"http://purl.obolibrary.org/obo/MONDO_0003243", :disease_name=>"hepatocellular clear cell carcinoma", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0003243/mappings"}
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings"}
# ["DOID_7551", "MONDO_0003243", "Orphanet_101010"]

# %%
def get_snomed_from_mapping(mapping)
  if mapping =~ /MONDO/ 
    type = "MONDO"
  else
    type = "DOID_ORDO"  # mapping =~ /Orphanet/
  end

  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    url = mapping+"?apikey=#{api_key}"
#     warn url
    response = RestClient.get(url)
  rescue StandardError => e
    warn "No data found for mapping #{e.inspect}\n"
    return false
  end
  mappings = []
  data = JSON.parse(response)

  if type == "DOID_ORDO"
    data.each do |mapp|
      mapp["classes"].each do |thisclass|
        next unless thisclass["@id"] =~ /SNOMEDCT/
        return {"snomed": thisclass["@id"]}
      end
    end
    warn "no SNOMED found for DOID/ORDO #{mapping}"
    return false
  else
    data.each do |mapp|
      mapp["classes"].each do |thisclass|
        next unless thisclass["@id"] =~ /(DOID_\d+)/  # if we start with MONDO, thre is no snomed,but there is a DOID
        doid = $1
        results = map_id_to_disease(doid) # go back to the beginning
        if results
          results = results.first # (can only be one doid)
          snomedres = get_snomed_from_mapping(results[:linksurl])  # recursive, but this time its a DOID
          if snomedres
            return snomedres  # {"snomed": thisclass["@id"]} from the routine above
          else
            warn "found no snomed for #{mapping}"
            return false
          end
        else
          warn "found no results for xreffed doid #{doid}"
          return false
        end
      end
    end
  end
    
  warn "No SNOMED found in #{mapping}\n"
  return false
rescue StandardError => e
  warn  "parsing or other error in #{mapping} Error: #{e.inspect}\n"
  return false
end
# Out:
# :get_snomed_from_mapping

# %%
# test
["DOID_7551", "MONDO_0003243", "Orphanet_101010"].each do |name|
  results = map_id_to_disease(name)
  if results
    results = results.first # (can only be one)
    nextres = get_snomed_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    end
    puts results
  else
    warn "found no results for #{name}"
  end
end
# Out:
# {:id=>"DOID_7551", :uri=>"http://purl.obolibrary.org/obo/DOID_7551", :disease_name=>"gonorrhea", :linksurl=>"https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7551/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/15628003"}
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_5016/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0003243/mappings
# {:id=>"MONDO_0003243", :uri=>"http://purl.obolibrary.org/obo/MONDO_0003243", :disease_name=>"hepatocellular clear cell carcinoma", :linksurl=>"https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0003243/mappings"}
# {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/763377006"}
# ["DOID_7551", "MONDO_0003243", "Orphanet_101010"]

# %%
require 'csv'

filelist = ["disease-gene.csv","disease-therapeuticarea.csv"]  # in these two it is called "source"

diseaselist = {}
filelist.each do |csvfile|
  CSV.foreach("./rawdata/#{csvfile}", headers: true) do |row|
    next if row.size < 3

    source = row['source']
    abort unless source
    diseaselist[source] = 1
  end
end

filelist = ["drug-disease.csv"]  # in these two it is called "target"

filelist.each do |csvfile|
  CSV.foreach("./rawdata/#{csvfile}", headers: true) do |row|
    next if row.size < 3

    source = row['target']
    abort unless source
    diseaselist[source] = 1
  end
end

puts diseaselist.length
# Out:
# 9339

# %%
# write the mapping file
f = File.open("./mappings/diseases.map", "w")
e = File.open("./mappings/diseases-errors.txt", "w")

f.write CSV.generate_line(["source","snomedct","orpha","prefname"])

diseaselist.each_key do |name|
  warn name
  next if name =~ /HP_/  # not HPO terms
  next if name =~ /EFO_/  # not EFO terms
  next if name =~ /OTAR_/  # not EFO terms
  
  results = map_id_to_disease(name)
  if results
    results = results.first # (can only be one)
    nextres = get_snomed_from_mapping(results[:linksurl])
    if nextres
      results.merge! nextres
    else
      warn "found no snomed for links in #{name}"
      e.write "found no snomed for links in #{name}\n"
    end
    snomed = results[:snomed]
    snomed = "https://fake.snomed/not-found" unless snomed
    if results[:uri] =~ /orpha/
      orpha = results[:uri]
    else
      orpha = "https://fake.orphanet/not-found"
    end
    f.write CSV.generate_line([results[:id],snomed,orpha,results[:disease_name]])
    # {:id=>"Orphanet_101010", :uri=>"http://www.orpha.net/ORDO/Orphanet_101010", :disease_name=>"Autosomal spastic paraplegia type 30", :linksurl=>"https://data.bioontology.org/ontologies/ORDO/classes/http%3A%2F%2Fwww.orpha.net%2FORDO%2FOrphanet_101010/mappings", :snomed=>"http://purl.bioontology.org/ontology/SNOMEDCT/763377006"}
  else
    warn "found no results for #{name}"
    e.write "found no results for #{name}\n"
  end
end
# Out:
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0112117/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0030006/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0021116/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0002203/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0004392/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0081079/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0012806/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0032911/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0008597/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0044784/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0111482/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0054781/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0081432/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0009619/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0110646/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0011377/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0015003/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0032889/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0000030/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0030060/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_11968/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0001410/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014725/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0054695/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0012670/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0060978/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0044325/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0009559/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0060281/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0015643/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0080963/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0030019/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0002368/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7694/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0004331/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0007845/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0008630/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0112145/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0032940/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014919/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0010888/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0021804/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0009374/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0110943/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0009816/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0090094/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0010635/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0018715/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0020854/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7468/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0044793/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0020845/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0010589/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0030910/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0032917/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0009703/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0013680/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0018794/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0060589/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0021469/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0060582/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0060916/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0054699/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_7843/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0004379/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0030917/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0081364/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014940/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0070525/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0054852/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0112002/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0010504/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0020593/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0100186/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0010318/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014850/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0018653/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0002278/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0044312/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0054860/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0110310/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0007268/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0110213/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0007336/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0029143/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0002863/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0009866/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014369/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0020638/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0054565/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0060758/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0012586/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0013618/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014603/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0008939/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0009948/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0011571/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0011973/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0090051/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0013928/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0020853/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0111062/mappings
# found no snomed for https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014252/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0019457/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0032928/mappings
# No SNOMED found in https://data.bioontology.org/ontologies/MONDO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FMONDO_0014801/mappings
# no SNOMED found for DOID/ORDO https://data.bioontology.org/ontologies/DOID/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDOID_0