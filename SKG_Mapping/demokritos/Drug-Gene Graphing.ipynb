# %%
puts `ls -l raw-data`
# Out:
# total 484
# -rw-rw-r-- 1 osboxes osboxes  34777 Aug 12 17:45 Demokritos-KG-information.xlsx
# -rw-rw-r-- 1 osboxes osboxes 207331 Aug 12 17:45 Disease-Therapeutic_Area.tsv
# -rw-rw-r-- 1 osboxes osboxes  36869 Aug 12 17:45 Drug-Diseasetriples.tsv
# -rw-rw-r-- 1 osboxes osboxes 111643 Aug 12 17:45 Drug-Drug_type.tsv
# -rw-rw-r-- 1 osboxes osboxes  32600 Aug 12 17:45 Drug-Genetriples.tsv
# -rw-rw-r-- 1 osboxes osboxes  51800 Aug 12 17:45 Gene-Diseasetriples.tsv
# -rw-rw-r-- 1 osboxes osboxes   7965 Aug 12 17:45 Gene-Pathwaytriples.tsv

# %%
puts `head -5 ./raw-data/Drug-Genetriples.tsv`
# Out:
# ﻿Drug	Drug_id	Gene	Gene_id
# Dopamine Hydrochloride	C0282151	UCP1 gene	C1421313
# Dopamine Hydrochloride	C0282151	PPARA gene	C1418776
# Dopamine Hydrochloride	C0282151	PPP1R12A gene	C1417581
# Dopamine Hydrochloride	C0282151	NLRP1 wt Allele	C3538756

# %%
puts `head -5 ./mappings/drug-mappings.map`
# Out:
# demokritosid,xref,demokritos_label,pubchem_cid,IUPACname
# C0613621,http://purl.bioontology.org/ontology/MESH/C030536,"2,2-dichloro-1,1-difluoroethyl difluoromethyl ether",https://pubchem.ncbi.nlm.nih.gov/compound/152803,"2,2-dichloro-1,1-difluoroethyl%20difluoromethyl%20ether"
# C0042291,http://purl.bioontology.org/ontology/SNOMEDCT/387080000,Valproic Acid,https://pubchem.ncbi.nlm.nih.gov/compound/3121,Valproic%20acid
# C0059747,http://purl.bioontology.org/ontology/SNOMEDCT/83298009,ethyl acetate,https://pubchem.ncbi.nlm.nih.gov/compound/8857,Ethyl%20acetate
# C0059747,http://purl.bioontology.org/ontology/MESH/C007650,ethyl acetate,https://pubchem.ncbi.nlm.nih.gov/compound/8857,ethyl%20acetate

# %%
puts `head -5 ./mappings/gene-mappings.map`
# Out:
# source,label,geneid,protein,recommended_full,taxon
# C1421313,UCP1,http://purl.uniprot.org/geneid/7350,http://purl.uniprot.org/uniprot/P25874,uncoupling protein 1,http://purl.uniprot.org/taxonomy/9606
# C1418776,PPARA,http://purl.uniprot.org/geneid/5465,http://purl.uniprot.org/uniprot/Q07869,peroxisome proliferator activated receptor alpha,http://purl.uniprot.org/taxonomy/9606
# C1417581,PPP1R12A,http://purl.uniprot.org/geneid/4659,http://purl.uniprot.org/uniprot/O14974,protein phosphatase 1 regulatory subunit 12A,http://purl.uniprot.org/taxonomy/9606
# C1418482,CFP,http://purl.uniprot.org/geneid/5199,http://purl.uniprot.org/uniprot/P27918,complement factor properdin,http://purl.uniprot.org/taxonomy/9606

# %%
require 'linkeddata'
require 'csv'

graphing_errors = File.open('./graph/drug-gene-errors.txt', 'w') 

# Define namespaces
SIMPATHIC = RDF::Vocabulary.new('urn:simpathic:')
RDFS = RDF::Vocabulary.new('http://www.w3.org/2000/01/rdf-schema#')

# Read input files
entity_relations = CSV.read('./raw-data/Drug-Genetriples.tsv', col_sep: "\t", headers: true)
drug_mappings = CSV.read('./mappings/drug-mappings.map', headers: true)
gene_mappings = CSV.read('./mappings/gene-mappings.map', headers: true)

# Create RDF graph
graph = RDF::Repository.new

failures = {}
# Process each entity relation
entity_relations.each do |row|
  # warn row.inspect
  drug_id = row['Drug_id']
  gene_id = row['Gene_id']
  warn "Drug #{drug_id} -- Gene #{gene_id}"
  # Find corresponding mappings
  drug = drug_mappings.find { |d| d['demokritosid'] == drug_id }
  gene = gene_mappings.find { |d| d['source'] == gene_id }
  
  unless drug
    next if failures[drug_id]
    failures[drug_id] = 1
    warn "drug lookup failed #{drug_id}"
    graphing_errors.write "drug lookup failed #{drug_id}\n"
    next
  end
  unless gene
    next if failures[gene_id]
    failures[gene_id] = 1
    warn "gene lookup failed #{gene_id}"
    graphing_errors.write "gene lookup failed #{gene_id}\n"
    next
  end
  
  # Extract relevant IDs and labels
  # demokratisid,xref,demokratis_label,pubchem_cid,IUPACname
  # C0613621,http://purl.bioontology.org/ontology/MESH/C030536,"2,2-dichloro-1,1-difluoroethyl difluoromethyl ether",https://pubchem.ncbi.nlm.nih.gov/compound/152803,"2,2-dichloro-1,1-difluoroethyl%20difluoromethyl%20ether"
  pubchem_uri = RDF::URI.new(drug['pubchem_cid'])
  pubchem_type = RDF::URI.new("http://semanticscience.org/resource/CHEMINF_000302")
  pubchem_label =  RDF::Literal.new(drug['xref'])
  pubchem_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Drug")
  human_drug_label = RDF::Literal.new(drug['demokritos_label'])
  iupac_drug_label = RDF::Literal.new(drug['IUPACname'])

  #   source,label,geneid,protein,recommended_full,taxon
  #   C1421313,UCP1,http://purl.uniprot.org/geneid/7350,http://purl.uniprot.org/uniprot/P25874,uncoupling protein 1,http://purl.uniprot.org/taxonomy/9606
  gene_uri = RDF::URI.new(gene['geneid'])
  gene_type = RDF::URI.new("http://edamontology.org/data_2610")
  gene_label =  RDF::Literal.new(gene['label'])
  gene_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Gene")
  human_gene_label = RDF::Literal.new(gene['recommended_full'])

  
  protein_uri = RDF::URI.new(gene['protein'])
  protein_type = RDF::URI.new("http://edamontology.org/data_2291")
  protein_label =  RDF::Literal.new(gene['protein'])
  protein_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Protein")
  human_protein_label = RDF::Literal.new(gene['recommended_full'])

  taxon = RDF::URI.new(gene['taxon'])

  
  # Create context URI
  context_uri = RDF::URI.new("urn:simpathic:context:#{drug_id}_#{gene_id}")
  general_context = RDF::URI.new("urn:simpathic:context:all_metadata")
  
  # Add quads to graph using RDF::Statement
  graph << RDF::Statement.new(pubchem_uri, SIMPATHIC['associated-with'], gene_uri, graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri, SIMPATHIC['associated-with'], pubchem_uri , graph_name: context_uri)
  
  graph << RDF::Statement.new(pubchem_uri,  RDFS.label,     human_drug_label, graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  RDFS.label,     iupac_drug_label, graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  RDF.type,       pubchem_type,          graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  RDF.type,       pubchem_core_type,             graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_type, RDFS.label,     RDF::Literal.new("PubChem"), graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_core_type, RDFS.label,     RDF::Literal.new("Drug"), graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{drug_id}"), graph_name: context_uri)
  
  graph << RDF::Statement.new(gene_uri,  RDFS.label,       human_gene_label , graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  RDF.type,         gene_type, graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  RDF.type,         gene_core_type, graph_name: context_uri)
  graph << RDF::Statement.new(gene_type, RDFS.label,       RDF::Literal.new("NCBI Gene"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_core_type, RDFS.label,  RDF::Literal.new("Gene"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{gene_id}"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  SIMPATHIC['in-taxon'], taxon, graph_name: context_uri)

  
  
  graph << RDF::Statement.new(pubchem_uri, SIMPATHIC['associated-with'], protein_uri, graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri, SIMPATHIC['associated-with'], pubchem_uri, graph_name: context_uri)

  graph << RDF::Statement.new(protein_uri,  RDFS.label,       human_protein_label , graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  RDF.type,         protein_type, graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  RDF.type,         protein_core_type, graph_name: context_uri)
  graph << RDF::Statement.new(protein_type, RDFS.label,       RDF::Literal.new("UniProt"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_core_type, RDFS.label,  RDF::Literal.new("Protein"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{gene_id}"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  SIMPATHIC['in-taxon'], taxon, graph_name: context_uri)

  
  graph << RDF::Statement.new(context_uri, SIMPATHIC['skg-source'], RDF::Literal.new("DEMOKRITOS"), graph_name: general_context)
  # graph << RDF::Statement.new(context_uri, SIMPATHIC['skg-evidence'], RDF::Literal.new("TBD"), graph_name: general_context)
end

# Write RDF to file in N-Quads format
File.open('./graph/drug-gene.nq.large', 'w') do |f|
  RDF::Writer.for(:nquads).new(f) do |writer|
    writer << graph
  end
end
graphing_errors.close

puts "RDF quads written"
# Out:
# (irb):6: warning: already initialized constant Object::SIMPATHIC
# (irb):6: warning: previous definition of SIMPATHIC was here
# (irb):7: warning: already initialized constant Object::RDFS
# (irb):7: warning: previous definition of RDFS was here
# Drug C0282151 -- Gene C1421313
# Drug C0282151 -- Gene C1418776
# Drug C0282151 -- Gene C1417581
# Drug C0282151 -- Gene C3538756
# gene lookup failed C3538756
# Drug C0282151 -- Gene C3813713
# gene lookup failed C3813713
# Drug C0282151 -- Gene C1418482
# Drug C0282151 -- Gene C1825598
# Drug C0282151 -- Gene C1333250
# Drug C0282151 -- Gene C1538301
# Drug C0282151 -- Gene C1420115
# Drug C0282151 -- Gene C1538300
# Drug C0013030 -- Gene C1418482
# Drug C0013030 -- Gene C3538756
# Drug C0013030 -- Gene C1883559
# gene lookup failed C1883559
# Drug C0013030 -- Gene C1420870
# Drug C0013030 -- Gene C1425023
# Drug C0013030 -- Gene C2239937
# gene lookup failed C2239937
# Drug C0013030 -- Gene C1422657
# Drug C0013030 -- Gene C3813713
# Drug C0014939 -- Gene C1825598
# Drug C0014939 -- Gene C1417651
# Drug C0014939 -- Gene C1332826
# Drug C0014939 -- Gene C0086661
# Drug C0014939 -- Gene C1415223
# Drug C0034282 -- Gene C1419867
# drug lookup failed C0034282
# Drug C2936588 -- Gene C1418217
# drug lookup failed C2936588
# Drug C3661282 -- Gene C1415816
# Drug C0031923 -- Gene C1415294
# drug lookup failed C0031923
# Drug C0031978 -- Gene C1366752
# drug lookup failed C0031978
# Drug C0002403 -- Gene C1421210
# Drug C0251991 -- Gene C1419266
# drug lookup failed C0251991
# Drug C0251991 -- Gene C1418217
# Drug C0065610 -- Gene C0376515
# drug lookup failed C0065610
# Drug C1097132 -- Gene C1415501
# drug lookup failed C1097132
# Drug C1565316 -- Gene C1415502
# drug lookup failed C1565316
# Drug C0965044 -- Gene C1415245
# drug lookup failed C0965044
# Drug C0965044 -- Gene C1413555
# Drug C0075632 -- Gene C1421452
# Drug C0075632 -- Gene C1415142
# Drug C0526470 -- Gene C1413554
# drug lookup failed C0526470
# Drug C0033008 -- Gene C1427949
# drug lookup failed C0033008
# Drug C0014912 -- Gene C3280555
# drug lookup failed C0014912
# Drug C0014912 -- Gene C1422359
# Drug C0014912 -- Gene C1420116
# Drug C0031399 -- Gene C1417002
# drug lookup failed C0031399
# Drug C2825146 -- Gene C1416842
# drug lookup failed C2825146
# Drug C2825146 -- Gene C1413554
# Drug C0057142 -- Gene C1704697
# drug lookup failed C0057142
# Drug C0057142 -- Gene C1416832
# Drug C0536217 -- Gene C1332735
# drug lookup failed C0536217
# Drug C0025598 -- Gene C1414377
# Drug C0025598 -- Gene C1425023
# Drug C0025598 -- Gene C1421834
# Drug C0913506 -- Gene C1420563
# drug lookup failed C0913506
# Drug C0537150 -- Gene C1705701
# drug lookup failed C0537150
# Drug C0541746 -- Gene C1422646
# Drug C0678075 -- Gene C1419147
# drug lookup failed C0678075
# Drug C0678075 -- Gene C1418476
# Drug C0678075 -- Gene C1419149
# Drug C0678075 -- Gene C1883559
# Drug C0678075 -- Gene C1825598
# Drug C0678075 -- Gene C1425988
# Drug C0678075 -- Gene C1418526
# Drug C0055278 -- Gene C3539645
# drug lookup failed C0055278
# Drug C0939905 -- Gene C1823140
# drug lookup failed C0939905
# Drug C0065180 -- Gene C1425290
# Drug C0065180 -- Gene C0162508
# Drug C0064368 -- Gene C1418215
# drug lookup failed C0064368
# Drug C0039542 -- Gene C1825121
# drug lookup failed C0039542
# Drug C1609177 -- Gene C1418526
# drug lookup failed C1609177
# Drug C0022179 -- Gene C1413554
# drug lookup failed C0022179
# Drug C0061202 -- Gene C1413554
# Drug C3661274 -- Gene C1416775
# Drug C0006462 -- Gene C1417507
# Drug C0360301 -- Gene C1420137
# drug lookup failed C0360301
# Drug C0360301 -- Gene C1420131
# Drug C0360301 -- Gene C1420132
# Drug C0360301 -- Gene C1853262
# Drug C0360301 -- Gene C1853261
# Drug C0360301 -- Gene C1420141
# Drug C0360301 -- Gene C1412070
# Drug C0908935 -- Gene C1439351
# drug lookup failed C0908935
# Drug C0250350 -- Gene C1883559
# drug lookup failed C0250350
# Drug C0011892 -- Gene C1416375
# drug lookup failed C0011892
# Drug C0031448 -- Gene C1825598
# drug lookup failed C0031448
# Drug C0031448 -- Gene C1419086
# Drug C0031448 -- Gene C1420120
# Drug C0718565 -- Gene C1413554
# drug lookup failed C0718565
# Drug C0030049 -- Gene C1412716
# drug lookup failed C0030049
# Drug C1120149 -- Gene C1425330
# drug lookup failed C1120149
# Drug C2698875 -- Gene C1413666
# drug lookup failed C2698875
# Drug C0729511 -- Gene C1415223
# drug lookup failed C0729511
# Drug C0729511 -- Gene C1422009
# Drug C0010194 -- Gene C3538756
# drug lookup failed C0010194
# Drug C1096766 -- Gene C1412495
# drug lookup failed C1096766
# Drug C1096766 -- Gene C1413057
# Drug C0034283 -- Gene C1853261
# drug lookup failed C0034283
# Drug C0034283 -- Gene C1853262
# Drug C0171368 -- Gene C1335824
# drug lookup failed C0171368
# Drug C0058185 -- Gene C1335824
# drug lookup failed C0058185
# Drug C0025627 -- Gene C3813609
# drug lookup failed C0025627
# Drug C0025627 -- Gene C1417002
# Drug C0529351 -- Gene C1412268
# Drug C0085170 -- Gene C1425290
# drug lookup failed C0085170
# Drug C0008931 -- Gene C1425290
# drug lookup failed C0008931
# Drug C0138666 -- Gene C1412268
# drug lookup failed C0138666
# Drug C0061223 -- Gene C1414372
# drug lookup failed C0061223
# Drug C0128170 -- Gene C1417870
# drug lookup failed C0128170
# Drug C0039623 -- Gene C1420115
# drug lookup failed C0039623
# Drug C0534301 -- Gene C1413514
# drug lookup failed C0534301
# Drug C0048255 -- Gene C1336636
# drug lookup failed C0048255
# Drug C0068897 -- Gene C1420206
# drug lookup failed C0068897
# Drug C0054863 -- Gene C3273659
# drug lookup failed C0054863
# Drug C0039654 -- Gene C3539645
# drug lookup failed C0039654
# Drug C0024002 -- Gene C1419997
# drug lookup failed C0024002
# Drug C0754659 -- Gene C1416886
# drug lookup failed C0754659
# Drug C1176316 -- Gene C3811063
# drug lookup failed C1176316
# Drug C0023556 -- Gene C1883559
# drug lookup failed C0023556
# Drug C0084563 -- Gene C1415300
# drug lookup failed C0084563
# Drug C0084563 -- Gene C1415299
# Drug C0163557 -- Gene C0376622
# drug lookup failed C0163557
# Drug C0066646 -- Gene C1417679
# drug lookup failed C0066646
# Drug C0002333 -- Gene C1707163
# drug lookup failed C0002333
# Drug C0348029 -- Gene C1413554
# drug lookup failed C0348029
# Drug C0242546 -- Gene C1417819
# drug lookup failed C0242546
# Drug C0242546 -- Gene C1418858
# Drug C0720523 -- Gene C1418674
# drug lookup failed C0720523
# Drug C0037556 -- Gene C1415353
# drug lookup failed C0037556
# Drug C0037556 -- Gene C1422359
# Drug C0024742 -- Gene C1334074
# Drug C0024742 -- Gene C1416788
# Drug C0024742 -- Gene C1426768
# Drug C0024742 -- Gene C3715044
# Drug C0024742 -- Gene C1418674
# Drug C0024742 -- Gene C1367477
# Drug C0024742 -- Gene C1426190
# Drug C0024742 -- Gene C2239937
# Drug C0024742 -- Gene C1417244
# Drug C0968642 -- Gene C1413555
# drug lookup failed C0968642
# Drug C1456750 -- Gene C1439351
# drug lookup failed C1456750
# Drug C1456750 -- Gene C1424950
# Drug C1699861 -- Gene C1427005
# drug lookup failed C1699861
# Drug C1876226 -- Gene C1412268
# drug lookup failed C1876226
# Drug C0007044 -- Gene C1417222
# drug lookup failed C0007044
# Drug C0011177 -- Gene C3812373
# drug lookup failed C0011177
# Drug C0529793 -- Gene C1416498
# Drug C0971841 -- Gene C1416842
# drug lookup failed C0971841
# Drug C0023899 -- Gene C1415009
# drug lookup failed C0023899
# Drug C0025872 -- Gene C1825598
# drug lookup failed C0025872
# Drug C0025872 -- Gene C1428025
# Drug C0013618 -- Gene C1420459
# drug lookup failed C0013618
# Drug C0013618 -- Gene C1823521
# Drug C0059804 -- Gene C3539770
# drug lookup failed C0059804
# Drug C0126174 -- Gene C1413931
# Drug C0008803 -- Gene C3539618
# drug lookup failed C0008803
# Drug C0012381 -- Gene C1416548
# drug lookup failed C0012381
# Drug C0965129 -- Gene C1415619
# drug lookup failed C0965129
# Drug C0672708 -- Gene C1414085
# drug lookup failed C0672708
# Drug C0672708 -- Gene C1412637
# Drug C0672708 -- Gene C1417055
# Drug C0041175 -- Gene C1823521
# Drug C0041175 -- Gene C3813713
# Drug C0041175 -- Gene C1420214
# Drug C0876060 -- Gene C1427005
# drug lookup failed C0876060
# Drug C0045283 -- Gene C3539643
# gene lookup failed C3539643
# Drug C0060454 -- Gene C1415803
# drug lookup failed C0060454
# Drug C0301363 -- Gene C1428119
# drug lookup failed C0301363
# Drug C0012968 -- Gene C1418526
# drug lookup failed C0012968
# Drug C0142554 -- Gene C1425223
# drug lookup failed C0142554
# Drug C1456443 -- Gene C2987167
# drug lookup failed C1456443
# Drug C2353951 -- Gene C1825598
# drug lookup failed C2353951
# Drug C0081660 -- Gene C1418779
# drug lookup failed C0081660
# Drug C0081660 -- Gene C3539783
# Drug C0041415 -- Gene C1412113
# drug lookup failed C0041415
# Drug C0033148 -- Gene C1425222
# drug lookup failed C0033148
# Drug C0059865 -- Gene C1366516
# drug lookup failed C0059865
# Drug C0042845 -- Gene C1826260
# Drug C0035339 -- Gene C1426084
# drug lookup failed C0035339
# Drug C0292873 -- Gene C1425223
# drug lookup failed C0292873
# Drug C0682884 -- Gene C1415502
# drug lookup failed C0682884
# Drug C0083535 -- Gene C1415304
# drug lookup failed C0083535
# Drug C0034272 -- Gene C1538689
# Drug C0034272 -- Gene C1412691
# Drug C0068700 -- Gene C3813548
# drug lookup failed C0068700
# Drug C0107190 -- Gene C3538756
# drug lookup failed C0107190
# Drug C0001771 -- Gene C1426025
# drug lookup failed C0001771
# Drug C3253985 -- Gene C1417002
# drug lookup failed C3253985
# Drug C0022237 -- Gene C1417656
# drug lookup failed C0022237
# Drug C0074406 -- Gene C1418591
# drug lookup failed C0074406
# Drug C2740858 -- Gene C1414290
# drug lookup failed C2740858
# Drug C1176309 -- Gene C1425023
# Drug C1176309 -- Gene C1883559
# Drug C1566043 -- Gene C1424232
# drug lookup failed C1566043
# Drug C0084866 -- Gene C1418674
# drug lookup failed C0084866
# Drug C0002502 -- Gene C1418215
# drug lookup failed C0002502
# Drug C0075710 -- Gene C1420490
# drug lookup failed C0075710
# Drug C1567066 -- Gene C1413554
# drug lookup failed C1567066
# Drug C0219736 -- Gene C1418482
# drug lookup failed C0219736
# Drug C0006463 -- Gene C1417055
# drug lookup failed C0006463
# Drug C3713362 -- Gene C1538686
# drug lookup failed C3713362
# Drug C0246421 -- Gene C1825598
# drug lookup failed C0246421
# Drug C2348308 -- Gene C1419149
# drug lookup failed C2348308
# Drug C2825264 -- Gene C1415501
# drug lookup failed C2825264
# Drug C0090306 -- Gene C1825843
# Drug C1173066 -- Gene C1415321
# drug lookup failed C1173066
# Drug C0033513 -- Gene C1825598
# drug lookup failed C0033513
# Drug C0084183 -- Gene C1412247
# drug lookup failed C0084183
# Drug C0061506 -- Gene C1424938
# Drug C0061506 -- Gene C1428114
# Drug C0061506 -- Gene C1415009
# Drug C0095278 -- Gene C1418674
# Drug C0055568 -- Gene C1412328
# drug lookup failed C0055568
# Drug C0055568 -- Gene C1425449
# Drug C0055568 -- Gene C1419149
# Drug C0008024 -- Gene C1417825
# drug lookup failed C0008024
# Drug C0008024 -- Gene C1412328
# Drug C0008024 -- Gene C1425449
# Drug C0008024 -- Gene C1419149
# Drug C0146951 -- Gene C1823521
# drug lookup failed C0146951
# Drug C0146951 -- Gene C1414168
# Drug C0045010 -- Gene C1539322
# drug lookup failed C0045010
# Drug C3273375 -- Gene C1415321
# drug lookup failed C3273375
# Drug C0030863 -- Gene C1417055
# drug lookup failed C0030863
# Drug C0006674 -- Gene C1417055
# drug lookup failed C0006674
# Drug C0722157 -- Gene C1416832
# drug lookup failed C0722157
# Drug C0031463 -- Gene C1417055
# drug lookup failed C0031463
# Drug C0603200 -- Gene C1414085
# drug lookup failed C0603200
# Drug C0084393 -- Gene C1413824
# drug lookup failed C0084393
# Drug C0084393 -- Gene C3539645
# Drug C0084393 -- Gene C1417055
# Drug C0873195 -- Gene C1538301
# drug lookup failed C0873195
# Drug C2935082 -- Gene C0079419
# drug lookup failed C2935082
# Drug C0282194 -- Gene C1413824
# drug lookup failed C0282194
# Drug C0031493 -- Gene C1415009
# drug lookup failed C0031493
# Drug C0163159 -- Gene C1425023
# drug lookup failed C0163159
# Drug C0163159 -- Gene C1427969
# Drug C0769341 -- Gene C1422736
# drug lookup failed C0769341
# Drug C3467949 -- Gene C1425023
# drug lookup failed C3467949
# Drug C0055412 -- Gene C1419304
# drug lookup failed C0055412
# Drug C0671834 -- Gene C1414444
# drug lookup failed C0671834
# Drug C0671834 -- Gene C1419036
# Drug C0085542 -- Gene C1364142
# drug lookup failed C0085542
# Drug C0087161 -- Gene C1824930
# drug lookup failed C0087161
# Drug C0257357 -- Gene C0812257
# drug lookup failed C0257357
# Drug C3467746 -- Gene C1413824
# drug lookup failed C3467746
# Drug C3467746 -- Gene C1414376
# Drug C3851669 -- Gene C1417055
# drug lookup failed C3851669
# Drug C2001572 -- Gene C1416548
# drug lookup failed C2001572
# Drug C0068273 -- Gene C1412056
# drug lookup failed C0068273
# Drug C0076281 -- Gene C1883559
# drug lookup failed C0076281
# Drug C0029300 -- Gene C3811119
# drug lookup failed C0029300
# RDF quads written

# %%
graphing_errors.close
