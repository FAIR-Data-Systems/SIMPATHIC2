# %%
puts `ls -l raw-data`
# Out:
# total 484
# -rw-rw-r-- 1 osboxes osboxes  34777 May 29 07:33 Demokritos-KG-information.xlsx
# -rw-rw-r-- 1 osboxes osboxes 207331 May 29 07:33 Disease-Therapeutic_Area.tsv
# -rw-rw-r-- 1 osboxes osboxes  36869 May 29 07:33 Drug-Disease triples.tsv
# -rw-rw-r-- 1 osboxes osboxes 111643 May 29 09:32 Drug-Drug_type.tsv
# -rw-rw-r-- 1 osboxes osboxes  32600 May 29 07:33 Drug-Gene triples.tsv
# -rw-rw-r-- 1 osboxes osboxes  51800 May 29 07:33 Gene-Disease triples.tsv
# -rw-rw-r-- 1 osboxes osboxes   7965 May 29 07:33 Gene-Pathway triples.tsv

# %%
puts `head "raw-data/Disease-Therapeutic_Area.tsv"`
# Out:
# Disease	Disease_id	Therapeutic_area	Therapeutic_area_id
# Third cranial nerve disorder	C0271353	Cranial nerve diseases	C0010266
# Other specified trigeminal nerve disorders	C0029834	Cranial nerve diseases	C0010266
# Marcus Gunn phenomenon	C0266521	Cranial nerve diseases	C0010266
# Cranial nerve palsies	C0151311	Cranial nerve diseases	C0010266
# Disorders of other cranial nerves	C0154730	Cranial nerve diseases	C0010266
# Cranial Nerve Neoplasms, Malignant	C0153644	Cranial nerve diseases	C0010266
# Disorder of the optic nerve	C0029132	Cranial nerve diseases	C0010266
# Facial Nerve Diseases	C0015464	Cranial nerve diseases	C0010266
# Superior Oblique Palsy, Neurogenic	C0751939	Cranial nerve diseases	C0010266

# %% [markdown]
# # Column 4 = MedGen CUI
#
# UMLS requires an API key, that has onerous reporting requirements.
#
# Skip it and use OBO, where the ICD vocabularies use the same CUI
#
# e.g. https://data.bioontology.org/search?q=C0010266&ontologies=ICD10CM&require_exact_match=true&apikey=...

# %%
# puts `curl -H "Accept: application/json" "https://mygene.info/v3/query?q=C1538301&fields=symbol,ensembl.gene,uniprot"`
require "rest-client"
require 'json'

apikey = ENV["APIKEY"] # Replace with BioPortal API key

puts JSON.pretty_generate(JSON.parse(RestClient.get("https://data.bioontology.org/search?q=C0010266&ontologies=ICD10CM&require_exact_match=true&apikey=#{apikey}").body))
# Out:
# {
#   "page": 1,
#   "pageCount": 1,
#   "totalCount": 1,
#   "prevPage": null,
#   "nextPage": null,
#   "links": {
#     "nextPage": null,
#     "prevPage": null
#   },
#   "collection": [
#     {
#       "prefLabel": "Cranial nerve disorder, unspecified",
#       "cui": [
#         "C0010266"
#       ],
#       "semanticType": [
#         "T047"
#       ],
#       "obsolete": false,
#       "matchType": "cui",
#       "ontologyType": "ONTOLOGY",
#       "provisional": false,
#       "@id": "http://purl.bioontology.org/ontology/ICD10CM/G52.9",
#       "@type": "http://www.w3.org/2002/07/owl#Class",
#       "links": {
#         "self": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9",
#         "ontology": "https://data.bioontology.org/ontologies/ICD10CM",
#         "children": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/children",
#         "parents": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/parents",
#         "descendants": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/descendants",
#         "ancestors": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/ancestors",
#         "instances": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/instances",
#         "tree": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/tree",
#         "notes": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/notes",
#         "mappings": "https://data.bioontology.org/ontologies/ICD10CM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9/mappings",
#         "ui": "http://bioportal.bioontology.org/ontologies/ICD10CM?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FICD10CM%2FG52.9",
#         "@context": {
#           "self": "http://www.w3.org/2002/07/owl#Class",
#           "ontology": "http://data.bioontology.org/metadata/Ontology",
#           "children": "http://www.w3.org/2002/07/owl#Class",
#           "parents": "http://www.w3.org/2002/07/owl#Class",
#           "descendants": "http://www.w3.org/2002/07/owl#Class",
#           "ancestors": "http://www.w3.org/2002/07/owl#Class",
#           "instances": "http://data.bioontology.org/metadata/Instance",
#           "tree": "http://www.w3.org/2002/07/owl#Class",
#           "notes": "http://data.bioontology.org/metadata/Note",
#           "mappings": "http://data.bioontology.org/metadata/Mapping",
#           "ui": "http://www.w3.org/2002/07/owl#Class"
#         }
#       },
#       "@context": {
#         "@vocab": "http://data.bioontology.org/metadata/",
#         "prefLabel": "http://www.w3.org/2004/02/skos/core#prefLabel",
#         "obsolete": "http://www.w3.org/2002/07/owl#deprecated",
#         "semanticType": "http://bioportal.bioontology.org/ontologies/umls/hasSTY",
#         "cui": "http://bioportal.bioontology.org/ontologies/umls/cui",
#         "@language": "en"
#       }
#     }
#   ]
# }

# %%
require "rest-client"
require 'json'


def map_cui_to_ICD(cui)
  api_key = ENV["APIKEY"] # Replace with BioPortal API key
  begin
    response = RestClient.get("https://data.bioontology.org/search?q=#{cui}&ontologies=ICD10&require_exact_match=true&apikey=#{api_key}")
  rescue
    return false
  end
  mappings = []
  data = JSON.parse(response)

  if hit = data.dig('collection')
    hit.each do |h|
      therapeuticarea = h&.dig('prefLabel')
      icd10 = h&.dig('@id')
      mappings << { cui: cui, therapeuticarea: therapeuticarea, icd10: icd10}
    end
    return mappings
  else
    warn "No data found for #{cui}\n"
    return false
  end

rescue StandardError => e
  warn "No data found for #{cui} Error: #{e.inspect}\n"
  return false
end
# Out:
# :map_cui_to_ICD

# %%
# Example usage
cuis = ['C0010266'] 
results = cuis.map do |cui|
  cui_result = map_cui_to_ICD(cui)
  puts cui_result
#   abort
  next if cui_result == false

end
# Out:
# {:cui=>"C0010266", :therapeuticarea=>"Cranial nerve disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G52.9"}
# [nil]

# %% [markdown]
# # The MedGen CUI to ICD10 Mapping

# %%
require 'csv'

f = File.open('./mappings/therapeutic-mappings.csv', 'w')
e = File.open('./mappings/therapeutic-errors.txt', 'w')
f.sync = true # Ensure immediate writes
e.sync = true # Ensure immediate writes
f.write CSV.generate_line(["source","icd10","prefname"])


CSVFILE="raw-data/Disease-Therapeutic_Area.tsv"

seen={}
CSV.foreach(CSVFILE, headers: true, col_sep: "\t") do |row|
  next if row.size < 3
  cui = row["Therapeutic_area_id"]  # this is a UMLS CUI
  next if seen[cui]
  seen[cui] = 1
  cui_result = map_cui_to_ICD(cui) # {:cui=>"C0010266", :therapeuticarea=>"Cranial nerve disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G52.9"}
warn cui_result.class
  if cui_result == false
    e.write "error getting #{cui}\n"
    next
  elsif cui_result.empty?
    e.write "No ICD10 matches for #{cui}\n"
    next    
  end
  
  cui_result.each do |res|
    warn res
    f.write CSV.generate_line([cui,res[:icd10],res[:therapeuticarea]])
  end
end
f.close
e.close
# Out:
# (irb):9: warning: already initialized constant Object::CSVFILE
# (irb):9: warning: previous definition of CSVFILE was here
# Array
# {:cui=>"C0010266", :therapeuticarea=>"Cranial nerve disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G52.9"}
# Array
# Array
# {:cui=>"C0042594", :therapeuticarea=>"Disorders of vestibular function", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H81"}
# {:cui=>"C0042594", :therapeuticarea=>"Disorder of vestibular function, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H81.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0027121", :therapeuticarea=>"Myositis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M60"}
# {:cui=>"C0027121", :therapeuticarea=>"Myositis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M60.9"}
# Array
# Array
# {:cui=>"C0242172", :therapeuticarea=>"Female pelvic inflammatory disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N73.9"}
# {:cui=>"C0242172", :therapeuticarea=>"Inflammatory diseases of female pelvic organs", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N70-N77.9"}
# Array
# Array
# {:cui=>"C0152025", :therapeuticarea=>"Polyneuropathy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G62.9"}
# Array
# {:cui=>"C0015397", :therapeuticarea=>"Disorders of globe", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H44"}
# {:cui=>"C0015397", :therapeuticarea=>"Disorder of globe, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H44.9"}
# Array
# {:cui=>"C0010278", :therapeuticarea=>"Craniosynostosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q75.0"}
# Array
# {:cui=>"C0011884", :therapeuticarea=>"Diabetic retinopathy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H36.0"}
# Array
# Array
# Array
# {:cui=>"C0027765", :therapeuticarea=>"Diseases of the nervous system", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G00-G99.9"}
# Array
# {:cui=>"C0018889", :therapeuticarea=>"Helminthiases", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B65-B83.9"}
# {:cui=>"C0018889", :therapeuticarea=>"Helminthiasis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B83.9"}
# Array
# {:cui=>"C0014877", :therapeuticarea=>"Convergent concomitant strabismus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H50.0"}
# Array
# {:cui=>"C0015310", :therapeuticarea=>"Divergent concomitant strabismus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H50.1"}
# Array
# {:cui=>"C0026847", :therapeuticarea=>"Spinal muscular atrophy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G12.9"}
# Array
# Array
# {:cui=>"C0037315", :therapeuticarea=>"Sleep apnoea", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G47.3"}
# Array
# {:cui=>"C0042769", :therapeuticarea=>"Viral infection, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B34.9"}
# {:cui=>"C0042769", :therapeuticarea=>"Viral infection of unspecified site", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B34"}
# Array
# Array
# {:cui=>"C0002726", :therapeuticarea=>"Amyloidosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E85"}
# {:cui=>"C0002726", :therapeuticarea=>"Amyloidosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E85.9"}
# Array
# {:cui=>"C0014544", :therapeuticarea=>"Epilepsy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G40.9"}
# {:cui=>"C0014544", :therapeuticarea=>"Epilepsy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G40"}
# Array
# {:cui=>"C0011860", :therapeuticarea=>"Non-insulin-dependent diabetes mellitus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E11"}
# Array
# Array
# Array
# {:cui=>"C0037773", :therapeuticarea=>"Hereditary spastic paraplegia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G11.4"}
# Array
# Array
# {:cui=>"C0026769", :therapeuticarea=>"Multiple sclerosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G35"}
# Array
# {:cui=>"C0026850", :therapeuticarea=>"Muscular dystrophy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G71.0"}
# Array
# {:cui=>"C0035309", :therapeuticarea=>"Retinal disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H35.9"}
# Array
# {:cui=>"C0085084", :therapeuticarea=>"Motor neuron disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G12.2"}
# Array
# {:cui=>"C0028754", :therapeuticarea=>"Obesity", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E66"}
# {:cui=>"C0028754", :therapeuticarea=>"Obesity, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E66.9"}
# Array
# Array
# {:cui=>"C0020492", :therapeuticarea=>"Hypertrophy of bone", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M89.3"}
# Array
# {:cui=>"C0029124", :therapeuticarea=>"Optic atrophy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H47.2"}
# Array
# {:cui=>"C0021831", :therapeuticarea=>"Disease of intestine, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K63.9"}
# Array
# Array
# {:cui=>"C0085584", :therapeuticarea=>"Encephalopathy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G93.4"}
# Array
# {:cui=>"C0162674", :therapeuticarea=>"Progressive external ophthalmoplegia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H49.4"}
# Array
# Array
# Array
# {:cui=>"C0079298", :therapeuticarea=>"Epidermolysis bullosa simplex", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q81.0"}
# Array
# {:cui=>"C0026848", :therapeuticarea=>"Myopathy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G72.9"}
# {:cui=>"C0026848", :therapeuticarea=>"Disorders of muscles", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M60-M63.9"}
# {:cui=>"C0026848", :therapeuticarea=>"Disorder of muscle, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M62.9"}
# Array
# {:cui=>"C0025517", :therapeuticarea=>"Metabolic disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E70-E90.9"}
# {:cui=>"C0025517", :therapeuticarea=>"Metabolic disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E88.9"}
# Array
# {:cui=>"C0032285", :therapeuticarea=>"Pneumonia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J18.9"}
# Array
# Array
# {:cui=>"C0002871", :therapeuticarea=>"Anaemia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D64.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0035078", :therapeuticarea=>"Unspecified renal failure", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N19"}
# {:cui=>"C0035078", :therapeuticarea=>"Renal failure", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N17-N19.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0007682", :therapeuticarea=>"Disorder of central nervous system, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G96.9"}
# Array
# {:cui=>"C0878544", :therapeuticarea=>"Cardiomyopathy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I42"}
# {:cui=>"C0878544", :therapeuticarea=>"Cardiomyopathy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I42.9"}
# Array
# {:cui=>"C0023895", :therapeuticarea=>"Diseases of liver", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K70-K77.9"}
# {:cui=>"C0023895", :therapeuticarea=>"Liver disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K76.9"}
# Array
# {:cui=>"C0154246", :therapeuticarea=>"Disorders of urea cycle metabolism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E72.2"}
# Array
# {:cui=>"C0149931", :therapeuticarea=>"Migraine", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G43"}
# {:cui=>"C0149931", :therapeuticarea=>"Migraine, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G43.9"}
# Array
# {:cui=>"C0020615", :therapeuticarea=>"Hypoglycaemia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E16.2"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0018378", :therapeuticarea=>"Guillain-Barre syndrome", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G61.0"}
# Array
# {:cui=>"C0027868", :therapeuticarea=>"Myoneural disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G70.9"}
# Array
# Array
# {:cui=>"C0011849", :therapeuticarea=>"Diabetes mellitus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E10-E14.9"}
# {:cui=>"C0011849", :therapeuticarea=>"Unspecified diabetes mellitus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E14"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0018799", :therapeuticarea=>"Heart disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I51.9"}
# Array
# {:cui=>"C0020255", :therapeuticarea=>"Hydrocephalus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G91"}
# {:cui=>"C0020255", :therapeuticarea=>"Hydrocephalus, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G91.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0020538", :therapeuticarea=>"Hypertensive diseases", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I10-I15.9"}
# Array
# Array
# {:cui=>"C0085437", :therapeuticarea=>"Bacterial meningitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G00.9"}
# Array
# Array
# Array
# {:cui=>"C0020490", :therapeuticarea=>"Hypermetropia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H52.0"}
# Array
# {:cui=>"C0027092", :therapeuticarea=>"Myopia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H52.1"}
# Array
# {:cui=>"C0004106", :therapeuticarea=>"Astigmatism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H52.2"}
# Array
# {:cui=>"C0007222", :therapeuticarea=>"Cardiovascular disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I51.6"}
# Array
# Array
# Array
# {:cui=>"C0036421", :therapeuticarea=>"Progressive systemic sclerosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M34.0"}
# {:cui=>"C0036421", :therapeuticarea=>"Systemic sclerosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M34"}
# {:cui=>"C0036421", :therapeuticarea=>"Systemic sclerosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M34.9"}
# Array
# {:cui=>"C0001824", :therapeuticarea=>"Agranulocytosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D70"}
# Array
# {:cui=>"C0034951", :therapeuticarea=>"Disorder of refraction, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H52.7"}
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0007785", :therapeuticarea=>"Cerebral infarction, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I63.9"}
# {:cui=>"C0007785", :therapeuticarea=>"Cerebral infarction", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I63"}
# Array
# {:cui=>"C0494491", :therapeuticarea=>"Mononeuropathy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G58.9"}
# Array
# {:cui=>"C0020456", :therapeuticarea=>"Hyperglycaemia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/R73.9"}
# Array
# {:cui=>"C0007193", :therapeuticarea=>"Dilated cardiomyopathy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I42.0"}
# Array
# {:cui=>"C0002514", :therapeuticarea=>"Disorder of amino-acid metabolism, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E72.9"}
# Array
# {:cui=>"C0155514", :therapeuticarea=>"Labyrinthine dysfunction", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H83.2"}
# Array
# Array
# {:cui=>"C0393593", :therapeuticarea=>"Dystonia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G24.9"}
# {:cui=>"C0393593", :therapeuticarea=>"Dystonia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G24"}
# Array
# {:cui=>"C0027726", :therapeuticarea=>"Nephrotic syndrome", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N04"}
# {:cui=>"C0027726", :therapeuticarea=>"Nephrotic syndrome, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N04.9"}
# Array
# Array
# {:cui=>"C0029882", :therapeuticarea=>"Otitis media, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H66.9"}
# Array
# {:cui=>"C0032371", :therapeuticarea=>"Acute poliomyelitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A80.9"}
# {:cui=>"C0032371", :therapeuticarea=>"Acute poliomyelitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A80"}
# Array
# {:cui=>"C0011603", :therapeuticarea=>"Dermatitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L30.9"}
# Array
# Array
# {:cui=>"C0014130", :therapeuticarea=>"Endocrine disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E34.9"}
# Array
# Array
# {:cui=>"C0264490", :therapeuticarea=>"Acute respiratory failure", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J96.0"}
# Array
# {:cui=>"C0020428", :therapeuticarea=>"Hyperaldosteronism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E26"}
# {:cui=>"C0020428", :therapeuticarea=>"Hyperaldosteronism, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E26.9"}
# Array
# {:cui=>"C0030486", :therapeuticarea=>"Paraplegia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G82.2"}
# Array
# {:cui=>"C0007787", :therapeuticarea=>"Transient cerebral ischaemic attack, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G45.9"}
# Array
# Array
# {:cui=>"C0005779", :therapeuticarea=>"Coagulation defect, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D68.9"}
# Array
# {:cui=>"C0018802", :therapeuticarea=>"Congestive heart failure", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I50.0"}
# Array
# {:cui=>"C0024117", :therapeuticarea=>"Chronic obstructive pulmonary disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J44.9"}
# Array
# {:cui=>"C0020676", :therapeuticarea=>"Hypothyroidism, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E03.9"}
# Array
# {:cui=>"C0003873", :therapeuticarea=>"Rheumatoid arthritis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M06.9"}
# Array
# {:cui=>"C0033860", :therapeuticarea=>"Psoriasis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L40.9"}
# {:cui=>"C0033860", :therapeuticarea=>"Psoriasis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L40"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0017601", :therapeuticarea=>"Glaucoma", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H40"}
# {:cui=>"C0017601", :therapeuticarea=>"Glaucoma, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H40.9"}
# {:cui=>"C0017601", :therapeuticarea=>"Glaucoma", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H40-H42.9"}
# Array
# {:cui=>"C0005686", :therapeuticarea=>"Bladder disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N32.9"}
# Array
# {:cui=>"C0019693", :therapeuticarea=>"Unspecified human immunodeficiency virus [HIV] disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B24"}
# {:cui=>"C0019693", :therapeuticarea=>"Human immunodeficiency virus [HIV] disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B20-B24.9"}
# Array
# Array
# {:cui=>"C0012242", :therapeuticarea=>"Diseases of the digestive system", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K00-K93.9"}
# {:cui=>"C0012242", :therapeuticarea=>"Disease of digestive system, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K92.9"}
# Array
# Array
# {:cui=>"C0155626", :therapeuticarea=>"Acute myocardial infarction, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I21.9"}
# {:cui=>"C0155626", :therapeuticarea=>"Acute myocardial infarction", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I21"}
# Array
# Array
# Array
# Array
# {:cui=>"C0014175", :therapeuticarea=>"Endometriosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N80.9"}
# {:cui=>"C0014175", :therapeuticarea=>"Endometriosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N80"}
# Array
# Array
# Array
# Array
# {:cui=>"C0032064", :therapeuticarea=>"Plague, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A20.9"}
# {:cui=>"C0032064", :therapeuticarea=>"Plague", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A20"}
# Array
# {:cui=>"C0025281", :therapeuticarea=>"Meniere's disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H81.0"}
# Array
# {:cui=>"C0004623", :therapeuticarea=>"Bacterial infection of unspecified site", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A49"}
# {:cui=>"C0004623", :therapeuticarea=>"Bacterial infection, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A49.9"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0029456", :therapeuticarea=>"Osteoporosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M81.9"}
# Array
# Array
# {:cui=>"C0034065", :therapeuticarea=>"Pulmonary embolism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I26"}
# Array
# Array
# {:cui=>"C0030920", :therapeuticarea=>"Peptic ulcer, site unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K27"}
# Array
# {:cui=>"C0009763", :therapeuticarea=>"Conjunctivitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H10.9"}
# {:cui=>"C0009763", :therapeuticarea=>"Conjunctivitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H10"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0017152", :therapeuticarea=>"Gastritis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K29.7"}
# Array
# Array
# {:cui=>"C0024899", :therapeuticarea=>"Mastocytosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q82.2"}
# Array
# Array
# {:cui=>"C0018939", :therapeuticarea=>"Disease of blood and blood-forming organs, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D75.9"}
# Array
# {:cui=>"C0010692", :therapeuticarea=>"Cystitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N30.9"}
# {:cui=>"C0010692", :therapeuticarea=>"Cystitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N30"}
# Array
# {:cui=>"C0011848", :therapeuticarea=>"Diabetes insipidus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E23.2"}
# Array
# Array
# {:cui=>"C0040558", :therapeuticarea=>"Toxoplasmosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B58"}
# {:cui=>"C0040558", :therapeuticarea=>"Toxoplasmosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B58.9"}
# Array
# {:cui=>"C0026603", :therapeuticarea=>"Motion sickness", :icd10=>"http://purl.bioontology.org/ontology/ICD10/T75.3"}
# Array
# {:cui=>"C0006840", :therapeuticarea=>"Candidiasis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B37"}
# {:cui=>"C0006840", :therapeuticarea=>"Candidiasis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B37.9"}
# Array
# {:cui=>"C0004153", :therapeuticarea=>"Atherosclerosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I70"}
# {:cui=>"C0004153", :therapeuticarea=>"Atherosclerotic cardiovascular disease, so described", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I25.0"}
# Array
# Array
# {:cui=>"C0021051", :therapeuticarea=>"Immunodeficiency, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D84.9"}
# Array
# {:cui=>"C0085580", :therapeuticarea=>"Essential (primary) hypertension", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I10"}
# Array
# Array
# {:cui=>"C0024530", :therapeuticarea=>"Unspecified malaria", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B54"}
# Array
# {:cui=>"C0003864", :therapeuticarea=>"Arthritis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M13.9"}
# Array
# {:cui=>"C0002171", :therapeuticarea=>"Alopecia areata", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L63"}
# {:cui=>"C0002171", :therapeuticarea=>"Alopecia areata, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L63.9"}
# Array
# {:cui=>"C0162820", :therapeuticarea=>"Allergic contact dermatitis, unspecified cause", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L23.9"}
# {:cui=>"C0162820", :therapeuticarea=>"Allergic contact dermatitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L23"}
# Array
# {:cui=>"C0157749", :therapeuticarea=>"Infectious arthropathies", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M00-M03.9"}
# Array
# {:cui=>"C0014868", :therapeuticarea=>"Oesophagitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K20"}
# Array
# Array
# {:cui=>"C0178238", :therapeuticarea=>"Intestinal infectious diseases", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A00-A09.9"}
# Array
# {:cui=>"C0028077", :therapeuticarea=>"Night blindness", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H53.6"}
# Array
# Array
# Array
# {:cui=>"C0006145", :therapeuticarea=>"Disorder of breast, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N64.9"}
# {:cui=>"C0006145", :therapeuticarea=>"Disorders of breast", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N60-N64.9"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0028841", :therapeuticarea=>"Hypotony of eye", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H44.4"}
# Array
# {:cui=>"C0494559", :therapeuticarea=>"Diseases of inner ear", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H80-H83.9"}
# {:cui=>"C0494559", :therapeuticarea=>"Disease of inner ear, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H83.9"}
# Array
# Array
# Array
# {:cui=>"C0021364", :therapeuticarea=>"Male infertility", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N46"}
# Array
# Array
# {:cui=>"C0005940", :therapeuticarea=>"Disorder of bone, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M89.9"}
# Array
# {:cui=>"C0206062", :therapeuticarea=>"Interstitial pulmonary disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J84.9"}
# Array
# Array
# Array
# {:cui=>"C0027059", :therapeuticarea=>"Myocarditis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I51.4"}
# Array
# Array
# {:cui=>"C0040128", :therapeuticarea=>"Disorder of thyroid, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E07.9"}
# {:cui=>"C0040128", :therapeuticarea=>"Disorders of thyroid gland", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E00-E07.9"}
# Array
# Array
# {:cui=>"C0155223", :therapeuticarea=>"Dacryoadenitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H04.0"}
# Array
# {:cui=>"C0011311", :therapeuticarea=>"Dengue fever [classical dengue]", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A90"}
# Array
# {:cui=>"C0155616", :therapeuticarea=>"Secondary hypertension, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I15.9"}
# {:cui=>"C0155616", :therapeuticarea=>"Secondary hypertension", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I15"}
# Array
# Array
# Array
# Array
# {:cui=>"C0019101", :therapeuticarea=>"Haemorrhagic fever with renal syndrome", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A98.5"}
# Array
# {:cui=>"C0026946", :therapeuticarea=>"Mycoses", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B35-B49.9"}
# {:cui=>"C0026946", :therapeuticarea=>"Unspecified mycosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B49"}
# Array
# Array
# {:cui=>"C0014457", :therapeuticarea=>"Eosinophilia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D72.1"}
# Array
# {:cui=>"C0008311", :therapeuticarea=>"Cholangitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K83.0"}
# Array
# {:cui=>"C0020635", :therapeuticarea=>"Hypopituitarism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E23.0"}
# Array
# Array
# {:cui=>"C0004626", :therapeuticarea=>"Bacterial pneumonia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J15.9"}
# Array
# {:cui=>"C0011616", :therapeuticarea=>"Unspecified contact dermatitis, unspecified cause", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L25.9"}
# {:cui=>"C0011616", :therapeuticarea=>"Unspecified contact dermatitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L25"}
# Array
# {:cui=>"C0030569", :therapeuticarea=>"Secondary parkinsonism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G21"}
# {:cui=>"C0030569", :therapeuticarea=>"Secondary parkinsonism, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G21.9"}
# Array
# {:cui=>"C0040156", :therapeuticarea=>"Thyrotoxicosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E05.9"}
# Array
# {:cui=>"C0032273", :therapeuticarea=>"Unspecified pneumoconiosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J64"}
# Array
# Array
# {:cui=>"C0020502", :therapeuticarea=>"Hyperparathyroidism, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E21.3"}
# Array
# Array
# {:cui=>"C0037928", :therapeuticarea=>"Disease of spinal cord, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G95.9"}
# Array
# {:cui=>"C0152227", :therapeuticarea=>"Epiphora", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H04.2"}
# Array
# {:cui=>"C0009759", :therapeuticarea=>"Disorder of conjunctiva, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H11.9"}
# {:cui=>"C0009759", :therapeuticarea=>"Disorders of conjunctiva", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H10-H13.9"}
# Array
# {:cui=>"C0022568", :therapeuticarea=>"Keratitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H16.9"}
# {:cui=>"C0022568", :therapeuticarea=>"Keratitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H16"}
# Array
# Array
# {:cui=>"C0029134", :therapeuticarea=>"Optic neuritis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H46"}
# Array
# {:cui=>"C0012739", :therapeuticarea=>"Disseminated intravascular coagulation [defibrination syndrome]", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D65"}
# Array
# Array
# Array
# {:cui=>"C0151436", :therapeuticarea=>"Hypersensitivity angiitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M31.0"}
# Array
# Array
# {:cui=>"C0042974", :therapeuticarea=>"Von Willebrand's disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D68.0"}
# Array
# {:cui=>"C0019087", :therapeuticarea=>"Haemorrhagic condition, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D69.9"}
# Array
# {:cui=>"C1260873", :therapeuticarea=>"Aortic valve disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I35.9"}
# Array
# {:cui=>"C0002878", :therapeuticarea=>"Haemolytic anaemias", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D55-D59.9"}
# Array
# {:cui=>"C0011633", :therapeuticarea=>"Dermatopolymyositis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M33.9"}
# {:cui=>"C0011633", :therapeuticarea=>"Dermatopolymyositis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M33"}
# Array
# {:cui=>"C0029434", :therapeuticarea=>"Osteogenesis imperfecta", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q78.0"}
# Array
# Array
# {:cui=>"C0039585", :therapeuticarea=>"Androgen resistance syndrome", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E34.5"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0272242", :therapeuticarea=>"Defects in the complement system", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D84.1"}
# Array
# Array
# {:cui=>"C0020302", :therapeuticarea=>"Congenital glaucoma", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q15.0"}
# Array
# Array
# {:cui=>"C0017919", :therapeuticarea=>"Glycogen storage disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E74.0"}
# Array
# Array
# Array
# {:cui=>"C0002876", :therapeuticarea=>"Congenital dyserythropoietic anaemia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D64.4"}
# Array
# Array
# Array
# {:cui=>"C0008370", :therapeuticarea=>"Obstruction of bile duct", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K83.1"}
# Array
# Array
# Array
# {:cui=>"C0234398", :therapeuticarea=>"Disorders of visual cortex", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H47.6"}
# Array
# Array
# {:cui=>"C0008445", :therapeuticarea=>"Chondrodysplasia punctata", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q77.3"}
# Array
# {:cui=>"C0013720", :therapeuticarea=>"Ehlers-Danlos syndrome", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q79.6"}
# Array
# {:cui=>"C0034072", :therapeuticarea=>"Pulmonary heart disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I27.9"}
# Array
# {:cui=>"C0010043", :therapeuticarea=>"Corneal ulcer", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H16.0"}
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0553604", :therapeuticarea=>"Myotonic disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G71.1"}
# Array
# Array
# Array
# Array
# {:cui=>"C0014852", :therapeuticarea=>"Disease of oesophagus, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K22.9"}
# Array
# {:cui=>"C0033806", :therapeuticarea=>"Pseudohypoparathyroidism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E20.1"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0034089", :therapeuticarea=>"Pulmonary valve stenosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I37.0"}
# Array
# {:cui=>"C0155765", :therapeuticarea=>"Diseases of capillaries", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I78"}
# {:cui=>"C0155765", :therapeuticarea=>"Disease of capillaries, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I78.9"}
# Array
# {:cui=>"C0036202", :therapeuticarea=>"Sarcoidosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D86.9"}
# {:cui=>"C0036202", :therapeuticarea=>"Sarcoidosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D86"}
# Array
# Array
# Array
# {:cui=>"C0036508", :therapeuticarea=>"Seborrhoeic dermatitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L21"}
# {:cui=>"C0036508", :therapeuticarea=>"Seborrhoeic dermatitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L21.9"}
# Array
# {:cui=>"C0009451", :therapeuticarea=>"Communicating hydrocephalus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G91.0"}
# Array
# {:cui=>"C0039730", :therapeuticarea=>"Thalassaemia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D56.9"}
# {:cui=>"C0039730", :therapeuticarea=>"Thalassaemia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D56"}
# Array
# {:cui=>"C0006705", :therapeuticarea=>"Disorders of calcium metabolism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E83.5"}
# Array
# {:cui=>"C0030353", :therapeuticarea=>"Papilloedema, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H47.1"}
# Array
# {:cui=>"C0022573", :therapeuticarea=>"Keratoconjunctivitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H16.2"}
# Array
# Array
# Array
# {:cui=>"C0700594", :therapeuticarea=>"Radiculopathy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M54.1"}
# Array
# Array
# Array
# Array
# {:cui=>"C0008325", :therapeuticarea=>"Cholecystitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K81"}
# {:cui=>"C0008325", :therapeuticarea=>"Cholecystitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K81.9"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0014527", :therapeuticarea=>"Epidermolysis bullosa", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q81"}
# {:cui=>"C0014527", :therapeuticarea=>"Epidermolysis bullosa, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q81.9"}
# Array
# Array
# {:cui=>"C0152221", :therapeuticarea=>"Paralytic strabismus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H49"}
# {:cui=>"C0152221", :therapeuticarea=>"Paralytic strabismus, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H49.9"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0025289", :therapeuticarea=>"Meningitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G03.9"}
# Array
# Array
# {:cui=>"C0026703", :therapeuticarea=>"Mucopolysaccharidosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E76.3"}
# Array
# {:cui=>"C0035021", :therapeuticarea=>"Relapsing fevers", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A68"}
# {:cui=>"C0035021", :therapeuticarea=>"Relapsing fever, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A68.9"}
# Array
# Array
# {:cui=>"C0003090", :therapeuticarea=>"Ankylosis of joint", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M24.6"}
# Array
# Array
# Array
# Array
# {:cui=>"C0022596", :therapeuticarea=>"Keratosis punctata (palmaris et plantaris)", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L85.2"}
# Array
# Array
# {:cui=>"C0010034", :therapeuticarea=>"Disorder of cornea, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H18.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0152223", :therapeuticarea=>"Mechanical strabismus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H50.6"}
# Array
# Array
# {:cui=>"C0029422", :therapeuticarea=>"Osteochondrodysplasia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q78.9"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0040409", :therapeuticarea=>"Diseases of tongue", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K14"}
# {:cui=>"C0040409", :therapeuticarea=>"Disease of tongue, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K14.9"}
# Array
# Array
# {:cui=>"C0023308", :therapeuticarea=>"Disorder of lens, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H27.9"}
# {:cui=>"C0023308", :therapeuticarea=>"Disorders of lens", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H25-H28.9"}
# Array
# Array
# {:cui=>"C0154748", :therapeuticarea=>"Lesion of sciatic nerve", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G57.0"}
# Array
# Array
# {:cui=>"C0031090", :therapeuticarea=>"Periodontal disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K05.6"}
# Array
# Array
# {:cui=>"C0016977", :therapeuticarea=>"Disease of gallbladder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K82.9"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0030517", :therapeuticarea=>"Disorder of parathyroid gland, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E21.5"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0005424", :therapeuticarea=>"Disease of biliary tract, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K83.9"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0156147", :therapeuticarea=>"Crohn's disease of large intestine", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K50.1"}
# Array
# {:cui=>"C0019348", :therapeuticarea=>"Herpesviral [herpes simplex] infections", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B00"}
# Array
# {:cui=>"C0022904", :therapeuticarea=>"Disorder of lacrimal system, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H04.9"}
# {:cui=>"C0022904", :therapeuticarea=>"Disorders of lacrimal system", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H04"}
# Array
# Array
# {:cui=>"C0012715", :therapeuticarea=>"Disorders of iron metabolism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E83.1"}
# Array
# Array
# Array
# {:cui=>"C0037899", :therapeuticarea=>"Sphingolipidosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E75.3"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0033581", :therapeuticarea=>"Inflammatory diseases of prostate", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N41"}
# {:cui=>"C0033581", :therapeuticarea=>"Inflammatory disease of prostate, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N41.9"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0029771", :therapeuticarea=>"Other specified diseases of pancreas", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K86.8"}
# Array
# {:cui=>"C0409974", :therapeuticarea=>"Lupus erythematosus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L93"}
# Array
# Array
# Array
# Array
# {:cui=>"C0149512", :therapeuticarea=>"Acute sinusitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J01.9"}
# {:cui=>"C0149512", :therapeuticarea=>"Acute sinusitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J01"}
# Array
# {:cui=>"C2980104", :therapeuticarea=>"Superficial mycosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B36.9"}
# Array
# Array
# {:cui=>"C0029582", :therapeuticarea=>"Other diseases of the respiratory system", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J95-J99.9"}
# {:cui=>"C0029582", :therapeuticarea=>"Other respiratory disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J98"}
# Array
# {:cui=>"C0041333", :therapeuticarea=>"Tuberculosis of genitourinary system", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A18.1"}
# Array
# Array
# {:cui=>"C0030807", :therapeuticarea=>"Pemphigus, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L10.9"}
# {:cui=>"C0030807", :therapeuticarea=>"Pemphigus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L10"}
# Array
# Array
# {:cui=>"C0031707", :therapeuticarea=>"Disorders of phosphorus metabolism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E83.3"}
# Array
# Array
# {:cui=>"C0027339", :therapeuticarea=>"Nail disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L60"}
# {:cui=>"C0027339", :therapeuticarea=>"Nail disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L60.9"}
# Array
# {:cui=>"C0037354", :therapeuticarea=>"Smallpox", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B03"}
# Array
# Array
# Array
# Array
# {:cui=>"C0155774", :therapeuticarea=>"Other venous embolism and thrombosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I82"}
# Array
# {:cui=>"C0264776", :therapeuticarea=>"Tricuspid valve disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I07.9"}
# {:cui=>"C0264776", :therapeuticarea=>"Rheumatic tricuspid valve diseases", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I07"}
# Array
# Array
# Array
# Array
# {:cui=>"C0029595", :therapeuticarea=>"Other disorders of purine and pyrimidine metabolism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E79.8"}
# Array
# {:cui=>"Other disorders of purine and pyrimidine metabolism", :therapeuticarea=>"Other disorders of purine and pyrimidine metabolism", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E79.8"}
# Array
# Array
# {:cui=>"C0029872", :therapeuticarea=>"Other vitreous opacities", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H43.3"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0004771", :therapeuticarea=>"Bartonellosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A44.9"}
# {:cui=>"C0004771", :therapeuticarea=>"Bartonellosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A44"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0023510", :therapeuticarea=>"Disorder of white blood cells, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D72.9"}
# Array
# Array
# {:cui=>"C0029454", :therapeuticarea=>"Osteopetrosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q78.2"}
# Array
# Array
# Array
# Array
# {:cui=>"C0079294", :therapeuticarea=>"Epidermolysis bullosa dystrophica", :icd10=>"http://purl.bioontology.org/ontology/ICD10/Q81.2"}
# Array
# Array
# {:cui=>"C0023786", :therapeuticarea=>"Mucopolysaccharidosis, type I", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E76.0"}
# Array
# Array
# {:cui=>"C0154860", :therapeuticarea=>"Hereditary retinal dystrophy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H35.5"}
# Array
# {:cui=>"C0154777", :therapeuticarea=>"Degenerated conditions of globe", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H44.5"}
# Array
# Array
# {:cui=>"C0152198", :therapeuticarea=>"Disorders of accommodation", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H52.5"}
# Array
# {:cui=>"C0155428", :therapeuticarea=>"Eustachian salpingitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H68.0"}
# Array
# Array
# {:cui=>"C0026113", :therapeuticarea=>"Miliaria, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L74.3"}
# Array
# Array
# {:cui=>"C2711630", :therapeuticarea=>"Combined immunodeficiencies", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D81"}
# {:cui=>"C2711630", :therapeuticarea=>"Combined immunodeficiency, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D81.9"}
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0027927", :therapeuticarea=>"Neurosyphilis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A52.3"}
# Array
# {:cui=>"C0029607", :therapeuticarea=>"Other emphysema", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J43.8"}
# Array
# {:cui=>"C0039131", :therapeuticarea=>"Congenital syphilis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A50.9"}
# {:cui=>"C0039131", :therapeuticarea=>"Congenital syphilis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A50"}
# Array
# Array
# Array
# {:cui=>"C0033740", :therapeuticarea=>"Protozoal diseases", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B50-B64.9"}
# {:cui=>"C0033740", :therapeuticarea=>"Unspecified protozoal disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B64"}
# Array
# {:cui=>"C0015423", :therapeuticarea=>"Disorder of eyelid, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H02.9"}
# Array
# {:cui=>"C0022578", :therapeuticarea=>"Keratoconus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H18.6"}
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0023343", :therapeuticarea=>"Leprosy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A30.9"}
# {:cui=>"C0023343", :therapeuticarea=>"Leprosy [Hansen's disease]", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A30"}
# Array
# Array
# {:cui=>"C0013447", :therapeuticarea=>"Disorder of ear, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H93.9"}
# Array
# {:cui=>"C0019338", :therapeuticarea=>"Enteroviral vesicular pharyngitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B08.5"}
# Array
# {:cui=>"C0033575", :therapeuticarea=>"Disorder of prostate, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N42.9"}
# Array
# {:cui=>"C0031115", :therapeuticarea=>"Peripheral angiopathy in diseases classified elsewhere", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I79.2"}
# Array
# Array
# Array
# {:cui=>"C0154653", :therapeuticarea=>"Chronic meningitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G03.1"}
# Array
# Array
# {:cui=>"C0700251", :therapeuticarea=>"Brachial plexus disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G54.0"}
# Array
# Array
# {:cui=>"C0029888", :therapeuticarea=>"Suppurative and unspecified otitis media", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H66"}
# {:cui=>"C0029888", :therapeuticarea=>"Suppurative otitis media, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H66.4"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0152097", :therapeuticarea=>"Disorders of diaphragm", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J98.6"}
# Array
# Array
# Array
# {:cui=>"C0155261", :therapeuticarea=>"Chronic inflammatory disorders of orbit", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H05.1"}
# Array
# Array
# {:cui=>"C0043388", :therapeuticarea=>"Yaws, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A66.9"}
# {:cui=>"C0043388", :therapeuticarea=>"Yaws", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A66"}
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0259800", :therapeuticarea=>"Purulent endophthalmitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H44.0"}
# Array
# Array
# {:cui=>"C0155686", :therapeuticarea=>"Acute myocarditis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I40.9"}
# {:cui=>"C0155686", :therapeuticarea=>"Acute myocarditis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I40"}
# Array
# {:cui=>"C0157705", :therapeuticarea=>"Acute lymphadenitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L04.9"}
# {:cui=>"C0157705", :therapeuticarea=>"Acute lymphadenitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L04"}
# Array
# Array
# {:cui=>"C0016085", :therapeuticarea=>"Filariasis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B74"}
# {:cui=>"C0016085", :therapeuticarea=>"Filariasis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B74.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0149881", :therapeuticarea=>"Orchitis and epididymitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N45"}
# Array
# Array
# {:cui=>"C0017412", :therapeuticarea=>"Disorder of male genital organs, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N50.9"}
# {:cui=>"C0017412", :therapeuticarea=>"Diseases of male genital organs", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N40-N51.9"}
# Array
# {:cui=>"C0029831", :therapeuticarea=>"Other specified strabismus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H50.8"}
# Array
# {:cui=>"C0339436", :therapeuticarea=>"Degeneration of macula and posterior pole", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H35.3"}
# Array
# {:cui=>"C0265057", :therapeuticarea=>"Phlebitis and thrombophlebitis of superficial vessels of lower extremities", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I80.0"}
# Array
# {:cui=>"C0038041", :therapeuticarea=>"Spotted fever, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A77.9"}
# {:cui=>"C0038041", :therapeuticarea=>"Spotted fever [tick-borne rickettsioses]", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A77"}
# Array
# Array
# Array
# {:cui=>"C0155490", :therapeuticarea=>"Cholesteatoma of middle ear", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H71"}
# Array
# Array
# {:cui=>"C0036133", :therapeuticarea=>"Salpingitis and oophoritis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N70"}
# {:cui=>"C0036133", :therapeuticarea=>"Salpingitis and oophoritis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N70.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0007302", :therapeuticarea=>"Disorder of cartilage, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M94.9"}
# {:cui=>"C0007302", :therapeuticarea=>"Chondropathies", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M91-M94.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0027030", :therapeuticarea=>"Myiasis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B87"}
# {:cui=>"C0027030", :therapeuticarea=>"Myiasis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B87.9"}
# Array
# Array
# Array
# {:cui=>"C0038986", :therapeuticarea=>"Eccrine sweat disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L74"}
# {:cui=>"C0038986", :therapeuticarea=>"Eccrine sweat disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L74.9"}
# Array
# {:cui=>"C0155118", :therapeuticarea=>"Corneal degeneration", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H18.4"}
# Array
# {:cui=>"C0029182", :therapeuticarea=>"Disorders of orbit", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H05"}
# {:cui=>"C0029182", :therapeuticarea=>"Disorder of orbit, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H05.9"}
# Array
# {:cui=>"C0271446", :therapeuticarea=>"Nonsuppurative otitis media, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H65.9"}
# {:cui=>"C0271446", :therapeuticarea=>"Nonsuppurative otitis media", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H65"}
# Array
# Array
# {:cui=>"C0155145", :therapeuticarea=>"Chronic conjunctivitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H10.4"}
# Array
# {:cui=>"C0041825", :therapeuticarea=>"Disorder of tympanic membrane, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H73.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0158997", :therapeuticarea=>"Transient neonatal neutropenia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/P61.5"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0155727", :therapeuticarea=>"Occlusion and stenosis of unspecified precerebral artery", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I65.9"}
# Array
# Array
# {:cui=>"C0036412", :therapeuticarea=>"Disorder of sclera, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H15.9"}
# {:cui=>"C0036412", :therapeuticarea=>"Disorders of sclera", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H15"}
# Array
# {:cui=>"C0156264", :therapeuticarea=>"Calculus of lower urinary tract", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N21"}
# {:cui=>"C0156264", :therapeuticarea=>"Calculus of lower urinary tract, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N21.9"}
# Array
# {:cui=>"C0085109", :therapeuticarea=>"Corneal neovascularization", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H16.4"}
# Array
# Array
# {:cui=>"C0008521", :therapeuticarea=>"Disorder of choroid, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H31.9"}
# Array
# Array
# {:cui=>"C0264765", :therapeuticarea=>"Mitral valve disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I05.9"}
# {:cui=>"C0264765", :therapeuticarea=>"Rheumatic mitral valve diseases", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I05"}
# Array
# Array
# {:cui=>"C0155087", :therapeuticarea=>"Interstitial and deep keratitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H16.3"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0085438", :therapeuticarea=>"Meningitis in mycoses", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G02.1"}
# Array
# {:cui=>"C0029785", :therapeuticarea=>"Other specified disorders of penis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N48.8"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0158445", :therapeuticarea=>"Other juvenile osteochondrosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M92"}
# Array
# {:cui=>"C0037997", :therapeuticarea=>"Diseases of spleen", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D73"}
# {:cui=>"C0037997", :therapeuticarea=>"Disease of spleen, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D73.9"}
# Array
# Array
# {:cui=>"C0264694", :therapeuticarea=>"Chronic ischaemic heart disease, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I25.9"}
# {:cui=>"C0264694", :therapeuticarea=>"Chronic ischaemic heart disease", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I25"}
# Array
# {:cui=>"C0154870", :therapeuticarea=>"Focal chorioretinal inflammation", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H30.0"}
# Array
# Array
# Array
# {:cui=>"C0021099", :therapeuticarea=>"Impetigo [any organism] [any site]", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L01.0"}
# {:cui=>"C0021099", :therapeuticarea=>"Impetigo", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L01"}
# Array
# {:cui=>"C0011636", :therapeuticarea=>"Dermatophytosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B35"}
# {:cui=>"C0011636", :therapeuticarea=>"Dermatophytosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B35.9"}
# Array
# Array
# {:cui=>"C0155287", :therapeuticarea=>"Disorder of visual pathways, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H47.7"}
# Array
# Array
# Array
# {:cui=>"C0041806", :therapeuticarea=>"Disorder involving the immune mechanism, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D89.9"}
# Array
# {:cui=>"C0029119", :therapeuticarea=>"Opportunistic mycoses", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B48.7"}
# Array
# Array
# Array
# Array
# {:cui=>"C0029644", :therapeuticarea=>"Other inflammatory spondylopathies", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M46"}
# Array
# {:cui=>"C1320640", :therapeuticarea=>"Peripheral retinal degeneration", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H35.4"}
# Array
# Array
# Array
# {:cui=>"C0155795", :therapeuticarea=>"Pelvic varices", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I86.2"}
# Array
# {:cui=>"C0001621", :therapeuticarea=>"Disorder of adrenal gland, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E27.9"}
# Array
# {:cui=>"C0034212", :therapeuticarea=>"Pyoderma", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L08.0"}
# Array
# Array
# Array
# Array
# {:cui=>"C0155937", :therapeuticarea=>"Acute gingivitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K05.0"}
# Array
# {:cui=>"C0029706", :therapeuticarea=>"Other peripheral vertigo", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H81.3"}
# Array
# {:cui=>"C0155435", :therapeuticarea=>"Other disorders of Eustachian tube", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H69"}
# Array
# Array
# {:cui=>"C0041969", :therapeuticarea=>"Urethral disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N36.9"}
# Array
# Array
# Array
# {:cui=>"C0154780", :therapeuticarea=>"Other degenerative disorders of globe", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H44.3"}
# Array
# {:cui=>"C0002874", :therapeuticarea=>"Aplastic anaemia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D61.9"}
# Array
# Array
# {:cui=>"C0242490", :therapeuticarea=>"Enthesopathy, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M77.9"}
# Array
# {:cui=>"C0154730", :therapeuticarea=>"Disorders of other cranial nerves", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G52"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0008513", :therapeuticarea=>"Chorioretinal inflammation", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H30"}
# {:cui=>"C0008513", :therapeuticarea=>"Chorioretinal inflammation, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H30.9"}
# Array
# {:cui=>"C0029770", :therapeuticarea=>"Other specified diseases of hard tissues of teeth", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K03.8"}
# Array
# Array
# {:cui=>"C0013592", :therapeuticarea=>"Ectropion of eyelid", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H02.1"}
# Array
# {:cui=>"C0155699", :therapeuticarea=>"Cardiomyopathy in other diseases classified elsewhere", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I43.8"}
# Array
# {:cui=>"C0152226", :therapeuticarea=>"Lagophthalmos", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H02.2"}
# Array
# {:cui=>"C0002881", :therapeuticarea=>"Hereditary haemolytic anaemia, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D58.9"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0149523", :therapeuticarea=>"Acute cystitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N30.0"}
# Array
# {:cui=>"C0004030", :therapeuticarea=>"Aspergillosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B44.9"}
# {:cui=>"C0004030", :therapeuticarea=>"Aspergillosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B44"}
# Array
# {:cui=>"C0040451", :therapeuticarea=>"Pathological resorption of teeth", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K03.3"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0029531", :therapeuticarea=>"Other cataract", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H26"}
# Array
# Array
# {:cui=>"C0085700", :therapeuticarea=>"Chondromalacia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M94.2"}
# Array
# Array
# {:cui=>"C0041473", :therapeuticarea=>"Epidemic louse-borne typhus fever due to Rickettsia prowazekii", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A75.0"}
# Array
# Array
# Array
# {:cui=>"C0155020", :therapeuticarea=>"Blindness and low vision", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H54"}
# Array
# Array
# {:cui=>"C0036416", :therapeuticarea=>"Scleritis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H15.0"}
# Array
# Array
# {:cui=>"C0015464", :therapeuticarea=>"Disorder of facial nerve, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G51.9"}
# {:cui=>"C0015464", :therapeuticarea=>"Facial nerve disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/G51"}
# Array
# {:cui=>"C0035326", :therapeuticarea=>"Retinal vascular occlusion, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H34.9"}
# {:cui=>"C0035326", :therapeuticarea=>"Retinal vascular occlusions", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H34"}
# Array
# {:cui=>"C0022893", :therapeuticarea=>"Labyrinthitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H83.0"}
# Array
# {:cui=>"C0017606", :therapeuticarea=>"Primary angle-closure glaucoma", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H40.2"}
# Array
# Array
# Array
# {:cui=>"C0040436", :therapeuticarea=>"Erosion of teeth", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K03.2"}
# Array
# {:cui=>"C0154189", :therapeuticarea=>"Other disorders of pancreatic internal secretion", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E16"}
# Array
# {:cui=>"C0013292", :therapeuticarea=>"Obstruction of duodenum", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K31.5"}
# Array
# Array
# {:cui=>"C0030756", :therapeuticarea=>"Pediculosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B85.2"}
# Array
# Array
# {:cui=>"C0018190", :therapeuticarea=>"Granuloma inguinale", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A58"}
# Array
# Array
# {:cui=>"C0005743", :therapeuticarea=>"Blepharoconjunctivitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H10.5"}
# Array
# {:cui=>"C1305122", :therapeuticarea=>"Thoracoabdominal aortic aneurysm, ruptured", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I71.5"}
# Array
# {:cui=>"C0006309", :therapeuticarea=>"Brucellosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A23"}
# {:cui=>"C0006309", :therapeuticarea=>"Brucellosis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A23.9"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0017675", :therapeuticarea=>"Glossitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K14.0"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0155389", :therapeuticarea=>"Perichondritis of external ear", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H61.0"}
# Array
# Array
# {:cui=>"C0034087", :therapeuticarea=>"Pulmonary valve disorders", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I37"}
# {:cui=>"C0034087", :therapeuticarea=>"Pulmonary valve disorder, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I37.9"}
# Array
# {:cui=>"C0014013", :therapeuticarea=>"Pyothorax", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J86"}
# Array
# {:cui=>"C0040147", :therapeuticarea=>"Thyroiditis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E06.9"}
# {:cui=>"C0040147", :therapeuticarea=>"Thyroiditis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E06"}
# Array
# {:cui=>"C0036262", :therapeuticarea=>"Scabies", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B86"}
# Array
# {:cui=>"C0155964", :therapeuticarea=>"Atrophy of tongue papillae", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K14.4"}
# Array
# {:cui=>"C0032763", :therapeuticarea=>"Postgastric surgery syndromes", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K91.1"}
# Array
# {:cui=>"C0154199", :therapeuticarea=>"Disease of thymus, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E32.9"}
# {:cui=>"C0154199", :therapeuticarea=>"Diseases of thymus", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E32"}
# Array
# Array
# Array
# Array
# {:cui=>"C0030326", :therapeuticarea=>"Panniculitis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M79.3"}
# Array
# Array
# {:cui=>"C0029850", :therapeuticarea=>"Other spontaneous pneumothorax", :icd10=>"http://purl.bioontology.org/ontology/ICD10/J93.1"}
# Array
# {:cui=>"C0156268", :therapeuticarea=>"Other chronic cystitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N30.2"}
# Array
# {:cui=>"C0155567", :therapeuticarea=>"Rheumatic aortic stenosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I06.0"}
# Array
# Array
# {:cui=>"C0023760", :therapeuticarea=>"Diseases of lips", :icd10=>"http://purl.bioontology.org/ontology/ICD10/K13.0"}
# Array
# Array
# Array
# {:cui=>"C0155176", :therapeuticarea=>"Noninfectious dermatoses of eyelid", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H01.1"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0162823", :therapeuticarea=>"Irritant contact dermatitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L24"}
# {:cui=>"C0162823", :therapeuticarea=>"Irritant contact dermatitis, unspecified cause", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L24.9"}
# Array
# Array
# Array
# {:cui=>"C0016034", :therapeuticarea=>"Diffuse cystic mastopathy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N60.1"}
# Array
# {:cui=>"C0268274", :therapeuticarea=>"GM2 gangliosidosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/E75.0"}
# Array
# {:cui=>"C0018789", :therapeuticarea=>"Aneurysm of heart", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I25.3"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0155388", :therapeuticarea=>"Diseases of external ear", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H60-H62.9"}
# {:cui=>"C0155388", :therapeuticarea=>"Disorder of external ear, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H61.9"}
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0029485", :therapeuticarea=>"Other acne", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L70.8"}
# Array
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0156257", :therapeuticarea=>"Calculus of kidney with calculus of ureter", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N20.2"}
# {:cui=>"C0156257", :therapeuticarea=>"Calculus of kidney and ureter", :icd10=>"http://purl.bioontology.org/ontology/ICD10/N20"}
# Array
# Array
# Array
# Array
# Array
# {:cui=>"C0339129", :therapeuticarea=>"Acute and unspecified inflammation of lacrimal passages", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H04.3"}
# Array
# {:cui=>"C0410005", :therapeuticarea=>"Pseudosarcomatous fibromatosis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M72.4"}
# {:cui=>"C0410005", :therapeuticarea=>"Nodular fasciitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/M72.3"}
# Array
# {:cui=>"C0003175", :therapeuticarea=>"Anthrax", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A22"}
# {:cui=>"C0003175", :therapeuticarea=>"Anthrax, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/A22.9"}
# Array
# Array
# Array
# {:cui=>"C0011608", :therapeuticarea=>"Dermatitis herpetiformis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/L13.0"}
# Array
# Array
# Array
# {:cui=>"C0477317", :therapeuticarea=>"Other primary thrombocytopenia", :icd10=>"http://purl.bioontology.org/ontology/ICD10/D69.4"}
# Array
# {:cui=>"C0023281", :therapeuticarea=>"Leishmaniasis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B55"}
# {:cui=>"C0023281", :therapeuticarea=>"Leishmaniasis, unspecified", :icd10=>"http://purl.bioontology.org/ontology/ICD10/B55.9"}
# Array
# Array
# Array
# Array
# {:cui=>"C0009768", :therapeuticarea=>"Mucopurulent conjunctivitis", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H10.0"}
# Array
# Array
# {:cui=>"C0019112", :therapeuticarea=>"Haemorrhoids", :icd10=>"http://purl.bioontology.org/ontology/ICD10/I84"}
# Array
# {:cui=>"C0344297", :therapeuticarea=>"Choroidal degeneration", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H31.1"}
# Array
# {:cui=>"C0154893", :therapeuticarea=>"Hereditary choroidal dystrophy", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H31.2"}
# Array
# Array
# Array
# Array
# {:cui=>"C0155239", :therapeuticarea=>"Chronic inflammation of lacrimal passages", :icd10=>"http://purl.bioontology.org/ontology/ICD10/H04.4"}
# Array
