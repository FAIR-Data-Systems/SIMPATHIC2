# %% [markdown]
# # Use Monarch API
# going from a CUI to MONDO

# %%
puts `cat ./maps/2025-biovista-disease.map`
# Out:
# biovistaid,orphanet,label
# C0027126,http://www.orpha.net/ORDO/Orphanet_273,MYOTONIC DYSTROPHY TYPE 1
# C0349653,http://www.orpha.net/ORDO/Orphanet_79318,PMM2-CDG
# C0023264,http://www.orpha.net/ORDO/Orphanet_506,LEIGH SYNDROME
# C0268467,http://www.orpha.net/ORDO/Orphanet_2102,GTPCH DEFICIENCY
# C0268631, http://www.orpha.net/ORDO/Orphanet_22,SSADH DEFICIENCY
# C0043459,http://www.orpha.net/ORDO/Orphanet_912,ZELLWEGER SYNDROME
# C0751882,http://www.orpha.net/ORDO/Orphanet_590,CONGENITAL MYASTHENIC SYNDROME

# %%
#!/usr/bin/env ruby

require 'csv'
require 'rest-client'
require 'json'
require 'uri'

# Configuration
INPUT_FILE       = './maps/2025-biovista-disease.map'
OUTPUT_FILE      = "./maps/2026-biovista-disease-mondo.map"
NO_MATCH_FILE    = './maps/2026-possible-phenotype-cuis.csv'

unless File.exist?(INPUT_FILE)
  abort "Error: #{INPUT_FILE} not found!"
end

# Read CSV and collect CUIs
rows = CSV.read(INPUT_FILE, headers: true)
cuis = rows.map { |row| row['biovista_umls'].strip }
puts cuis.size
if cuis.empty?
  abort "Error: No CUIs found in #{INPUT_FILE}"
end

warn "cuis #{cuis}"
# Build query parameters for Monarch API
params = {
  format: 'json',
  limit:  20,
  offset: 0
}
entity_ids = ""
cuis.each do |cui|
  entity_ids += "entity_id=UMLS:#{cui}"
  entity_ids += "&"
end

# Make the request using RestClient
puts "Querying Monarch API for #{cuis.size} CUIs..."
# https://api-v3.monarchinitiative.org/v3/api/mappings?
# entity_id=UMLS%3AC0019247&entity_id=UMLS%3AC0087012&entity_id=UMLS%3AC0752120&format=json&limit=20&offset=0

response = RestClient.get(
  "https://api-v3.monarchinitiative.org/v3/api/mappings?#{entity_ids}format=json&limit=500&offset=0",
)
warn response.request.url

data = JSON.parse(response.body)
warn JSON.pretty_generate(response.body)

# Map CUI → MONDO ID
mondo_map = {}
data['items'].each do |item|
  if item['object_id'] =~ /^UMLS:(C\d+)/
    cui = $1
    mondo_id = item['subject_id']  # e.g. "MONDO:0018940"
    mondo_map[cui] = mondo_id
  end
end

# Process rows
output_rows    = []
no_match_rows  = []

rows.each do |row|
  cui = row['biovista_umls'].strip
  if (mondo_id = mondo_map[cui])
    # BioPortal PURL format
    row['mondo'] = "http://purl.obolibrary.org/obo/#{mondo_id.gsub(':', '_')}"
    output_rows << row
  else
    no_match_rows << row
  end
end

# Write output CSV (with mondo column)
headers = rows.headers + ['mondo']
CSV.open(OUTPUT_FILE, 'w', write_headers: true, headers: headers) do |csv|
  output_rows.each { |row| csv << row }
end
puts "Wrote #{output_rows.size} rows with MONDO mappings to #{OUTPUT_FILE}"

# Write unmatched rows
if no_match_rows.any?
  CSV.open(NO_MATCH_FILE, 'w', write_headers: true, headers: rows.headers) do |csv|
    no_match_rows.each { |row| csv << row }
  end
  puts "Wrote #{no_match_rows.size} unmatched rows to #{NO_MATCH_FILE}"
else
  puts "All CUIs found a MONDO match!"
end
# Out:
# (irb):8: warning: already initialized constant Object::INPUT_FILE
# (irb):8: warning: previous definition of INPUT_FILE was here
# (irb):9: warning: already initialized constant Object::OUTPUT_FILE
# (irb):9: warning: previous definition of OUTPUT_FILE was here
# (irb):10: warning: already initialized constant Object::NO_MATCH_FILE
# (irb):10: warning: previous definition of NO_MATCH_FILE was here
# 11
# cuis ["C0027126", "C0349653", "C0023264", "C0268467", "C0268631", "C0043459", "C0751882", "C1849508", "C0024408", "C0268595", "C2931891"]
# Querying Monarch API for 11 CUIs...
# https://api-v3.monarchinitiative.org/v3/api/mappings?entity_id=UMLS:C0027126&entity_id=UMLS:C0349653&entity_id=UMLS:C0023264&entity_id=UMLS:C0268467&entity_id=UMLS:C0268631&entity_id=UMLS:C0043459&entity_id=UMLS:C0751882&entity_id=UMLS:C1849508&entity_id=UMLS:C0024408&entity_id=UMLS:C0268595&entity_id=UMLS:C2931891&format=json&limit=500&offset=0
# "{\"limit\":500,\"offset\":0,\"total\":10,\"items\":[{\"subject_id\":\"MONDO:0007182\",\"subject_label\":\"Machado-Joseph disease\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0024408\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"12a32e50-58ca-4ac2-95d1-9169acc11cf2\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0008907\",\"subject_label\":\"PMM2-congenital disorder of glycosylation\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0349653\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"91ddf207-705a-4ad8-a7f0-31ad38236f4b\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0009281\",\"subject_label\":\"glutaryl-CoA dehydrogenase deficiency\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0268595\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"70951e50-ea08-4905-a219-27cdb92339f0\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0009723\",\"subject_label\":\"Leigh syndrome\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C2931891\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"948c6110-f074-4869-8e48-3ce85e9a5554\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0009945\",\"subject_label\":\"pyridoxine-dependent epilepsy\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C1849508\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"c61babd9-eed2-4196-bfeb-6c29eaf6da8c\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0010083\",\"subject_label\":\"succinic semialdehyde dehydrogenase deficiency\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0268631\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"ac04a384-3ee7-491c-aa92-5aa6bb904460\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0016107\",\"subject_label\":\"myotonic dystrophy\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0027126\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"28fe6311-0820-46bc-9ba9-d64127d92896\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0018940\",\"subject_label\":\"congenital myasthenic syndrome\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0751882\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"93c24067-715b-4a9b-bfd6-31485726a7cf\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0019609\",\"subject_label\":\"Zellweger spectrum disorders\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0043459\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"3040b20e-fea7-46d8-9f04-326044c4ec6d\",\"mapping_source\":[\"mondo\"],\"highlighting\":null},{\"subject_id\":\"MONDO:0100184\",\"subject_label\":\"GTP cyclohydrolase I deficiency\",\"predicate_id\":\"skos:exactMatch\",\"object_id\":\"UMLS:C0268467\",\"object_label\":null,\"mapping_justification\":\"semapv:UnspecifiedMatching\",\"id\":\"3bc1417b-d767-4677-9711-d5f08368d67e\",\"mapping_source\":[\"mondo\"],\"highlighting\":null}]}"
# Wrote 10 rows with MONDO mappings to ./maps/2026-biovista-disease-mondo.map
# Wrote 1 unmatched rows to ./maps/2026-possible-phenotype-cuis.csv

# %% [markdown]
# # Comments
#
# C0023264,http://www.orpha.net/ORDO/Orphanet_506,http://purl.bioontology.org/ontology/SNOMEDCT/29570005,LEIGH SYNDROME
#
# This UMLS CUI has a synonym:  UMLS:C2931891
#
# I have added this to the main list of UMLS CUIs so that I get all 10, but this was a manual update to harmonize with MONARCH
