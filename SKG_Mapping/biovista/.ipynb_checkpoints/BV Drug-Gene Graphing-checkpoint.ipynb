# %%
puts `ls -l`
# Out:
# total 620
# -rw-rw-r-- 1 osboxes osboxes 259423 May 29 19:23 biovista-diseases-2025.ipynb
# -rw-rw-r-- 1 osboxes osboxes  66941 Jun  4 15:25 biovista-drug-2025.ipynb
# -rw-rw-r-- 1 osboxes osboxes  49944 May 29 17:37 biovista-gene-2025.ipynb
# -rw-rw-r-- 1 osboxes osboxes 145025 Jun  4 17:16 biovista-pathways-2025.ipynb
# -rw-rw-r-- 1 osboxes osboxes  31822 Jun  4 15:38 biovista-phenotypes.ipynb
# -rw-rw-r-- 1 osboxes osboxes  18570 Jul  1 10:51 BV Drug-Disease Graphing.ipynb
# -rw-rw-r-- 1 osboxes osboxes  26990 Jul  1 11:46 BV Drug-Gene Graphing.ipynb
# drwxrwxr-x 2 osboxes osboxes   4096 Jun  4 15:37 deprecated
# -rw-rw-r-- 1 osboxes osboxes   1282 May 29 21:19 drug mapping strategy
# drwxrwxr-x 2 osboxes osboxes   4096 Jun  4 16:05 maps
# drwxrwxr-x 2 osboxes osboxes   4096 May 22 16:58 maps backup
# drwxrwxr-x 2 osboxes osboxes   4096 Jun  4 17:07 raw_data

# %%
puts `head -2 ./raw_data/bv-kg-20250225.large`
# Out:
# source_1	id_1	type_1	name_1	source_2	id_2	type_2	name_2	score	url
# UMLS:Disease or Syndrome:MSH	C0268631	Disease	SSADH Deficiency	HP:human_phenotype	HP:0001263	Human Phenotype	Global developmental delay	0.0501869	https://www.biovista.com/db/link/%5B%5B%22Disease%7CSSADH%20Deficiency%22%5D,%20%5B%22Human%20Phenotype%7CGlobal%20developmental%20delay%22%5D%5D?strength-weight-map=%257B%2522MEDLINE_STRENGTH_AB%2522:1.0,%2522HPO%2522:100.0%257D

# %%
require 'csv'
drugs = {}
sourcesleft = {}
sourcesright = {}
CSV.foreach('./raw_data/bv-kg-20250225.large', col_sep: "\t", quote_char: '"', liberal_parsing: true, headers: true) do |row|
  sourcesleft[row["type_1"]] = 1
  sourcesright[row["type_2"]] = 1
end
puts sourcesleft.keys
puts
puts sourcesright.keys
# Out:
# Disease
# Pathway
# Drug
# Human Phenotype
# Gene
#
# Human Phenotype
# Gene
# Pathway
# Drug

# %%
puts `head -5 ./maps/2025-biovista-drugs.map`
# Out:
# biovista_meshid,biovista_label,CID,IUPACname
# http://purl.bioontology.org/ontology/MESH/D005680,gamma-Aminobutyric Acid,119,gamma-Aminobutyric Acid
# http://purl.bioontology.org/ontology/MESH/D012978,Sodium Oxybate,23663870,Sodium Oxybate
# http://purl.bioontology.org/ontology/MESH/D020888,Vigabatrin,5665,Vigabatrin
# http://purl.bioontology.org/ontology/MESH/C066471,NCS 382,3613485,NCS 382

# %% [markdown]
# # genes have two sources
#
# biovista-genes  are from NCBI and UniProt
#
# and
#
# biovista-mesh (these are mostly gene categories not genes...)
#
# Handled separately

# %%
puts `head -5 ./maps/2025-biovista-genes.map`
# Out:
# bv_geneid,bv_label,geneid,protein,recommended_full,taxon
# 11758,GPx,http://purl.uniprot.org/geneid/11758,http://purl.uniprot.org/uniprot/D3Z0Y2,Peroxiredoxin-6,http://purl.uniprot.org/taxonomy/10090
# 11758,GPx,http://purl.uniprot.org/geneid/11758,http://purl.uniprot.org/uniprot/O08709,Peroxiredoxin-6,http://purl.uniprot.org/taxonomy/10090
# 11758,GPx,http://purl.uniprot.org/geneid/11758,http://purl.uniprot.org/uniprot/Q6GT24,Peroxiredoxin-6,http://purl.uniprot.org/taxonomy/10090
# 1213,HC,http://purl.uniprot.org/geneid/1213,http://purl.uniprot.org/uniprot/A0A087WVQ6,Clathrin heavy chain,http://purl.uniprot.org/taxonomy/9606

# %%
require 'linkeddata'
require 'rdf/nquads'
require 'csv'

graphing_errors = File.open('./graph/drug-gene-errors.txt', 'w') 

# Define namespaces
SIMPATHIC = RDF::Vocabulary.new('urn:simpathic:')
RDFS = RDF::Vocabulary.new('http://www.w3.org/2000/01/rdf-schema#')

# Read input files
drug_mappings = CSV.read('./maps/2025-biovista-drugs.map', headers: true)
gene_mappings = CSV.read('./maps/2025-biovista-genes.map', headers: true)


failures = {}
# Process each entity relation

# refresh
f = File.open('./graph/biovista_drug-gene.nq', 'w')
f.close
    
recordcount = 0
CSV.foreach('./raw_data/bv-kg-20250225.large', col_sep: "\t", quote_char: '"', 
  liberal_parsing: true, headers: true) do |row|
    
        # Disease
        # Pathway
        # Drug
        # Human Phenotype
        # Gene
  next unless row['type_1'] == "Drug" or row['type_2'] == "Drug"
  next unless row['type_1'] == "Gene" or row['type_2'] == "Gene"
  if row['type_1'] == "Drug"
    drug_id = row['id_1']
    gene_id = row['id_2']  # gene ids from NCBI are only numerical, from MeSH have a letter
  else
    drug_id = row['id_2']
    gene_id = row['id_1']
  end

  score = row['score']
  evidence = row['url']
    
  # Find corresponding mappings
  
  # mesh is going to be differnt from NCBI
  next if gene_id =~ /[A-Z]/  # this is a MeSH id, so we can't deal with it here

    recordcount = recordcount + 1
    warn "drug #{drug_id} gene #{gene_id}" if (recordcount) % 5000 == 0  # log every 5000 records because the notebook gets overloaded

#   warn "searching for #{drug_id}"
# biovista_meshid,biovista_label,CID,IUPACname
# http://purl.bioontology.org/ontology/MESH/D005680,gamma-Aminobutyric Acid,119,gamma-Aminobutyric Acid
  # Find corresponding mappings
  drug = drug_mappings.find { |d| d['biovista_meshid'] =~ /\/#{drug_id}/ }

  gene = gene_mappings.find { |d| d['bv_geneid'] == gene_id }
  
#     warn "found #{drug}"
  unless drug
    next if failures[drug_id]
    failures[drug_id] = 1
    warn "drug lookup failed #{drug_id}"
    graphing_errors.write "drug lookup failed #{drug_id}\n"
    next
  end
  unless gene
    next if failures[gene_id]
    failures[gene_id] = 1
    warn "gene lookup failed #{gene_id}"
    graphing_errors.write "gene lookup failed #{gene_id}\n"
    next
  end
  
  # Extract relevant IDs and labels
  # biovista_meshid,biovista_label,CID,IUPACname
  # http://purl.bioontology.org/ontology/MESH/D005680,gamma-Aminobutyric Acid,119,4-aminobutanoic acid
  pubchem_uri = RDF::URI.new("https://pubchem.ncbi.nlm.nih.gov/compound/#{drug['CID']}")
  pubchem_type = RDF::URI.new("http://semanticscience.org/resource/CHEMINF_000302")
  pubchem_label =  RDF::Literal.new("PubChem Identifier")
  pubchem_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Drug")
  biovista_drug_label = RDF::Literal.new(drug['biovista_label'])
  iupac_drug_label = RDF::Literal.new(drug['IUPACname'])

  #   bv_geneid,bv_label,geneid,protein,recommended_full,taxon
  # 11758,GPx,http://purl.uniprot.org/geneid/11758,http://purl.uniprot.org/uniprot/D3Z0Y2,Peroxiredoxin-6,http://purl.uniprot.org/taxonomy/10090
  gene_uri = RDF::URI.new(gene['geneid'])
  gene_type = RDF::URI.new("http://edamontology.org/data_1027")
  gene_label =  RDF::Literal.new("NCBI/UniProt Gene Identifier")
  gene_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Gene")
  biovista_gene_label = RDF::Literal.new(gene['bv_label'])

  
  protein_uri = RDF::URI.new(gene['protein'])
  protein_type = RDF::URI.new("http://edamontology.org/data_2291")
  protein_label =  RDF::Literal.new("UniProt Identifier")
  protein_core_type = RDF::URI.new("https://w3id.org/biolink/vocab/Protein")
  biovista_protein_label = RDF::Literal.new(gene['recommended_full'])
    
  taxon = RDF::URI.new(gene['taxon'])
  
  # Create context URI
  context_uri = RDF::URI.new("urn:simpathic:context:#{drug_id}_#{gene_id}")
  general_context = RDF::URI.new("urn:simpathic:context:all_metadata")

  # Create RDF repository (need to do this each time, since there are hundreds of thousands of lines, and the graph gets too big for memory)
  graph = RDF::Repository.new
    
  # Add quads to graph using RDF::Statement
  graph << RDF::Statement.new(pubchem_uri, SIMPATHIC['associated-with'],gene_uri , graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri, SIMPATHIC['associated-with'], pubchem_uri, graph_name: context_uri)
  
  graph << RDF::Statement.new(pubchem_uri,  RDFS.label,     biovista_drug_label, graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  RDFS.label,     iupac_drug_label, graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  RDF.type,       pubchem_type,          graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  RDF.type,       pubchem_core_type,             graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_type, RDFS.label,     RDF::Literal.new("PubChem"), graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_core_type, RDFS.label,     RDF::Literal.new("Drug"), graph_name: context_uri)
  graph << RDF::Statement.new(pubchem_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{drug_id}"), graph_name: context_uri)
  
  graph << RDF::Statement.new(gene_uri,  RDFS.label,       biovista_gene_label , graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  RDF.type,         gene_type, graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  RDF.type,         gene_core_type, graph_name: context_uri)
  graph << RDF::Statement.new(gene_type, RDFS.label,       RDF::Literal.new("NCBI Gene"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_core_type, RDFS.label,  RDF::Literal.new("Gene"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{gene_id}"), graph_name: context_uri)
  graph << RDF::Statement.new(gene_uri,  SIMPATHIC['in-taxon'], taxon, graph_name: context_uri)
  

  graph << RDF::Statement.new(pubchem_uri, SIMPATHIC['associated-with'], protein_uri, graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri, SIMPATHIC['associated-with'], pubchem_uri , graph_name: context_uri)
  
  graph << RDF::Statement.new(protein_uri,  RDFS.label,       biovista_protein_label , graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  RDF.type,         protein_type, graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  RDF.type,         protein_core_type, graph_name: context_uri)
  graph << RDF::Statement.new(protein_type, RDFS.label,       RDF::Literal.new("UniProt"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_core_type, RDFS.label,  RDF::Literal.new("Protein"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  SIMPATHIC['original-id'], RDF::Literal.new("#{gene_id}"), graph_name: context_uri)
  graph << RDF::Statement.new(protein_uri,  SIMPATHIC['in-taxon'], taxon, graph_name: context_uri)

  
  graph << RDF::Statement.new(context_uri, SIMPATHIC['skg-source'], RDF::Literal.new("Biovista"),  graph_name: general_context)
  graph << RDF::Statement.new(context_uri, SIMPATHIC['evidence'], RDF::URI.new(evidence),  graph_name: general_context)
  graph << RDF::Statement.new(context_uri, SIMPATHIC['score'], RDF::Literal.new(score),  graph_name: general_context)


#   warn "graph #{context_uri} built"
  # Write RDF to file in N-Quads format
  File.open('./graph/biovista_drug-gene.nq.large', 'a') do |f|
    RDF::Writer.for(:nquads).new(f) do |writer|
      writer << graph
    end
  end
#   warn "end graph writing"

end
warn "completed graph building"
graphing_errors.close

puts "RDF quads written"
# Out:
# drug lookup failed 4901d7c1b4e2aef6913d880bfc91240e
# drug lookup failed C000600259
# drug lookup failed C000606551
# drug lookup failed C000711730
# drug lookup failed C003223
# drug lookup failed C003402
# drug lookup failed C003800
# drug lookup failed C004479
# drug lookup failed C004691
# drug lookup failed C004742
# drug lookup failed C004999
# drug lookup failed C005390
# drug lookup failed C008088
# drug lookup failed C009265
# drug lookup failed C009288
# drug lookup failed C009365
# drug lookup failed C010597
# drug lookup failed C010643
# drug lookup failed C010680
# drug lookup failed C010739
# drug lookup failed C013216
# drug lookup failed C013579
# drug lookup failed C015392
# drug lookup failed C016030
# drug lookup failed C016766
# drug lookup failed C020549
# drug lookup failed C020804
# drug lookup failed C021279
# drug lookup failed C023863
# drug lookup failed C024989
# drug lookup failed C027576
# drug lookup failed C030123
# drug lookup failed C030571
# drug lookup failed C030614
# drug lookup failed C031149
# drug lookup failed C031215
# drug C031215 gene 2330
# drug lookup failed C031349
# drug lookup failed C031385
# drug lookup failed C032523
# drug lookup failed C032727
# drug lookup failed C033110
# drug lookup failed C033668
# drug lookup failed C033891
# drug lookup failed C036309
# drug lookup failed C036619
# drug lookup failed C037476
# drug lookup failed C038131
# drug lookup failed C039304
# drug lookup failed C040048
# drug lookup failed C043437
# drug lookup failed C044447
# drug lookup failed C045651
# drug lookup failed C049853
# drug lookup failed C050199
# drug lookup failed C051360
# drug lookup failed C054207
# drug lookup failed C055267
# drug lookup failed C055743
# drug lookup failed C056165
# drug lookup failed C056723
# drug lookup failed C059659
# drug lookup failed C059896
# drug lookup failed C060152
# drug lookup failed C065640
# drug lookup failed C066026
# drug lookup failed C066430
# drug lookup failed C066471
# drug lookup failed C067713
# drug lookup failed C068239
# drug lookup failed C072553
# drug lookup failed C075773
# drug lookup failed C079148
# drug lookup failed C079420
# drug lookup failed C081643
# drug lookup failed C084711
# drug lookup failed C085075
# drug lookup failed C090092
# drug lookup failed C091590
# drug lookup failed C092292
# drug lookup failed C100195
# drug lookup failed C100573
# drug lookup failed C103494
# drug C103494 gene 1756
# drug lookup failed C104196
# drug lookup failed C105051
# drug lookup failed C401859
# drug lookup failed C487773
# drug lookup failed C520571
# drug lookup failed C522181
# drug lookup failed C522667
# drug lookup failed C541932
# drug lookup failed C545824
# drug lookup failed C549445
# drug lookup failed C551441
# drug lookup failed C570710
# drug lookup failed D000068180
# drug lookup failed D000068258
# drug lookup failed D000068579
# drug lookup failed D000068580
# drug lookup failed D000068756
# drug lookup failed D000068800
# drug lookup failed D000068818
# drug lookup failed D000069056
# drug lookup failed D000069283
# drug lookup failed D000069349
# drug lookup failed D000069470
# drug lookup failed D000069552
# drug lookup failed D000069896
# drug lookup failed D000075462
# drug lookup failed D000077122
# drug lookup failed D000077123
# drug lookup failed D000077146
# drug lookup failed D000077149
# drug lookup failed D000077150
# drug lookup failed D000077185
# drug lookup failed D000077206
# drug lookup failed D000077208
# drug lookup failed D000077213
# drug D000077213 gene 351
# drug lookup failed D000077236
# drug lookup failed D000077237
# drug lookup failed D000077276
# drug lookup failed D000077287
# drug lookup failed D000077300
# drug lookup failed D000077408
# drug lookup failed D000077423
# drug lookup failed D000077443
# drug lookup failed D000077485
# drug lookup failed D000077487
# drug lookup failed D000077770
# drug lookup failed D000078305
# drug lookup failed D000078306
# drug lookup failed D000078328
# drug lookup failed D000078330
# drug lookup failed D000078785
# drug lookup failed D000082
# drug lookup failed D000086
# drug lookup failed D000086663
# drug lookup failed D000089983
# drug lookup failed D000108
# drug lookup failed D000109
# drug lookup failed D000111
# drug lookup failed D000324
# drug lookup failed D000404
# drug lookup failed D000420
# drug lookup failed D000515
# drug lookup failed D000547
# drug D000547 gene 718
# drug lookup failed D000590
# drug lookup failed D000628
# drug lookup failed D000640
# drug lookup failed D000804
# drug lookup failed D000968
# drug lookup failed D000990
# drug lookup failed D001058
# drug lookup failed D001205
# drug lookup failed D001241
# drug lookup failed D001279
# drug lookup failed D001285
# drug lookup failed D001418
# drug lookup failed D001430
# drug lookup failed D001546
# drug lookup failed D001622
# drug lookup failed D001629
# drug lookup failed D001647
# drug lookup failed D001663
# drug lookup failed D001905
# drug lookup failed D001920
# drug D001920 gene 4915
# drug lookup failed D001965
# drug lookup failed D001973
# drug lookup failed D002045
# drug lookup failed D002047
# drug lookup failed D002065
# drug lookup failed D002110
# drug lookup failed D002220
# drug lookup failed D002230
# drug lookup failed D002248
# drug lookup failed D002266
# drug lookup failed D002331
# drug lookup failed D002364
# drug lookup failed D002635
# drug lookup failed D002738
# drug lookup failed D002746
# drug lookup failed D002753
# drug lookup failed D002772
# drug lookup failed D002793
# drug lookup failed D002794
# drug D002794 gene 5649
# drug lookup failed D002939
# drug lookup failed D002945
# drug lookup failed D002953
# drug lookup failed D002955
# drug lookup failed D002981
# drug lookup failed D002994
# drug lookup failed D002995
# drug lookup failed D002997
# drug lookup failed D002998
# drug lookup failed D003042
# drug lookup failed D003091
# drug lookup failed D003176
# drug lookup failed D003181
# drug lookup failed D003345
# drug lookup failed D003346
# drug lookup failed D003348
# drug lookup failed D003474
# drug lookup failed D003513
# drug lookup failed D003520
# drug D003520 gene 9370
# drug lookup failed D003543
# drug lookup failed D003609
# drug lookup failed D003620
# drug lookup failed D003687
# drug lookup failed D003847
# drug lookup failed D003871
# drug lookup failed D003891
# drug lookup failed D003907
# drug lookup failed D003913
# drug lookup failed D003915
# drug lookup failed D003975
# drug lookup failed D003981
# drug lookup failed D004002
# drug lookup failed D004008
# drug lookup failed D004121
# drug lookup failed D004164
# drug lookup failed D004295
# drug lookup failed D004298
# drug lookup failed D004317
# drug D004317 gene 10763
# drug lookup failed D004318
# drug lookup failed D004491
# drug lookup failed D004656
# drug lookup failed D004745
# drug lookup failed D004809
# drug lookup failed D004837
# drug lookup failed D004917
# drug lookup failed D004958
# drug lookup failed D004986
# drug lookup failed D005013
# drug lookup failed D005027
# drug lookup failed D005033
# drug lookup failed D005283
# drug lookup failed D005424
# drug lookup failed D005442
# drug lookup failed D005472
# drug lookup failed D005473
# drug lookup failed D005486
# drug lookup failed D005492
# drug D005492 gene 170574
# drug lookup failed D005557
# drug lookup failed D005620
# drug lookup failed D005640
# drug lookup failed D005680
# drug lookup failed D005934
# drug lookup failed D005947
# drug lookup failed D006063
# drug lookup failed D006065
# drug lookup failed D006220
# drug lookup failed D006221
# drug lookup failed D006493
# drug lookup failed D006632
# drug lookup failed D006820
# drug lookup failed D006854
# drug lookup failed D006861
# drug D006861 gene 107826841
# drug lookup failed D006862
# drug lookup failed D006916
# drug lookup failed D007072
# drug lookup failed D007074
# drug lookup failed D007075
# drug lookup failed D007099
# drug lookup failed D007140
# drug lookup failed D007213
# drug lookup failed D007252
# drug lookup failed D007294
# drug lookup failed D007371
# drug lookup failed D007372
# drug lookup failed D007472
# drug lookup failed D007530
# drug lookup failed D007538
# drug lookup failed D007545
# drug lookup failed D007608
# drug lookup failed D007612
# drug lookup failed D007616
# drug D007616 gene 3569
# drug lookup failed D007649
# drug lookup failed D007736
# drug lookup failed D007792
# drug lookup failed D007976
# drug lookup failed D007980
# drug lookup failed D007987
# drug lookup failed D008012
# drug lookup failed D008063
# drug lookup failed D008110
# drug lookup failed D008135
# drug lookup failed D008139
# drug lookup failed D008148
# drug lookup failed D008238
# drug lookup failed D008276
# drug lookup failed D008454
# drug lookup failed D008550
# drug lookup failed D008559
# drug lookup failed D008614
# drug lookup failed D008687
# drug lookup failed D008691
# drug lookup failed D008694
# drug lookup failed D008727
# drug D008727 gene 403164
# drug lookup failed D008751
# drug lookup failed D008774
# drug lookup failed D008775
# drug lookup failed D008787
# drug lookup failed D008801
# drug lookup failed D008874
# drug lookup failed D009020
# drug lookup failed D009113
# drug lookup failed D009118
# drug lookup failed D009173
# drug lookup failed D009270
# drug lookup failed D009388
# drug lookup failed D009525
# drug lookup failed D009536
# drug lookup failed D009538
# drug lookup failed D009543
# drug lookup failed D009555
# drug lookup failed D009567
# drug lookup failed D009569
# drug lookup failed D009609
# drug D009609 gene 1119
# drug lookup failed D009638
# drug lookup failed D009840
# drug lookup failed D010042
# drug lookup failed D010197
# drug lookup failed D010205
# drug lookup failed D010281
# drug lookup failed D010396
# drug lookup failed D010406
# drug lookup failed D010419
# drug lookup failed D010433
# drug lookup failed D010634
# drug lookup failed D010672
# drug lookup failed D010725
# drug lookup failed D010830
# drug lookup failed D010835
# drug lookup failed D011112
# drug lookup failed D011113
# drug lookup failed D011189
# drug lookup failed D011190
# drug lookup failed D011239
# drug D011239 gene 5610
# drug lookup failed D011241
# drug lookup failed D011342
# drug lookup failed D011374
# drug lookup failed D011433
# drug lookup failed D011464
# drug lookup failed D011479
# drug lookup failed D011486
# drug lookup failed D011729
# drug lookup failed D011730
# drug lookup failed D011732
# drug lookup failed D011733
# drug lookup failed D011736
# drug lookup failed D011745
# drug lookup failed D011794
# drug lookup failed D011802
# drug lookup failed D011803
# drug lookup failed D012110
# drug lookup failed D012254
# drug lookup failed D012256
# drug lookup failed D012312
# drug lookup failed D012402
# drug lookup failed D012450
# drug D012450 gene 3639366
# drug lookup failed D012642
# drug lookup failed D012643
# drug lookup failed D012701
# drug lookup failed D012978
# drug lookup failed D013004
# drug lookup failed D013012
# drug lookup failed D013024
# drug lookup failed D013134
# drug lookup failed D013148
# drug lookup failed D013307
# drug lookup failed D013311
# drug lookup failed D013390
# drug lookup failed D013420
# drug lookup failed D013482
# drug lookup failed D013656
# drug lookup failed D013739
# drug lookup failed D013747
# drug lookup failed D013752
# drug lookup failed D013763
# drug D013763 gene 125772317
# drug lookup failed D013806
# drug lookup failed D013831
# drug lookup failed D013835
# drug lookup failed D013838
# drug lookup failed D013874
# drug lookup failed D013917
# drug lookup failed D013973
# drug lookup failed D013974
# drug lookup failed D014044
# drug lookup failed D014046
# drug lookup failed D014212
# drug lookup failed D014284
# drug lookup failed D014295
# drug lookup failed D014364
# drug lookup failed D014403
# drug lookup failed D014415
# drug lookup failed D014439
# drug lookup failed D014527
# drug lookup failed D014635
# drug D014635 gene 1822
# drug lookup failed D014667
# drug lookup failed D014673
# drug lookup failed D014750
# drug lookup failed D014801
# drug lookup failed D014805
# drug lookup failed D014807
# drug lookup failed D014810
# drug lookup failed D014812
# drug lookup failed D014859
# drug lookup failed D014994
# drug lookup failed D015029
# drug lookup failed D015034
# drug lookup failed D015074
# drug lookup failed D015095
# drug lookup failed D015232
# drug lookup failed D015237
# drug lookup failed D015283
# drug lookup failed D015320
# drug lookup failed D015632
# drug lookup failed D015662
# drug lookup failed D015739
# drug D015739 gene 14599
# drug lookup failed D015742
# drug lookup failed D015759
# drug lookup failed D015761
# drug lookup failed D015922
# drug lookup failed D016202
# drug lookup failed D016291
# drug lookup failed D016559
# drug lookup failed D016572
# drug lookup failed D016651
# drug lookup failed D016756
# drug lookup failed D017239
# drug lookup failed D017292
# drug lookup failed D017293
# drug lookup failed D017311
# drug lookup failed D017485
# drug lookup failed D017780
# drug lookup failed D017830
# drug lookup failed D017963
# drug lookup failed D018020
# drug lookup failed D018021
# drug lookup failed D018350
# drug D018350 gene 1738
# drug lookup failed D018664
# drug lookup failed D018723
# drug lookup failed D018750
# drug lookup failed D018967
# drug lookup failed D019207
# drug lookup failed D019274
# drug lookup failed D019287
# drug lookup failed D019297
# drug lookup failed D019308
# drug lookup failed D019331
# drug lookup failed D019344
# drug lookup failed D019382
# drug lookup failed D019690
# drug lookup failed D019782
# drug lookup failed D019788
# drug lookup failed D019791
# drug lookup failed D019793
# drug lookup failed D019797
# drug lookup failed D019826
# drug lookup failed D019840
# drug D019840 gene 56729
# drug lookup failed D019904
# drug lookup failed D020123
# drug lookup failed D020148
# drug lookup failed D020156
# drug lookup failed D020280
# drug lookup failed D020367
# drug lookup failed D020888
# drug lookup failed D020891
# drug lookup failed D020909
# drug lookup failed D022242
# drug lookup failed D024502
# drug lookup failed D025101
# drug lookup failed D037102
# drug lookup failed D048271
# drug lookup failed D050759
# drug lookup failed D053491
# drug lookup failed D053590
# drug lookup failed D061466
# completed graph building
# RDF quads written
